# %% [markdown]
# ## Downloading Dependencies

# %%
# First, we need to install pycocotools. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.
# The version by default in Colab has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-bmsc18bu
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-bmsc18bu
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (57.0.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (0.29.23)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=263899 sha256=df2c49526f1363c5ec3a0a15b051e3aedadf4e8615f38ff71f35164fbe3009b2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8_f90y2i/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# Successfully installed pycocotools-2.0

# %%
import json
import math
import os
import random
import sys
import time

import numpy as np
import torch
import torch.utils.data
import torchvision

from PIL import Image, ImageDraw
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms
from torchvision.ops import batched_nms
from torchvision.transforms import functional as F

# %%
from typing import List, Tuple

import torchvision.models as models

from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

# %% [markdown]
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/utils.py` and `references/detection/coco_eval.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/coco_eval.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 29387, done.
# remote: Counting objects: 100% (1930/1930), done.
# remote: Compressing objects: 100% (502/502), done.
# remote: Total 29387 (delta 1447), reused 1841 (delta 1391), pack-reused 27457
# Receiving objects: 100% (29387/29387), 37.39 MiB | 26.96 MiB/s, done.
# Resolving deltas: 100% (22063/22063), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
import utils
from coco_eval import CocoEvaluator

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Object Detection Dataset
# We will be providing the base dataset that will be used for the first task of the Object Detection competition.

# %%
# You should have uploaded the training dataset onto your google drive.

base_folder = '/content/drive/MyDrive/TIL2021_CV' # Change this path to your folder for this competition
training_path = os.path.join(base_folder, "challenge_3_training_dataset.zip") # zip file for training dataset
training_path_2 = os.path.join(base_folder, "challenge_3_egg.zip")

# %%
# unzip the training dataset
# !unzip $training_path
# Out:
# Archive:  /content/drive/MyDrive/TIL2021_CV/challenge_3_training_dataset.zip
#    creating: challenge_3_training_dataset/
#   inflating: challenge_3_training_dataset/val.json
#   inflating: challenge_3_training_dataset/train.json
#   inflating: challenge_3_training_dataset/labels.json
#   inflating: challenge_3_training_dataset/CREDITS.txt
#    creating: challenge_3_training_dataset/images/
#   inflating: challenge_3_training_dataset/images/b17efa200ec83130.jpg
#   inflating: challenge_3_training_dataset/images/9749488a9461e86a.jpg
#   inflating: challenge_3_training_dataset/images/985b5a8ecc499c68.jpg
#   inflating: challenge_3_training_dataset/images/4c0e82ba040c279a.jpg
#   inflating: challenge_3_training_dataset/images/df16f10ddca78407.jpg
#   inflating: challenge_3_training_dataset/images/3fa9fe4f8445d16c.jpg
#   inflating: challenge_3_training_dataset/images/5fc0f5a22dfadde8.jpg
#   inflating: challenge_3_training_dataset/images/927779879f810605.jpg
#   inflating: challenge_3_training_dataset/images/01132ff663381d7c.jpg
#   inflating: challenge_3_training_dataset/images/49fcc0bfec890d22.jpg
#   inflating: challenge_3_training_dataset/images/89ca1ec2a4b32a58.jpg
#   inflating: challenge_3_training_dataset/images/04aa0b6cf11e6cda.jpg
#   inflating: challenge_3_training_dataset/images/af802bed383ca531.jpg
#   inflating: challenge_3_training_dataset/images/92609875bf3be0bc.jpg
#   inflating: challenge_3_training_dataset/images/0161198dcf6a0b69.jpg
#   inflating: challenge_3_training_dataset/images/02ee4cb7545f889b.jpg
#   inflating: challenge_3_training_dataset/images/1ef71265477dc47b.jpg
#   inflating: challenge_3_training_dataset/images/0f0063bf8c1ceb3f.jpg
#   inflating: challenge_3_training_dataset/images/237827d9bb734a5e.jpg
#   inflating: challenge_3_training_dataset/images/c0e767490b2a1050.jpg
#   inflating: challenge_3_training_dataset/images/9e50d37a7e879a2b.jpg
#   inflating: challenge_3_training_dataset/images/a9d8a51ecf0e7889.jpg
#   inflating: challenge_3_training_dataset/images/b2b0a167b021eea3.jpg
#   inflating: challenge_3_training_dataset/images/93194954e27d6d4e.jpg
#   inflating: challenge_3_training_dataset/images/21ad072c9c6423a9.jpg
#   inflating: challenge_3_training_dataset/images/b071e980dba12816.jpg
#   inflating: challenge_3_training_dataset/images/4e7969e707ad5913.jpg
#   inflating: challenge_3_training_dataset/images/2778eafa1929c917.jpg
#   inflating: challenge_3_training_dataset/images/7a1e6f5c41500f43.jpg
#   inflating: challenge_3_training_dataset/images/5a5a9396819e03ca.jpg
#   inflating: challenge_3_training_dataset/images/4c2c93a92244980e.jpg
#   inflating: challenge_3_training_dataset/images/134c0985e65c77cc.jpg
#   inflating: challenge_3_training_dataset/images/1864d4ac4ae13779.jpg
#   inflating: challenge_3_training_dataset/images/9558611708c8fd50.jpg
#   inflating: challenge_3_training_dataset/images/cc8848167bc4b299.jpg
#   inflating: challenge_3_training_dataset/images/3226a299bf13bc6a.jpg
#   inflating: challenge_3_training_dataset/images/687a3623e1a59a98.jpg
#   inflating: challenge_3_training_dataset/images/6359ceb7d02391bb.jpg
#   inflating: challenge_3_training_dataset/images/8562cc6664721d2c.jpg
#   inflating: challenge_3_training_dataset/images/3d88ba56b73bd854.jpg
#   inflating: challenge_3_training_dataset/images/cda706bdc55c4618.jpg
#   inflating: challenge_3_training_dataset/images/02fe950c629603b9.jpg
#   inflating: challenge_3_training_dataset/images/e7fc657c2887e9ac.jpg
#   inflating: challenge_3_training_dataset/images/32e348f0aec9fd4b.jpg
#   inflating: challenge_3_training_dataset/images/462aa20e35f9252d.jpg
#   inflating: challenge_3_training_dataset/images/985c262ac5dbcd09.jpg
#   inflating: challenge_3_training_dataset/images/0f9e40247ddf57e8.jpg
#   inflating: challenge_3_training_dataset/images/18df407b37b661f3.jpg
#   inflating: challenge_3_training_dataset/images/131cb9cb5b8842f8.jpg
#   inflating: challenge_3_training_dataset/images/99c700b98afe36ac.jpg
#   inflating: challenge_3_training_dataset/images/2965e9fb2814c4b7.jpg
#   inflating: challenge_3_training_dataset/images/169e72ff98b47646.jpg
#   inflating: challenge_3_training_dataset/images/ef75410a991b5baa.jpg
#   inflating: challenge_3_training_dataset/images/6f4828aebf9254a0.jpg
#   inflating: challenge_3_training_dataset/images/af480cc7db0ff65b.jpg
#   inflating: challenge_3_training_dataset/images/6f20247d5393c30d.jpg
#   inflating: challenge_3_training_dataset/images/c6fa2e7f08453d3a.jpg
#   inflating: challenge_3_training_dataset/images/7210e9497e1a5ae4.jpg
#   inflating: challenge_3_training_dataset/images/aea76768b94b6311.jpg
#   inflating: challenge_3_training_dataset/images/838bf98ae51789b8.jpg
#   inflating: challenge_3_training_dataset/images/740a8e51ae926ea9.jpg
#   inflating: challenge_3_training_dataset/images/ada83316560bbe8b.jpg
#   inflating: challenge_3_training_dataset/images/5006dcbabde3bf67.jpg
#   inflating: challenge_3_training_dataset/images/2873da6aae112a92.jpg
#   inflating: challenge_3_training_dataset/images/796a72f79b334037.jpg
#   inflating: challenge_3_training_dataset/images/bf416baab0b7e31d.jpg
#   inflating: challenge_3_training_dataset/images/917e3b8debae740f.jpg
#   inflating: challenge_3_training_dataset/images/0d0ffaae8cf01ae2.jpg
#   inflating: challenge_3_training_dataset/images/fff455b95086ef72.jpg
#   inflating: challenge_3_training_dataset/images/7933c07b3d312106.jpg
#   inflating: challenge_3_training_dataset/images/13c7975bb7d92a03.jpg
#   inflating: challenge_3_training_dataset/images/1f1fc33e657f13d2.jpg
#   inflating: challenge_3_training_dataset/images/272ac5d279e213e8.jpg
#   inflating: challenge_3_training_dataset/images/6a1792d3c76628e7.jpg
#   inflating: challenge_3_training_dataset/images/01928bb382020c06.jpg
#   inflating: challenge_3_training_dataset/images/75459aab90aeecac.jpg
#   inflating: challenge_3_training_dataset/images/83a6e2af3f249d28.jpg
#   inflating: challenge_3_training_dataset/images/0f4e052813f9456a.jpg
#   inflating: challenge_3_training_dataset/images/905db23d18181b10.jpg
#   inflating: challenge_3_training_dataset/images/9cca01340e303cc7.jpg
#   inflating: challenge_3_training_dataset/images/1626832202e8edcb.jpg
#   inflating: challenge_3_training_dataset/images/94c9ac53e77dadef.jpg
#   inflating: challenge_3_training_dataset/images/81fa18ed2c8a05ce.jpg
#   inflating: challenge_3_training_dataset/images/348995c49c137b71.jpg
#   inflating: challenge_3_training_dataset/images/2769d92e8b043b0c.jpg
#   inflating: challenge_3_training_dataset/images/1c3a820450b067e8.jpg
#   inflating: challenge_3_training_dataset/images/ccae37a741c8a7e6.jpg
#   inflating: challenge_3_training_dataset/images/6fc3551920c75313.jpg
#   inflating: challenge_3_training_dataset/images/0334e65bfe37bcb2.jpg
#   inflating: challenge_3_training_dataset/images/269571d77039af4f.jpg
#   inflating: challenge_3_training_dataset/images/e7e58802c854d72c.jpg
#   inflating: challenge_3_training_dataset/images/7d1dd8f8892844ba.jpg
#   inflating: challenge_3_training_dataset/images/b3faed8a3fd2ca5e.jpg
#   inflating: challenge_3_training_dataset/images/4dafe7233de034ad.jpg
#   inflating: challenge_3_training_dataset/images/2e01a5ea7d1a854c.jpg
#   inflating: challenge_3_training_dataset/images/5f5abb3842197900.jpg
#   inflating: challenge_3_training_dataset/images/afeeca47fcae19f9.jpg
#   inflating: challenge_3_training_dataset/images/dfc490f02bd3ccb5.jpg
#   inflating: challenge_3_training_dataset/images/0372323ed8f82a2c.jpg
#   inflating: challenge_3_training_dataset/images/19e9363909c3f86e.jpg
#   inflating: challenge_3_training_dataset/images/15c3662e3ea2fc12.jpg
#   inflating: challenge_3_training_dataset/images/dd0cb182b2d54a6a.jpg
#   inflating: challenge_3_training_dataset/images/6f51ecb5ef88f062.jpg
#   inflating: challenge_3_training_dataset/images/ddfa9c2dd32f4817.jpg
#   inflating: challenge_3_training_dataset/images/16f42c8d9bdf1ae5.jpg
#   inflating: challenge_3_training_dataset/images/0333e05c5dfea8ee.jpg
#   inflating: challenge_3_training_dataset/images/97684fac769964ac.jpg
#   inflating: challenge_3_training_dataset/images/00371870727e83d8.jpg
#   inflating: challenge_3_training_dataset/images/1596e3ac1713fc46.jpg
#   inflating: challenge_3_training_dataset/images/98cfb8c0a175c3a5.jpg
#   inflating: challenge_3_training_dataset/images/214b74cce47cf72d.jpg
#   inflating: challenge_3_training_dataset/images/a61673c2add4a4b2.jpg
#   inflating: challenge_3_training_dataset/images/1fca58217ec55f6e.jpg
#   inflating: challenge_3_training_dataset/images/87e39ea3d76c67f1.jpg
#   inflating: challenge_3_training_dataset/images/20cdaa2acfee401a.jpg
#   inflating: challenge_3_training_dataset/images/0c36e877a0940873.jpg
#   inflating: challenge_3_training_dataset/images/7216c47655729b8c.jpg
#   inflating: challenge_3_training_dataset/images/633b828f69434630.jpg
#   inflating: challenge_3_training_dataset/images/0101127511e36fe8.jpg
#   inflating: challenge_3_training_dataset/images/dcb3e17de80c00a6.jpg
#   inflating: challenge_3_training_dataset/images/8ad2ac81110f5b78.jpg
#   inflating: challenge_3_training_dataset/images/a28aa83c6252475c.jpg
#   inflating: challenge_3_training_dataset/images/e5e328e809bdccb3.jpg
#   inflating: challenge_3_training_dataset/images/ff59b0866a19cb43.jpg
#   inflating: challenge_3_training_dataset/images/9b5c48fb278a02c6.jpg
#   inflating: challenge_3_training_dataset/images/e66296a1c5fa9d37.jpg
#   inflating: challenge_3_training_dataset/images/3f742084247a1310.jpg
#   inflating: challenge_3_training_dataset/images/30f31f56a0e01b66.jpg
#   inflating: challenge_3_training_dataset/images/24ae2e3e03886bbd.jpg
#   inflating: challenge_3_training_dataset/images/24d918abcc9c101a.jpg
#   inflating: challenge_3_training_dataset/images/c9397580dd3fc08a.jpg
#   inflating: challenge_3_training_dataset/images/6e4bd77018e3c12f.jpg
#   inflating: challenge_3_training_dataset/images/4333157b6287b8a0.jpg
#   inflating: challenge_3_training_dataset/images/269c7275bbae9514.jpg
#   inflating: challenge_3_training_dataset/images/d8e1719bb7c1476e.jpg
#   inflating: challenge_3_training_dataset/images/93742d6d8d4569ef.jpg
#   inflating: challenge_3_training_dataset/images/b1adffb16c9e6245.jpg
#   inflating: challenge_3_training_dataset/images/359a721529c55a47.jpg
#   inflating: challenge_3_training_dataset/images/c1f91c6a07fc4604.jpg
#   inflating: challenge_3_training_dataset/images/c0903de35772c5f7.jpg
#   inflating: challenge_3_training_dataset/images/df528f1212e83eef.jpg
#   inflating: challenge_3_training_dataset/images/777609f1874e311c.jpg
#   inflating: challenge_3_training_dataset/images/9cb0c58734bee9dd.jpg
#   inflating: challenge_3_training_dataset/images/d2b8714af66a330a.jpg
#   inflating: challenge_3_training_dataset/images/394a61171ed36f6e.jpg
#   inflating: challenge_3_training_dataset/images/24dcd3a85e40f135.jpg
#   inflating: challenge_3_training_dataset/images/bc82b837b9bbef91.jpg
#   inflating: challenge_3_training_dataset/images/26aef4d67c728ecc.jpg
#   inflating: challenge_3_training_dataset/images/a6ea9da3a5b3c301.jpg
#   inflating: challenge_3_training_dataset/images/60886294eb29a292.jpg
#   inflating: challenge_3_training_dataset/images/416aa04ac5f58f81.jpg
#   inflating: challenge_3_training_dataset/images/e8204a293517c989.jpg
#   inflating: challenge_3_training_dataset/images/95af9fdc37bcf0de.jpg
#   inflating: challenge_3_training_dataset/images/013f30ffc32faba8.jpg
#   inflating: challenge_3_training_dataset/images/ed5ab804f9844111.jpg
#   inflating: challenge_3_training_dataset/images/4f5d071a64a0cbe1.jpg
#   inflating: challenge_3_training_dataset/images/1740ed089b7439c2.jpg
#   inflating: challenge_3_training_dataset/images/21d77eea384dfa8c.jpg
#   inflating: challenge_3_training_dataset/images/e7ebdef8d8463200.jpg
#   inflating: challenge_3_training_dataset/images/15dea08255fffc3a.jpg
#   inflating: challenge_3_training_dataset/images/66592e8299972d43.jpg
#   inflating: challenge_3_training_dataset/images/fbe2a617101b6057.jpg
#   inflating: challenge_3_training_dataset/images/e57f83299b6d1e24.jpg
#   inflating: challenge_3_training_dataset/images/01fb343ba58cdc3e.jpg
#   inflating: challenge_3_training_dataset/images/2650ad23548be324.jpg
#   inflating: challenge_3_training_dataset/images/11d819d39cd42fa6.jpg
#   inflating: challenge_3_training_dataset/images/e730dada2999d15c.jpg
#   inflating: challenge_3_training_dataset/images/04e682caca163aa1.jpg
#   inflating: challenge_3_training_dataset/images/37547ab19a05f4dc.jpg
#   inflating: challenge_3_training_dataset/images/ade3c127d4b21336.jpg
#   inflating: challenge_3_training_dataset/images/a78c35f1e8a94136.jpg
#   inflating: challenge_3_training_dataset/images/6e884856b3905c7f.jpg
#   inflating: challenge_3_training_dataset/images/d64d4a6cd777f0a0.jpg
#   inflating: challenge_3_training_dataset/images/4ff84c47cba2e720.jpg
#   inflating: challenge_3_training_dataset/images/2d0b43925c444321.jpg
#   inflating: challenge_3_training_dataset/images/a64643dfd866e35a.jpg
#   inflating: challenge_3_training_dataset/images/436ddf7893163049.jpg
#   inflating: challenge_3_training_dataset/images/b857f7d51d63f113.jpg
#   inflating: challenge_3_training_dataset/images/ed3ebf3858f412e4.jpg
#   inflating: challenge_3_training_dataset/images/066222d18d7b7023.jpg
#   inflating: challenge_3_training_dataset/images/6b2af4cdb3b9a4c5.jpg
#   inflating: challenge_3_training_dataset/images/2b19ff875d44c70f.jpg
#   inflating: challenge_3_training_dataset/images/81b27b757beb1004.jpg
#   inflating: challenge_3_training_dataset/images/b16cd50af4212804.jpg
#   inflating: challenge_3_training_dataset/images/2d7984e98028c7a4.jpg
#   inflating: challenge_3_training_dataset/images/c97d8b4086c4334b.jpg
#   inflating: challenge_3_training_dataset/images/109c3c4b29266e48.jpg
#   inflating: challenge_3_training_dataset/images/9c4399316b5c48e1.jpg
#   inflating: challenge_3_training_dataset/images/2f20ec292351feb0.jpg
#   inflating: challenge_3_training_dataset/images/03fb6bd0b8978d8c.jpg
#   inflating: challenge_3_training_dataset/images/6fc9cd821ef996a7.jpg
#   inflating: challenge_3_training_dataset/images/03c56b2d64f11eab.jpg
#   inflating: challenge_3_training_dataset/images/b9d4c952291b7d2e.jpg
#   inflating: challenge_3_training_dataset/images/716576725695e1ef.jpg
#   inflating: challenge_3_training_dataset/images/24f08ac615fe283f.jpg
#   inflating: challenge_3_training_dataset/images/10f1446edcd74759.jpg
#   inflating: challenge_3_training_dataset/images/e6de7146c5ff0fe5.jpg
#   inflating: challenge_3_training_dataset/images/0771b546893fc5dc.jpg
#   inflating: challenge_3_training_dataset/images/8994b2f25e09f294.jpg
#   inflating: challenge_3_training_dataset/images/2274655b4dd74b7f.jpg
#   inflating: challenge_3_training_dataset/images/7ca293932087c456.jpg
#   inflating: challenge_3_training_dataset/images/991d838912eb7106.jpg
#   inflating: challenge_3_training_dataset/images/08c40598d0bda346.jpg
#   inflating: challenge_3_training_dataset/images/a574d44d06e9e813.jpg
#   inflating: challenge_3_training_dataset/images/2cd23d176c2d612f.jpg
#   inflating: challenge_3_training_dataset/images/3e78741c8a933c36.jpg
#   inflating: challenge_3_training_dataset/images/14651728f901d93d.jpg
#   inflating: challenge_3_training_dataset/images/77f5bea979228468.jpg
#   inflating: challenge_3_training_dataset/images/4f25c1665322bfe1.jpg
#   inflating: challenge_3_training_dataset/images/d508db9650bc96ee.jpg
#   inflating: challenge_3_training_dataset/images/0d0c200753952544.jpg
#   inflating: challenge_3_training_dataset/images/7cdcbd8d51746357.jpg
#   inflating: challenge_3_training_dataset/images/c00916b8cdd7eff5.jpg
#   inflating: challenge_3_training_dataset/images/c14ae412f0170677.jpg
#   inflating: challenge_3_training_dataset/images/454e2466f3a54d51.jpg
#   inflating: challenge_3_training_dataset/images/1ab09b99c19c309b.jpg
#   inflating: challenge_3_training_dataset/images/67370031de848968.jpg
#   inflating: challenge_3_training_dataset/images/00ed3f12a3793e37.jpg
#   inflating: challenge_3_training_dataset/images/6e53276534af148f.jpg
#   inflating: challenge_3_training_dataset/images/02755b91beeba404.jpg
#   inflating: challenge_3_training_dataset/images/93781d97b8079d5c.jpg
#   inflating: challenge_3_training_dataset/images/e6c7ef6e92a70317.jpg
#   inflating: challenge_3_training_dataset/images/3dcfd4a9986a253a.jpg
#   inflating: challenge_3_training_dataset/images/b019dc8c905a2947.jpg
#   inflating: challenge_3_training_dataset/images/04bee43abfe5c3e4.jpg
#   inflating: challenge_3_training_dataset/images/0186920a1181171e.jpg
#   inflating: challenge_3_training_dataset/images/391dc3e402ed41b5.jpg
#   inflating: challenge_3_training_dataset/images/8ca1ed365780a7a8.jpg
#   inflating: challenge_3_training_dataset/images/012c48b05bc9c01a.jpg
#   inflating: challenge_3_training_dataset/images/1f965049d7b8f608.jpg
#   inflating: challenge_3_training_dataset/images/06054557237a40d9.jpg
#   inflating: challenge_3_training_dataset/images/c4dd4b13f4004d8c.jpg
#   inflating: challenge_3_training_dataset/images/21001b0ecb1c0885.jpg
#   inflating: challenge_3_training_dataset/images/6d532ce72f8d0b81.jpg
#   inflating: challenge_3_training_dataset/images/096325e59244c7bf.jpg
#   inflating: challenge_3_training_dataset/images/4eaa53fdbe693b1a.jpg
#   inflating: challenge_3_training_dataset/images/9fbd4c72c7c59e7d.jpg
#   inflating: challenge_3_training_dataset/images/6ac16187bcffdef9.jpg
#   inflating: challenge_3_training_dataset/images/b339b6b1d614d1ef.jpg
#   inflating: challenge_3_training_dataset/images/bac10441ccd95a61.jpg
#   inflating: challenge_3_training_dataset/images/0907c0a70b17eac5.jpg
#   inflating: challenge_3_training_dataset/images/a7bb2db8d3690be7.jpg
#   inflating: challenge_3_training_dataset/images/35449092b4952a8d.jpg
#   inflating: challenge_3_training_dataset/images/9f34f8a386fb26c8.jpg
#   inflating: challenge_3_training_dataset/images/b2765c8fdff4fe4b.jpg
#   inflating: challenge_3_training_dataset/images/46adaa4c2ba2d759.jpg
#   inflating: challenge_3_training_dataset/images/59420fa3eb4bf3d2.jpg
#   inflating: challenge_3_training_dataset/images/1ec4dfe656d1b0c1.jpg
#   inflating: challenge_3_training_dataset/images/e289cfbcbb9044c4.jpg
#   inflating: challenge_3_training_dataset/images/080c93ae51316595.jpg
#   inflating: challenge_3_training_dataset/images/ed006437a3e95219.jpg
#   inflating: challenge_3_training_dataset/images/ea50fb7f561653af.jpg
#   inflating: challenge_3_training_dataset/images/0cf19047200dc376.jpg
#   inflating: challenge_3_training_dataset/images/aaaf433214a83cbb.jpg
#   inflating: challenge_3_training_dataset/images/e36107e0a375cb0b.jpg
#   inflating: challenge_3_training_dataset/images/ce1f3f9de336a632.jpg
#   inflating: challenge_3_training_dataset/images/fad7844266dcfb31.jpg
#   inflating: challenge_3_training_dataset/images/26ee95f2f6b3dae3.jpg
#   inflating: challenge_3_training_dataset/images/5f16a349120fa51f.jpg
#   inflating: challenge_3_training_dataset/images/6c2b745a0033c8b0.jpg
#   inflating: challenge_3_training_dataset/images/7a7be92c48339fba.jpg
#   inflating: challenge_3_training_dataset/images/4c31b41ecfea74bb.jpg
#   inflating: challenge_3_training_dataset/images/d593b3a9e8221777.jpg
#   inflating: challenge_3_training_dataset/images/51894c9bde1a4e52.jpg
#   inflating: challenge_3_training_dataset/images/df47c3bccfc0e872.jpg
#   inflating: challenge_3_training_dataset/images/e43bd95c4141c995.jpg
#   inflating: challenge_3_training_dataset/images/0d4328d0133dc03d.jpg
#   inflating: challenge_3_training_dataset/images/485ae3003fec4555.jpg
#   inflating: challenge_3_training_dataset/images/fca391368bb19f6b.jpg
#   inflating: challenge_3_training_dataset/images/e56982b793e12976.jpg
#   inflating: challenge_3_training_dataset/images/a9427ecf67cfe0c0.jpg
#   inflating: challenge_3_training_dataset/images/b74a7c57f13b9367.jpg
#   inflating: challenge_3_training_dataset/images/6c834f1a1ba3b936.jpg
#   inflating: challenge_3_training_dataset/images/dde785ab5bb564c1.jpg
#   inflating: challenge_3_training_dataset/images/b40cd864078e1b42.jpg
#   inflating: challenge_3_training_dataset/images/3e031e7d072a30e5.jpg
#   inflating: challenge_3_training_dataset/images/81b4ab9b3f48d7e7.jpg
#   inflating: challenge_3_training_dataset/images/6d5cff30ec11ba5d.jpg
#   inflating: challenge_3_training_dataset/images/206d1fe769bc006a.jpg
#   inflating: challenge_3_training_dataset/images/d3113733ee136cb6.jpg
#   inflating: challenge_3_training_dataset/images/987ced7fd98867b5.jpg
#   inflating: challenge_3_training_dataset/images/02904024c6d2bfb5.jpg
#   inflating: challenge_3_training_dataset/images/3ce71a52a02215a2.jpg
#   inflating: challenge_3_training_dataset/images/64bd7a94c2eca158.jpg
#   inflating: challenge_3_training_dataset/images/0e11b653e0e86b01.jpg
#   inflating: challenge_3_training_dataset/images/1133cbcf7bb47f17.jpg
#   inflating: challenge_3_training_dataset/images/353e137979a52723.jpg
#   inflating: challenge_3_training_dataset/images/ca6d66f2cf315afd.jpg
#   inflating: challenge_3_training_dataset/images/06cec2366599a625.jpg
#   inflating: challenge_3_training_dataset/images/ba7e17d4e5dabcf1.jpg
#   inflating: challenge_3_training_dataset/images/e13883b263f0bf48.jpg
#   inflating: challenge_3_training_dataset/images/e3d3baa305097c93.jpg
#   inflating: challenge_3_training_dataset/images/cc8efd1cbabc6993.jpg
#   inflating: challenge_3_training_dataset/images/adfb36f0466e723c.jpg
#   inflating: challenge_3_training_dataset/images/f1baf0a97218775e.jpg
#   inflating: challenge_3_training_dataset/images/01898677a6e446d2.jpg
#   inflating: challenge_3_training_dataset/images/aaad588dfe4cc7ff.jpg
#   inflating: challenge_3_training_dataset/images/6dd1fa737b301250.jpg
#   inflating: challenge_3_training_dataset/images/1a3a1f17331afb96.jpg
#   inflating: challenge_3_training_dataset/images/561c3af7284c915a.jpg
#   inflating: challenge_3_training_dataset/images/09cb8b0e5be0fdbb.jpg
#   inflating: challenge_3_training_dataset/images/6c9d9240ca976e1c.jpg
#   inflating: challenge_3_training_dataset/images/de911522d6b0590f.jpg
#   inflating: challenge_3_training_dataset/images/aaa862ecf627a62d.jpg
#   inflating: challenge_3_training_dataset/images/05e28266b2373158.jpg
#   inflating: challenge_3_training_dataset/images/89f3068caf377e8f.jpg
#   inflating: challenge_3_training_dataset/images/4a85b8f974f857e1.jpg
#   inflating: challenge_3_training_dataset/images/9af2743baf58c0d7.jpg
#   inflating: challenge_3_training_dataset/images/a1299420fa21177e.jpg
#   inflating: challenge_3_training_dataset/images/910d98d407a94fd9.jpg
#   inflating: challenge_3_training_dataset/images/95400891116a7cda.jpg
#   inflating: challenge_3_training_dataset/images/c2441d5e3f05666c.jpg
#   inflating: challenge_3_training_dataset/images/888adad3e55ecd62.jpg
#   inflating: challenge_3_training_dataset/images/04adc8c1e834630d.jpg
#   inflating: challenge_3_training_dataset/images/3e526b96cea6f6f8.jpg
#   inflating: challenge_3_training_dataset/images/50abbdb66c21dbab.jpg
#   inflating: challenge_3_training_dataset/images/00856c65aa180288.jpg
#   inflating: challenge_3_training_dataset/images/86d074c479d41b2b.jpg
#   inflating: challenge_3_training_dataset/images/ebd9fbd49d2ff057.jpg
#   inflating: challenge_3_training_dataset/images/7165578fee3ed518.jpg
#   inflating: challenge_3_training_dataset/images/c82a197e84fde464.jpg
#   inflating: challenge_3_training_dataset/images/417a3598f0e3f135.jpg
#   inflating: challenge_3_training_dataset/images/23f04adfe10665e3.jpg
#   inflating: challenge_3_training_dataset/images/1058dbb916e6af48.jpg
#   inflating: challenge_3_training_dataset/images/0776c68ab9a8e3ef.jpg
#   inflating: challenge_3_training_dataset/images/341778e460fae38e.jpg
#   inflating: challenge_3_training_dataset/images/b383344c6e3003ad.jpg
#   inflating: challenge_3_training_dataset/images/44746ff2a0dd6524.jpg
#   inflating: challenge_3_training_dataset/images/7d458c059c732a95.jpg
#   inflating: challenge_3_training_dataset/images/35154dba28c75a75.jpg
#   inflating: challenge_3_training_dataset/images/1872a06e52cc267b.jpg
#   inflating: challenge_3_training_dataset/images/246ee805163ec4ae.jpg
#   inflating: challenge_3_training_dataset/images/8cd6a8034d185d27.jpg
#   inflating: challenge_3_training_dataset/images/e3b19b25ff5a7bb8.jpg
#   inflating: challenge_3_training_dataset/images/04af77cca5b2ba0c.jpg
#   inflating: challenge_3_training_dataset/images/7bb9886ba3f8b00e.jpg
#   inflating: challenge_3_training_dataset/images/0813558e1e729e57.jpg
#   inflating: challenge_3_training_dataset/images/fce350186446fef0.jpg
#   inflating: challenge_3_training_dataset/images/f4d644813b8ba2f1.jpg
#   inflating: challenge_3_training_dataset/images/eb3e1da738066868.jpg
#   inflating: challenge_3_training_dataset/images/b8928edeaf4ccc15.jpg
#   inflating: challenge_3_training_dataset/images/0424e8d18de1a881.jpg
#   inflating: challenge_3_training_dataset/images/b0552ea8e5459f37.jpg
#   inflating: challenge_3_training_dataset/images/48bdf753bad43c1c.jpg
#   inflating: challenge_3_training_dataset/images/a9f23ea289b225b5.jpg
#   inflating: challenge_3_training_dataset/images/ef12efd5e988e5cf.jpg
#   inflating: challenge_3_training_dataset/images/bea89ae6d6af344d.jpg
#   inflating: challenge_3_training_dataset/images/429e01a097ea160e.jpg
#   inflating: challenge_3_training_dataset/images/8919536b577eb796.jpg
#   inflating: challenge_3_training_dataset/images/63f1765e06a6233d.jpg
#   inflating: challenge_3_training_dataset/images/696f384648a87423.jpg
#   inflating: challenge_3_training_dataset/images/09f5672a780bc246.jpg
#   inflating: challenge_3_training_dataset/images/489f8b817f687834.jpg
#   inflating: challenge_3_training_dataset/images/a12b7314b1ab2da1.jpg
#   inflating: challenge_3_training_dataset/images/5a3ca33cabe8a174.jpg
#   inflating: challenge_3_training_dataset/images/6ed680463ef78dbe.jpg
#   inflating: challenge_3_training_dataset/images/d5b386d4af9f518d.jpg
#   inflating: challenge_3_training_dataset/images/e0a9029da76eccd4.jpg
#   inflating: challenge_3_training_dataset/images/95689e9ae12720e8.jpg
#   inflating: challenge_3_training_dataset/images/ce8b2ca2c0578cad.jpg
#   inflating: challenge_3_training_dataset/images/4fe43c17e4d92f9f.jpg
#   inflating: challenge_3_training_dataset/images/691fa76ff9f1d6cb.jpg
#   inflating: challenge_3_training_dataset/images/058816e3339cc5ce.jpg
#   inflating: challenge_3_training_dataset/images/7ca4fbc972ee3e4a.jpg
#   inflating: challenge_3_training_dataset/images/23e184fd20f69402.jpg
#   inflating: challenge_3_training_dataset/images/6e2fc1a8f13e7fa4.jpg
#   inflating: challenge_3_training_dataset/images/4708877b60ae3554.jpg
#   inflating: challenge_3_training_dataset/images/b23e11a2162392be.jpg
#   inflating: challenge_3_training_dataset/images/43ceed9909ae8a57.jpg
#   inflating: challenge_3_training_dataset/images/24a82e4c4ea46767.jpg
#   inflating: challenge_3_training_dataset/images/19a7eb0867645ea8.jpg
#   inflating: challenge_3_training_dataset/images/9cc5c900072bf59a.jpg
#   inflating: challenge_3_training_dataset/images/04234ac608c73e9d.jpg
#   inflating: challenge_3_training_dataset/images/e411157931158317.jpg
#   inflating: challenge_3_training_dataset/images/4080b8928028890a.jpg
#   inflating: challenge_3_training_dataset/images/04eb178e8535ef59.jpg
#   inflating: challenge_3_training_dataset/images/05fe0257c734a078.jpg
#   inflating: challenge_3_training_dataset/images/2c264c6b9d96fa49.jpg
#   inflating: challenge_3_training_dataset/images/5d302522846d3802.jpg
#   inflating: challenge_3_training_dataset/images/c7e9c1d5ae1a544c.jpg
#   inflating: challenge_3_training_dataset/images/baa6a60167900e74.jpg
#   inflating: challenge_3_training_dataset/images/2e7016bd57978ebf.jpg
#   inflating: challenge_3_training_dataset/images/af2d4b4fa3a3df77.jpg
#   inflating: challenge_3_training_dataset/images/0ee726d453c2d1ae.jpg
#   inflating: challenge_3_training_dataset/images/e6870ad1c7f9acf4.jpg
#   inflating: challenge_3_training_dataset/images/5eb8360be45016eb.jpg
#   inflating: challenge_3_training_dataset/images/04c4b3c29d3e4c36.jpg
#   inflating: challenge_3_training_dataset/images/889600638e7e5bb6.jpg
#   inflating: challenge_3_training_dataset/images/380dd415db24735a.jpg
#   inflating: challenge_3_training_dataset/images/18ca89ed92ffa3c5.jpg
#   inflating: challenge_3_training_dataset/images/025aad2119b35e45.jpg
#   inflating: challenge_3_training_dataset/images/709a522186684aaf.jpg
#   inflating: challenge_3_training_dataset/images/b6c152600006b933.jpg
#   inflating: challenge_3_training_dataset/images/0a1b3e3606b26bbd.jpg
#   inflating: challenge_3_training_dataset/images/9eb87d0432f7e7a4.jpg
#   inflating: challenge_3_training_dataset/images/2aa0b5892d5eaf2c.jpg
#   inflating: challenge_3_training_dataset/images/445d8423295e2f1a.jpg
#   inflating: challenge_3_training_dataset/images/010f74c4e2604427.jpg
#   inflating: challenge_3_training_dataset/images/ab04070be108a63f.jpg
#   inflating: challenge_3_training_dataset/images/fba81cabadf9f2c0.jpg
#   inflating: challenge_3_training_dataset/images/ece6a5c371f5a5b5.jpg
#   inflating: challenge_3_training_dataset/images/002a253d25d9f647.jpg
#   inflating: challenge_3_training_dataset/images/8841f38273268a49.jpg
#   inflating: challenge_3_training_dataset/images/90341af669ffb07a.jpg
#   inflating: challenge_3_training_dataset/images/048e67bc1bf5aeee.jpg
#   inflating: challenge_3_training_dataset/images/061101e0b47cfd6f.jpg
#   inflating: challenge_3_training_dataset/images/10631c85e2e0340e.jpg
#   inflating: challenge_3_training_dataset/images/802df4cae08b081a.jpg
#   inflating: challenge_3_training_dataset/images/009e8d99ac59229d.jpg
#   inflating: challenge_3_training_dataset/images/028f8db193a85ecf.jpg
#   inflating: challenge_3_training_dataset/images/138281f4d56107fe.jpg
#   inflating: challenge_3_training_dataset/images/3a995435dc1f8359.jpg
#   inflating: challenge_3_training_dataset/images/08686848dce4f7ff.jpg
#   inflating: challenge_3_training_dataset/images/1473d1da2de08ee8.jpg
#   inflating: challenge_3_training_dataset/images/2ad4398a23748e3e.jpg
#   inflating: challenge_3_training_dataset/images/2cb132d8ef1e756b.jpg
#   inflating: challenge_3_training_dataset/images/e1d744c854c3a645.jpg
#   inflating: challenge_3_training_dataset/images/f37b443691c58363.jpg
#   inflating: challenge_3_training_dataset/images/11cac22a7837ce5c.jpg
#   inflating: challenge_3_training_dataset/images/026969016d5db109.jpg
#   inflating: challenge_3_training_dataset/images/6f064a5493c42372.jpg
#   inflating: challenge_3_training_dataset/images/d43010cf5f9596f1.jpg
#   inflating: challenge_3_training_dataset/images/89e773b57058dc0d.jpg
#   inflating: challenge_3_training_dataset/images/c82dddcd8f0e4894.jpg
#   inflating: challenge_3_training_dataset/images/bbafeddab331d4a3.jpg
#   inflating: challenge_3_training_dataset/images/1732d67fe6a855bb.jpg
#   inflating: challenge_3_training_dataset/images/945b47576afaf8d9.jpg
#   inflating: challenge_3_training_dataset/images/262beb22ec7aaac4.jpg
#   inflating: challenge_3_training_dataset/images/b54508bf75d3fb08.jpg
#   inflating: challenge_3_training_dataset/images/091a934694c45682.jpg
#   inflating: challenge_3_training_dataset/images/3b80a26bed3c7e46.jpg
#   inflating: challenge_3_training_dataset/images/01c4e2bf77e71efe.jpg
#   inflating: challenge_3_training_dataset/images/2a867c3910faea9f.jpg
#   inflating: challenge_3_training_dataset/images/d2f8c016fd3631d8.jpg
#   inflating: challenge_3_training_dataset/images/d340bd83c78d1db7.jpg
#   inflating: challenge_3_training_dataset/images/80d5d36acfe05abc.jpg
#   inflating: challenge_3_training_dataset/images/8b6307fb64b4efd0.jpg
#   inflating: challenge_3_training_dataset/images/00c74835c53aa86b.jpg
#   inflating: challenge_3_training_dataset/images/ccaa29e7bf503fa3.jpg
#   inflating: challenge_3_training_dataset/images/b25774d86831edaa.jpg
#   inflating: challenge_3_training_dataset/images/7a0c5f6593bc7262.jpg
#   inflating: challenge_3_training_dataset/images/042ec2fb6dc546a5.jpg
#   inflating: challenge_3_training_dataset/images/2df0cfa577176727.jpg
#   inflating: challenge_3_training_dataset/images/af4d9c4d72c7c2be.jpg
#   inflating: challenge_3_training_dataset/images/0339290b1087e03a.jpg
#   inflating: challenge_3_training_dataset/images/026f53f05f8c8ad9.jpg
#   inflating: challenge_3_training_dataset/images/b1f86fcb2b9dd575.jpg
#   inflating: challenge_3_training_dataset/images/64c195d453287d56.jpg
#   inflating: challenge_3_training_dataset/images/997cebef441de495.jpg
#   inflating: challenge_3_training_dataset/images/46973f2ff12426c4.jpg
#   inflating: challenge_3_training_dataset/images/d850b5c59842ac04.jpg
#   inflating: challenge_3_training_dataset/images/c338e21d0158530d.jpg
#   inflating: challenge_3_training_dataset/images/f8d9b6a2e8466a31.jpg
#   inflating: challenge_3_training_dataset/images/20e3f99fbf04a636.jpg
#   inflating: challenge_3_training_dataset/images/09d25ea12ee96689.jpg
#   inflating: challenge_3_training_dataset/images/0075679b808245e7.jpg
#   inflating: challenge_3_training_dataset/images/c55a1f139ac7dba5.jpg
#   inflating: challenge_3_training_dataset/images/aba5b33c3aedf459.jpg
#   inflating: challenge_3_training_dataset/images/13fada80a7c1b54e.jpg
#   inflating: challenge_3_training_dataset/images/04189894067e3639.jpg
#   inflating: challenge_3_training_dataset/images/939cf623fa2e32b5.jpg
#   inflating: challenge_3_training_dataset/images/f2d544e06a2f04d0.jpg
#   inflating: challenge_3_training_dataset/images/1eac85172374ea56.jpg
#   inflating: challenge_3_training_dataset/images/ff1d0113a9fc176c.jpg
#   inflating: challenge_3_training_dataset/images/8e91ae807a64621d.jpg
#   inflating: challenge_3_training_dataset/images/6c981a41ad7baa31.jpg
#   inflating: challenge_3_training_dataset/images/f2aec51f398b6455.jpg
#   inflating: challenge_3_training_dataset/images/588d94b2b55b91f9.jpg
#   inflating: challenge_3_training_dataset/images/806a4dcb477a9b3d.jpg
#   inflating: challenge_3_training_dataset/images/0308ad116086e13f.jpg
#   inflating: challenge_3_training_dataset/images/06eb8da7ead1ca12.jpg
#   inflating: challenge_3_training_dataset/images/04d9be07fc550688.jpg
#   inflating: challenge_3_training_dataset/images/be0e69da8969de7b.jpg
#   inflating: challenge_3_training_dataset/images/515c67710a17791c.jpg
#   inflating: challenge_3_training_dataset/images/6f15d7416b61af60.jpg
#   inflating: challenge_3_training_dataset/images/03d14a83866d9a4c.jpg
#   inflating: challenge_3_training_dataset/images/87477ccd287f8ffc.jpg
#   inflating: challenge_3_training_dataset/images/79b0828c01385198.jpg
#   inflating: challenge_3_training_dataset/images/333ac1348d64b5c6.jpg
#   inflating: challenge_3_training_dataset/images/d1644a1d5f385ac7.jpg
#   inflating: challenge_3_training_dataset/images/114d4f00fdc01e67.jpg
#   inflating: challenge_3_training_dataset/images/f6eb4bf1cd026307.jpg
#   inflating: challenge_3_training_dataset/images/c0d12151a5d2a91a.jpg
#   inflating: challenge_3_training_dataset/images/fb3867b8b0e4dcdc.jpg
#   inflating: challenge_3_training_dataset/images/956313088b0453d8.jpg
#   inflating: challenge_3_training_dataset/images/2a02fa9fe5239470.jpg
#   inflating: challenge_3_training_dataset/images/19d1702851d5950c.jpg
#   inflating: challenge_3_training_dataset/images/066ed679c721bf70.jpg
#   inflating: challenge_3_training_dataset/images/f87eee47b432900a.jpg
#   inflating: challenge_3_training_dataset/images/6f7bcb740cd712af.jpg
#   inflating: challenge_3_training_dataset/images/9aa4b47ea29989fa.jpg
#   inflating: challenge_3_training_dataset/images/780dc0ff229f14f1.jpg
#   inflating: challenge_3_training_dataset/images/68c2eaae31804d0c.jpg
#   inflating: challenge_3_training_dataset/images/0e677422693286e8.jpg
#   inflating: challenge_3_training_dataset/images/25c1fa5d2f144bc3.jpg
#   inflating: challenge_3_training_dataset/images/ba57d60796691956.jpg
#   inflating: challenge_3_training_dataset/images/a9080685b5a3182e.jpg
#   inflating: challenge_3_training_dataset/images/6d93e902a5074947.jpg
#   inflating: challenge_3_training_dataset/images/5eb288c76e0175ab.jpg
#   inflating: challenge_3_training_dataset/images/5c0d0e657b34fdd9.jpg
#   inflating: challenge_3_training_dataset/images/38916c71864680b0.jpg
#   inflating: challenge_3_training_dataset/images/a8fe148279cb1ac9.jpg
#   inflating: challenge_3_training_dataset/images/019c51d63daf9530.jpg
#   inflating: challenge_3_training_dataset/images/5b49c63cb29d0ee6.jpg
#   inflating: challenge_3_training_dataset/images/0233bf593bc46c15.jpg
#   inflating: challenge_3_training_dataset/images/3488638d8642ac1b.jpg
#   inflating: challenge_3_training_dataset/images/05ca9ad0b8d8a818.jpg
#   inflating: challenge_3_training_dataset/images/6f513e34b28ff0a2.jpg
#   inflating: challenge_3_training_dataset/images/90c8e536ddc27c99.jpg
#   inflating: challenge_3_training_dataset/images/259f58cb3ce9b80a.jpg
#   inflating: challenge_3_training_dataset/images/7f6e04b5623cb601.jpg
#   inflating: challenge_3_training_dataset/images/1210d1a6936232bf.jpg
#   inflating: challenge_3_training_dataset/images/a3cbead8d496154e.jpg
#   inflating: challenge_3_training_dataset/images/cb037b6c52cf4708.jpg
#   inflating: challenge_3_training_dataset/images/c44a528b4f9c6c7a.jpg
#   inflating: challenge_3_training_dataset/images/0b6fd161a8b23bd0.jpg
#   inflating: challenge_3_training_dataset/images/8878b7e4e11e7e09.jpg
#   inflating: challenge_3_training_dataset/images/12a6c8434e5787ec.jpg
#   inflating: challenge_3_training_dataset/images/91f9489c064c6d9a.jpg
#   inflating: challenge_3_training_dataset/images/24cc1775972bb0a4.jpg
#   inflating: challenge_3_training_dataset/images/9814fee92ff57bc7.jpg
#   inflating: challenge_3_training_dataset/images/3b3864f5f55dbe9d.jpg
#   inflating: challenge_3_training_dataset/images/1f568dc272724385.jpg
#   inflating: challenge_3_training_dataset/images/d0030a58d11c1924.jpg
#   inflating: challenge_3_training_dataset/images/c8821820a96c8cd7.jpg
#   inflating: challenge_3_training_dataset/images/b641182628f79420.jpg
#   inflating: challenge_3_training_dataset/images/86048a46d0272788.jpg
#   inflating: challenge_3_training_dataset/images/15e25d06344cf0fa.jpg
#   inflating: challenge_3_training_dataset/images/d153aaa9667d658a.jpg
#   inflating: challenge_3_training_dataset/images/f1c9f6ea96c269c7.jpg
#   inflating: challenge_3_training_dataset/images/480ded925126b392.jpg
#   inflating: challenge_3_training_dataset/images/084599bb84e38f34.jpg
#   inflating: challenge_3_training_dataset/images/3b2519b1b0f4e495.jpg
#   inflating: challenge_3_training_dataset/images/afe1bdf1b65bdb7a.jpg
#   inflating: challenge_3_training_dataset/images/bca93ba9d5bde5f0.jpg
#   inflating: challenge_3_training_dataset/images/1b120a97f9b4c150.jpg
#   inflating: challenge_3_training_dataset/images/1e784117853fa6b1.jpg
#   inflating: challenge_3_training_dataset/images/0a7add5c1be3f704.jpg
#   inflating: challenge_3_training_dataset/images/12cbb1467d014b4e.jpg
#   inflating: challenge_3_training_dataset/images/dfadc1b1cda914f6.jpg
#   inflating: challenge_3_training_dataset/images/ecfb9b838d59f755.jpg
#   inflating: challenge_3_training_dataset/images/dba6e1b8711b5042.jpg
#   inflating: challenge_3_training_dataset/images/1597659862196c00.jpg
#   inflating: challenge_3_training_dataset/images/13b7f8332d209f16.jpg
#   inflating: challenge_3_training_dataset/images/d17c3c08b1b5e748.jpg
#   inflating: challenge_3_training_dataset/images/a99e5f1041d7e2ee.jpg
#   inflating: challenge_3_training_dataset/images/1069fadb168ae44a.jpg
#   inflating: challenge_3_training_dataset/images/1e303f7aa0064290.jpg
#   inflating: challenge_3_training_dataset/images/5e2a733ec314d7e1.jpg
#   inflating: challenge_3_training_dataset/images/091f8cbe32ba5523.jpg
#   inflating: challenge_3_training_dataset/images/5ae5a78f8dad5ad8.jpg
#   inflating: challenge_3_training_dataset/images/9945e53c4f3d9f15.jpg
#   inflating: challenge_3_training_dataset/images/d08919480f28116d.jpg
#   inflating: challenge_3_training_dataset/images/55896f98fc21b83f.jpg
#   inflating: challenge_3_training_dataset/images/b550bb5d14336f14.jpg
#   inflating: challenge_3_training_dataset/images/19e87f4653dbddb2.jpg
#   inflating: challenge_3_training_dataset/images/dccd23dea2a5a3dd.jpg
#   inflating: challenge_3_training_dataset/images/fca2a8d604a29af6.jpg
#   inflating: challenge_3_training_dataset/images/61246ab7b9b4af9b.jpg
#   inflating: challenge_3_training_dataset/images/5f1a9ffa1bda72d2.jpg
#   inflating: challenge_3_training_dataset/images/dfb066fe241bc54f.jpg
#   inflating: challenge_3_training_dataset/images/492dbcacc0870c44.jpg
#   inflating: challenge_3_training_dataset/images/f2a81c0123047eba.jpg
#   inflating: challenge_3_training_dataset/images/839521592430e640.jpg
#   inflating: challenge_3_training_dataset/images/3af9d51cc8e69363.jpg
#   inflating: challenge_3_training_dataset/images/1775ad9cc954879b.jpg
#   inflating: challenge_3_training_dataset/images/c6fc32c9d09162b5.jpg
#   inflating: challenge_3_training_dataset/images/a3bcee1726247066.jpg
#   inflating: challenge_3_training_dataset/images/e245bf6c16995d45.jpg
#   inflating: challenge_3_training_dataset/images/dfc2aa5e25621216.jpg
#   inflating: challenge_3_training_dataset/images/d23062feec698392.jpg
#   inflating: challenge_3_training_dataset/images/37e0065bdcc7d4a6.jpg
#   inflating: challenge_3_training_dataset/images/a124126bfbb7b607.jpg
#   inflating: challenge_3_training_dataset/images/8003b6aabeb97c93.jpg
#   inflating: challenge_3_training_dataset/images/0ca289eddbe17ede.jpg
#   inflating: challenge_3_training_dataset/images/4f2f627c591367b5.jpg
#   inflating: challenge_3_training_dataset/images/4ddced7bc891a73c.jpg
#   inflating: challenge_3_training_dataset/images/dc4652d8952351b4.jpg
#   inflating: challenge_3_training_dataset/images/9985aa7024ed5b26.jpg
#   inflating: challenge_3_training_dataset/images/a9936f622dececf1.jpg
#   inflating: challenge_3_training_dataset/images/5054127fd708e5c7.jpg
#   inflating: challenge_3_training_dataset/images/ec5da84f4bc547de.jpg
#   inflating: challenge_3_training_dataset/images/f40433be46f80d08.jpg
#   inflating: challenge_3_training_dataset/images/a83f574ba88f426d.jpg
#   inflating: challenge_3_training_dataset/images/c246f21e87240c7c.jpg
#   inflating: challenge_3_training_dataset/images/eb82ec636694d548.jpg
#   inflating: challenge_3_training_dataset/images/8b4a750463a068fc.jpg
#   inflating: challenge_3_training_dataset/images/5a931e194e1e817a.jpg
#   inflating: challenge_3_training_dataset/images/92a3c792d79a99e4.jpg
#   inflating: challenge_3_training_dataset/images/a7da5d07dbb8d6b3.jpg
#   inflating: challenge_3_training_dataset/images/86e772d1f00a368c.jpg
#   inflating: challenge_3_training_dataset/images/007ab59b9606a05e.jpg
#   inflating: challenge_3_training_dataset/images/e6d1d686b030fc57.jpg
#   inflating: challenge_3_training_dataset/images/3dc4496d500107fd.jpg
#   inflating: challenge_3_training_dataset/images/d30c524bcd724844.jpg
#   inflating: challenge_3_training_dataset/images/93f6e167ad9c00a2.jpg
#   inflating: challenge_3_training_dataset/images/7b51c77bf5431bae.jpg
#   inflating: challenge_3_training_dataset/images/dab7da46d234a5c2.jpg
#   inflating: challenge_3_training_dataset/images/e518fb81826c4e39.jpg
#   inflating: challenge_3_training_dataset/images/01da39d05aabb55a.jpg
#   inflating: challenge_3_training_dataset/images/7b6187151bced639.jpg
#   inflating: challenge_3_training_dataset/images/b3e56d9445454302.jpg
#   inflating: challenge_3_training_dataset/images/1aa9623294a19fa3.jpg
#   inflating: challenge_3_training_dataset/images/6c35ed969ffad914.jpg
#   inflating: challenge_3_training_dataset/images/80cef44125e2f7a6.jpg
#   inflating: challenge_3_training_dataset/images/912b4583cbdf8eae.jpg
#   inflating: challenge_3_training_dataset/images/02d4bfb508216a94.jpg
#   inflating: challenge_3_training_dataset/images/8360931dafb54c3c.jpg
#   inflating: challenge_3_training_dataset/images/9be162010b645917.jpg
#   inflating: challenge_3_training_dataset/images/44e0b1f7f9a93911.jpg
#   inflating: challenge_3_training_dataset/images/db925e27d58073b7.jpg
#   inflating: challenge_3_training_dataset/images/ec1455330549897c.jpg
#   inflating: challenge_3_training_dataset/images/6fe6b3e3f400e9cc.jpg
#   inflating: challenge_3_training_dataset/images/b4664897e7118060.jpg
#   inflating: challenge_3_training_dataset/images/2b59d96f15801cdd.jpg
#   inflating: challenge_3_training_dataset/images/437fe5ad478de3fc.jpg
#   inflating: challenge_3_training_dataset/images/ef25b160872b3d41.jpg
#   inflating: challenge_3_training_dataset/images/38ff288f5d048616.jpg
#   inflating: challenge_3_training_dataset/images/1392c7cc6903c580.jpg
#   inflating: challenge_3_training_dataset/images/e17dc8e08ca42264.jpg
#   inflating: challenge_3_training_dataset/images/7b355adbda56d59b.jpg
#   inflating: challenge_3_training_dataset/images/4de20a203cca0415.jpg
#   inflating: challenge_3_training_dataset/images/2c50257bde627503.jpg
#   inflating: challenge_3_training_dataset/images/66cc87578f8597b7.jpg
#   inflating: challenge_3_training_dataset/images/ce5fcff35f33116b.jpg
#   inflating: challenge_3_training_dataset/images/3432a41b3d91d8e8.jpg
#   inflating: challenge_3_training_dataset/images/8a7094b465ea873a.jpg
#   inflating: challenge_3_training_dataset/images/02e92218ab075be9.jpg
#   inflating: challenge_3_training_dataset/images/d4f924427449957e.jpg
#   inflating: challenge_3_training_dataset/images/ebc803426f69ff8e.jpg
#   inflating: challenge_3_training_dataset/images/34509118ab7d8c56.jpg
#   inflating: challenge_3_training_dataset/images/cc39aff4aab1dfa4.jpg
#   inflating: challenge_3_training_dataset/images/174fb5b248d5b878.jpg
#   inflating: challenge_3_training_dataset/images/3558c9cc421d657a.jpg
#   inflating: challenge_3_training_dataset/images/8992f585c6256eb2.jpg
#   inflating: challenge_3_training_dataset/images/b84b91fc807afc8f.jpg
#   inflating: challenge_3_training_dataset/images/846c42ff36ce1ef6.jpg
#   inflating: challenge_3_training_dataset/images/66f8aee57e76115f.jpg
#   inflating: challenge_3_training_dataset/images/903dee6d5057017a.jpg
#   inflating: challenge_3_training_dataset/images/72c657c7d0f613ac.jpg
#   inflating: challenge_3_training_dataset/images/6c282cdefd36ed05.jpg
#   inflating: challenge_3_training_dataset/images/0da980b8a7d68ee7.jpg
#   inflating: challenge_3_training_dataset/images/fd63237c3a18f33f.jpg
#   inflating: challenge_3_training_dataset/images/c6cc72bb6764b835.jpg
#   inflating: challenge_3_training_dataset/images/bee819a086021cf2.jpg
#   inflating: challenge_3_training_dataset/images/df325b1ff28c6ee5.jpg
#   inflating: challenge_3_training_dataset/images/d8dc53ff87ea8658.jpg
#   inflating: challenge_3_training_dataset/images/17a880c568849e74.jpg
#   inflating: challenge_3_training_dataset/images/dcca2e1e79d0a5a3.jpg
#   inflating: challenge_3_training_dataset/images/c6f47d486d3a11ca.jpg
#   inflating: challenge_3_training_dataset/images/446ebd5a92a2b1db.jpg
#   inflating: challenge_3_training_dataset/images/15d29a241dfc4de8.jpg
#   inflating: challenge_3_training_dataset/images/06e92c8aa9abbcc8.jpg
#   inflating: challenge_3_training_dataset/images/1a22fffb9740ea26.jpg
#   inflating: challenge_3_training_dataset/images/880c9bb43adecb0f.jpg
#   inflating: challenge_3_training_dataset/images/fcdfbf699fd17196.jpg
#   inflating: challenge_3_training_dataset/images/45e197172c910f0e.jpg
#   inflating: challenge_3_training_dataset/images/90967da1f70cecda.jpg
#   inflating: challenge_3_training_dataset/images/ee2d16eaac95cefa.jpg
#   inflating: challenge_3_training_dataset/images/88c7a560f37c12d8.jpg
#   inflating: challenge_3_training_dataset/images/30335d7159aea019.jpg
# ...
#   inflating: challenge_3_training_dataset/images/cef2172281957794.jpg
#   inflating: challenge_3_training_dataset/images/0bdff6b89b838f1c.jpg
#   inflating: challenge_3_training_dataset/images/6d0e70f0354b74a7.jpg
#   inflating: challenge_3_training_dataset/images/0f57a00e92ee2b00.jpg
#   inflating: challenge_3_training_dataset/images/1530e6d960e8d3b0.jpg
#   inflating: challenge_3_training_dataset/images/161c7e04a0f91fdd.jpg
#   inflating: challenge_3_training_dataset/images/eb453fbe7147e8fa.jpg
#   inflating: challenge_3_training_dataset/images/941aa0656ca0d291.jpg
#   inflating: challenge_3_training_dataset/images/4d6e1475a3f153bb.jpg
#   inflating: challenge_3_training_dataset/images/b1cbcfabef14b0c4.jpg
#   inflating: challenge_3_training_dataset/images/70e5a2384a74d69d.jpg
#   inflating: challenge_3_training_dataset/images/1558273c04e53c09.jpg
#   inflating: challenge_3_training_dataset/images/1643c16233d46128.jpg
#   inflating: challenge_3_training_dataset/images/058802a4abb270b9.jpg
#   inflating: challenge_3_training_dataset/images/c3116f589b265e46.jpg
#   inflating: challenge_3_training_dataset/images/ee484dfd140f52de.jpg
#   inflating: challenge_3_training_dataset/images/e3c6b1765c2a3daf.jpg
#   inflating: challenge_3_training_dataset/images/a820da8d4fbe44dd.jpg
#   inflating: challenge_3_training_dataset/images/20099545c58fe00f.jpg
#   inflating: challenge_3_training_dataset/images/6e17728cf68ea2d7.jpg
#   inflating: challenge_3_training_dataset/images/5aea12e07dd46282.jpg
#   inflating: challenge_3_training_dataset/images/ec76429cc2ca8bcb.jpg
#   inflating: challenge_3_training_dataset/images/2e5541c127c9af35.jpg
#   inflating: challenge_3_training_dataset/images/c23c8e0ab890c05e.jpg
#   inflating: challenge_3_training_dataset/images/c72bed4ad1a2224c.jpg
#   inflating: challenge_3_training_dataset/images/e64905ba5043448b.jpg
#   inflating: challenge_3_training_dataset/images/887af2226cb620e9.jpg
#   inflating: challenge_3_training_dataset/images/813198d00c77758c.jpg
#   inflating: challenge_3_training_dataset/images/334aa985efb58e26.jpg
#   inflating: challenge_3_training_dataset/images/3741f021d550a773.jpg
#   inflating: challenge_3_training_dataset/images/5fbee917b9d43ae9.jpg
#   inflating: challenge_3_training_dataset/images/b70f803b7c53eff7.jpg
#   inflating: challenge_3_training_dataset/images/719e1a33595e2598.jpg
#   inflating: challenge_3_training_dataset/images/6355fa556122a231.jpg
#   inflating: challenge_3_training_dataset/images/67fa40334da81f60.jpg
#   inflating: challenge_3_training_dataset/images/b8db36df333af464.jpg
#   inflating: challenge_3_training_dataset/images/214dbe50efce0781.jpg
#   inflating: challenge_3_training_dataset/images/3f47a2e0b6aec6dd.jpg
#   inflating: challenge_3_training_dataset/images/fd759102029c4228.jpg
#   inflating: challenge_3_training_dataset/images/3ee3a6c389844a75.jpg
#   inflating: challenge_3_training_dataset/images/6a56954c060a4d9b.jpg
#   inflating: challenge_3_training_dataset/images/008a0aa3cf3f753e.jpg
#   inflating: challenge_3_training_dataset/images/ef0ff2e35382b407.jpg
#   inflating: challenge_3_training_dataset/images/05ae93c054a95cfd.jpg
#   inflating: challenge_3_training_dataset/images/019d09e58efe22e7.jpg
#   inflating: challenge_3_training_dataset/images/689e6aa000fe6442.jpg
#   inflating: challenge_3_training_dataset/images/350c866cb8c2f4d9.jpg
#   inflating: challenge_3_training_dataset/images/8d332b7e9879d4cb.jpg
#   inflating: challenge_3_training_dataset/images/773bb05a484e1c36.jpg
#   inflating: challenge_3_training_dataset/images/06cb0846a75b4a69.jpg
#   inflating: challenge_3_training_dataset/images/ed8cc51cc6aeb1eb.jpg
#   inflating: challenge_3_training_dataset/images/d4905063abfa62ab.jpg
#   inflating: challenge_3_training_dataset/images/090b5a48a7673334.jpg
#   inflating: challenge_3_training_dataset/images/75677a8e038581d0.jpg
#   inflating: challenge_3_training_dataset/images/6ee7465e7185776a.jpg
#   inflating: challenge_3_training_dataset/images/026dce91294a5d9d.jpg
#   inflating: challenge_3_training_dataset/images/0160061d0018ccc3.jpg
#   inflating: challenge_3_training_dataset/images/34aab8e06e105956.jpg
#   inflating: challenge_3_training_dataset/images/26a11d4ff3012887.jpg
#   inflating: challenge_3_training_dataset/images/d1af0a1d165c308d.jpg
#   inflating: challenge_3_training_dataset/images/d8511fae279d6897.jpg
#   inflating: challenge_3_training_dataset/images/2694601c64623eb9.jpg
#   inflating: challenge_3_training_dataset/images/08ffb9f870b70fcc.jpg
#   inflating: challenge_3_training_dataset/images/b407c0b83d964e92.jpg
#   inflating: challenge_3_training_dataset/images/6c990022a577e21e.jpg
#   inflating: challenge_3_training_dataset/images/4df02bae79c033b5.jpg
#   inflating: challenge_3_training_dataset/images/dff671fdd6ca9588.jpg
#   inflating: challenge_3_training_dataset/images/e1e680ee88c15db2.jpg
#   inflating: challenge_3_training_dataset/images/dc123c00bb2b108d.jpg
#   inflating: challenge_3_training_dataset/images/2e7e1d148e7df7ea.jpg
#   inflating: challenge_3_training_dataset/images/aa953198817b11cb.jpg
#   inflating: challenge_3_training_dataset/images/796913a310bee9c2.jpg
#   inflating: challenge_3_training_dataset/images/01112b3e7a0633e2.jpg
#   inflating: challenge_3_training_dataset/images/7b820b4c80a6dddc.jpg
#   inflating: challenge_3_training_dataset/images/aa7beeab306c8ce4.jpg
#   inflating: challenge_3_training_dataset/images/0856a7d08004266a.jpg
#   inflating: challenge_3_training_dataset/images/881ad760797218d7.jpg
#   inflating: challenge_3_training_dataset/images/d8ee2c99501b5e7d.jpg
#   inflating: challenge_3_training_dataset/images/fe781f361a6621fa.jpg
#   inflating: challenge_3_training_dataset/images/b98db22ca7aff6d9.jpg
#   inflating: challenge_3_training_dataset/images/e68890c2fe85192c.jpg
#   inflating: challenge_3_training_dataset/images/168658acd8d23af8.jpg
#   inflating: challenge_3_training_dataset/images/8ed28d2eeb16eb0d.jpg
#   inflating: challenge_3_training_dataset/images/93957c8346324b97.jpg
#   inflating: challenge_3_training_dataset/images/f382994b6e829f19.jpg
#   inflating: challenge_3_training_dataset/images/811cc414d9780d05.jpg
#   inflating: challenge_3_training_dataset/images/cd6ccc693a1bd3ac.jpg
#   inflating: challenge_3_training_dataset/images/ee11f73254f93a15.jpg
#   inflating: challenge_3_training_dataset/images/168c1013ee0beea2.jpg
#   inflating: challenge_3_training_dataset/images/31a762c7888bad23.jpg
#   inflating: challenge_3_training_dataset/images/d02df08b27cf65cd.jpg
#   inflating: challenge_3_training_dataset/images/1b3d45462920ca87.jpg
#   inflating: challenge_3_training_dataset/images/5ca9ee25fd21f8e1.jpg
#   inflating: challenge_3_training_dataset/images/b8ee30536d46be98.jpg
#   inflating: challenge_3_training_dataset/images/5c4c492692c87ecd.jpg
#   inflating: challenge_3_training_dataset/images/e36c15cfd28bfc08.jpg
#   inflating: challenge_3_training_dataset/images/4c4551569f47ad49.jpg
#   inflating: challenge_3_training_dataset/images/4dbb2b3190a51569.jpg
#   inflating: challenge_3_training_dataset/images/b922fe38da6fa50d.jpg
#   inflating: challenge_3_training_dataset/images/a2b5126e34af7fd6.jpg
#   inflating: challenge_3_training_dataset/images/4f23a6df51640253.jpg
#   inflating: challenge_3_training_dataset/images/6bbbec6427d1c779.jpg
#   inflating: challenge_3_training_dataset/images/e4b9d10da742d7b7.jpg
#   inflating: challenge_3_training_dataset/images/0a4dec2621dcd3a5.jpg
#   inflating: challenge_3_training_dataset/images/4ae06b398632742a.jpg
#   inflating: challenge_3_training_dataset/images/87de2f0fdb2db1a2.jpg
#   inflating: challenge_3_training_dataset/images/56621febbea4524e.jpg
#   inflating: challenge_3_training_dataset/images/b6030979ffbf6c00.jpg
#   inflating: challenge_3_training_dataset/images/efb9ff0de3ad11a2.jpg
#   inflating: challenge_3_training_dataset/images/de87fafc62573667.jpg
#   inflating: challenge_3_training_dataset/images/1766195f38429179.jpg
#   inflating: challenge_3_training_dataset/images/378a9a2ef7f45dd3.jpg
#   inflating: challenge_3_training_dataset/images/d778f1f57adf4754.jpg
#   inflating: challenge_3_training_dataset/images/56043ab8efdbe5b2.jpg
#   inflating: challenge_3_training_dataset/images/032ad8d5bc321c18.jpg
#   inflating: challenge_3_training_dataset/images/fefc782cf6a95e5b.jpg
#   inflating: challenge_3_training_dataset/images/06e1577ba49438fc.jpg
#   inflating: challenge_3_training_dataset/images/871bdd75102dad18.jpg
#   inflating: challenge_3_training_dataset/images/a99a0d4a56e7028a.jpg
#   inflating: challenge_3_training_dataset/images/0d36342bc84bb028.jpg
#   inflating: challenge_3_training_dataset/images/97635b2ff7c23c88.jpg
#   inflating: challenge_3_training_dataset/images/7a4143689fd6b616.jpg
#   inflating: challenge_3_training_dataset/images/c740e3cf6d3602f7.jpg
#   inflating: challenge_3_training_dataset/images/2efcd72467c1aca0.jpg
#   inflating: challenge_3_training_dataset/images/ad0ee9d9af02cd89.jpg
#   inflating: challenge_3_training_dataset/images/b7f9d5519830c286.jpg
#   inflating: challenge_3_training_dataset/images/dbcacc17e6e4a3cf.jpg
#   inflating: challenge_3_training_dataset/images/84918f7ff34e6b78.jpg
#   inflating: challenge_3_training_dataset/images/1ab410308103e47a.jpg
#   inflating: challenge_3_training_dataset/images/00b1546d70acfc68.jpg
#   inflating: challenge_3_training_dataset/images/0c46a332a6824cdb.jpg
#   inflating: challenge_3_training_dataset/images/3f107b80e7151196.jpg
#   inflating: challenge_3_training_dataset/images/e6e5b92a6dea7b57.jpg
#   inflating: challenge_3_training_dataset/images/ea91243eb2b0f587.jpg
#   inflating: challenge_3_training_dataset/images/ffc8c4cb8555bf28.jpg
#   inflating: challenge_3_training_dataset/images/4b0ee704c164799f.jpg
#   inflating: challenge_3_training_dataset/images/b859b8b5019cd7e3.jpg
#   inflating: challenge_3_training_dataset/images/6e169d1c0a40d9ae.jpg
#   inflating: challenge_3_training_dataset/images/047386d21e492ea7.jpg
#   inflating: challenge_3_training_dataset/images/f1887717e51fa0da.jpg
#   inflating: challenge_3_training_dataset/images/0d805777be866ed5.jpg
#   inflating: challenge_3_training_dataset/images/1540c95c1f0f6c45.jpg
#   inflating: challenge_3_training_dataset/images/0fab62b433e2df57.jpg
#   inflating: challenge_3_training_dataset/images/0ef1017030401a2c.jpg
#   inflating: challenge_3_training_dataset/images/0654feeb185de6c0.jpg
#   inflating: challenge_3_training_dataset/images/6b158f387d49e8d5.jpg
#   inflating: challenge_3_training_dataset/images/57697c6d6c8fe5cd.jpg
#   inflating: challenge_3_training_dataset/images/02217dc6dd05d48b.jpg
#   inflating: challenge_3_training_dataset/images/a9488bce38b479cc.jpg
#   inflating: challenge_3_training_dataset/images/d616d3085c007cd1.jpg
#   inflating: challenge_3_training_dataset/images/9e2e18a8f7430ea4.jpg
#   inflating: challenge_3_training_dataset/images/82cddd746f109428.jpg
#   inflating: challenge_3_training_dataset/images/0bcc70e4083d8a16.jpg
#   inflating: challenge_3_training_dataset/images/0f6b1ca06bc6b4c5.jpg
#   inflating: challenge_3_training_dataset/images/d3275c467b36262d.jpg
#   inflating: challenge_3_training_dataset/images/2e53b8ccaa8c9138.jpg
#   inflating: challenge_3_training_dataset/images/76f58a87934f4dc6.jpg
#   inflating: challenge_3_training_dataset/images/188011f100f8e03e.jpg
#   inflating: challenge_3_training_dataset/images/03714cc06f882fc8.jpg
#   inflating: challenge_3_training_dataset/images/aacf2ab21b65e9e2.jpg
#   inflating: challenge_3_training_dataset/images/9e4990414672d622.jpg
#   inflating: challenge_3_training_dataset/images/ae9a1409cd6d0c13.jpg
#   inflating: challenge_3_training_dataset/images/761b0a44b8b90681.jpg
#   inflating: challenge_3_training_dataset/images/5a228fbbec007f46.jpg
#   inflating: challenge_3_training_dataset/images/ba8a80600ab238c9.jpg
#   inflating: challenge_3_training_dataset/images/af6999e0c06958db.jpg
#   inflating: challenge_3_training_dataset/images/e313f933b1e8f321.jpg
#   inflating: challenge_3_training_dataset/images/1e69af1a633da7ae.jpg
#   inflating: challenge_3_training_dataset/images/2059e303a8b7e5fd.jpg
#   inflating: challenge_3_training_dataset/images/044b3c000665b228.jpg
#   inflating: challenge_3_training_dataset/images/1c657d28352baf45.jpg
#   inflating: challenge_3_training_dataset/images/03fd40e16eacba92.jpg
#   inflating: challenge_3_training_dataset/images/c964ba53e580caf1.jpg
#   inflating: challenge_3_training_dataset/images/a1c8899e8ea34424.jpg
#   inflating: challenge_3_training_dataset/images/9fe2202abd8110f1.jpg
#   inflating: challenge_3_training_dataset/images/8de1d9102983f356.jpg
#   inflating: challenge_3_training_dataset/images/05ea04c0b3aa2e8a.jpg
#   inflating: challenge_3_training_dataset/images/fc32114c26722fb2.jpg
#   inflating: challenge_3_training_dataset/images/b41f2ff0a00d4ef1.jpg
#   inflating: challenge_3_training_dataset/images/1010fa785b253901.jpg
#   inflating: challenge_3_training_dataset/images/55101587e9be3682.jpg
#   inflating: challenge_3_training_dataset/images/bc99ddf3a3d80448.jpg
#   inflating: challenge_3_training_dataset/images/f006f3aa9d8d68f4.jpg
#   inflating: challenge_3_training_dataset/images/9b28d5cd7a20c92d.jpg
#   inflating: challenge_3_training_dataset/images/1261ff4a750bddbb.jpg
#   inflating: challenge_3_training_dataset/images/e01263c97c5382b0.jpg
#   inflating: challenge_3_training_dataset/images/cb12322c2ea16494.jpg
#   inflating: challenge_3_training_dataset/images/c667f0879d72a238.jpg
#   inflating: challenge_3_training_dataset/images/92fc8793c3c98f97.jpg
#   inflating: challenge_3_training_dataset/images/2bfefa303d112750.jpg
#   inflating: challenge_3_training_dataset/images/0c61b63cd816ec7b.jpg
#   inflating: challenge_3_training_dataset/images/ad0bbcd5afd3b39c.jpg
#   inflating: challenge_3_training_dataset/images/b8814482dc475369.jpg
#   inflating: challenge_3_training_dataset/images/3813fd89a0b8a885.jpg
#   inflating: challenge_3_training_dataset/images/17b958fb9bfd1f80.jpg
#   inflating: challenge_3_training_dataset/images/001b4f6d9aedff6f.jpg
#   inflating: challenge_3_training_dataset/images/18cce26c393a6e7e.jpg
#   inflating: challenge_3_training_dataset/images/2124817d82188d8d.jpg
#   inflating: challenge_3_training_dataset/images/96824ff7418de0ad.jpg
#   inflating: challenge_3_training_dataset/images/a133f10cae0dcf0b.jpg
#   inflating: challenge_3_training_dataset/images/e685e56dafd55ab2.jpg
#   inflating: challenge_3_training_dataset/images/12f270452effb284.jpg
#   inflating: challenge_3_training_dataset/images/0a60896e08b1dd23.jpg
#   inflating: challenge_3_training_dataset/images/308f1a8dfd3af262.jpg
#   inflating: challenge_3_training_dataset/images/40b92c1f8f1830e8.jpg
#   inflating: challenge_3_training_dataset/images/ab296ec6ddfb58b8.jpg
#   inflating: challenge_3_training_dataset/images/1a12288b422cd011.jpg
#   inflating: challenge_3_training_dataset/images/c9b8ed02ac692391.jpg
#   inflating: challenge_3_training_dataset/images/477ca003d0c72997.jpg
#   inflating: challenge_3_training_dataset/images/a5a3e3f9902ede18.jpg
#   inflating: challenge_3_training_dataset/images/4cc61fddd2669a38.jpg
#   inflating: challenge_3_training_dataset/images/6f3fc91a96e478fc.jpg
#   inflating: challenge_3_training_dataset/images/d9fa517b20e3d328.jpg
#   inflating: challenge_3_training_dataset/images/a46de638fc176504.jpg
#   inflating: challenge_3_training_dataset/images/06d8605f0779c0ef.jpg
#   inflating: challenge_3_training_dataset/images/3b8c3b924f46c4db.jpg
#   inflating: challenge_3_training_dataset/images/a2fcdbe1d2010526.jpg
#   inflating: challenge_3_training_dataset/images/407110f8918b741a.jpg
#   inflating: challenge_3_training_dataset/images/a1f9ea596c18f642.jpg
#   inflating: challenge_3_training_dataset/images/0dd3211c2ad294a3.jpg
#   inflating: challenge_3_training_dataset/images/02a694cdf187832f.jpg
#   inflating: challenge_3_training_dataset/images/2312ed137dc24406.jpg

# %%
# unzip the hidden dataset
# !unzip $training_path_2
# Out:
# Archive:  /content/drive/MyDrive/TIL2021_CV/challenge_3_egg.zip
#    creating: c2_egg/
#   inflating: c2_egg/labels.json
#   inflating: c2_egg/CREDITS.txt
#    creating: c2_egg/images/
#   inflating: c2_egg/images/430b6c8952b3d278.jpg
#   inflating: c2_egg/images/b37f9ae6aead7898.jpg
#   inflating: c2_egg/images/00eb56e0181bbc4c.jpg
#   inflating: c2_egg/images/49a263e08f5b1a68.jpg
#   inflating: c2_egg/images/36f6913546ab262c.jpg
#   inflating: c2_egg/images/cdb7a5e2e8e634d8.jpg
#   inflating: c2_egg/images/12f6efb65e152127.jpg
#   inflating: c2_egg/images/073c2441e569da93.jpg
#   inflating: c2_egg/images/010d3504e978b684.jpg
#   inflating: c2_egg/images/0a638fe177e9e544.jpg
#   inflating: c2_egg/images/8dce731f03f50326.jpg
#   inflating: c2_egg/images/072cc4e2ee20944d.jpg
#   inflating: c2_egg/images/b5e8ea4ba1c290c3.jpg
#   inflating: c2_egg/images/05f2c2f0879ffbbd.jpg
#   inflating: c2_egg/images/0c6656d1ba3dcb13.jpg
#   inflating: c2_egg/images/0aa058a0af200832.jpg
#   inflating: c2_egg/images/36c8912ee2b7e120.jpg
#   inflating: c2_egg/images/0c906bcf6f8e3595.jpg
#   inflating: c2_egg/images/96fa340b4b722395.jpg
#   inflating: c2_egg/images/361bf50c94412928.jpg
#   inflating: c2_egg/images/6b948b5b9590d105.jpg
#   inflating: c2_egg/images/3ab56777a5c13219.jpg
#   inflating: c2_egg/images/22229f46ac2d35c4.jpg
#   inflating: c2_egg/images/b6f77e902a3a6097.jpg
#   inflating: c2_egg/images/0fa605e9e8326223.jpg
#   inflating: c2_egg/images/511814ed21a7dc3c.jpg
#   inflating: c2_egg/images/288717d759877c19.jpg
#   inflating: c2_egg/images/477f752d420f7306.jpg
#   inflating: c2_egg/images/0187938d277188fa.jpg
#   inflating: c2_egg/images/3aeda2b040c2a8a8.jpg
#   inflating: c2_egg/images/1d59043a276df26f.jpg
#   inflating: c2_egg/images/162449d590357ff7.jpg
#   inflating: c2_egg/images/01b4ceb860f69935.jpg
#   inflating: c2_egg/images/46b5b8733299ecaf.jpg
#   inflating: c2_egg/images/0a57c1829ae8f2a1.jpg
#   inflating: c2_egg/images/44e5680c5540be2b.jpg
#   inflating: c2_egg/images/8b13948a873a572c.jpg
#   inflating: c2_egg/images/9dec0c0023e808d0.jpg
#   inflating: c2_egg/images/5f5ca193628eaf37.jpg
#   inflating: c2_egg/images/198cd92119d4ca6c.jpg
#   inflating: c2_egg/images/0a9be7351e8152c9.jpg
#   inflating: c2_egg/images/61fb335b0fc73ce1.jpg
#   inflating: c2_egg/images/0bdc8bc48fd3a704.jpg
#   inflating: c2_egg/images/b7fffcf2ea0c74ca.jpg
#   inflating: c2_egg/images/2adbc285573e0125.jpg
#   inflating: c2_egg/images/34c83c9317680a08.jpg
#   inflating: c2_egg/images/6b4870fb794d8a44.jpg
#   inflating: c2_egg/images/1d1b15275897d8d8.jpg
#   inflating: c2_egg/images/6a6ee3ce087999a8.jpg
#   inflating: c2_egg/images/37b258506c359fab.jpg
#   inflating: c2_egg/images/501207cae896f008.jpg
#   inflating: c2_egg/images/1a66aaba40901da9.jpg
#   inflating: c2_egg/images/2f1a907e51d8c12e.jpg
#   inflating: c2_egg/images/0e68b845669914ac.jpg
#   inflating: c2_egg/images/2e063e44b6d88899.jpg
#   inflating: c2_egg/images/7271e7827d61e533.jpg
#   inflating: c2_egg/images/96b89562d165b0d8.jpg
#   inflating: c2_egg/images/54cc2d0dc82639f1.jpg
#   inflating: c2_egg/images/98c8f11c1d0ce4c2.jpg
#   inflating: c2_egg/images/28bd217d0578d630.jpg
#   inflating: c2_egg/images/ceee05d602f1d5ab.jpg
#   inflating: c2_egg/images/6ffd708485e73df0.jpg
#   inflating: c2_egg/images/0b86812c24878e9e.jpg
#   inflating: c2_egg/images/37a1bdb2b9b52e4d.jpg
#   inflating: c2_egg/images/0bd164322fee0cff.jpg
#   inflating: c2_egg/images/2cef000a22595b9a.jpg
#   inflating: c2_egg/images/0fc278c7599d8e66.jpg
#   inflating: c2_egg/images/02e9b2c4fc68e5f2.jpg
#   inflating: c2_egg/images/9eb940cc7558082d.jpg
#   inflating: c2_egg/images/2c20ce43b2bc9924.jpg
#   inflating: c2_egg/images/0d7fb9480f812478.jpg
#   inflating: c2_egg/images/0044bd9f234a09df.jpg
#   inflating: c2_egg/images/1e532184dd2b69a5.jpg
#   inflating: c2_egg/images/44dd1f9fd0525b93.jpg
#   inflating: c2_egg/images/b9cf679db36bf28d.jpg
#   inflating: c2_egg/images/11121cc44a99e018.jpg
#   inflating: c2_egg/images/5ffc2b3510ddbeda.jpg
#   inflating: c2_egg/images/ca540aa57ba9431f.jpg
#   inflating: c2_egg/images/b33bae93742766bc.jpg
#   inflating: c2_egg/images/9514e7b0de6b287a.jpg
#   inflating: c2_egg/images/1e9355888979a1d7.jpg
#   inflating: c2_egg/images/1d810be7bc6f370b.jpg
#   inflating: c2_egg/images/049e0512e75a1b25.jpg
#   inflating: c2_egg/images/1d9f65531d68ec05.jpg
#   inflating: c2_egg/images/9860ed76ae8768e0.jpg
#   inflating: c2_egg/images/01dd166313ba7ca5.jpg
#   inflating: c2_egg/images/2eb08429dda57bf7.jpg
#   inflating: c2_egg/images/2e9f99593025064b.jpg
#   inflating: c2_egg/images/1ee3066a476fb619.jpg
#   inflating: c2_egg/images/b981ba3eada64a5c.jpg
#   inflating: c2_egg/images/1bde4319f699b471.jpg
#   inflating: c2_egg/images/2f258bd4c67c490d.jpg
#   inflating: c2_egg/images/01befe6ba0fded96.jpg
#   inflating: c2_egg/images/99338c0171a30f16.jpg
#   inflating: c2_egg/images/1b4cdf2f85782aa1.jpg
#   inflating: c2_egg/images/0d247adaa87e4587.jpg
#   inflating: c2_egg/images/9d96547140a5e8e6.jpg
#   inflating: c2_egg/images/0dd0f2b97da1999b.jpg
#   inflating: c2_egg/images/244eb778cfdfeb04.jpg
#   inflating: c2_egg/images/d6fbb2b2f7f800aa.jpg
#   inflating: c2_egg/images/408592b4ecf411cc.jpg
#   inflating: c2_egg/images/96fedc6ea5c91f26.jpg
#   inflating: c2_egg/images/8381be4321f8b5ac.jpg
#   inflating: c2_egg/images/cbbe520482167d89.jpg
#   inflating: c2_egg/images/28e8e6874af4d23d.jpg
#   inflating: c2_egg/images/40ef95b90cb3c430.jpg
#   inflating: c2_egg/images/0ca88b2e450e1257.jpg
#   inflating: c2_egg/images/788677debdb73180.jpg
#   inflating: c2_egg/images/46b9f5c6b0ce6039.jpg
#   inflating: c2_egg/images/0aeb3b0d5870bb1a.jpg
#   inflating: c2_egg/images/6d7d075bd2f45b31.jpg
#   inflating: c2_egg/images/45f0be0212c258b5.jpg
#   inflating: c2_egg/images/261189f153105802.jpg
#   inflating: c2_egg/images/d6f9b5413448ccdd.jpg
#   inflating: c2_egg/images/08b537a0093ae4f0.jpg
#   inflating: c2_egg/images/261c5a92e8ad6a63.jpg
#   inflating: c2_egg/images/2db13583339ce2b5.jpg
#   inflating: c2_egg/images/b6fda0b9c264f381.jpg
#   inflating: c2_egg/images/10f1b57e797593af.jpg
#   inflating: c2_egg/images/00ac21346de661cb.jpg
#   inflating: c2_egg/images/63a1f698dd258d10.jpg
#   inflating: c2_egg/images/0c222a6ab4ece888.jpg
#   inflating: c2_egg/images/0396cf22eb62ae97.jpg
#   inflating: c2_egg/images/0afc1399e0d6290f.jpg
#   inflating: c2_egg/images/0d1db5a77fb71f61.jpg
#   inflating: c2_egg/images/2d743594c2b2ce1f.jpg
#   inflating: c2_egg/images/12601c8e25c37395.jpg
#   inflating: c2_egg/images/1c41fff272948175.jpg
#   inflating: c2_egg/images/7df05110b9d02888.jpg
#   inflating: c2_egg/images/73c6e816e391c435.jpg
#   inflating: c2_egg/images/229182db2b587c18.jpg
#   inflating: c2_egg/images/39c699e35cbdbc11.jpg
#   inflating: c2_egg/images/7e1e14bf2065b5a7.jpg
#   inflating: c2_egg/images/48b72dab41ea7496.jpg
#   inflating: c2_egg/images/526775c6f6ba5e34.jpg
#   inflating: c2_egg/images/35fe45dfd9d181a8.jpg
#   inflating: c2_egg/images/95c9b77bef0f9171.jpg
#   inflating: c2_egg/images/b04cda346958530e.jpg
#   inflating: c2_egg/images/13f6ac74922a9ade.jpg
#   inflating: c2_egg/images/0b4d3e75eeecd058.jpg
#   inflating: c2_egg/images/92e024269907f738.jpg
#   inflating: c2_egg/images/b8b7a1b5165d9176.jpg
#   inflating: c2_egg/images/39d2013cce8ec7ca.jpg
#   inflating: c2_egg/images/35a08d82448f9e36.jpg
#   inflating: c2_egg/images/1f034e36ca785fa4.jpg
#   inflating: c2_egg/images/1cd75c94664a0e69.jpg
#   inflating: c2_egg/images/38e237e73c986360.jpg
#   inflating: c2_egg/images/05cfd4ecf5521857.jpg
#   inflating: c2_egg/images/9924d3e9896f7ea2.jpg
#   inflating: c2_egg/images/0ef642b528370232.jpg
#   inflating: c2_egg/images/08c35012dcbd4f95.jpg
#   inflating: c2_egg/images/2ced2cac4034b47c.jpg
#   inflating: c2_egg/images/34b55134c6f50f4a.jpg
#   inflating: c2_egg/images/277eb11281ff5c5e.jpg
#   inflating: c2_egg/images/63ae1f1cfac76f01.jpg
#   inflating: c2_egg/images/1b3d3bf019d041e9.jpg
#   inflating: c2_egg/images/39a2e947cf56d6ca.jpg
#   inflating: c2_egg/images/cfabf844cee31064.jpg
#   inflating: c2_egg/images/0bed81ce2db75c4a.jpg
#   inflating: c2_egg/images/0b012176fa4a2f0c.jpg
#   inflating: c2_egg/images/313a49ce1db7ace7.jpg
#   inflating: c2_egg/images/7f97c12895487cde.jpg
#   inflating: c2_egg/images/179837c36ed8cc2f.jpg
#   inflating: c2_egg/images/01c64f0a32e1d48d.jpg
#   inflating: c2_egg/images/0c0e20b0948494b0.jpg
#   inflating: c2_egg/images/5c984fa91a1f9197.jpg
#   inflating: c2_egg/images/9e550ebad0f229b1.jpg
#   inflating: c2_egg/images/00c5cee909ccb813.jpg
#   inflating: c2_egg/images/169523f8607525dc.jpg
#   inflating: c2_egg/images/2c0b85ac9cedb43d.jpg
#   inflating: c2_egg/images/cfef2c74b29cb088.jpg
#   inflating: c2_egg/images/074ecc0d068758e9.jpg
#   inflating: c2_egg/images/0f3031ec7ce327f3.jpg
#   inflating: c2_egg/images/b73226c4365dff16.jpg
#   inflating: c2_egg/images/0760695feee2f30a.jpg
#   inflating: c2_egg/images/24334a0e1c88495c.jpg
#   inflating: c2_egg/images/d7d503087cc98533.jpg
#   inflating: c2_egg/images/57c4d3306e380120.jpg
#   inflating: c2_egg/images/1d4744c1ef1c7867.jpg
#   inflating: c2_egg/images/9567f7390f4efc70.jpg
#   inflating: c2_egg/images/0c6713cf002f756a.jpg
#   inflating: c2_egg/images/0f25dd002d26158b.jpg
#   inflating: c2_egg/images/0cab0cb9f4a63d4c.jpg
#   inflating: c2_egg/images/6b3eec109c55ac14.jpg
#   inflating: c2_egg/images/45dfdf4d4b862d9c.jpg
#   inflating: c2_egg/images/0029a9c8dbbd3dc6.jpg
#   inflating: c2_egg/images/0e8a24b569a3770c.jpg
#   inflating: c2_egg/images/2e35842058863c8e.jpg
#   inflating: c2_egg/images/2de6c66b335294ee.jpg
#   inflating: c2_egg/images/423bb175ea94d697.jpg
#   inflating: c2_egg/images/9e520791e466f2ad.jpg
#   inflating: c2_egg/images/b9dddc0bd16ef6db.jpg
#   inflating: c2_egg/images/1d5f24f4ea2da95c.jpg
#   inflating: c2_egg/images/02f23eae5ac0ef42.jpg
#   inflating: c2_egg/images/7e221ad9496b1c7c.jpg
#   inflating: c2_egg/images/0cefe79a0a9fb213.jpg
#   inflating: c2_egg/images/1c08b76c661e5c06.jpg
#   inflating: c2_egg/images/3b64c2140f014dff.jpg
#   inflating: c2_egg/images/1b642ac517ab10b5.jpg
#   inflating: c2_egg/images/198c7498cc4de910.jpg
#   inflating: c2_egg/images/9de6d84984ff55ec.jpg
#   inflating: c2_egg/images/01bcb081c487a4b1.jpg
#   inflating: c2_egg/images/0c0603b8c0105a6d.jpg
#   inflating: c2_egg/images/006f7dfef6badd6a.jpg
#   inflating: c2_egg/images/59e113e00a72d95e.jpg
#   inflating: c2_egg/images/0fef4545be15c3bd.jpg
#   inflating: c2_egg/images/0ebbea68d6fb2768.jpg
#   inflating: c2_egg/images/00fb001de33a7b71.jpg
#   inflating: c2_egg/images/0a79782f1fee353e.jpg
#   inflating: c2_egg/images/0c83c424679ad9c8.jpg
#   inflating: c2_egg/images/7f4ba37199bbcbc0.jpg
#   inflating: c2_egg/images/2a54a813f4d7149b.jpg
#   inflating: c2_egg/images/02fe96679cf5d8e5.jpg
#   inflating: c2_egg/images/5feb298154ac4fef.jpg
#   inflating: c2_egg/images/b727077f59ca553e.jpg
#   inflating: c2_egg/images/3a191c0749484f8e.jpg
#   inflating: c2_egg/images/494d710685ad9290.jpg
#   inflating: c2_egg/images/03ae2eda6e83f025.jpg
#   inflating: c2_egg/images/ce684e28b0aa05cb.jpg
#   inflating: c2_egg/images/41febee2903a69d8.jpg
#   inflating: c2_egg/images/00e6d310f33c2e42.jpg
#   inflating: c2_egg/images/40bf3894830e114a.jpg
#   inflating: c2_egg/images/2b8e92d3c8c1099c.jpg
#   inflating: c2_egg/images/410862ad104c2ebe.jpg
#   inflating: c2_egg/images/1c11ec5102cce880.jpg
#   inflating: c2_egg/images/b95d5c89f68d5ced.jpg
#   inflating: c2_egg/images/1de68e44f26155a7.jpg
#   inflating: c2_egg/images/1d85cd68f06d808c.jpg
#   inflating: c2_egg/images/48f263ecd5460501.jpg
#   inflating: c2_egg/images/48045d93a5458e97.jpg
#   inflating: c2_egg/images/d30cb4dde7f4eeab.jpg
#   inflating: c2_egg/images/d9a8d6f471aa04f4.jpg
#   inflating: c2_egg/images/913421c3dd3bada9.jpg
#   inflating: c2_egg/images/51dbdee04d1f6490.jpg
#   inflating: c2_egg/images/6aa234b831647db1.jpg
#   inflating: c2_egg/images/0ef30cd6bbf348fc.jpg
#   inflating: c2_egg/images/0d0f57ccbc7f97df.jpg
#   inflating: c2_egg/images/8db600950c992f7c.jpg
#   inflating: c2_egg/images/47057f1b98d8b74b.jpg
#   inflating: c2_egg/images/9811c9e2c85518fc.jpg
#   inflating: c2_egg/images/0de37fd2d28dd3f9.jpg
#   inflating: c2_egg/images/2d394caf550b8c75.jpg
#   inflating: c2_egg/images/0d41b39d09b8db04.jpg
#   inflating: c2_egg/images/cb2987c0796349de.jpg
#   inflating: c2_egg/images/5bff0c3e04c922ff.jpg
#   inflating: c2_egg/images/119ef168507675e6.jpg
#   inflating: c2_egg/images/45b55746e8f153c1.jpg
#   inflating: c2_egg/images/0f1deffebd654cfe.jpg
#   inflating: c2_egg/images/35b7be2d65bd9327.jpg
#   inflating: c2_egg/images/9dbc7640b4a9a4e8.jpg
#   inflating: c2_egg/images/0605612b2f1bb5af.jpg
#   inflating: c2_egg/images/45a8d9fee8ff45b5.jpg
#   inflating: c2_egg/images/2fe3612f49b03c44.jpg
#   inflating: c2_egg/images/495060e8eccef70f.jpg
#   inflating: c2_egg/images/38beb7f6e10318bd.jpg
#   inflating: c2_egg/images/6d054fb5ce268c7e.jpg
#   inflating: c2_egg/images/0a61c79bae099e59.jpg
#   inflating: c2_egg/images/1be83aeb9c6eff5e.jpg
#   inflating: c2_egg/images/0a8bb3387dc08b31.jpg
#   inflating: c2_egg/images/0fdd15f168b49b61.jpg
#   inflating: c2_egg/images/92d004879847dd0e.jpg
#   inflating: c2_egg/images/1edcb3f1f38d3d8d.jpg
#   inflating: c2_egg/images/0f426e88334b2b63.jpg
#   inflating: c2_egg/images/1b4ed19dfca20abb.jpg
#   inflating: c2_egg/images/b8a4d651bf85d0d1.jpg
#   inflating: c2_egg/images/08a98dd2c64bde49.jpg
#   inflating: c2_egg/images/70b0a8aca68eee0e.jpg
#   inflating: c2_egg/images/07b30d393afe9ec7.jpg
#   inflating: c2_egg/images/0f10a09374f4e487.jpg
#   inflating: c2_egg/images/9f14b6cd8f30d0a3.jpg
#   inflating: c2_egg/images/8d6170e811c98cad.jpg
#   inflating: c2_egg/images/7b6fae5fb480da21.jpg
#   inflating: c2_egg/images/874074c2b113a318.jpg
#   inflating: c2_egg/images/38c7738e3e76e19d.jpg
#   inflating: c2_egg/images/107c94518285c482.jpg
#   inflating: c2_egg/images/40a3040278e731e2.jpg
#   inflating: c2_egg/images/1fc2136fe0df1ec2.jpg
#   inflating: c2_egg/images/b855b48a33411d6e.jpg
#   inflating: c2_egg/images/8817fb7dfc70f00e.jpg
#   inflating: c2_egg/images/39cbf42572aef2d3.jpg
#   inflating: c2_egg/images/0adfe14b34dc90d7.jpg
#   inflating: c2_egg/images/810612fa8a257a46.jpg
#   inflating: c2_egg/images/48b5750f8de6ad29.jpg
#   inflating: c2_egg/images/14a0c603bfa93107.jpg
#   inflating: c2_egg/images/b1046ae5788a376b.jpg
#   inflating: c2_egg/images/5d8e80fde5c0e9a5.jpg
#   inflating: c2_egg/images/0ba8f4463ed0513f.jpg
#   inflating: c2_egg/images/6a51d94f9fea1282.jpg
#   inflating: c2_egg/images/6b08fddd817f4498.jpg
#   inflating: c2_egg/images/08b1347f2e2daed8.jpg
#   inflating: c2_egg/images/0c450a106b43192c.jpg
#   inflating: c2_egg/images/880503b921832ce6.jpg
#   inflating: c2_egg/images/6d73457671ae08e3.jpg
#   inflating: c2_egg/images/1c6b578ed548a788.jpg
#   inflating: c2_egg/images/879234f73f9c7f7a.jpg
#   inflating: c2_egg/images/0c667cd7a88a69bc.jpg
#   inflating: c2_egg/images/6cfd37c2bff63f54.jpg
#   inflating: c2_egg/images/9d80b0c30bf8037f.jpg
#   inflating: c2_egg/images/0d43a66f6c0f1762.jpg
#   inflating: c2_egg/images/d1e1c64166db71b0.jpg
#   inflating: c2_egg/images/cf956c7272e66c44.jpg
#   inflating: c2_egg/images/00bc274417086be8.jpg
#   inflating: c2_egg/images/d7a7a567498967ab.jpg
#   inflating: c2_egg/images/8f0035b28b4d731a.jpg
#   inflating: c2_egg/images/2a1fe2203701846e.jpg
#   inflating: c2_egg/images/691270d41fe244f7.jpg
#   inflating: c2_egg/images/9603c3e72e602dfa.jpg
#   inflating: c2_egg/images/b82b3832af5083a8.jpg
#   inflating: c2_egg/images/7e3e06829a79f387.jpg
#   inflating: c2_egg/images/d7afe1abd0114faa.jpg
#   inflating: c2_egg/images/0fb5818d079e5bd8.jpg
#   inflating: c2_egg/images/0ed98a3dc7c9749b.jpg
#   inflating: c2_egg/images/0116a9590f55a74a.jpg
#   inflating: c2_egg/images/851475d1b1bebd6e.jpg
#   inflating: c2_egg/images/225726c336ba627c.jpg
#   inflating: c2_egg/images/0b6009218f775540.jpg
#   inflating: c2_egg/images/0a16b5b8dc4a94f4.jpg
#   inflating: c2_egg/images/28b995bf296aa721.jpg
#   inflating: c2_egg/images/195142c397956115.jpg
#   inflating: c2_egg/images/1be4ab523fcba1b5.jpg
#   inflating: c2_egg/images/47703d18b2919fae.jpg
#   inflating: c2_egg/images/05e753d1256bf65e.jpg
#   inflating: c2_egg/images/78b201788ab28a18.jpg
#   inflating: c2_egg/images/7aeb74a2b01dcfce.jpg
#   inflating: c2_egg/images/437bf7b3a2e9aa94.jpg
#   inflating: c2_egg/images/d1bbaffe93b7d9be.jpg
#   inflating: c2_egg/images/1be1f01218a7ab1f.jpg
#   inflating: c2_egg/images/7e23ecc939de592f.jpg
#   inflating: c2_egg/images/cbe77174e19adf18.jpg
#   inflating: c2_egg/images/2c1d47ce076e49f8.jpg
#   inflating: c2_egg/images/53e281027435ac55.jpg
#   inflating: c2_egg/images/d03d874fc50190c3.jpg
#   inflating: c2_egg/images/0d09f6c2c80d398c.jpg
#   inflating: c2_egg/images/43bf8cce9e2c4057.jpg
#   inflating: c2_egg/images/1cbe030af35c22e2.jpg
#   inflating: c2_egg/images/455315d7a09428d8.jpg
#   inflating: c2_egg/images/9d875c1e7ccd73b2.jpg
#   inflating: c2_egg/images/43fa3c06dd50255e.jpg
#   inflating: c2_egg/images/0a540a5dacc15c4a.jpg
#   inflating: c2_egg/images/32fadc77d3dd202f.jpg
#   inflating: c2_egg/images/9da22f0fe6a391a1.jpg
#   inflating: c2_egg/images/1f55a26fc0fc4a18.jpg
#   inflating: c2_egg/images/0bb418465b4edaac.jpg
#   inflating: c2_egg/images/06e8d670ff5b873b.jpg
#   inflating: c2_egg/images/1c3a5ca432c31f68.jpg
#   inflating: c2_egg/images/36bfa1323d4d96d6.jpg
#   inflating: c2_egg/images/02b6ef8194309a1d.jpg
#   inflating: c2_egg/images/62c02e03473d4939.jpg
#   inflating: c2_egg/images/0c0837f60e8406f2.jpg
#   inflating: c2_egg/images/045fcc437d8c4f56.jpg
#   inflating: c2_egg/images/090059a10c7cb3fb.jpg
#   inflating: c2_egg/images/057b22b77d455784.jpg
#   inflating: c2_egg/images/0b719eba5b604429.jpg
#   inflating: c2_egg/images/3abaaf3c50f16185.jpg
#   inflating: c2_egg/images/8538ae41301da5ee.jpg
#   inflating: c2_egg/images/0dbd1a7c6aa55deb.jpg
#   inflating: c2_egg/images/00b115e52ab95c0b.jpg
#   inflating: c2_egg/images/623231f76c1c482f.jpg
#   inflating: c2_egg/images/8cf1be53ac57a257.jpg
#   inflating: c2_egg/images/53efa292b1cf3d57.jpg
#   inflating: c2_egg/images/d7a76c3498e1a826.jpg
#   inflating: c2_egg/images/57d0a993c25a4c4b.jpg
#   inflating: c2_egg/images/9f81b0ac1dd893d6.jpg
#   inflating: c2_egg/images/14cf28f3a53db541.jpg
#   inflating: c2_egg/images/07ac2069b4bed13c.jpg
#   inflating: c2_egg/images/5bb16b066f861afa.jpg
#   inflating: c2_egg/images/28c42e47ba771e4c.jpg
#   inflating: c2_egg/images/9d779c260afc5e20.jpg
#   inflating: c2_egg/images/7923f64f557d9073.jpg
#   inflating: c2_egg/images/42fb3f2cc693455d.jpg
#   inflating: c2_egg/images/0eda15360745effb.jpg
#   inflating: c2_egg/images/06cc27864a476e45.jpg
#   inflating: c2_egg/images/00c4288add401893.jpg
#   inflating: c2_egg/images/11d2433614e8fa7d.jpg
#   inflating: c2_egg/images/d5e8d53e137c1622.jpg
#   inflating: c2_egg/images/0bd1a1d5446d9e32.jpg
#   inflating: c2_egg/images/48fb65376aa81139.jpg
#   inflating: c2_egg/images/75f29ddc741b19e6.jpg
#   inflating: c2_egg/images/0c3a1083eccd98d4.jpg
#   inflating: c2_egg/images/5e75e1a43b2f5fa7.jpg
#   inflating: c2_egg/images/366afc8bb83ffcca.jpg
#   inflating: c2_egg/images/43fab4af00d7d2f5.jpg
#   inflating: c2_egg/images/93cbd98fba9af736.jpg
#   inflating: c2_egg/images/b50ff84cfe223a89.jpg
#   inflating: c2_egg/images/0c4441333b95cff1.jpg
#   inflating: c2_egg/images/0ae031feb4bf5ea9.jpg
#   inflating: c2_egg/images/02c119fa324c2dea.jpg
#   inflating: c2_egg/images/b9ff39d8146e5b15.jpg
#   inflating: c2_egg/images/2fc770bb4ad1f7f4.jpg
#   inflating: c2_egg/images/50db4276a5c9b558.jpg
#   inflating: c2_egg/images/0d7f40ff39fb3f9c.jpg
#   inflating: c2_egg/images/6acc63ecd29875a0.jpg
#   inflating: c2_egg/images/51eb9b5df5dafbd8.jpg
#   inflating: c2_egg/images/0c354a2da5c00133.jpg
#   inflating: c2_egg/images/7ac469ae1490423c.jpg
#   inflating: c2_egg/images/0e2daf0c06044c0d.jpg
#   inflating: c2_egg/images/1f8310675913ce2e.jpg
#   inflating: c2_egg/images/32aea5d394584be3.jpg
#   inflating: c2_egg/images/37dedab240f19b1f.jpg
#   inflating: c2_egg/images/706214bbe9143ccc.jpg
#   inflating: c2_egg/images/1c48e607b2107a3c.jpg
#   inflating: c2_egg/images/01b7d11556592a08.jpg
#   inflating: c2_egg/images/59c169a4d0cf65af.jpg
#   inflating: c2_egg/images/400660cff0ce0174.jpg
#   inflating: c2_egg/images/1d37ebc07c5fbc10.jpg
#   inflating: c2_egg/images/2abf5be02564b76e.jpg
#   inflating: c2_egg/images/0c2c81c616ae969a.jpg
#   inflating: c2_egg/images/47b730a24132f4e6.jpg
#   inflating: c2_egg/images/0b825fd28b7079f2.jpg
#   inflating: c2_egg/images/0d4e82dfe65704eb.jpg
#   inflating: c2_egg/images/0332f8c0a4ef9946.jpg
#   inflating: c2_egg/images/50d1b9aa1a9d4666.jpg
#   inflating: c2_egg/images/98ed8e23352cc4ab.jpg
#   inflating: c2_egg/images/9e502e766eea3486.jpg
#   inflating: c2_egg/images/0e677d36f8aa1d88.jpg
#   inflating: c2_egg/images/0a8b07df06749c8b.jpg
#   inflating: c2_egg/images/43bb8d0d9cf83dc1.jpg
#   inflating: c2_egg/images/7c530a29650e2ba8.jpg
#   inflating: c2_egg/images/7e97700c809cadd2.jpg
#   inflating: c2_egg/images/0a98bef3e02bbf66.jpg
#   inflating: c2_egg/images/59b2442d3e4ee08f.jpg
#   inflating: c2_egg/images/5fcf77f0412638b1.jpg
#   inflating: c2_egg/images/d6f51bbd3daffe62.jpg
#   inflating: c2_egg/images/1da1c11601bacf84.jpg
#   inflating: c2_egg/images/06f4a9f6f3269c4c.jpg
#   inflating: c2_egg/images/53c1f69f17495fcc.jpg
#   inflating: c2_egg/images/9842c24eb9fc7545.jpg
#   inflating: c2_egg/images/2e3cc0335395abd9.jpg
#   inflating: c2_egg/images/2da696faa756b892.jpg
#   inflating: c2_egg/images/5f7cc98342e694d9.jpg
#   inflating: c2_egg/images/401805c63cb32ba3.jpg
#   inflating: c2_egg/images/365ff9ab109f7b8e.jpg
#   inflating: c2_egg/images/00ce20a1f57a4bb2.jpg
#   inflating: c2_egg/images/0288b15f70d74b72.jpg
#   inflating: c2_egg/images/47f19460670cd5ed.jpg
#   inflating: c2_egg/images/46d4ba61e07b9673.jpg
#   inflating: c2_egg/images/0d5de52a97386b6e.jpg
#   inflating: c2_egg/images/1e777f19164b763f.jpg
#   inflating: c2_egg/images/5f3e6e43625c4f40.jpg
#   inflating: c2_egg/images/63d0a3cf949339d0.jpg
#   inflating: c2_egg/images/cb67980cc2aa67c5.jpg
#   inflating: c2_egg/images/75ad8af1daa1a91e.jpg
#   inflating: c2_egg/images/7b6f8f280dff9e9a.jpg
#   inflating: c2_egg/images/2e8e0c3c3a8036a2.jpg
#   inflating: c2_egg/images/36e107b67c7bfb41.jpg
#   inflating: c2_egg/images/770448d4e2eda248.jpg
#   inflating: c2_egg/images/42aeed9aaedb54a7.jpg
#   inflating: c2_egg/images/2d1f194ffe483ab1.jpg
#   inflating: c2_egg/images/0f6163a20ec2ec02.jpg
#   inflating: c2_egg/images/23743ad48aedae22.jpg
#   inflating: c2_egg/images/01b654e21f6687d2.jpg
#   inflating: c2_egg/images/0c146091018d2dae.jpg
#   inflating: c2_egg/images/0ad8526193fb8cc2.jpg
#   inflating: c2_egg/images/0c57b7bf65996622.jpg
#   inflating: c2_egg/images/2acae55a7aa4f923.jpg
#   inflating: c2_egg/images/48dd04cf273e4685.jpg
#   inflating: c2_egg/images/5f808f503a91bd65.jpg
#   inflating: c2_egg/images/9e612c3b8b525b39.jpg
#   inflating: c2_egg/images/7f076116c3984705.jpg
#   inflating: c2_egg/images/0d898a022fa250fa.jpg
#   inflating: c2_egg/images/cb7f17c4e459564f.jpg
#   inflating: c2_egg/images/2db1030fb8105659.jpg
#   inflating: c2_egg/images/48fc65299afb5793.jpg
#   inflating: c2_egg/images/0f752ebb76aecf41.jpg
#   inflating: c2_egg/images/7e54ceaf39bbe335.jpg
#   inflating: c2_egg/images/0c0a37e35e850bd4.jpg
#   inflating: c2_egg/images/0f12626d20f7fbdb.jpg
#   inflating: c2_egg/images/11fcc498c37450ab.jpg
#   inflating: c2_egg/images/52a9af0c73066e47.jpg
#   inflating: c2_egg/images/2aad338d1b8b7865.jpg
#   inflating: c2_egg/images/0da7f2292c7c9119.jpg
#   inflating: c2_egg/images/0c884af8e6078325.jpg
#   inflating: c2_egg/images/cbf95caa5d695938.jpg
#   inflating: c2_egg/images/1f86da51e9ca9c31.jpg
#   inflating: c2_egg/images/2e9ebb61da7825fe.jpg
#   inflating: c2_egg/images/222c38d9991e97e2.jpg
#   inflating: c2_egg/images/0278a0702bb46012.jpg
#   inflating: c2_egg/images/33ebccd6a6d1bf54.jpg
#   inflating: c2_egg/images/0c75eb92633b6f65.jpg
#   inflating: c2_egg/images/b810d7a8e8903a10.jpg
#   inflating: c2_egg/images/049e700bb3ad0459.jpg
#   inflating: c2_egg/images/4dabd049212b2fd5.jpg
#   inflating: c2_egg/images/30ea820a7388e3a0.jpg
#   inflating: c2_egg/images/500087d36073db54.jpg
#   inflating: c2_egg/images/5f0152267be1e03a.jpg
#   inflating: c2_egg/images/b3326e7e0845ea20.jpg
#   inflating: c2_egg/images/9d48bf280a13ac0b.jpg
#   inflating: c2_egg/images/2cad4b7bf1e28eff.jpg
#   inflating: c2_egg/images/d9d59b11275d852f.jpg
#   inflating: c2_egg/images/32c10462a51dadee.jpg
#   inflating: c2_egg/images/9cab1a7a7ef5af09.jpg
#   inflating: c2_egg/images/09465f0c71195ce2.jpg
#   inflating: c2_egg/images/37b96e62d80f7778.jpg
#   inflating: c2_egg/images/d0e2c05dc4abd374.jpg
#   inflating: c2_egg/images/92f8f7ac0a9fa050.jpg
#   inflating: c2_egg/images/2e6e5c7b8a860c6d.jpg
#   inflating: c2_egg/images/333f788d8d829f2a.jpg
#   inflating: c2_egg/images/418ba2a705d649e6.jpg
#   inflating: c2_egg/images/06cd8ba83b5b4321.jpg
#   inflating: c2_egg/images/1faf0e16aaef0e1c.jpg
#   inflating: c2_egg/images/2ed662b4d320061a.jpg
#   inflating: c2_egg/images/97cda8f6f6de4f72.jpg
#   inflating: c2_egg/images/432218a6182f5111.jpg
#   inflating: c2_egg/images/9f74a92c42f1c0ad.jpg
#   inflating: c2_egg/images/015177f2c3007a7d.jpg
#   inflating: c2_egg/images/469ae737247d3e1b.jpg
#   inflating: c2_egg/images/0a7eebb5e22fa236.jpg
#   inflating: c2_egg/images/96b5a40645bb4fa6.jpg
#   inflating: c2_egg/images/0c7ce7d62db85440.jpg
#   inflating: c2_egg/images/5b6c6735dca4f6a3.jpg
#   inflating: c2_egg/images/770411e8e92be35c.jpg
#   inflating: c2_egg/images/5ba4d89a39ff1fb3.jpg
#   inflating: c2_egg/images/d9eef584d390266a.jpg
#   inflating: c2_egg/images/33aee894452648ec.jpg
#   inflating: c2_egg/images/062db5cb91f92dfc.jpg
#   inflating: c2_egg/images/cec58cfdf57370f1.jpg
#   inflating: c2_egg/images/07738de6cda2b3cf.jpg
#   inflating: c2_egg/images/5e2989af5b2dd1c1.jpg
#   inflating: c2_egg/images/215868acb93c400e.jpg
#   inflating: c2_egg/images/58e17369ae30802c.jpg
#   inflating: c2_egg/images/0c339e616f3cb332.jpg
#   inflating: c2_egg/images/d0e3747898cbe833.jpg
#   inflating: c2_egg/images/0c288b38a00be01a.jpg
#   inflating: c2_egg/images/ce9ec358cc49fc5a.jpg
#   inflating: c2_egg/images/8a0007783dd74867.jpg
#   inflating: c2_egg/images/8e6391ea3a2e00b6.jpg
#   inflating: c2_egg/images/1ae56067864b7461.jpg
#   inflating: c2_egg/images/207631dc16ed7f03.jpg
#   inflating: c2_egg/images/5fd862fcfe23a88d.jpg
#   inflating: c2_egg/images/b44fc7afd051fac0.jpg
#   inflating: c2_egg/images/46eff59263c9555b.jpg
#   inflating: c2_egg/images/d6e1949551c4b15c.jpg
#   inflating: c2_egg/images/40f7d41bc03a2272.jpg
#   inflating: c2_egg/images/12a46e69b36252cb.jpg
#   inflating: c2_egg/images/430e9378d07095e9.jpg
#   inflating: c2_egg/images/0b722780adbc6e3f.jpg
#   inflating: c2_egg/images/1b385a0b09ee6d69.jpg
#   inflating: c2_egg/images/0cc1a80b2cde7bfe.jpg
#   inflating: c2_egg/images/2ac322da5b1ae95b.jpg
#   inflating: c2_egg/images/239fd80dc2a6e054.jpg
#   inflating: c2_egg/images/78a6bce5cdd40657.jpg
#   inflating: c2_egg/images/5e2324fc3655f7e6.jpg
#   inflating: c2_egg/images/1b4f9e0c2e409d30.jpg
#   inflating: c2_egg/images/73a1dab225c75ad1.jpg
#   inflating: c2_egg/images/0c11dfc1f05e5f84.jpg
#   inflating: c2_egg/images/097074ada4af7de0.jpg
#   inflating: c2_egg/images/9ce2f4913d185d6a.jpg
#   inflating: c2_egg/images/1dd3f22229a33756.jpg
#   inflating: c2_egg/images/5b39209cb5fe97bf.jpg
#   inflating: c2_egg/images/b084ebc013ccbd56.jpg
#   inflating: c2_egg/images/788826e390075469.jpg
#   inflating: c2_egg/images/9fb139a723aa9aab.jpg
#   inflating: c2_egg/images/93ae5ebf118b204e.jpg
#   inflating: c2_egg/images/5dd9f4700aad3a32.jpg
#   inflating: c2_egg/images/29b34abb80c9959f.jpg
#   inflating: c2_egg/images/8756e7a70a2be4c2.jpg
#   inflating: c2_egg/images/060a0bee1883c654.jpg
#   inflating: c2_egg/images/624108ddbabd78e4.jpg
#   inflating: c2_egg/images/8e6001808cdde594.jpg
#   inflating: c2_egg/images/0303001d420b1e21.jpg
#   inflating: c2_egg/images/30d3bbdcd70fcee0.jpg
#   inflating: c2_egg/images/402dc6c48f4b5ec5.jpg
#   inflating: c2_egg/images/75f39d7b893421da.jpg
#   inflating: c2_egg/images/8e77daa4cca94091.jpg
#   inflating: c2_egg/images/053da482bc4d5f8c.jpg
#   inflating: c2_egg/images/5c1a93139772b3e3.jpg
#   inflating: c2_egg/images/2c7728e3371d3d6c.jpg
#   inflating: c2_egg/images/28cb1b4d936dc2fe.jpg
#   inflating: c2_egg/images/7f221e2f12bf308d.jpg
#   inflating: c2_egg/images/50f2b8006164fbc3.jpg
#   inflating: c2_egg/images/9e357a736d09ede9.jpg
#   inflating: c2_egg/images/9cc67239e9731d20.jpg
#   inflating: c2_egg/images/7e0a5b298a397317.jpg
#   inflating: c2_egg/images/0c74da0b19be6d65.jpg
#   inflating: c2_egg/images/6c93e6a55e5dbf92.jpg
#   inflating: c2_egg/images/7daf305cf138b8c7.jpg
#   inflating: c2_egg/images/6b27470f56727ed3.jpg
#   inflating: c2_egg/images/14cc6d86941ad77e.jpg
#   inflating: c2_egg/images/6fb68efc0b5bf7e7.jpg
#   inflating: c2_egg/images/1aa3ba7824ef29cb.jpg
#   inflating: c2_egg/images/0a952556909bfb4b.jpg
#   inflating: c2_egg/images/8bec86ab838829d7.jpg
#   inflating: c2_egg/images/75da267779220ef7.jpg
#   inflating: c2_egg/images/1fc4e0832902e7c7.jpg
#   inflating: c2_egg/images/1a42202fddae5ba5.jpg
#   inflating: c2_egg/images/0bcc5f32f96fe911.jpg
#   inflating: c2_egg/images/33d1e969f000124c.jpg
#   inflating: c2_egg/images/d1d96f4a82397278.jpg
#   inflating: c2_egg/images/2dae6ff2a1e318c4.jpg
#   inflating: c2_egg/images/0f13f448693ab6ed.jpg
#   inflating: c2_egg/images/07c23a303b65e819.jpg
#   inflating: c2_egg/images/0f0ce4043b030857.jpg
#   inflating: c2_egg/images/8722b3aee0cc2a47.jpg
#   inflating: c2_egg/images/0b0a7f131561b5be.jpg
#   inflating: c2_egg/images/ccb1a96fa046eac0.jpg
#   inflating: c2_egg/images/96a769f385367cf1.jpg
#   inflating: c2_egg/images/b4866fdf587cfba3.jpg
#   inflating: c2_egg/images/b9e5bc7789432f0a.jpg
#   inflating: c2_egg/images/5b0dae98bb95829d.jpg
#   inflating: c2_egg/images/0468a9b9187d8190.jpg
#   inflating: c2_egg/images/94611fa9a2b66f1f.jpg
#   inflating: c2_egg/images/9e68831bca01ebc8.jpg
#   inflating: c2_egg/images/72d6d93bf180d094.jpg
#   inflating: c2_egg/images/4d6b97472b2f6b7c.jpg
#   inflating: c2_egg/images/30fc94157cfae971.jpg
#   inflating: c2_egg/images/57cb7e648194d520.jpg
#   inflating: c2_egg/images/0bdb374d0843cdae.jpg
#   inflating: c2_egg/images/92d4109bdb09bd89.jpg
#   inflating: c2_egg/images/07d02bc540513b0b.jpg
#   inflating: c2_egg/images/0acea9680a2ab2f8.jpg
#   inflating: c2_egg/images/00f9961dcfdf1a4b.jpg
#   inflating: c2_egg/images/9566bec1ead989d3.jpg
#   inflating: c2_egg/images/b7bda710a097350b.jpg
#   inflating: c2_egg/images/0fd63a7fde29b1aa.jpg
#   inflating: c2_egg/images/9f64a7d4640fee63.jpg
#   inflating: c2_egg/images/0b29596a52458751.jpg
#   inflating: c2_egg/images/1f656cdaf9570ee9.jpg
#   inflating: c2_egg/images/5b444f57ecd78b70.jpg
#   inflating: c2_egg/images/37e9e7b9167c85cb.jpg
#   inflating: c2_egg/images/46c020c8c65fffc5.jpg
#   inflating: c2_egg/images/37bc2561fe594e26.jpg
#   inflating: c2_egg/images/71ccce209e0da5b4.jpg
#   inflating: c2_egg/images/6ea29cd2219d767c.jpg
#   inflating: c2_egg/images/15c52fa9b3e6780c.jpg
#   inflating: c2_egg/images/0c578b45676547c2.jpg
#   inflating: c2_egg/images/7694b6950eb41236.jpg
#   inflating: c2_egg/images/96e2b03803ed6f8a.jpg
#   inflating: c2_egg/images/2e9122fc151582e8.jpg
#   inflating: c2_egg/images/6ee9aa1d7f4ebbc6.jpg
#   inflating: c2_egg/images/c8507328d8d7eca1.jpg
#   inflating: c2_egg/images/1ef9bc8021380bd1.jpg
#   inflating: c2_egg/images/1e1b1c741ef24e49.jpg
#   inflating: c2_egg/images/50a2bde8694536f0.jpg
#   inflating: c2_egg/images/095fdc7389a2e097.jpg
#   inflating: c2_egg/images/6c783bec977951a0.jpg
#   inflating: c2_egg/images/253c6e9f377e5163.jpg
#   inflating: c2_egg/images/70ba9477ec3a6a5d.jpg
#   inflating: c2_egg/images/36eac75f129d9797.jpg
#   inflating: c2_egg/images/01f0551ef9bd446c.jpg
#   inflating: c2_egg/images/93825ef920780000.jpg
#   inflating: c2_egg/images/749419ab1f09e129.jpg
#   inflating: c2_egg/images/70b72fad3788a64e.jpg
#   inflating: c2_egg/images/8848b5dbbefcda4a.jpg
#   inflating: c2_egg/images/30cea2b783fbf4ae.jpg
#   inflating: c2_egg/images/0f88f454353f828d.jpg
#   inflating: c2_egg/images/cc0258cf09621fc4.jpg
#   inflating: c2_egg/images/456db0483f55ca97.jpg
#   inflating: c2_egg/images/70d65e4c2c8bb09e.jpg
#   inflating: c2_egg/images/01ca1add8d9f3338.jpg
#   inflating: c2_egg/images/98dfa0b8bb3bfba4.jpg
#   inflating: c2_egg/images/50982d66306ae64e.jpg
#   inflating: c2_egg/images/11a27adcaa51a532.jpg
#   inflating: c2_egg/images/325128c5ef4e9333.jpg
#   inflating: c2_egg/images/07cf1fc43e68a685.jpg
#   inflating: c2_egg/images/31d460c1d5b03488.jpg
#   inflating: c2_egg/images/477d2b35132431b7.jpg
#   inflating: c2_egg/images/08c9722404c1c54b.jpg
#   inflating: c2_egg/images/97bcc26cd2dd2b1e.jpg
#   inflating: c2_egg/images/106b55acdaa0b156.jpg
#   inflating: c2_egg/images/38bd34763214d020.jpg
#   inflating: c2_egg/images/11df5dec5e8b657f.jpg
#   inflating: c2_egg/images/046c51a51bccc9c8.jpg
#   inflating: c2_egg/images/214af643e72c7814.jpg
#   inflating: c2_egg/images/045aac14c4873ed6.jpg
#   inflating: c2_egg/images/6ecaaeeebef02ff6.jpg
#   inflating: c2_egg/images/33c0666bff41427f.jpg
#   inflating: c2_egg/images/cc806bdb2e68c985.jpg
#   inflating: c2_egg/images/5c925e27b59fbe50.jpg
#   inflating: c2_egg/images/358daec8e4281930.jpg
#   inflating: c2_egg/images/2ab75847c1b512ef.jpg
#   inflating: c2_egg/images/00d8fb77250a2343.jpg
#   inflating: c2_egg/images/504467ea0029d820.jpg
#   inflating: c2_egg/images/b11c7f3e0b1fb2b0.jpg
#   inflating: c2_egg/images/0c160d90e1026972.jpg
#   inflating: c2_egg/images/6d828b2459d8330a.jpg
#   inflating: c2_egg/images/8f78bf635a3979ab.jpg
#   inflating: c2_egg/images/d1e3ae6f91bdeada.jpg
#   inflating: c2_egg/images/ccb604c8b9c8cd51.jpg
#   inflating: c2_egg/images/213e64df4c158bee.jpg
#   inflating: c2_egg/images/caf78c2275647fe4.jpg
#   inflating: c2_egg/images/799120f8ac8909b3.jpg
#   inflating: c2_egg/images/1d112cb195bca130.jpg
#   inflating: c2_egg/images/497794f00912ae10.jpg
#   inflating: c2_egg/images/364df6c1fb2352cc.jpg
#   inflating: c2_egg/images/396eadd30aed93ec.jpg
#   inflating: c2_egg/images/2d76e99188c0687a.jpg
#   inflating: c2_egg/images/08ee6c5bff054200.jpg
#   inflating: c2_egg/images/53c2b6916205e627.jpg
#   inflating: c2_egg/images/914311ee005532c9.jpg
#   inflating: c2_egg/images/32d1d82bea9aaf91.jpg
#   inflating: c2_egg/images/13557e56734a18f5.jpg
#   inflating: c2_egg/images/798841da733a051a.jpg
#   inflating: c2_egg/images/d5a8874b5d252531.jpg
#   inflating: c2_egg/images/115c6d439bcbd038.jpg
#   inflating: c2_egg/images/9ebef84d4a4fcedc.jpg
#   inflating: c2_egg/images/2d126140050f781f.jpg
#   inflating: c2_egg/images/5c2aaebe414334f6.jpg
#   inflating: c2_egg/images/01b7a46c9b0a768d.jpg
#   inflating: c2_egg/images/257157aea3b9952d.jpg
#   inflating: c2_egg/images/b416e200e693e536.jpg

# %% [markdown]
# Let's have a look at the dataset and how it is layed down.
#
# The data is structured as follows
# ```
# c1_release/
#   images/
#     0001e6adc4fbab0c.jpg
#     00067fe83e3e21c8.jpg
#     0008ab3d8674f6ca.jpg
#     ...
#   labels.json
#   train.json
#   val.json
# ```
#
# `labels.json` contains the labels for the whole dataset (`train.json` + `val.json`) if you need it.

# %% [markdown]
# ### Defining the Dataset
#
# The [torchvision reference scripts for training object detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
# Additionally, if you want to use aspect ratio grouping during training (so that each batch only contains images with similar aspect ratio), then it is recommended to also implement a `get_height_and_width` method, which returns the height and the width of the image. If this method is not provided, we query all elements of the dataset via `__getitem__` , which loads the image in memory and is slower than if a custom method is provided.
#
# Let's write a `torch.utils.data.Dataset` class for this dataset.

# %%
class TILDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))
        cats = self.coco.loadCats(self.coco.getCatIds())
        self.cat2name = {cat['id']:cat['name'] for cat in cats} # maps category id to category name (useful for visualization)

    def __getitem__(self, index):
        coco = self.coco
        img_id = self.ids[index] # Image ID
        ann_ids = coco.getAnnIds(imgIds=img_id) # get annotation id from coco
        coco_annotation = coco.loadAnns(ann_ids) # target coco_annotation file for an image
        path = coco.loadImgs(img_id)[0]['file_name'] # path for input image
        img = Image.open(os.path.join(self.root, 'images', path)).convert('RGB') # open the input image

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        # Labels
        labels = []
        for i in range(num_objs):
            labels.append(coco_annotation[i]['category_id'])
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Tensorise img_id
        img_id = torch.tensor([img_id])

        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        target["area"] = areas
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.ids)

# %% [markdown]
# That's all for the dataset. Let's see how the outputs are structured for this dataset

# %%
til_root = "/content/challenge_3_training_dataset/" # extracted training dataset path
train_annotation = os.path.join(til_root, "train.json")
val_annotation = os.path.join(til_root, "val.json")

til_root_2 = "/content/c2_egg/"
train_annotation_2 = os.path.join(til_root_2, "labels.json")

dataset = TILDataset(til_root, train_annotation)
dataset[30]
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# (<PIL.Image.Image image mode=RGB size=1024x683 at 0x7FCB90948FD0>,
#  {'area': tensor([92906.]),
#   'boxes': tensor([[618.,   0., 824., 451.]]),
#   'image_id': tensor([31]),
#   'iscrowd': tensor([0]),
#   'labels': tensor([3])})

# %% [markdown]
# So we can see that by default, the dataset returns a `PIL.Image` and a dictionary containing several fields, including `boxes` and `labels`.
#
# Let's next look at one example from the training set.

# %%
source_img, img_annots = dataset[13]
draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCB30F11ED0>

# %% [markdown]
# ## Setting up the Model
#
# In this object detection example, we will make use of Faster R-CNN model with a ResNet50-FPN backbone. To understand the underlying code structure, you can read this [article](https://zhuanlan.zhihu.com/p/145842317) (right click and translate to English).
#
# Feel free to explore with different hyper-parameters to see what works best!

# %%
# hyper-parameters
params = {'BATCH_SIZE': 20,
          'LR': 0.007,
          'CLASSES': 8,
          'MAXEPOCHS': 20,
          'BACKBONE': 'resnet50',
          'FPN': True,
          'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
          'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
          'MIN_SIZE': 512,
          'MAX_SIZE': 512,
          'IMG_MEAN': [0.485, 0.456, 0.406],
          'IMG_STD': [0.229, 0.224, 0.225],
          'IOU_THRESHOLD': 0.5
          }

# %%
def get_resnet_backbone(backbone_name: str):
    """
    Returns a resnet backbone pretrained on ImageNet.
    Removes the average-pooling layer and the linear layer at the end.
    """
    if backbone_name == 'resnet18':
        pretrained_model = models.resnet18(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet34':
        pretrained_model = models.resnet34(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet50':
        pretrained_model = models.resnet50(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet101':
        pretrained_model = models.resnet101(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet152':
        pretrained_model = models.resnet152(pretrained=True, progress=False)
        out_channels = 2048

    backbone = torch.nn.Sequential(*list(pretrained_model.children())[:-2])
    backbone.out_channels = out_channels

    return backbone

# %%
def get_resnet_fpn_backbone(backbone_name: str):
    """
    Returns a specified ResNet backbone with FPN pretrained on ImageNet.
    """
    return resnet_fpn_backbone(backbone_name, pretrained=True, trainable_layers=3)

# %%
def get_anchor_generator(anchor_size: Tuple[tuple] = None, aspect_ratios: Tuple[tuple] = None):
    """Returns the anchor generator."""
    if anchor_size is None:
        anchor_size = ((16,), (32,), (64,), (128,))
    if aspect_ratios is None:
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_size)

    anchor_generator = AnchorGenerator(sizes=anchor_size,
                                       aspect_ratios=aspect_ratios)
    return anchor_generator

# %%
def get_roi_pool(featmap_names: List[str] = None, output_size: int = 7, sampling_ratio: int = 2):
    """Returns the ROI Pooling"""
    if featmap_names is None:
        # default for resnet with FPN
        featmap_names = ['0', '1', '2', '3']

    roi_pooler = MultiScaleRoIAlign(featmap_names=featmap_names,
                                    output_size=output_size,
                                    sampling_ratio=sampling_ratio)

    return roi_pooler

# %%
def get_fasterRCNN(backbone: torch.nn.Module,
                   anchor_generator: AnchorGenerator,
                   roi_pooler: MultiScaleRoIAlign,
                   num_classes: int,
                   image_mean: List[float] = [0.485, 0.456, 0.406],
                   image_std: List[float] = [0.229, 0.224, 0.225],
                   min_size: int = 512,
                   max_size: int = 1024,
                   **kwargs
                   ):
    """Returns the Faster-RCNN model. Default normalization: ImageNet"""
    model = FasterRCNN(backbone=backbone,
                       rpn_anchor_generator=anchor_generator,
                       box_roi_pool=roi_pooler,
                       num_classes=num_classes,
                       image_mean=image_mean,  # ImageNet
                       image_std=image_std,  # ImageNet
                       min_size=min_size,
                       max_size=max_size,
                       **kwargs
                       )
    model.num_classes = num_classes
    model.image_mean = image_mean
    model.image_std = image_std
    model.min_size = min_size
    model.max_size = max_size

    return model

# %%
def get_fasterRCNN_resnet(num_classes: int,
                          backbone_name: str,
                          anchor_size: List[float],
                          aspect_ratios: List[float],
                          fpn: bool = True,
                          min_size: int = 512,
                          max_size: int = 1024,
                          **kwargs
                          ):
    """Returns the Faster-RCNN model with resnet backbone with and without fpn."""

    # Backbone
    if fpn:
        backbone = get_resnet_fpn_backbone(backbone_name=backbone_name)
    else:
        backbone = get_resnet_backbone(backbone_name=backbone_name)

    # Anchors
    anchor_size = anchor_size
    aspect_ratios = aspect_ratios * len(anchor_size)
    anchor_generator = get_anchor_generator(anchor_size=anchor_size, aspect_ratios=aspect_ratios)

    # ROI Pool
    with torch.no_grad():
        backbone.eval()
        random_input = torch.rand(size=(1, 3, 512, 512))
        features = backbone(random_input)

    if isinstance(features, torch.Tensor):
        from collections import OrderedDict

        features = OrderedDict([('0', features)])

    featmap_names = [key for key in features.keys() if key.isnumeric()]

    roi_pool = get_roi_pool(featmap_names=featmap_names)

    # Model
    return get_fasterRCNN(backbone=backbone,
                          anchor_generator=anchor_generator,
                          roi_pooler=roi_pool,
                          num_classes=num_classes,
                          min_size=min_size,
                          max_size=max_size,
                          **kwargs)

# %%
model = get_fasterRCNN_resnet(num_classes=params['CLASSES'],
                              backbone_name=params['BACKBONE'],
                              anchor_size=params['ANCHOR_SIZE'],
                              aspect_ratios=params['ASPECT_RATIOS'],
                              fpn=params['FPN'],
                              min_size=params['MIN_SIZE'],
                              max_size=params['MAX_SIZE'],
                              image_mean=params['IMG_MEAN'],
                              image_std=params['IMG_STD'])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# HBox(children=(FloatProgress(value=0.0, max=102530333.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# load pretrained weights for FasterRCNN ResNet50 FPN
pretrained_dict = torch.hub.load_state_dict_from_url('https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth', progress=True)
model_dict = model.state_dict()

# filter out roi_heads.box_predictor weights
pretrained_dict = {k: v for k, v in pretrained_dict.items() if not k.startswith('roi_heads.box_predictor')}
# overwrite entries in the existing state dict
model_dict.update(pretrained_dict)
# load the new state dict
model.load_state_dict(model_dict)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(FloatProgress(value=0.0, max=167502836.0), HTML(value='')))
# <All keys matched successfully>

# %%
# move model to the right device
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=8, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=32, bias=True)
#     )
#   )
# )

# %%
# construct an optimizer
model_params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(model_params, 
                            lr=params['LR'],
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %% [markdown]
# ## Data Augmentation
#
# Let's write some helper functions for data augmentation / transformation.
#
# Do not just stop here, add in your own data augmentations! Remember to also augment the bounding boxes accordingly.

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
# converts the image, a PIL image, into a PyTorch Tensor
class ToTensor(object):
    def __call__(self, image, target):
        image = F.to_tensor(image)
        return image, target

# %%
# randomly horizontal flip the images and ground-truth labels
class RandomHorizontalFlip(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
            height, width = image.shape[-2:]
            image = image.flip(-1)
            bbox = target["boxes"]
            bbox[:, [0, 2]] = width - bbox[:, [2, 0]]
            target["boxes"] = bbox
        return image, target

# %%
def get_transform(train):
    if train:
        transforms = Compose([
            ToTensor(), 
            RandomHorizontalFlip(0.5)
        ])
    else: # during evaluation, no augmentations will be done
        transforms = Compose([
            ToTensor()
        ])
    
    return transforms

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled by the R-CNN model.

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.
#
# We now have the dataset class, the models and the data transforms. Let's instantiate them

# %%
NUM_WORKERS = 4

# use our dataset and defined transformations
train_dataset = TILDataset(til_root, train_annotation, get_transform(train=True))
train_dataset_2 = TILDataset(til_root_2, train_annotation_2, get_transform(train=True))
val_dataset = TILDataset(til_root, val_annotation, get_transform(train=False))

# define training and validation data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset + train_dataset_2,  batch_size=params['BATCH_SIZE'], shuffle=True, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=1, shuffle=False, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## Model Training
#
# And now let's train the model, evaluating at the end of every epoch.

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', utils.SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = utils.warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            print(loss_dict)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses, **loss_dict)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

# %%
@torch.no_grad()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    torch.set_num_threads(1)
    model.eval()
    metric_logger = utils.MetricLogger(delimiter="  ")
    header = 'Test:'

    coco = data_loader.dataset.coco
    iou_types = ["bbox"]
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for image, targets in metric_logger.log_every(data_loader, 100, header):
        image = list(img.to(device) for img in image)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(image)

        outputs = [{k: v for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluator_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    return coco_evaluator

# %%
for epoch in range(params['MAXEPOCHS']):
    # train for one epoch, printing every 100 iterations
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=100)

    # update the learning rate
    lr_scheduler.step()

    # evaluate on the test dataset
    evaluate(model, val_loader, device=device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0]  [  0/132]  eta: 0:10:43  lr: 0.000060  loss: 2.6942 (2.6942)  loss_classifier: 2.3373 (2.3373)  loss_box_reg: 0.3429 (0.3429)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 4.8732  data: 2.3105  max mem: 6908
# Epoch: [0]  [100/132]  eta: 0:01:01  lr: 0.005399  loss: 0.2558 (0.5823)  loss_classifier: 0.1094 (0.3444)  loss_box_reg: 0.1430 (0.2098)  loss_objectness: 0.0104 (0.0228)  loss_rpn_box_reg: 0.0037 (0.0052)  time: 1.9263  data: 0.0815  max mem: 7338
# Epoch: [0]  [131/132]  eta: 0:00:01  lr: 0.007000  loss: 0.2681 (0.5106)  loss_classifier: 0.1070 (0.2895)  loss_box_reg: 0.1431 (0.1935)  loss_objectness: 0.0130 (0.0224)  loss_rpn_box_reg: 0.0038 (0.0051)  time: 1.8368  data: 0.0745  max mem: 7338
# Epoch: [0] Total time: 0:04:10 (1.9015 s / it)
# Test:  [  0/214]  eta: 0:01:22  model_time: 0.0686 (0.0686)  evaluator_time: 0.0122 (0.0122)  time: 0.3874  data: 0.3031  max mem: 7338
# Test:  [100/214]  eta: 0:00:06  model_time: 0.0391 (0.0403)  evaluator_time: 0.0025 (0.0031)  time: 0.0555  data: 0.0056  max mem: 7338
# Test:  [200/214]  eta: 0:00:00  model_time: 0.0389 (0.0397)  evaluator_time: 0.0021 (0.0027)  time: 0.0498  data: 0.0051  max mem: 7338
# Test:  [213/214]  eta: 0:00:00  model_time: 0.0372 (0.0395)  evaluator_time: 0.0020 (0.0027)  time: 0.0470  data: 0.0043  max mem: 7338
# Test: Total time: 0:00:11 (0.0519 s / it)
# Averaged stats: model_time: 0.0372 (0.0395)  evaluator_time: 0.0020 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
# Epoch: [1]  [  0/132]  eta: 0:11:45  lr: 0.007000  loss: 0.3230 (0.3230)  loss_classifier: 0.1284 (0.1284)  loss_box_reg: 0.1798 (0.1798)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 5.3437  data: 3.0511  max mem: 7338
# Epoch: [1]  [100/132]  eta: 0:01:03  lr: 0.007000  loss: 0.2185 (0.2255)  loss_classifier: 0.0835 (0.0882)  loss_box_reg: 0.1181 (0.1225)  loss_objectness: 0.0081 (0.0103)  loss_rpn_box_reg: 0.0043 (0.0045)  time: 1.9696  data: 0.0822  max mem: 7338
# Epoch: [1]  [131/132]  eta: 0:00:01  lr: 0.007000  loss: 0.1991 (0.2209)  loss_classifier: 0.0810 (0.0864)  loss_box_reg: 0.0952 (0.1196)  loss_objectness: 0.0086 (0.0103)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 1.8544  data: 0.0743  max mem: 7338
# Epoch: [1] Total time: 0:04:20 (1.9734 s / it)
# Test:  [  0/214]  eta: 0:01:17  model_time: 0.1098 (0.1098)  evaluator_time: 0.0042 (0.0042)  time: 0.3605  data: 0.2407  max mem: 7338
# Test:  [100/214]  eta: 0:00:06  model_time: 0.0388 (0.0405)  evaluator_time: 0.0022 (0.0026)  time: 0.0508  data: 0.0051  max mem: 7338
# Test:  [200/214]  eta: 0:00:00  model_time: 0.0390 (0.0400)  evaluator_time: 0.0018 (0.0024)  time: 0.0503  data: 0.0057  max mem: 7338
# Test:  [213/214]  eta: 0:00:00  model_time: 0.0375 (0.0399)  evaluator_time: 0.0016 (0.0023)  time: 0.0478  data: 0.0046  max mem: 7338
# Test: Total time: 0:00:11 (0.0520 s / it)
# Averaged stats: model_time: 0.0375 (0.0399)  evaluator_time: 0.0016 (0.0023)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.766
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.611
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
# Epoch: [2]  [  0/132]  eta: 0:10:44  lr: 0.007000  loss: 0.1818 (0.1818)  loss_classifier: 0.0690 (0.0690)  loss_box_reg: 0.1025 (0.1025)  loss_objectness: 0.0073 (0.0073)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 4.8854  data: 2.5924  max mem: 7338
# Epoch: [2]  [100/132]  eta: 0:01:03  lr: 0.007000  loss: 0.1522 (0.1749)  loss_classifier: 0.0580 (0.0643)  loss_box_reg: 0.0890 (0.0997)  loss_objectness: 0.0044 (0.0070)  loss_rpn_box_reg: 0.0032 (0.0040)  time: 1.9632  data: 0.0795  max mem: 7342
# Epoch: [2]  [131/132]  eta: 0:00:01  lr: 0.007000  loss: 0.1678 (0.1767)  loss_classifier: 0.0584 (0.0651)  loss_box_reg: 0.0986 (0.1006)  loss_objectness: 0.0054 (0.0071)  loss_rpn_box_reg: 0.0030 (0.0039)  time: 1.8536  data: 0.0736  max mem: 7342
# Epoch: [2] Total time: 0:04:20 (1.9740 s / it)
# Test:  [  0/214]  eta: 0:01:22  model_time: 0.1228 (0.1228)  evaluator_time: 0.0048 (0.0048)  time: 0.3856  data: 0.2542  max mem: 7342
# Test:  [100/214]  eta: 0:00:06  model_time: 0.0395 (0.0405)  evaluator_time: 0.0020 (0.0022)  time: 0.0503  data: 0.0049  max mem: 7342
# Test:  [200/214]  eta: 0:00:00  model_time: 0.0388 (0.0400)  evaluator_time: 0.0016 (0.0020)  time: 0.0493  data: 0.0052  max mem: 7342
# Test:  [213/214]  eta: 0:00:00  model_time: 0.0377 (0.0399)  evaluator_time: 0.0013 (0.0020)  time: 0.0475  data: 0.0046  max mem: 7342
# Test: Total time: 0:00:11 (0.0517 s / it)
# Averaged stats: model_time: 0.0377 (0.0399)  evaluator_time: 0.0013 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.777
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.613
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
# Epoch: [3]  [  0/132]  eta: 0:10:41  lr: 0.000700  loss: 0.1786 (0.1786)  loss_classifier: 0.0629 (0.0629)  loss_box_reg: 0.1074 (0.1074)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 4.8575  data: 2.4601  max mem: 7342

# %% [markdown]
# ## Visualization of results
#
# Now that training has finished, let's have a look at what it actually predicts.

# %%
# pick one image from the validation set
img, _ = val_dataset[3]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

prediction

# %% [markdown]
# Printing the prediction shows that we have a list of dictionaries. Each element of the list corresponds to a different image. As we have a single image, there is a single dictionary in the list.
# The dictionary contains the predictions for the image we passed. In this case, we can see that it contains `boxes`, `labels`, and `scores` as fields.
#
# Let's inspect the image and the predicted boxes.
# For that, we need to convert the image, which has been rescaled to 0-1 and had the channels flipped so that we have it in `[C, H, W]` format.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

img_preds = prediction[0]
for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}: {score}'
    draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# ## Post-processing
#
# We might notice that there are duplicate detections in the image. Let's post-process the detections with non-maximum suppression.
#
# ** Update: FasterRCNN already has NMS built into it, so you actually do not need to do NMS again.

# %%
img_preds = prediction[0]
keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])

# %% [markdown]
# Check the predictions again after applying nms.
#
# ** Update: You should not see any difference unless you have specified a lower IoU threshold than the default of 0.5.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Now, let's further filter out the non-confident detections.

# %%
det_threshold = 0.5

# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        # filter out non-confident detections
        if score > det_threshold:
            draw.rectangle(((x1, y1), (x2, y2)), outline="red")
            text = f'{dataset.cat2name[label]}: {score}'
            draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Much better! Once you are satisfied with the results, save your model weights.

# %%
# save model weights
savefilename = "c3"+"_bs-"+str(params['BATCH_SIZE'])+"_lr_"+str(params['LR'])+"_ep_"+str(params['MAXEPOCHS'])+"_weights_"+str(params['BACKBONE'])+".pth"
save_path = os.path.join(base_folder, savefilename)
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ## Evaluation on Validation Set
#
# As a sanity check, let's evaluate the model performance on the validation set

# %%
with open(val_annotation) as json_file:
    val_data = json.load(json_file)

model.eval()
detections = []
with torch.no_grad():
    for image in val_data["images"]:
        img_name = image["file_name"]
        img_id = image["id"]

        img = Image.open(os.path.join(til_root, 'images', img_name)).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
savefilename = "validation_c3"+"_bs-"+str(params['BATCH_SIZE'])+"_lr_"+str(params['LR'])+"_ep_"+str(params['MAXEPOCHS'])+"_weights_"+str(params['BACKBONE'])+".json"
validation_json = os.path.join(base_folder, savefilename)
with open(validation_json, 'w') as f:
    json.dump(detections, f)

# %%
# Get evaluation score against validation set to make sure your prediction json file is in the correct format
coco_gt = COCO(val_annotation)
coco_dt = coco_gt.loadRes(validation_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# ## Generate Predictions on Test Images

# %%
# You should already have uploaded the testing images onto your google drive.

testing_images_path = os.path.join(base_folder, "challenge_3_test_dataset.zip") # change this path to the zip file for the test images
# !unzip $testing_images_path

# %%
til_test_root = "/content/challenge_3_test_dataset/" # extracted testing images path
test_img_root = os.path.join(til_test_root, "images")
img_dir = os.scandir(test_img_root)

# %%
# load model weights (if not using the current trained model)
model.load_state_dict(torch.load(save_path, map_location=device))
model.to(device)
model.eval()

# %% [markdown]
# Let's visualize some predictions on the test images. Run this a few times to visualize different images.

# %%
img = Image.open(next(img_dir).path).convert('RGB')
draw = ImageDraw.Draw(img)
det_threshold = 0.5

# do the prediction
with torch.no_grad():
    img_tensor = transforms.ToTensor()(img)
    img_preds = model([img_tensor.to(device)])[0]

for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    # filter out non-confident detections
    if score > det_threshold:
        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(img)

# %% [markdown]
# ## Submission of Results
#
# Submission json file should be in [COCO format](https://cocodataset.org/#format-results).
#
# ```
# [{
#     "image_id": int,
#     "category_id": int,
#     "bbox": [x,y,width,height],
#     "score": float,
# }]
# ```
#
# Refer to **sample_submission_cv.json** for an example.
#
# For this competition, the metric for evaluation will be mAP @ 0.50:0.95

# %%
# generate detections on the folder of test images (this will be used for submission)
detections = []
with torch.no_grad():
    for image in img_dir:
        img_id = int(image.name.split('.')[0])

        img = Image.open(image.path).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
savefilename = "test_c3"+"_bs-"+str(params['BATCH_SIZE'])+"_lr_"+str(params['LR'])+"_ep_"+str(params['MAXEPOCHS'])+"_weights_"+str(params['BACKBONE'])+".json"

test_pred_json = os.path.join(base_folder, savefilename)
with open(test_pred_json, 'w') as f:
    json.dump(detections, f)

# %% [markdown]
# ## Check Your Submission JSON Format (RUN THIS BEFORE SUBMISSION)
#
# Run this function first with the given sample json (change this path for the different challenges) to make sure everything works before you submit. Just need to ensure that there are no errors when you run this. **If you get any errors, check your generated json file.**

# %%
sample_json_path = os.path.join(til_test_root, "c1_test_sample.json")

coco_gt = COCO(sample_json_path)
coco_dt = coco_gt.loadRes(test_pred_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# If you get an `AssertionError: Results do not correspond to current coco set`, it most likely means that some of the "image_id" are out of range (either 0 or higher than number of test images).
