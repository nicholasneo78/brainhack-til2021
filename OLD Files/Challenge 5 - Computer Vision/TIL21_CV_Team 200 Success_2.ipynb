# %% [markdown]
# ## Downloading Dependencies

# %%
# First, we need to install pycocotools. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.
# The version by default in Colab has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
import json
import math
import os
import random
import sys
import time

import numpy as np
import torch
import torch.utils.data
import torchvision

from PIL import Image, ImageDraw
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms
from torchvision.ops import batched_nms
from torchvision.transforms import functional as F

# %%
from typing import List, Tuple

import torchvision.models as models

from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

# %% [markdown]
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/utils.py` and `references/detection/coco_eval.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/coco_eval.py ../
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
import utils
from coco_eval import CocoEvaluator

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Object Detection Dataset
# We will be providing the base dataset that will be used for the first task of the Object Detection competition.

# %%
# You should have uploaded the training dataset onto your google drive.

base_folder = '/content/drive/MyDrive' # Change this path to your folder for this competition
training_path_1 = os.path.join(base_folder, "c1_release.zip") # zip file for training dataset
training_path_3 = os.path.join(base_folder, "c1_hidden.zip") 
training_path_4 = os.path.join(base_folder, "challenge_3_training_dataset.zip")
training_path = os.path.join(base_folder, "challenge_5_training_dataset.zip")
training_path_2 = os.path.join(base_folder, "challenge_3_egg.zip")
training_path_5 = os.path.join(base_folder, "challenge_5_website.zip")

# %%
# unzip the training dataset
# !unzip $training_path
# !unzip $training_path_1
# !unzip $training_path_2
# !unzip $training_path_3
# !unzip $training_path_4
# !unzip $training_path_5
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: c1_release/images/c00bbfa477b1a244.jpg
#   inflating: c1_release/images/956881c7751b3dd0.jpg
#   inflating: c1_release/images/5992218a571b8061.jpg
#   inflating: c1_release/images/91464e216d9af7e6.jpg
#   inflating: c1_release/images/04066761e527d07d.jpg
#   inflating: c1_release/images/ef04822df9b29b2c.jpg
#   inflating: c1_release/images/1ff9dac5e26d12a1.jpg
#   inflating: c1_release/images/583ef04f16813c6a.jpg
#   inflating: c1_release/images/cadd744a84b50c24.jpg
#   inflating: c1_release/images/04d83ca02ffcd66c.jpg
#   inflating: c1_release/images/1a4b981a396c8b4d.jpg
#   inflating: c1_release/images/1e05f4a25529153b.jpg
#   inflating: c1_release/images/e7f39199c0aa3132.jpg
#   inflating: c1_release/images/676f069f6b38969d.jpg
#   inflating: c1_release/images/f08f5396f98adb9d.jpg
#   inflating: c1_release/images/14a55873a8f1cf82.jpg
#   inflating: c1_release/images/9c01a90cfbc9e7ad.jpg
#   inflating: c1_release/images/3d1768979c1b17b7.jpg
#   inflating: c1_release/images/76358b5afd56ad6b.jpg
#   inflating: c1_release/images/e96a516f916eaa75.jpg
#   inflating: c1_release/images/6816814aaab95799.jpg
#   inflating: c1_release/images/b2e33c7e6f96c0b7.jpg
#   inflating: c1_release/images/f5682c934bd5cb92.jpg
#   inflating: c1_release/images/d53966c9c91f99e0.jpg
#   inflating: c1_release/images/bf9ccd3b1e557371.jpg
#   inflating: c1_release/images/9a1f2762e69c1125.jpg
#   inflating: c1_release/images/39a8266bf8ca4f64.jpg
#   inflating: c1_release/images/b2164f7e2e32bc77.jpg
#   inflating: c1_release/images/e9971e1e02a9bc0a.jpg
#   inflating: c1_release/images/cb693426191776bd.jpg
#   inflating: c3_website/images/c4ce636f054c7111.jpg
#   inflating: c3_website/images/9359edce680feda7.jpg
#   inflating: c3_website/images/0d996e7c830b15b5.jpg
#   inflating: c3_website/images/bf9151b0d51bd75f.jpg
#   inflating: c3_website/images/6214fd9a19117758.jpg
#   inflating: c3_website/images/e7c23d860b975b80.jpg
#   inflating: c3_website/images/e8ad5af6a76bc554.jpg
#   inflating: c3_website/images/bac06758f30d2561.jpg
#   inflating: c3_website/images/cb1703a19bd0bbaa.jpg
#   inflating: c3_website/images/bf9cb4fbebc38b71.jpg
#   inflating: c3_website/images/e5b9dee18c23ad16.jpg
#   inflating: c3_website/images/088b8415f7cac22d.jpg
#   inflating: c3_website/images/084f061006b45e3b.jpg
#   inflating: c3_website/images/e1e8f46299f9afaa.jpg
#   inflating: c3_website/images/71b0856aa1ab249b.jpg
#   inflating: c3_website/images/e05aed282d8fd587.jpg
#   inflating: c3_website/images/0b8cbed949c1348c.jpg
#   inflating: c3_website/images/55524de24d9e59af.jpg
#   inflating: c3_website/images/ff822bd46eb31c7c.jpg
#   inflating: c3_website/images/7bebefda456425aa.jpg

# %% [markdown]
# Let's have a look at the dataset and how it is layed down.
#
# The data is structured as follows
# ```
# c1_release/
#   images/
#     0001e6adc4fbab0c.jpg
#     00067fe83e3e21c8.jpg
#     0008ab3d8674f6ca.jpg
#     ...
#   labels.json
#   train.json
#   val.json
# ```
#
# `labels.json` contains the labels for the whole dataset (`train.json` + `val.json`) if you need it.

# %% [markdown]
# ### Defining the Dataset
#
# The [torchvision reference scripts for training object detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
# Additionally, if you want to use aspect ratio grouping during training (so that each batch only contains images with similar aspect ratio), then it is recommended to also implement a `get_height_and_width` method, which returns the height and the width of the image. If this method is not provided, we query all elements of the dataset via `__getitem__` , which loads the image in memory and is slower than if a custom method is provided.
#
# Let's write a `torch.utils.data.Dataset` class for this dataset.

# %%
class TILDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))
        cats = self.coco.loadCats(self.coco.getCatIds())
        self.cat2name = {cat['id']:cat['name'] for cat in cats} # maps category id to category name (useful for visualization)

    def __getitem__(self, index):
        coco = self.coco
        img_id = self.ids[index] # Image ID
        ann_ids = coco.getAnnIds(imgIds=img_id) # get annotation id from coco
        coco_annotation = coco.loadAnns(ann_ids) # target coco_annotation file for an image
        path = coco.loadImgs(img_id)[0]['file_name'] # path for input image
        img = Image.open(os.path.join(self.root, 'images', path)).convert('RGB') # open the input image

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        # Labels
        labels = []
        for i in range(num_objs):
            labels.append(coco_annotation[i]['category_id'])
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Tensorise img_id
        img_id = torch.tensor([img_id])

        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        target["area"] = areas
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.ids)

# %% [markdown]
# That's all for the dataset. Let's see how the outputs are structured for this dataset

# %%
til_root_1 = "/content/c1_release/" # extracted training dataset path
train_annotation_1 = os.path.join(til_root_1, "labels.json")

til_root = "/content/challenge_5_training_dataset/"
train_annotation = os.path.join(til_root, "train.json")
val_annotation = os.path.join(til_root, "val.json")

til_root_2 = "/content/c2_egg/"
train_annotation_2 = os.path.join(til_root_2, "labels.json")

til_root_3 = "/content/c1_hidden/"
train_annotation_3 = os.path.join(til_root_3, "labels.json")

til_root_4 = "/content/challenge_3_training_dataset/"
train_annotation_4 = os.path.join(til_root_4, "labels.json")

til_root_5 = "/content/c3_website/"
train_annotation_5 = os.path.join(til_root_5, "labels.json")

dataset = TILDataset(til_root, train_annotation)
dataset[30]
# Out:
# loading annotations into memory...
# Done (t=2.58s)
# creating index...
# index created!
# (<PIL.Image.Image image mode=RGB size=1024x760 at 0x7F9FF7A45810>,
#  {'area': tensor([119040., 106546., 244488.]),
#   'boxes': tensor([[ 263.,  121.,  573.,  505.],
#           [ 704.,  425., 1023.,  759.],
#           [ 356.,  258.,  844.,  759.]]),
#   'image_id': tensor([31]),
#   'iscrowd': tensor([0, 0, 0]),
#   'labels': tensor([2, 2, 2])})

# %% [markdown]
# So we can see that by default, the dataset returns a `PIL.Image` and a dictionary containing several fields, including `boxes` and `labels`.
#
# Let's next look at one example from the training set.

# %%
source_img, img_annots = dataset[35]
draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F9FF58ADE90>

# %% [markdown]
# ## Setting up the Model
#
# In this object detection example, we will make use of Faster R-CNN model with a ResNet50-FPN backbone. To understand the underlying code structure, you can read this [article](https://zhuanlan.zhihu.com/p/145842317) (right click and translate to English).
#
# Feel free to explore with different hyper-parameters to see what works best!

# %%
classes = []

for j in range(len(dataset)):
  source_img, img_annots = dataset[j]
  for i in range(len(img_annots["boxes"])):
      label = int(img_annots["labels"][i])
      text = f'{dataset.cat2name[label]}'
      classes.append(text)

list(set(classes))
# Out:
# ['Snake', 'Crocodile', 'Dog', 'Chicken', 'Cat', 'Elephant', 'Bird', 'Dinosaur']

# %%
# Our modified hyper-parameters
params = {'BATCH_SIZE': 4,
          'LR': 0.003,
          'CLASSES': len(list(set(classes)))+1,
          'MAXEPOCHS': 10,
          'BACKBONE': 'resnet101',
          'FPN': True,
          'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
          'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
          'MIN_SIZE': 512,
          'MAX_SIZE': 512,
          'IMG_MEAN': [0.485, 0.456, 0.406],
          'IMG_STD': [0.229, 0.224, 0.225],
          'IOU_THRESHOLD': 0.5
          }

# # Original hyper-parameters
# params = {'BATCH_SIZE': 8,
#           'LR': 0.005,
#           'CLASSES': len(list(set(classes)))+1,
#           'MAXEPOCHS': 5,
#           'BACKBONE': 'resnet101',
#           'FPN': True,
#           'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
#           'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
#           'MIN_SIZE': 512,
#           'MAX_SIZE': 512,
#           'IMG_MEAN': [0.485, 0.456, 0.406],
#           'IMG_STD': [0.229, 0.224, 0.225],
#           'IOU_THRESHOLD': 0.5
#           }

# %%
def get_resnet_backbone(backbone_name: str):
    """
    Returns a resnet backbone pretrained on ImageNet.
    Removes the average-pooling layer and the linear layer at the end.
    """
    if backbone_name == 'resnet18':
        pretrained_model = models.resnet18(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet34':
        pretrained_model = models.resnet34(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet50':
        pretrained_model = models.resnet50(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet101':
        pretrained_model = models.resnet101(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet152':
        pretrained_model = models.resnet152(pretrained=True, progress=False)
        out_channels = 2048

    backbone = torch.nn.Sequential(*list(pretrained_model.children())[:-2])
    backbone.out_channels = out_channels

    return backbone

# %%
def get_resnet_fpn_backbone(backbone_name: str):
    """
    Returns a specified ResNet backbone with FPN pretrained on ImageNet.
    """
    return resnet_fpn_backbone(backbone_name, pretrained=True, trainable_layers=3)

# %%
def get_anchor_generator(anchor_size: Tuple[tuple] = None, aspect_ratios: Tuple[tuple] = None):
    """Returns the anchor generator."""
    if anchor_size is None:
        anchor_size = ((16,), (32,), (64,), (128,))
    if aspect_ratios is None:
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_size)

    anchor_generator = AnchorGenerator(sizes=anchor_size,
                                       aspect_ratios=aspect_ratios)
    return anchor_generator

# %%
def get_roi_pool(featmap_names: List[str] = None, output_size: int = 7, sampling_ratio: int = 2):
    """Returns the ROI Pooling"""
    if featmap_names is None:
        # default for resnet with FPN
        featmap_names = ['0', '1', '2', '3']

    roi_pooler = MultiScaleRoIAlign(featmap_names=featmap_names,
                                    output_size=output_size,
                                    sampling_ratio=sampling_ratio)

    return roi_pooler

# %%
def get_fasterRCNN(backbone: torch.nn.Module,
                   anchor_generator: AnchorGenerator,
                   roi_pooler: MultiScaleRoIAlign,
                   num_classes: int,
                   image_mean: List[float] = [0.485, 0.456, 0.406],
                   image_std: List[float] = [0.229, 0.224, 0.225],
                   min_size: int = 512,
                   max_size: int = 1024,
                   **kwargs
                   ):
    """Returns the Faster-RCNN model. Default normalization: ImageNet"""
    model = FasterRCNN(backbone=backbone,
                       rpn_anchor_generator=anchor_generator,
                       box_roi_pool=roi_pooler,
                       num_classes=num_classes,
                       image_mean=image_mean,  # ImageNet
                       image_std=image_std,  # ImageNet
                       min_size=min_size,
                       max_size=max_size,
                       **kwargs
                       )
    model.num_classes = num_classes
    model.image_mean = image_mean
    model.image_std = image_std
    model.min_size = min_size
    model.max_size = max_size

    return model

# %%
def get_fasterRCNN_resnet(num_classes: int,
                          backbone_name: str,
                          anchor_size: List[float],
                          aspect_ratios: List[float],
                          fpn: bool = True,
                          min_size: int = 512,
                          max_size: int = 1024,
                          **kwargs
                          ):
    """Returns the Faster-RCNN model with resnet backbone with and without fpn."""

    # Backbone
    if fpn:
        backbone = get_resnet_fpn_backbone(backbone_name=backbone_name)
    else:
        backbone = get_resnet_backbone(backbone_name=backbone_name)

    # Anchors
    anchor_size = anchor_size
    aspect_ratios = aspect_ratios * len(anchor_size)
    anchor_generator = get_anchor_generator(anchor_size=anchor_size, aspect_ratios=aspect_ratios)

    # ROI Pool
    with torch.no_grad():
        backbone.eval()
        random_input = torch.rand(size=(1, 3, 512, 512))
        features = backbone(random_input)

    if isinstance(features, torch.Tensor):
        from collections import OrderedDict

        features = OrderedDict([('0', features)])

    featmap_names = [key for key in features.keys() if key.isnumeric()]

    roi_pool = get_roi_pool(featmap_names=featmap_names)

    # Model
    return get_fasterRCNN(backbone=backbone,
                          anchor_generator=anchor_generator,
                          roi_pooler=roi_pool,
                          num_classes=num_classes,
                          min_size=min_size,
                          max_size=max_size,
                          **kwargs)

# %%
model = get_fasterRCNN_resnet(num_classes=params['CLASSES'],
                              backbone_name=params['BACKBONE'],
                              anchor_size=params['ANCHOR_SIZE'],
                              aspect_ratios=params['ASPECT_RATIOS'],
                              fpn=params['FPN'],
                              min_size=params['MIN_SIZE'],
                              max_size=params['MAX_SIZE'],
                              image_mean=params['IMG_MEAN'],
                              image_std=params['IMG_STD'])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# HBox(children=(FloatProgress(value=0.0, max=178793939.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# load pretrained weights for FasterRCNN ResNet50 FPN
pretrained_dict = torch.hub.load_state_dict_from_url('https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth', progress=True)
model_dict = model.state_dict()

# filter out roi_heads.box_predictor weights
pretrained_dict = {k: v for k, v in pretrained_dict.items() if not k.startswith('roi_heads.box_predictor')}
# overwrite entries in the existing state dict
model_dict.update(pretrained_dict)
# load the new state dict
model.load_state_dict(model_dict)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(FloatProgress(value=0.0, max=167502836.0), HTML(value='')))
# <All keys matched successfully>

# %%
# move model to the right device
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (7): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (8): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (9): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (10): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (11): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (12): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (13): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (14): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (15): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (16): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (17): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (18): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (19): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (20): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (21): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (22): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=9, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=36, bias=True)
#     )
#   )
# )

# %%
# construct an optimizer
model_params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(model_params, 
                            lr=params['LR'],
                            momentum=0.9, 
                            weight_decay=0.001)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %% [markdown]
# ## Data Augmentation
#
# Let's write some helper functions for data augmentation / transformation.
#
# Do not just stop here, add in your own data augmentations! Remember to also augment the bounding boxes accordingly.

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
# converts the image, a PIL image, into a PyTorch Tensor
class ToTensor(object):
    def __call__(self, image, target):
        image = F.to_tensor(image)
        return image, target

# %%
# randomly horizontal flip the images and ground-truth labels
class RandomHorizontalFlip(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
            height, width = image.shape[-2:]
            image = image.flip(-1)
            bbox = target["boxes"]
            bbox[:, [0, 2]] = width - bbox[:, [2, 0]]
            target["boxes"] = bbox
        return image, target

# %%
def get_transform(train):
    if train:
        transforms = Compose([
            ToTensor(), 
            RandomHorizontalFlip(0.5)
        ])
    else: # during evaluation, no augmentations will be done
        transforms = Compose([
            ToTensor()
        ])
    
    return transforms

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled by the R-CNN model.

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.
#
# We now have the dataset class, the models and the data transforms. Let's instantiate them

# %%
NUM_WORKERS = 4

# use our dataset and defined transformations
train_dataset = TILDataset(til_root, train_annotation, get_transform(train=True))
train_dataset_1 = TILDataset(til_root_1, train_annotation_1, get_transform(train=True))
train_dataset_2 = TILDataset(til_root_2, train_annotation_2, get_transform(train=True))
train_dataset_3 = TILDataset(til_root_3, train_annotation_3, get_transform(train=True))
train_dataset_4 = TILDataset(til_root_4, train_annotation_4, get_transform(train=True))
train_dataset_5 = TILDataset(til_root_5, train_annotation_5, get_transform(train=True))

val_dataset = TILDataset(til_root, val_annotation, get_transform(train=False))

# define training and validation data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset + train_dataset_1 + train_dataset_2 + train_dataset_3 + train_dataset_4 + train_dataset_5, 
    batch_size=params['BATCH_SIZE'], shuffle=True, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=1, shuffle=False, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
len(train_dataset) + len(train_dataset_1) + len(train_dataset_2) + len(train_dataset_3) + len(train_dataset_4) #+ len(train_dataset_5)
# Out:
# 8972

# %% [markdown]
# ## Model Training
#
# And now let's train the model, evaluating at the end of every epoch.

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', utils.SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = utils.warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            print(loss_dict)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses, **loss_dict)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

# %%
@torch.no_grad()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    torch.set_num_threads(1)
    model.eval()
    metric_logger = utils.MetricLogger(delimiter="  ")
    header = 'Test:'

    coco = data_loader.dataset.coco
    iou_types = ["bbox"]
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for image, targets in metric_logger.log_every(data_loader, 100, header):
        image = list(img.to(device) for img in image)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(image)

        outputs = [{k: v for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluator_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    return coco_evaluator

# %%
for epoch in range(params['MAXEPOCHS']):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)

    # update the learning rate
    lr_scheduler.step()

    # evaluate on the test dataset
    evaluate(model, val_loader, device=device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0]  [   0/2343]  eta: 1:05:37  lr: 0.000006  loss: 2.6336 (2.6336)  loss_classifier: 2.4086 (2.4086)  loss_box_reg: 0.1980 (0.1980)  loss_objectness: 0.0232 (0.0232)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 1.6804  data: 0.6647  max mem: 1876
# Epoch: [0]  [  10/2343]  eta: 0:23:04  lr: 0.000036  loss: 2.5083 (2.4842)  loss_classifier: 2.2811 (2.2590)  loss_box_reg: 0.1979 (0.2021)  loss_objectness: 0.0186 (0.0195)  loss_rpn_box_reg: 0.0022 (0.0035)  time: 0.5933  data: 0.0749  max mem: 2297
# Epoch: [0]  [  20/2343]  eta: 0:20:49  lr: 0.000066  loss: 2.1795 (2.1664)  loss_classifier: 1.9890 (1.9373)  loss_box_reg: 0.1979 (0.2059)  loss_objectness: 0.0130 (0.0187)  loss_rpn_box_reg: 0.0023 (0.0045)  time: 0.4808  data: 0.0177  max mem: 2297
# Epoch: [0]  [  30/2343]  eta: 0:19:55  lr: 0.000096  loss: 1.3083 (1.7742)  loss_classifier: 0.9198 (1.5064)  loss_box_reg: 0.2008 (0.2003)  loss_objectness: 0.0115 (0.0560)  loss_rpn_box_reg: 0.0027 (0.0114)  time: 0.4751  data: 0.0186  max mem: 2297
# Epoch: [0]  [  40/2343]  eta: 0:19:21  lr: 0.000126  loss: 0.6109 (1.4787)  loss_classifier: 0.3936 (1.2129)  loss_box_reg: 0.1978 (0.2077)  loss_objectness: 0.0078 (0.0476)  loss_rpn_box_reg: 0.0038 (0.0105)  time: 0.4690  data: 0.0175  max mem: 2297
# Epoch: [0]  [  50/2343]  eta: 0:18:59  lr: 0.000156  loss: 0.4410 (1.2840)  loss_classifier: 0.2525 (1.0265)  loss_box_reg: 0.1802 (0.2046)  loss_objectness: 0.0095 (0.0436)  loss_rpn_box_reg: 0.0036 (0.0092)  time: 0.4657  data: 0.0173  max mem: 2297
# Epoch: [0]  [  60/2343]  eta: 0:18:50  lr: 0.000186  loss: 0.4195 (1.1558)  loss_classifier: 0.2230 (0.8979)  loss_box_reg: 0.1730 (0.2024)  loss_objectness: 0.0158 (0.0458)  loss_rpn_box_reg: 0.0036 (0.0097)  time: 0.4770  data: 0.0175  max mem: 2297
# Epoch: [0]  [  70/2343]  eta: 0:18:38  lr: 0.000216  loss: 0.4160 (1.0672)  loss_classifier: 0.2165 (0.8102)  loss_box_reg: 0.1821 (0.2051)  loss_objectness: 0.0126 (0.0429)  loss_rpn_box_reg: 0.0040 (0.0090)  time: 0.4798  data: 0.0178  max mem: 2297
# Epoch: [0]  [  80/2343]  eta: 0:18:26  lr: 0.000246  loss: 0.3897 (0.9928)  loss_classifier: 0.2075 (0.7389)  loss_box_reg: 0.1776 (0.2050)  loss_objectness: 0.0108 (0.0404)  loss_rpn_box_reg: 0.0029 (0.0084)  time: 0.4690  data: 0.0176  max mem: 2297
# Epoch: [0]  [  90/2343]  eta: 0:18:19  lr: 0.000276  loss: 0.3759 (0.9308)  loss_classifier: 0.1888 (0.6812)  loss_box_reg: 0.1748 (0.2036)  loss_objectness: 0.0118 (0.0380)  loss_rpn_box_reg: 0.0025 (0.0080)  time: 0.4728  data: 0.0168  max mem: 2297
# Epoch: [0]  [ 100/2343]  eta: 0:18:14  lr: 0.000306  loss: 0.3748 (0.8848)  loss_classifier: 0.1888 (0.6366)  loss_box_reg: 0.1713 (0.2047)  loss_objectness: 0.0154 (0.0359)  loss_rpn_box_reg: 0.0033 (0.0077)  time: 0.4836  data: 0.0168  max mem: 2297
# Epoch: [0]  [ 110/2343]  eta: 0:18:09  lr: 0.000336  loss: 0.3409 (0.8418)  loss_classifier: 0.1680 (0.5973)  loss_box_reg: 0.1639 (0.2037)  loss_objectness: 0.0090 (0.0335)  loss_rpn_box_reg: 0.0038 (0.0073)  time: 0.4891  data: 0.0173  max mem: 2297
# Epoch: [0]  [ 120/2343]  eta: 0:18:05  lr: 0.000366  loss: 0.3758 (0.8090)  loss_classifier: 0.1856 (0.5657)  loss_box_reg: 0.1626 (0.2032)  loss_objectness: 0.0076 (0.0329)  loss_rpn_box_reg: 0.0032 (0.0071)  time: 0.4919  data: 0.0184  max mem: 2297
# Epoch: [0]  [ 130/2343]  eta: 0:18:03  lr: 0.000396  loss: 0.3758 (0.7806)  loss_classifier: 0.1929 (0.5387)  loss_box_reg: 0.1588 (0.2028)  loss_objectness: 0.0178 (0.0322)  loss_rpn_box_reg: 0.0027 (0.0070)  time: 0.4981  data: 0.0202  max mem: 2297
# Epoch: [0]  [ 140/2343]  eta: 0:17:57  lr: 0.000426  loss: 0.3718 (0.7599)  loss_classifier: 0.1948 (0.5168)  loss_box_reg: 0.1766 (0.2050)  loss_objectness: 0.0139 (0.0313)  loss_rpn_box_reg: 0.0031 (0.0068)  time: 0.4941  data: 0.0196  max mem: 2297
# Epoch: [0]  [ 150/2343]  eta: 0:17:55  lr: 0.000456  loss: 0.3610 (0.7322)  loss_classifier: 0.1757 (0.4927)  loss_box_reg: 0.1766 (0.2030)  loss_objectness: 0.0098 (0.0299)  loss_rpn_box_reg: 0.0031 (0.0066)  time: 0.4942  data: 0.0181  max mem: 2297
# Epoch: [0]  [ 160/2343]  eta: 0:17:52  lr: 0.000486  loss: 0.3570 (0.7120)  loss_classifier: 0.1623 (0.4738)  loss_box_reg: 0.1851 (0.2030)  loss_objectness: 0.0063 (0.0288)  loss_rpn_box_reg: 0.0025 (0.0064)  time: 0.5059  data: 0.0184  max mem: 2297
# Epoch: [0]  [ 170/2343]  eta: 0:17:49  lr: 0.000515  loss: 0.3666 (0.6980)  loss_classifier: 0.1643 (0.4584)  loss_box_reg: 0.1920 (0.2053)  loss_objectness: 0.0073 (0.0278)  loss_rpn_box_reg: 0.0043 (0.0066)  time: 0.5060  data: 0.0182  max mem: 2297
# Epoch: [0]  [ 180/2343]  eta: 0:17:47  lr: 0.000545  loss: 0.3538 (0.6779)  loss_classifier: 0.1566 (0.4412)  loss_box_reg: 0.1759 (0.2031)  loss_objectness: 0.0078 (0.0271)  loss_rpn_box_reg: 0.0047 (0.0064)  time: 0.5114  data: 0.0178  max mem: 2297
# Epoch: [0]  [ 190/2343]  eta: 0:17:45  lr: 0.000575  loss: 0.3175 (0.6632)  loss_classifier: 0.1386 (0.4268)  loss_box_reg: 0.1702 (0.2032)  loss_objectness: 0.0075 (0.0267)  loss_rpn_box_reg: 0.0038 (0.0064)  time: 0.5185  data: 0.0177  max mem: 2297
# Epoch: [0]  [ 200/2343]  eta: 0:17:43  lr: 0.000605  loss: 0.3700 (0.6496)  loss_classifier: 0.1625 (0.4140)  loss_box_reg: 0.1961 (0.2034)  loss_objectness: 0.0075 (0.0259)  loss_rpn_box_reg: 0.0034 (0.0063)  time: 0.5221  data: 0.0173  max mem: 2297
# Epoch: [0]  [ 210/2343]  eta: 0:17:39  lr: 0.000635  loss: 0.3788 (0.6413)  loss_classifier: 0.1561 (0.4014)  loss_box_reg: 0.1827 (0.2029)  loss_objectness: 0.0071 (0.0296)  loss_rpn_box_reg: 0.0028 (0.0074)  time: 0.5158  data: 0.0174  max mem: 2297
# Epoch: [0]  [ 220/2343]  eta: 0:17:35  lr: 0.000665  loss: 0.3305 (0.6289)  loss_classifier: 0.1420 (0.3906)  loss_box_reg: 0.1724 (0.2020)  loss_objectness: 0.0109 (0.0290)  loss_rpn_box_reg: 0.0026 (0.0073)  time: 0.5058  data: 0.0173  max mem: 2297
# Epoch: [0]  [ 230/2343]  eta: 0:17:31  lr: 0.000695  loss: 0.3295 (0.6187)  loss_classifier: 0.1420 (0.3810)  loss_box_reg: 0.1749 (0.2013)  loss_objectness: 0.0158 (0.0289)  loss_rpn_box_reg: 0.0024 (0.0075)  time: 0.5041  data: 0.0173  max mem: 2297
# Epoch: [0]  [ 240/2343]  eta: 0:17:27  lr: 0.000725  loss: 0.3294 (0.6083)  loss_classifier: 0.1349 (0.3713)  loss_box_reg: 0.1883 (0.2011)  loss_objectness: 0.0169 (0.0285)  loss_rpn_box_reg: 0.0022 (0.0073)  time: 0.5100  data: 0.0172  max mem: 2298
# Epoch: [0]  [ 250/2343]  eta: 0:17:21  lr: 0.000755  loss: 0.3789 (0.6014)  loss_classifier: 0.1387 (0.3635)  loss_box_reg: 0.1945 (0.2029)  loss_objectness: 0.0126 (0.0278)  loss_rpn_box_reg: 0.0036 (0.0072)  time: 0.5020  data: 0.0172  max mem: 2298
# Epoch: [0]  [ 260/2343]  eta: 0:17:17  lr: 0.000785  loss: 0.3142 (0.5937)  loss_classifier: 0.1220 (0.3558)  loss_box_reg: 0.1825 (0.2021)  loss_objectness: 0.0053 (0.0286)  loss_rpn_box_reg: 0.0033 (0.0073)  time: 0.4938  data: 0.0178  max mem: 2298
# Epoch: [0]  [ 270/2343]  eta: 0:17:14  lr: 0.000815  loss: 0.3137 (0.5862)  loss_classifier: 0.1160 (0.3491)  loss_box_reg: 0.1536 (0.2019)  loss_objectness: 0.0077 (0.0281)  loss_rpn_box_reg: 0.0020 (0.0071)  time: 0.5123  data: 0.0184  max mem: 2298
# Epoch: [0]  [ 280/2343]  eta: 0:17:09  lr: 0.000845  loss: 0.3462 (0.5792)  loss_classifier: 0.1483 (0.3424)  loss_box_reg: 0.1952 (0.2022)  loss_objectness: 0.0145 (0.0275)  loss_rpn_box_reg: 0.0025 (0.0070)  time: 0.5100  data: 0.0178  max mem: 2298
# Epoch: [0]  [ 290/2343]  eta: 0:17:03  lr: 0.000875  loss: 0.3487 (0.5722)  loss_classifier: 0.1442 (0.3362)  loss_box_reg: 0.1952 (0.2019)  loss_objectness: 0.0096 (0.0272)  loss_rpn_box_reg: 0.0026 (0.0069)  time: 0.4971  data: 0.0170  max mem: 2298
# Epoch: [0]  [ 300/2343]  eta: 0:16:59  lr: 0.000905  loss: 0.3375 (0.5657)  loss_classifier: 0.1415 (0.3298)  loss_box_reg: 0.1731 (0.2013)  loss_objectness: 0.0096 (0.0276)  loss_rpn_box_reg: 0.0026 (0.0070)  time: 0.4996  data: 0.0174  max mem: 2298
# Epoch: [0]  [ 310/2343]  eta: 0:16:55  lr: 0.000935  loss: 0.3053 (0.5600)  loss_classifier: 0.1153 (0.3237)  loss_box_reg: 0.1688 (0.2011)  loss_objectness: 0.0088 (0.0281)  loss_rpn_box_reg: 0.0027 (0.0072)  time: 0.5089  data: 0.0176  max mem: 2298
# Epoch: [0]  [ 320/2343]  eta: 0:16:49  lr: 0.000965  loss: 0.3221 (0.5532)  loss_classifier: 0.1215 (0.3179)  loss_box_reg: 0.1631 (0.2006)  loss_objectness: 0.0095 (0.0277)  loss_rpn_box_reg: 0.0027 (0.0071)  time: 0.5009  data: 0.0172  max mem: 2298
# Epoch: [0]  [ 330/2343]  eta: 0:16:44  lr: 0.000995  loss: 0.2838 (0.5456)  loss_classifier: 0.1098 (0.3115)  loss_box_reg: 0.1601 (0.1999)  loss_objectness: 0.0063 (0.0272)  loss_rpn_box_reg: 0.0022 (0.0070)  time: 0.4933  data: 0.0170  max mem: 2298
# Epoch: [0]  [ 340/2343]  eta: 0:16:39  lr: 0.001025  loss: 0.2520 (0.5375)  loss_classifier: 0.0983 (0.3054)  loss_box_reg: 0.1489 (0.1987)  loss_objectness: 0.0041 (0.0266)  loss_rpn_box_reg: 0.0028 (0.0069)  time: 0.4949  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 350/2343]  eta: 0:16:34  lr: 0.001055  loss: 0.2484 (0.5306)  loss_classifier: 0.0934 (0.2996)  loss_box_reg: 0.1448 (0.1978)  loss_objectness: 0.0054 (0.0264)  loss_rpn_box_reg: 0.0030 (0.0069)  time: 0.4966  data: 0.0181  max mem: 2298
# Epoch: [0]  [ 360/2343]  eta: 0:16:28  lr: 0.001085  loss: 0.2599 (0.5255)  loss_classifier: 0.0886 (0.2945)  loss_box_reg: 0.1451 (0.1970)  loss_objectness: 0.0069 (0.0270)  loss_rpn_box_reg: 0.0026 (0.0070)  time: 0.4971  data: 0.0177  max mem: 2298
# Epoch: [0]  [ 370/2343]  eta: 0:16:23  lr: 0.001115  loss: 0.2643 (0.5190)  loss_classifier: 0.0978 (0.2896)  loss_box_reg: 0.1532 (0.1959)  loss_objectness: 0.0090 (0.0266)  loss_rpn_box_reg: 0.0035 (0.0069)  time: 0.4933  data: 0.0177  max mem: 2298
# Epoch: [0]  [ 380/2343]  eta: 0:16:17  lr: 0.001145  loss: 0.2654 (0.5128)  loss_classifier: 0.1061 (0.2850)  loss_box_reg: 0.1447 (0.1945)  loss_objectness: 0.0117 (0.0265)  loss_rpn_box_reg: 0.0033 (0.0068)  time: 0.4896  data: 0.0182  max mem: 2298
# Epoch: [0]  [ 390/2343]  eta: 0:16:13  lr: 0.001175  loss: 0.2372 (0.5075)  loss_classifier: 0.0953 (0.2809)  loss_box_reg: 0.1290 (0.1935)  loss_objectness: 0.0081 (0.0264)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 0.4965  data: 0.0180  max mem: 2298
# Epoch: [0]  [ 400/2343]  eta: 0:16:09  lr: 0.001205  loss: 0.2425 (0.5030)  loss_classifier: 0.1018 (0.2771)  loss_box_reg: 0.1342 (0.1930)  loss_objectness: 0.0084 (0.0263)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 0.5088  data: 0.0179  max mem: 2298
# Epoch: [0]  [ 410/2343]  eta: 0:16:03  lr: 0.001235  loss: 0.2375 (0.4978)  loss_classifier: 0.0961 (0.2730)  loss_box_reg: 0.1342 (0.1919)  loss_objectness: 0.0084 (0.0261)  loss_rpn_box_reg: 0.0024 (0.0068)  time: 0.5002  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 420/2343]  eta: 0:15:58  lr: 0.001265  loss: 0.2103 (0.4918)  loss_classifier: 0.0953 (0.2690)  loss_box_reg: 0.1221 (0.1904)  loss_objectness: 0.0084 (0.0257)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 0.4892  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 430/2343]  eta: 0:15:53  lr: 0.001295  loss: 0.2098 (0.4857)  loss_classifier: 0.0774 (0.2647)  loss_box_reg: 0.1158 (0.1890)  loss_objectness: 0.0078 (0.0254)  loss_rpn_box_reg: 0.0027 (0.0066)  time: 0.4958  data: 0.0176  max mem: 2298
# Epoch: [0]  [ 440/2343]  eta: 0:15:49  lr: 0.001325  loss: 0.2229 (0.4806)  loss_classifier: 0.0839 (0.2611)  loss_box_reg: 0.1367 (0.1880)  loss_objectness: 0.0045 (0.0249)  loss_rpn_box_reg: 0.0022 (0.0065)  time: 0.5114  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 450/2343]  eta: 0:15:44  lr: 0.001355  loss: 0.2367 (0.4761)  loss_classifier: 0.0923 (0.2578)  loss_box_reg: 0.1377 (0.1872)  loss_objectness: 0.0071 (0.0246)  loss_rpn_box_reg: 0.0026 (0.0065)  time: 0.5080  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 460/2343]  eta: 0:15:39  lr: 0.001385  loss: 0.2304 (0.4711)  loss_classifier: 0.0863 (0.2543)  loss_box_reg: 0.1358 (0.1862)  loss_objectness: 0.0071 (0.0242)  loss_rpn_box_reg: 0.0030 (0.0064)  time: 0.5065  data: 0.0177  max mem: 2298
# Epoch: [0]  [ 470/2343]  eta: 0:15:34  lr: 0.001415  loss: 0.2251 (0.4665)  loss_classifier: 0.0863 (0.2512)  loss_box_reg: 0.1270 (0.1850)  loss_objectness: 0.0027 (0.0240)  loss_rpn_box_reg: 0.0022 (0.0063)  time: 0.5054  data: 0.0180  max mem: 2298
# Epoch: [0]  [ 480/2343]  eta: 0:15:29  lr: 0.001445  loss: 0.2517 (0.4623)  loss_classifier: 0.0970 (0.2481)  loss_box_reg: 0.1270 (0.1841)  loss_objectness: 0.0085 (0.0238)  loss_rpn_box_reg: 0.0034 (0.0063)  time: 0.4961  data: 0.0178  max mem: 2298
# Epoch: [0]  [ 490/2343]  eta: 0:15:25  lr: 0.001475  loss: 0.2517 (0.4588)  loss_classifier: 0.0970 (0.2455)  loss_box_reg: 0.1365 (0.1836)  loss_objectness: 0.0040 (0.0235)  loss_rpn_box_reg: 0.0034 (0.0063)  time: 0.5044  data: 0.0170  max mem: 2298
# Epoch: [0]  [ 500/2343]  eta: 0:15:20  lr: 0.001504  loss: 0.2709 (0.4553)  loss_classifier: 0.1097 (0.2428)  loss_box_reg: 0.1384 (0.1831)  loss_objectness: 0.0043 (0.0232)  loss_rpn_box_reg: 0.0025 (0.0062)  time: 0.5155  data: 0.0169  max mem: 2298
# Epoch: [0]  [ 510/2343]  eta: 0:15:15  lr: 0.001534  loss: 0.2163 (0.4511)  loss_classifier: 0.1016 (0.2400)  loss_box_reg: 0.1160 (0.1820)  loss_objectness: 0.0056 (0.0229)  loss_rpn_box_reg: 0.0027 (0.0062)  time: 0.5013  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 520/2343]  eta: 0:15:10  lr: 0.001564  loss: 0.2101 (0.4469)  loss_classifier: 0.0810 (0.2372)  loss_box_reg: 0.1119 (0.1810)  loss_objectness: 0.0056 (0.0226)  loss_rpn_box_reg: 0.0027 (0.0061)  time: 0.4956  data: 0.0176  max mem: 2298
# Epoch: [0]  [ 530/2343]  eta: 0:15:05  lr: 0.001594  loss: 0.2404 (0.4437)  loss_classifier: 0.0913 (0.2349)  loss_box_reg: 0.1315 (0.1804)  loss_objectness: 0.0056 (0.0224)  loss_rpn_box_reg: 0.0034 (0.0061)  time: 0.5046  data: 0.0169  max mem: 2298
# Epoch: [0]  [ 540/2343]  eta: 0:15:01  lr: 0.001624  loss: 0.2375 (0.4394)  loss_classifier: 0.0872 (0.2319)  loss_box_reg: 0.1244 (0.1794)  loss_objectness: 0.0053 (0.0221)  loss_rpn_box_reg: 0.0032 (0.0060)  time: 0.5108  data: 0.0172  max mem: 2298
# Epoch: [0]  [ 550/2343]  eta: 0:14:56  lr: 0.001654  loss: 0.1919 (0.4365)  loss_classifier: 0.0813 (0.2295)  loss_box_reg: 0.1042 (0.1786)  loss_objectness: 0.0042 (0.0223)  loss_rpn_box_reg: 0.0025 (0.0060)  time: 0.5071  data: 0.0179  max mem: 2298
# Epoch: [0]  [ 560/2343]  eta: 0:14:51  lr: 0.001684  loss: 0.2163 (0.4333)  loss_classifier: 0.0856 (0.2273)  loss_box_reg: 0.0989 (0.1776)  loss_objectness: 0.0056 (0.0224)  loss_rpn_box_reg: 0.0026 (0.0060)  time: 0.4941  data: 0.0182  max mem: 2298
# Epoch: [0]  [ 570/2343]  eta: 0:14:46  lr: 0.001714  loss: 0.2054 (0.4312)  loss_classifier: 0.0787 (0.2251)  loss_box_reg: 0.0904 (0.1765)  loss_objectness: 0.0110 (0.0234)  loss_rpn_box_reg: 0.0029 (0.0062)  time: 0.5016  data: 0.0180  max mem: 2298
# Epoch: [0]  [ 580/2343]  eta: 0:14:41  lr: 0.001744  loss: 0.1823 (0.4271)  loss_classifier: 0.0752 (0.2227)  loss_box_reg: 0.0800 (0.1750)  loss_objectness: 0.0128 (0.0233)  loss_rpn_box_reg: 0.0024 (0.0061)  time: 0.5049  data: 0.0175  max mem: 2298
# Epoch: [0]  [ 590/2343]  eta: 0:14:35  lr: 0.001774  loss: 0.1823 (0.4238)  loss_classifier: 0.0752 (0.2206)  loss_box_reg: 0.0831 (0.1738)  loss_objectness: 0.0080 (0.0233)  loss_rpn_box_reg: 0.0028 (0.0061)  time: 0.4914  data: 0.0181  max mem: 2299
# Epoch: [0]  [ 600/2343]  eta: 0:14:30  lr: 0.001804  loss: 0.2132 (0.4206)  loss_classifier: 0.0816 (0.2185)  loss_box_reg: 0.1033 (0.1730)  loss_objectness: 0.0087 (0.0230)  loss_rpn_box_reg: 0.0036 (0.0061)  time: 0.4902  data: 0.0182  max mem: 2299
# Epoch: [0]  [ 610/2343]  eta: 0:14:25  lr: 0.001834  loss: 0.1901 (0.4165)  loss_classifier: 0.0789 (0.2161)  loss_box_reg: 0.0916 (0.1716)  loss_objectness: 0.0054 (0.0227)  loss_rpn_box_reg: 0.0020 (0.0060)  time: 0.4959  data: 0.0174  max mem: 2299
# Epoch: [0]  [ 620/2343]  eta: 0:14:20  lr: 0.001864  loss: 0.1719 (0.4127)  loss_classifier: 0.0711 (0.2138)  loss_box_reg: 0.0858 (0.1705)  loss_objectness: 0.0044 (0.0225)  loss_rpn_box_reg: 0.0020 (0.0060)  time: 0.4893  data: 0.0176  max mem: 2299
# Epoch: [0]  [ 630/2343]  eta: 0:14:15  lr: 0.001894  loss: 0.1576 (0.4097)  loss_classifier: 0.0648 (0.2118)  loss_box_reg: 0.0880 (0.1698)  loss_objectness: 0.0049 (0.0222)  loss_rpn_box_reg: 0.0021 (0.0059)  time: 0.5020  data: 0.0182  max mem: 2299
# Epoch: [0]  [ 640/2343]  eta: 0:14:10  lr: 0.001924  loss: 0.1909 (0.4067)  loss_classifier: 0.0738 (0.2098)  loss_box_reg: 0.0880 (0.1690)  loss_objectness: 0.0030 (0.0219)  loss_rpn_box_reg: 0.0025 (0.0059)  time: 0.5062  data: 0.0180  max mem: 2299
# Epoch: [0]  [ 650/2343]  eta: 0:14:06  lr: 0.001954  loss: 0.2119 (0.4054)  loss_classifier: 0.0791 (0.2087)  loss_box_reg: 0.1113 (0.1686)  loss_objectness: 0.0045 (0.0222)  loss_rpn_box_reg: 0.0030 (0.0059)  time: 0.5025  data: 0.0177  max mem: 2299
# Epoch: [0]  [ 660/2343]  eta: 0:14:00  lr: 0.001984  loss: 0.2179 (0.4037)  loss_classifier: 0.1147 (0.2073)  loss_box_reg: 0.1330 (0.1683)  loss_objectness: 0.0117 (0.0221)  loss_rpn_box_reg: 0.0039 (0.0059)  time: 0.4992  data: 0.0173  max mem: 2299
# Epoch: [0]  [ 670/2343]  eta: 0:13:55  lr: 0.002014  loss: 0.2060 (0.4021)  loss_classifier: 0.1147 (0.2061)  loss_box_reg: 0.1221 (0.1677)  loss_objectness: 0.0123 (0.0223)  loss_rpn_box_reg: 0.0032 (0.0059)  time: 0.4865  data: 0.0172  max mem: 2299
# Epoch: [0]  [ 680/2343]  eta: 0:13:50  lr: 0.002044  loss: 0.2060 (0.3995)  loss_classifier: 0.0930 (0.2046)  loss_box_reg: 0.0954 (0.1668)  loss_objectness: 0.0074 (0.0221)  loss_rpn_box_reg: 0.0022 (0.0059)  time: 0.4894  data: 0.0175  max mem: 2299
# Epoch: [0]  [ 690/2343]  eta: 0:13:45  lr: 0.002074  loss: 0.2205 (0.3975)  loss_classifier: 0.0930 (0.2032)  loss_box_reg: 0.1152 (0.1665)  loss_objectness: 0.0063 (0.0220)  loss_rpn_box_reg: 0.0022 (0.0059)  time: 0.4949  data: 0.0178  max mem: 2299
# Epoch: [0]  [ 700/2343]  eta: 0:13:40  lr: 0.002104  loss: 0.1946 (0.3949)  loss_classifier: 0.0807 (0.2017)  loss_box_reg: 0.0996 (0.1655)  loss_objectness: 0.0068 (0.0218)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 0.4979  data: 0.0179  max mem: 2299
# Epoch: [0]  [ 710/2343]  eta: 0:13:35  lr: 0.002134  loss: 0.1513 (0.3917)  loss_classifier: 0.0658 (0.1999)  loss_box_reg: 0.0760 (0.1643)  loss_objectness: 0.0054 (0.0216)  loss_rpn_box_reg: 0.0022 (0.0058)  time: 0.4987  data: 0.0178  max mem: 2299
# Epoch: [0]  [ 720/2343]  eta: 0:13:30  lr: 0.002164  loss: 0.1513 (0.3895)  loss_classifier: 0.0658 (0.1985)  loss_box_reg: 0.0773 (0.1637)  loss_objectness: 0.0053 (0.0215)  loss_rpn_box_reg: 0.0023 (0.0058)  time: 0.4983  data: 0.0182  max mem: 2299
# Epoch: [0]  [ 730/2343]  eta: 0:13:25  lr: 0.002194  loss: 0.1738 (0.3871)  loss_classifier: 0.0784 (0.1969)  loss_box_reg: 0.0930 (0.1631)  loss_objectness: 0.0072 (0.0213)  loss_rpn_box_reg: 0.0023 (0.0058)  time: 0.5019  data: 0.0187  max mem: 2299
# Epoch: [0]  [ 740/2343]  eta: 0:13:19  lr: 0.002224  loss: 0.1731 (0.3855)  loss_classifier: 0.0784 (0.1959)  loss_box_reg: 0.0964 (0.1626)  loss_objectness: 0.0077 (0.0213)  loss_rpn_box_reg: 0.0025 (0.0058)  time: 0.4942  data: 0.0180  max mem: 2299
# Epoch: [0]  [ 750/2343]  eta: 0:13:15  lr: 0.002254  loss: 0.1679 (0.3831)  loss_classifier: 0.0764 (0.1944)  loss_box_reg: 0.0853 (0.1619)  loss_objectness: 0.0065 (0.0211)  loss_rpn_box_reg: 0.0025 (0.0057)  time: 0.4952  data: 0.0171  max mem: 2299
# Epoch: [0]  [ 760/2343]  eta: 0:13:09  lr: 0.002284  loss: 0.1562 (0.3803)  loss_classifier: 0.0703 (0.1930)  loss_box_reg: 0.0760 (0.1608)  loss_objectness: 0.0040 (0.0209)  loss_rpn_box_reg: 0.0016 (0.0057)  time: 0.5009  data: 0.0173  max mem: 2299
# Epoch: [0]  [ 770/2343]  eta: 0:13:05  lr: 0.002314  loss: 0.1562 (0.3783)  loss_classifier: 0.0729 (0.1917)  loss_box_reg: 0.0763 (0.1602)  loss_objectness: 0.0030 (0.0207)  loss_rpn_box_reg: 0.0022 (0.0056)  time: 0.5021  data: 0.0179  max mem: 2299
# Epoch: [0]  [ 780/2343]  eta: 0:13:00  lr: 0.002344  loss: 0.1719 (0.3760)  loss_classifier: 0.0783 (0.1904)  loss_box_reg: 0.0842 (0.1594)  loss_objectness: 0.0040 (0.0206)  loss_rpn_box_reg: 0.0026 (0.0056)  time: 0.4998  data: 0.0182  max mem: 2299
# Epoch: [0]  [ 790/2343]  eta: 0:12:55  lr: 0.002374  loss: 0.1802 (0.3739)  loss_classifier: 0.0837 (0.1892)  loss_box_reg: 0.0905 (0.1587)  loss_objectness: 0.0054 (0.0204)  loss_rpn_box_reg: 0.0028 (0.0056)  time: 0.4929  data: 0.0178  max mem: 2299
# Epoch: [0]  [ 800/2343]  eta: 0:12:49  lr: 0.002404  loss: 0.1878 (0.3720)  loss_classifier: 0.0853 (0.1881)  loss_box_reg: 0.0900 (0.1580)  loss_objectness: 0.0058 (0.0204)  loss_rpn_box_reg: 0.0029 (0.0056)  time: 0.4954  data: 0.0178  max mem: 2299
# Epoch: [0]  [ 810/2343]  eta: 0:12:44  lr: 0.002434  loss: 0.1890 (0.3698)  loss_classifier: 0.0854 (0.1867)  loss_box_reg: 0.0896 (0.1572)  loss_objectness: 0.0065 (0.0203)  loss_rpn_box_reg: 0.0026 (0.0056)  time: 0.4895  data: 0.0179  max mem: 2299
# Epoch: [0]  [ 820/2343]  eta: 0:12:39  lr: 0.002464  loss: 0.1570 (0.3670)  loss_classifier: 0.0592 (0.1852)  loss_box_reg: 0.0818 (0.1563)  loss_objectness: 0.0053 (0.0201)  loss_rpn_box_reg: 0.0023 (0.0055)  time: 0.4853  data: 0.0176  max mem: 2299
# Epoch: [0]  [ 830/2343]  eta: 0:12:34  lr: 0.002494  loss: 0.1334 (0.3647)  loss_classifier: 0.0510 (0.1838)  loss_box_reg: 0.0774 (0.1555)  loss_objectness: 0.0031 (0.0199)  loss_rpn_box_reg: 0.0017 (0.0055)  time: 0.4992  data: 0.0170  max mem: 2299
# Epoch: [0]  [ 840/2343]  eta: 0:12:29  lr: 0.002523  loss: 0.1504 (0.3632)  loss_classifier: 0.0587 (0.1828)  loss_box_reg: 0.0829 (0.1550)  loss_objectness: 0.0057 (0.0199)  loss_rpn_box_reg: 0.0030 (0.0055)  time: 0.5058  data: 0.0168  max mem: 2299
# Epoch: [0]  [ 850/2343]  eta: 0:12:24  lr: 0.002553  loss: 0.1826 (0.3611)  loss_classifier: 0.0798 (0.1817)  loss_box_reg: 0.0858 (0.1542)  loss_objectness: 0.0050 (0.0198)  loss_rpn_box_reg: 0.0029 (0.0054)  time: 0.4995  data: 0.0174  max mem: 2299
# Epoch: [0]  [ 860/2343]  eta: 0:12:19  lr: 0.002583  loss: 0.1787 (0.3598)  loss_classifier: 0.0870 (0.1809)  loss_box_reg: 0.0798 (0.1537)  loss_objectness: 0.0059 (0.0197)  loss_rpn_box_reg: 0.0022 (0.0054)  time: 0.4967  data: 0.0181  max mem: 2299
# Epoch: [0]  [ 870/2343]  eta: 0:12:14  lr: 0.002613  loss: 0.1842 (0.3582)  loss_classifier: 0.0817 (0.1799)  loss_box_reg: 0.0894 (0.1533)  loss_objectness: 0.0060 (0.0196)  loss_rpn_box_reg: 0.0023 (0.0054)  time: 0.4864  data: 0.0178  max mem: 2299
# Epoch: [0]  [ 880/2343]  eta: 0:12:09  lr: 0.002643  loss: 0.1912 (0.3568)  loss_classifier: 0.0800 (0.1790)  loss_box_reg: 0.0913 (0.1525)  loss_objectness: 0.0058 (0.0198)  loss_rpn_box_reg: 0.0021 (0.0055)  time: 0.5043  data: 0.0169  max mem: 2299
# Epoch: [0]  [ 890/2343]  eta: 0:12:04  lr: 0.002673  loss: 0.1912 (0.3555)  loss_classifier: 0.0841 (0.1781)  loss_box_reg: 0.0826 (0.1519)  loss_objectness: 0.0071 (0.0200)  loss_rpn_box_reg: 0.0020 (0.0055)  time: 0.5065  data: 0.0175  max mem: 2299
# Epoch: [0]  [ 900/2343]  eta: 0:11:59  lr: 0.002703  loss: 0.1646 (0.3536)  loss_classifier: 0.0765 (0.1770)  loss_box_reg: 0.0826 (0.1513)  loss_objectness: 0.0073 (0.0199)  loss_rpn_box_reg: 0.0017 (0.0055)  time: 0.4852  data: 0.0182  max mem: 2299
# Epoch: [0]  [ 910/2343]  eta: 0:11:54  lr: 0.002733  loss: 0.1678 (0.3520)  loss_classifier: 0.0722 (0.1759)  loss_box_reg: 0.0851 (0.1508)  loss_objectness: 0.0056 (0.0198)  loss_rpn_box_reg: 0.0019 (0.0055)  time: 0.4903  data: 0.0176  max mem: 2299
# Epoch: [0]  [ 920/2343]  eta: 0:11:48  lr: 0.002763  loss: 0.1698 (0.3500)  loss_classifier: 0.0642 (0.1748)  loss_box_reg: 0.0822 (0.1501)  loss_objectness: 0.0055 (0.0197)  loss_rpn_box_reg: 0.0025 (0.0055)  time: 0.4815  data: 0.0169  max mem: 2299
# Epoch: [0]  [ 930/2343]  eta: 0:11:44  lr: 0.002793  loss: 0.1690 (0.3486)  loss_classifier: 0.0686 (0.1739)  loss_box_reg: 0.0784 (0.1497)  loss_objectness: 0.0066 (0.0196)  loss_rpn_box_reg: 0.0027 (0.0054)  time: 0.4864  data: 0.0172  max mem: 2299
# Epoch: [0]  [ 940/2343]  eta: 0:11:39  lr: 0.002823  loss: 0.1789 (0.3470)  loss_classifier: 0.0737 (0.1730)  loss_box_reg: 0.0914 (0.1492)  loss_objectness: 0.0072 (0.0195)  loss_rpn_box_reg: 0.0023 (0.0054)  time: 0.5065  data: 0.0180  max mem: 2299
# Epoch: [0]  [ 950/2343]  eta: 0:11:34  lr: 0.002853  loss: 0.1601 (0.3455)  loss_classifier: 0.0641 (0.1720)  loss_box_reg: 0.0713 (0.1487)  loss_objectness: 0.0072 (0.0194)  loss_rpn_box_reg: 0.0025 (0.0054)  time: 0.5021  data: 0.0188  max mem: 2299
# Epoch: [0]  [ 960/2343]  eta: 0:11:29  lr: 0.002883  loss: 0.1801 (0.3441)  loss_classifier: 0.0668 (0.1713)  loss_box_reg: 0.0725 (0.1480)  loss_objectness: 0.0058 (0.0193)  loss_rpn_box_reg: 0.0027 (0.0054)  time: 0.5048  data: 0.0180  max mem: 2299
# Epoch: [0]  [ 970/2343]  eta: 0:11:24  lr: 0.002913  loss: 0.1948 (0.3429)  loss_classifier: 0.0938 (0.1705)  loss_box_reg: 0.0871 (0.1477)  loss_objectness: 0.0072 (0.0193)  loss_rpn_box_reg: 0.0025 (0.0055)  time: 0.5070  data: 0.0174  max mem: 2299
# Epoch: [0]  [ 980/2343]  eta: 0:11:19  lr: 0.002943  loss: 0.1563 (0.3411)  loss_classifier: 0.0572 (0.1694)  loss_box_reg: 0.0871 (0.1471)  loss_objectness: 0.0067 (0.0192)  loss_rpn_box_reg: 0.0027 (0.0054)  time: 0.4979  data: 0.0179  max mem: 2299
# Epoch: [0]  [ 990/2343]  eta: 0:11:14  lr: 0.002973  loss: 0.1693 (0.3400)  loss_classifier: 0.0657 (0.1686)  loss_box_reg: 0.0840 (0.1467)  loss_objectness: 0.0060 (0.0191)  loss_rpn_box_reg: 0.0031 (0.0055)  time: 0.4933  data: 0.0174  max mem: 2299
# Epoch: [0]  [1000/2343]  eta: 0:11:09  lr: 0.003000  loss: 0.1865 (0.3387)  loss_classifier: 0.0765 (0.1678)  loss_box_reg: 0.0885 (0.1463)  loss_objectness: 0.0061 (0.0191)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.5036  data: 0.0169  max mem: 2299
# Epoch: [0]  [1010/2343]  eta: 0:11:04  lr: 0.003000  loss: 0.1865 (0.3378)  loss_classifier: 0.0765 (0.1670)  loss_box_reg: 0.1082 (0.1462)  loss_objectness: 0.0052 (0.0190)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.4977  data: 0.0176  max mem: 2299
# Epoch: [0]  [1020/2343]  eta: 0:10:59  lr: 0.003000  loss: 0.1981 (0.3369)  loss_classifier: 0.0821 (0.1664)  loss_box_reg: 0.1079 (0.1460)  loss_objectness: 0.0059 (0.0190)  loss_rpn_box_reg: 0.0023 (0.0055)  time: 0.4983  data: 0.0188  max mem: 2299
# Epoch: [0]  [1030/2343]  eta: 0:10:54  lr: 0.003000  loss: 0.1706 (0.3357)  loss_classifier: 0.0712 (0.1656)  loss_box_reg: 0.0908 (0.1457)  loss_objectness: 0.0059 (0.0189)  loss_rpn_box_reg: 0.0021 (0.0055)  time: 0.4983  data: 0.0187  max mem: 2300
# Epoch: [0]  [1040/2343]  eta: 0:10:49  lr: 0.003000  loss: 0.1556 (0.3340)  loss_classifier: 0.0647 (0.1648)  loss_box_reg: 0.0836 (0.1450)  loss_objectness: 0.0035 (0.0188)  loss_rpn_box_reg: 0.0020 (0.0055)  time: 0.4811  data: 0.0177  max mem: 2300
# Epoch: [0]  [1050/2343]  eta: 0:10:44  lr: 0.003000  loss: 0.1329 (0.3323)  loss_classifier: 0.0602 (0.1638)  loss_box_reg: 0.0613 (0.1443)  loss_objectness: 0.0035 (0.0188)  loss_rpn_box_reg: 0.0023 (0.0055)  time: 0.4912  data: 0.0179  max mem: 2300
# Epoch: [0]  [1060/2343]  eta: 0:10:39  lr: 0.003000  loss: 0.1496 (0.3319)  loss_classifier: 0.0733 (0.1633)  loss_box_reg: 0.0717 (0.1442)  loss_objectness: 0.0067 (0.0189)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.4998  data: 0.0176  max mem: 2300
# Epoch: [0]  [1070/2343]  eta: 0:10:34  lr: 0.003000  loss: 0.1722 (0.3303)  loss_classifier: 0.0831 (0.1625)  loss_box_reg: 0.0736 (0.1436)  loss_objectness: 0.0081 (0.0188)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.5048  data: 0.0175  max mem: 2300
# Epoch: [0]  [1080/2343]  eta: 0:10:29  lr: 0.003000  loss: 0.1722 (0.3291)  loss_classifier: 0.0728 (0.1618)  loss_box_reg: 0.0732 (0.1432)  loss_objectness: 0.0089 (0.0187)  loss_rpn_box_reg: 0.0028 (0.0055)  time: 0.5063  data: 0.0181  max mem: 2300
# Epoch: [0]  [1090/2343]  eta: 0:10:24  lr: 0.003000  loss: 0.2343 (0.3283)  loss_classifier: 0.0893 (0.1613)  loss_box_reg: 0.1037 (0.1429)  loss_objectness: 0.0085 (0.0187)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 0.5042  data: 0.0180  max mem: 2300
# Epoch: [0]  [1100/2343]  eta: 0:10:19  lr: 0.003000  loss: 0.1428 (0.3267)  loss_classifier: 0.0691 (0.1605)  loss_box_reg: 0.0753 (0.1422)  loss_objectness: 0.0073 (0.0186)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 0.4970  data: 0.0178  max mem: 2300
# Epoch: [0]  [1110/2343]  eta: 0:10:14  lr: 0.003000  loss: 0.1617 (0.3261)  loss_classifier: 0.0733 (0.1601)  loss_box_reg: 0.0773 (0.1421)  loss_objectness: 0.0064 (0.0185)  loss_rpn_box_reg: 0.0035 (0.0054)  time: 0.4918  data: 0.0175  max mem: 2300
# Epoch: [0]  [1120/2343]  eta: 0:10:09  lr: 0.003000  loss: 0.2174 (0.3252)  loss_classifier: 0.0936 (0.1595)  loss_box_reg: 0.1108 (0.1418)  loss_objectness: 0.0094 (0.0185)  loss_rpn_box_reg: 0.0038 (0.0054)  time: 0.5072  data: 0.0173  max mem: 2300
# Epoch: [0]  [1130/2343]  eta: 0:10:04  lr: 0.003000  loss: 0.1816 (0.3241)  loss_classifier: 0.0790 (0.1587)  loss_box_reg: 0.0992 (0.1415)  loss_objectness: 0.0095 (0.0185)  loss_rpn_box_reg: 0.0028 (0.0054)  time: 0.5036  data: 0.0172  max mem: 2300
# Epoch: [0]  [1140/2343]  eta: 0:09:59  lr: 0.003000  loss: 0.1587 (0.3226)  loss_classifier: 0.0598 (0.1578)  loss_box_reg: 0.0864 (0.1411)  loss_objectness: 0.0058 (0.0184)  loss_rpn_box_reg: 0.0023 (0.0054)  time: 0.4865  data: 0.0169  max mem: 2300
# Epoch: [0]  [1150/2343]  eta: 0:09:54  lr: 0.003000  loss: 0.1606 (0.3216)  loss_classifier: 0.0522 (0.1572)  loss_box_reg: 0.0949 (0.1407)  loss_objectness: 0.0037 (0.0183)  loss_rpn_box_reg: 0.0024 (0.0054)  time: 0.4971  data: 0.0179  max mem: 2300
# Epoch: [0]  [1160/2343]  eta: 0:09:49  lr: 0.003000  loss: 0.1481 (0.3201)  loss_classifier: 0.0542 (0.1564)  loss_box_reg: 0.0895 (0.1402)  loss_objectness: 0.0045 (0.0182)  loss_rpn_box_reg: 0.0027 (0.0054)  time: 0.5071  data: 0.0182  max mem: 2300
# Epoch: [0]  [1170/2343]  eta: 0:09:44  lr: 0.003000  loss: 0.1165 (0.3184)  loss_classifier: 0.0472 (0.1555)  loss_box_reg: 0.0625 (0.1395)  loss_objectness: 0.0032 (0.0181)  loss_rpn_box_reg: 0.0017 (0.0054)  time: 0.5072  data: 0.0179  max mem: 2428
# Epoch: [0]  [1180/2343]  eta: 0:09:40  lr: 0.003000  loss: 0.1084 (0.3167)  loss_classifier: 0.0454 (0.1546)  loss_box_reg: 0.0570 (0.1389)  loss_objectness: 0.0026 (0.0179)  loss_rpn_box_reg: 0.0014 (0.0053)  time: 0.5113  data: 0.0170  max mem: 2428
# Epoch: [0]  [1190/2343]  eta: 0:09:35  lr: 0.003000  loss: 0.1252 (0.3161)  loss_classifier: 0.0627 (0.1542)  loss_box_reg: 0.0646 (0.1386)  loss_objectness: 0.0047 (0.0180)  loss_rpn_box_reg: 0.0024 (0.0053)  time: 0.5066  data: 0.0167  max mem: 2428
# Epoch: [0]  [1200/2343]  eta: 0:09:29  lr: 0.003000  loss: 0.2016 (0.3152)  loss_classifier: 0.0837 (0.1536)  loss_box_reg: 0.0864 (0.1383)  loss_objectness: 0.0053 (0.0179)  loss_rpn_box_reg: 0.0025 (0.0053)  time: 0.4892  data: 0.0178  max mem: 2428
# Epoch: [0]  [1210/2343]  eta: 0:09:24  lr: 0.003000  loss: 0.1400 (0.3137)  loss_classifier: 0.0759 (0.1529)  loss_box_reg: 0.0704 (0.1378)  loss_objectness: 0.0045 (0.0178)  loss_rpn_box_reg: 0.0018 (0.0053)  time: 0.4783  data: 0.0181  max mem: 2428
# Epoch: [0]  [1220/2343]  eta: 0:09:19  lr: 0.003000  loss: 0.1588 (0.3129)  loss_classifier: 0.0773 (0.1525)  loss_box_reg: 0.0704 (0.1375)  loss_objectness: 0.0036 (0.0177)  loss_rpn_box_reg: 0.0016 (0.0053)  time: 0.4924  data: 0.0185  max mem: 2428
# Epoch: [0]  [1230/2343]  eta: 0:09:14  lr: 0.003000  loss: 0.1781 (0.3120)  loss_classifier: 0.0904 (0.1519)  loss_box_reg: 0.0775 (0.1372)  loss_objectness: 0.0053 (0.0177)  loss_rpn_box_reg: 0.0026 (0.0052)  time: 0.5019  data: 0.0184  max mem: 2428
# Epoch: [0]  [1240/2343]  eta: 0:09:10  lr: 0.003000  loss: 0.1475 (0.3109)  loss_classifier: 0.0614 (0.1513)  loss_box_reg: 0.0775 (0.1368)  loss_objectness: 0.0052 (0.0176)  loss_rpn_box_reg: 0.0027 (0.0052)  time: 0.5100  data: 0.0177  max mem: 2428
# Epoch: [0]  [1250/2343]  eta: 0:09:04  lr: 0.003000  loss: 0.1387 (0.3098)  loss_classifier: 0.0570 (0.1507)  loss_box_reg: 0.0749 (0.1364)  loss_objectness: 0.0033 (0.0175)  loss_rpn_box_reg: 0.0022 (0.0052)  time: 0.5069  data: 0.0177  max mem: 2428
# Epoch: [0]  [1260/2343]  eta: 0:08:59  lr: 0.003000  loss: 0.1328 (0.3090)  loss_classifier: 0.0564 (0.1502)  loss_box_reg: 0.0755 (0.1360)  loss_objectness: 0.0038 (0.0175)  loss_rpn_box_reg: 0.0020 (0.0052)  time: 0.4937  data: 0.0175  max mem: 2428
# Epoch: [0]  [1270/2343]  eta: 0:08:55  lr: 0.003000  loss: 0.1859 (0.3084)  loss_classifier: 0.0688 (0.1499)  loss_box_reg: 0.0870 (0.1358)  loss_objectness: 0.0076 (0.0175)  loss_rpn_box_reg: 0.0032 (0.0052)  time: 0.4998  data: 0.0179  max mem: 2428
# Epoch: [0]  [1280/2343]  eta: 0:08:49  lr: 0.003000  loss: 0.1943 (0.3080)  loss_classifier: 0.1005 (0.1496)  loss_box_reg: 0.0931 (0.1356)  loss_objectness: 0.0083 (0.0176)  loss_rpn_box_reg: 0.0033 (0.0052)  time: 0.4931  data: 0.0182  max mem: 2428
# Epoch: [0]  [1290/2343]  eta: 0:08:44  lr: 0.003000  loss: 0.2039 (0.3075)  loss_classifier: 0.1005 (0.1492)  loss_box_reg: 0.0998 (0.1355)  loss_objectness: 0.0089 (0.0176)  loss_rpn_box_reg: 0.0033 (0.0052)  time: 0.4941  data: 0.0176  max mem: 2428
# Epoch: [0]  [1300/2343]  eta: 0:08:39  lr: 0.003000  loss: 0.1692 (0.3075)  loss_classifier: 0.0816 (0.1490)  loss_box_reg: 0.0736 (0.1351)  loss_objectness: 0.0118 (0.0179)  loss_rpn_box_reg: 0.0021 (0.0055)  time: 0.4959  data: 0.0176  max mem: 2428
# Epoch: [0]  [1310/2343]  eta: 0:08:34  lr: 0.003000  loss: 0.1476 (0.3066)  loss_classifier: 0.0647 (0.1484)  loss_box_reg: 0.0679 (0.1348)  loss_objectness: 0.0109 (0.0179)  loss_rpn_box_reg: 0.0020 (0.0055)  time: 0.4904  data: 0.0180  max mem: 2428
# Epoch: [0]  [1320/2343]  eta: 0:08:29  lr: 0.003000  loss: 0.1646 (0.3057)  loss_classifier: 0.0653 (0.1478)  loss_box_reg: 0.0730 (0.1345)  loss_objectness: 0.0089 (0.0179)  loss_rpn_box_reg: 0.0026 (0.0055)  time: 0.4937  data: 0.0182  max mem: 2428
# Epoch: [0]  [1330/2343]  eta: 0:08:24  lr: 0.003000  loss: 0.1347 (0.3046)  loss_classifier: 0.0599 (0.1472)  loss_box_reg: 0.0673 (0.1340)  loss_objectness: 0.0088 (0.0178)  loss_rpn_box_reg: 0.0016 (0.0055)  time: 0.5032  data: 0.0182  max mem: 2428
# Epoch: [0]  [1340/2343]  eta: 0:08:20  lr: 0.003000  loss: 0.1823 (0.3041)  loss_classifier: 0.0793 (0.1469)  loss_box_reg: 0.0762 (0.1339)  loss_objectness: 0.0064 (0.0178)  loss_rpn_box_reg: 0.0032 (0.0055)  time: 0.5164  data: 0.0185  max mem: 2428
# Epoch: [0]  [1350/2343]  eta: 0:08:15  lr: 0.003000  loss: 0.1962 (0.3032)  loss_classifier: 0.0801 (0.1464)  loss_box_reg: 0.0966 (0.1337)  loss_objectness: 0.0081 (0.0177)  loss_rpn_box_reg: 0.0034 (0.0055)  time: 0.5112  data: 0.0191  max mem: 2428
# Epoch: [0]  [1360/2343]  eta: 0:08:10  lr: 0.003000  loss: 0.1745 (0.3025)  loss_classifier: 0.0755 (0.1459)  loss_box_reg: 0.0914 (0.1335)  loss_objectness: 0.0096 (0.0177)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 0.5028  data: 0.0195  max mem: 2428
# Epoch: [0]  [1370/2343]  eta: 0:08:05  lr: 0.003000  loss: 0.1531 (0.3018)  loss_classifier: 0.0701 (0.1454)  loss_box_reg: 0.0846 (0.1332)  loss_objectness: 0.0079 (0.0177)  loss_rpn_box_reg: 0.0024 (0.0055)  time: 0.4980  data: 0.0195  max mem: 2428
# Epoch: [0]  [1380/2343]  eta: 0:08:00  lr: 0.003000  loss: 0.1404 (0.3006)  loss_classifier: 0.0599 (0.1447)  loss_box_reg: 0.0704 (0.1328)  loss_objectness: 0.0045 (0.0176)  loss_rpn_box_reg: 0.0021 (0.0055)  time: 0.5005  data: 0.0190  max mem: 2428
# Epoch: [0]  [1390/2343]  eta: 0:07:55  lr: 0.003000  loss: 0.1404 (0.2999)  loss_classifier: 0.0580 (0.1442)  loss_box_reg: 0.0772 (0.1326)  loss_objectness: 0.0042 (0.0176)  loss_rpn_box_reg: 0.0019 (0.0055)  time: 0.5033  data: 0.0182  max mem: 2428
# Epoch: [0]  [1400/2343]  eta: 0:07:50  lr: 0.003000  loss: 0.1564 (0.2991)  loss_classifier: 0.0605 (0.1438)  loss_box_reg: 0.0701 (0.1323)  loss_objectness: 0.0083 (0.0176)  loss_rpn_box_reg: 0.0033 (0.0055)  time: 0.5003  data: 0.0180  max mem: 2428
# Epoch: [0]  [1410/2343]  eta: 0:07:45  lr: 0.003000  loss: 0.1564 (0.2982)  loss_classifier: 0.0577 (0.1432)  loss_box_reg: 0.0701 (0.1319)  loss_objectness: 0.0083 (0.0175)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.5020  data: 0.0180  max mem: 2428
# Epoch: [0]  [1420/2343]  eta: 0:07:40  lr: 0.003000  loss: 0.1750 (0.2975)  loss_classifier: 0.0582 (0.1428)  loss_box_reg: 0.0905 (0.1318)  loss_objectness: 0.0055 (0.0174)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.5028  data: 0.0188  max mem: 2428
# Epoch: [0]  [1430/2343]  eta: 0:07:35  lr: 0.003000  loss: 0.1750 (0.2966)  loss_classifier: 0.0668 (0.1423)  loss_box_reg: 0.0868 (0.1315)  loss_objectness: 0.0053 (0.0174)  loss_rpn_box_reg: 0.0029 (0.0055)  time: 0.5114  data: 0.0181  max mem: 2428
# Epoch: [0]  [1440/2343]  eta: 0:07:30  lr: 0.003000  loss: 0.1334 (0.2962)  loss_classifier: 0.0541 (0.1420)  loss_box_reg: 0.0761 (0.1313)  loss_objectness: 0.0054 (0.0174)  loss_rpn_box_reg: 0.0024 (0.0055)  time: 0.5095  data: 0.0171  max mem: 2428
# Epoch: [0]  [1450/2343]  eta: 0:07:25  lr: 0.003000  loss: 0.1309 (0.2955)  loss_classifier: 0.0732 (0.1417)  loss_box_reg: 0.0642 (0.1310)  loss_objectness: 0.0082 (0.0174)  loss_rpn_box_reg: 0.0023 (0.0055)  time: 0.5029  data: 0.0181  max mem: 2428
# Epoch: [0]  [1460/2343]  eta: 0:07:20  lr: 0.003000  loss: 0.1445 (0.2947)  loss_classifier: 0.0624 (0.1412)  loss_box_reg: 0.0649 (0.1306)  loss_objectness: 0.0089 (0.0174)  loss_rpn_box_reg: 0.0026 (0.0055)  time: 0.4954  data: 0.0182  max mem: 2428
# Epoch: [0]  [1470/2343]  eta: 0:07:15  lr: 0.003000  loss: 0.1541 (0.2939)  loss_classifier: 0.0717 (0.1407)  loss_box_reg: 0.0707 (0.1304)  loss_objectness: 0.0064 (0.0173)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 0.4902  data: 0.0183  max mem: 2428
# Epoch: [0]  [1480/2343]  eta: 0:07:10  lr: 0.003000  loss: 0.1849 (0.2932)  loss_classifier: 0.0813 (0.1403)  loss_box_reg: 0.0976 (0.1301)  loss_objectness: 0.0061 (0.0173)  loss_rpn_box_reg: 0.0022 (0.0055)  time: 0.4969  data: 0.0182  max mem: 2428
# Epoch: [0]  [1490/2343]  eta: 0:07:05  lr: 0.003000  loss: 0.1709 (0.2924)  loss_classifier: 0.0786 (0.1399)  loss_box_reg: 0.0976 (0.1299)  loss_objectness: 0.0061 (0.0172)  loss_rpn_box_reg: 0.0027 (0.0055)  time: 0.5042  data: 0.0180  max mem: 2428
# Epoch: [0]  [1500/2343]  eta: 0:07:00  lr: 0.003000  loss: 0.1447 (0.2916)  loss_classifier: 0.0669 (0.1394)  loss_box_reg: 0.0784 (0.1296)  loss_objectness: 0.0056 (0.0172)  loss_rpn_box_reg: 0.0023 (0.0054)  time: 0.5041  data: 0.0181  max mem: 2428
# Epoch: [0]  [1510/2343]  eta: 0:06:55  lr: 0.003000  loss: 0.1587 (0.2914)  loss_classifier: 0.0637 (0.1391)  loss_box_reg: 0.0810 (0.1294)  loss_objectness: 0.0077 (0.0174)  loss_rpn_box_reg: 0.0021 (0.0055)  time: 0.4998  data: 0.0174  max mem: 2428
# Epoch: [0]  [1520/2343]  eta: 0:06:50  lr: 0.003000  loss: 0.1897 (0.2910)  loss_classifier: 0.0768 (0.1388)  loss_box_reg: 0.0890 (0.1293)  loss_objectness: 0.0138 (0.0175)  loss_rpn_box_reg: 0.0030 (0.0055)  time: 0.4986  data: 0.0174  max mem: 2428
# Epoch: [0]  [1530/2343]  eta: 0:06:45  lr: 0.003000  loss: 0.1624 (0.2900)  loss_classifier: 0.0684 (0.1383)  loss_box_reg: 0.0835 (0.1289)  loss_objectness: 0.0073 (0.0174)  loss_rpn_box_reg: 0.0023 (0.0055)  time: 0.4926  data: 0.0174  max mem: 2428
# Epoch: [0]  [1540/2343]  eta: 0:06:40  lr: 0.003000  loss: 0.1404 (0.2891)  loss_classifier: 0.0617 (0.1378)  loss_box_reg: 0.0752 (0.1286)  loss_objectness: 0.0029 (0.0173)  loss_rpn_box_reg: 0.0020 (0.0054)  time: 0.4950  data: 0.0174  max mem: 2428
# Epoch: [0]  [1550/2343]  eta: 0:06:35  lr: 0.003000  loss: 0.1426 (0.2883)  loss_classifier: 0.0585 (0.1374)  loss_box_reg: 0.0838 (0.1283)  loss_objectness: 0.0033 (0.0172)  loss_rpn_box_reg: 0.0025 (0.0054)  time: 0.4972  data: 0.0178  max mem: 2428
# Epoch: [0]  [1560/2343]  eta: 0:06:30  lr: 0.003000  loss: 0.1768 (0.2881)  loss_classifier: 0.0777 (0.1372)  loss_box_reg: 0.0851 (0.1282)  loss_objectness: 0.0059 (0.0172)  loss_rpn_box_reg: 0.0033 (0.0054)  time: 0.4926  data: 0.0182  max mem: 2428
# Epoch: [0]  [1570/2343]  eta: 0:06:25  lr: 0.003000  loss: 0.1937 (0.2879)  loss_classifier: 0.0939 (0.1371)  loss_box_reg: 0.0942 (0.1281)  loss_objectness: 0.0078 (0.0172)  loss_rpn_box_reg: 0.0033 (0.0054)  time: 0.4849  data: 0.0186  max mem: 2428
# Epoch: [0]  [1580/2343]  eta: 0:06:20  lr: 0.003000  loss: 0.1683 (0.2872)  loss_classifier: 0.0804 (0.1368)  loss_box_reg: 0.0844 (0.1278)  loss_objectness: 0.0078 (0.0172)  loss_rpn_box_reg: 0.0023 (0.0054)  time: 0.4915  data: 0.0180  max mem: 2428
# Epoch: [0]  [1590/2343]  eta: 0:06:15  lr: 0.003000  loss: 0.1375 (0.2863)  loss_classifier: 0.0552 (0.1363)  loss_box_reg: 0.0660 (0.1275)  loss_objectness: 0.0061 (0.0171)  loss_rpn_box_reg: 0.0019 (0.0054)  time: 0.4962  data: 0.0178  max mem: 2428
# Epoch: [0]  [1600/2343]  eta: 0:06:10  lr: 0.003000  loss: 0.1234 (0.2854)  loss_classifier: 0.0520 (0.1359)  loss_box_reg: 0.0662 (0.1271)  loss_objectness: 0.0050 (0.0171)  loss_rpn_box_reg: 0.0017 (0.0054)  time: 0.4995  data: 0.0183  max mem: 2428
# Epoch: [0]  [1610/2343]  eta: 0:06:05  lr: 0.003000  loss: 0.1535 (0.2852)  loss_classifier: 0.0659 (0.1357)  loss_box_reg: 0.0803 (0.1271)  loss_objectness: 0.0051 (0.0170)  loss_rpn_box_reg: 0.0022 (0.0054)  time: 0.4982  data: 0.0175  max mem: 2428
# Epoch: [0]  [1620/2343]  eta: 0:06:00  lr: 0.003000  loss: 0.1921 (0.2846)  loss_classifier: 0.0851 (0.1354)  loss_box_reg: 0.0896 (0.1269)  loss_objectness: 0.0075 (0.0170)  loss_rpn_box_reg: 0.0032 (0.0054)  time: 0.5016  data: 0.0180  max mem: 2428
# Epoch: [0]  [1630/2343]  eta: 0:05:55  lr: 0.003000  loss: 0.1318 (0.2837)  loss_classifier: 0.0567 (0.1349)  loss_box_reg: 0.0734 (0.1266)  loss_objectness: 0.0028 (0.0169)  loss_rpn_box_reg: 0.0024 (0.0053)  time: 0.5169  data: 0.0189  max mem: 2428
# Epoch: [0]  [1640/2343]  eta: 0:05:50  lr: 0.003000  loss: 0.1155 (0.2830)  loss_classifier: 0.0487 (0.1345)  loss_box_reg: 0.0669 (0.1263)  loss_objectness: 0.0027 (0.0169)  loss_rpn_box_reg: 0.0015 (0.0053)  time: 0.5022  data: 0.0179  max mem: 2428
# Epoch: [0]  [1650/2343]  eta: 0:05:45  lr: 0.003000  loss: 0.1299 (0.2823)  loss_classifier: 0.0487 (0.1341)  loss_box_reg: 0.0624 (0.1260)  loss_objectness: 0.0045 (0.0168)  loss_rpn_box_reg: 0.0018 (0.0053)  time: 0.4850  data: 0.0170  max mem: 2428
# Epoch: [0]  [1660/2343]  eta: 0:05:40  lr: 0.003000  loss: 0.1308 (0.2816)  loss_classifier: 0.0541 (0.1338)  loss_box_reg: 0.0624 (0.1258)  loss_objectness: 0.0048 (0.0168)  loss_rpn_box_reg: 0.0029 (0.0053)  time: 0.4861  data: 0.0173  max mem: 2428
# Epoch: [0]  [1670/2343]  eta: 0:05:35  lr: 0.003000  loss: 0.1674 (0.2811)  loss_classifier: 0.0761 (0.1335)  loss_box_reg: 0.0800 (0.1256)  loss_objectness: 0.0048 (0.0168)  loss_rpn_box_reg: 0.0031 (0.0053)  time: 0.4939  data: 0.0176  max mem: 2428
# Epoch: [0]  [1680/2343]  eta: 0:05:30  lr: 0.003000  loss: 0.2175 (0.2808)  loss_classifier: 0.0832 (0.1332)  loss_box_reg: 0.0972 (0.1256)  loss_objectness: 0.0064 (0.0167)  loss_rpn_box_reg: 0.0038 (0.0053)  time: 0.5000  data: 0.0177  max mem: 2428
# Epoch: [0]  [1690/2343]  eta: 0:05:25  lr: 0.003000  loss: 0.2000 (0.2805)  loss_classifier: 0.0860 (0.1330)  loss_box_reg: 0.1099 (0.1255)  loss_objectness: 0.0061 (0.0167)  loss_rpn_box_reg: 0.0038 (0.0053)  time: 0.4936  data: 0.0180  max mem: 2428
# Epoch: [0]  [1700/2343]  eta: 0:05:20  lr: 0.003000  loss: 0.1858 (0.2799)  loss_classifier: 0.0724 (0.1327)  loss_box_reg: 0.0812 (0.1253)  loss_objectness: 0.0066 (0.0167)  loss_rpn_box_reg: 0.0024 (0.0053)  time: 0.4887  data: 0.0184  max mem: 2428
# Epoch: [0]  [1710/2343]  eta: 0:05:15  lr: 0.003000  loss: 0.1687 (0.2799)  loss_classifier: 0.0791 (0.1326)  loss_box_reg: 0.0831 (0.1253)  loss_objectness: 0.0066 (0.0167)  loss_rpn_box_reg: 0.0023 (0.0053)  time: 0.4884  data: 0.0181  max mem: 2428
# Epoch: [0]  [1720/2343]  eta: 0:05:10  lr: 0.003000  loss: 0.2416 (0.2800)  loss_classifier: 0.1024 (0.1325)  loss_box_reg: 0.1160 (0.1254)  loss_objectness: 0.0073 (0.0167)  loss_rpn_box_reg: 0.0057 (0.0054)  time: 0.4833  data: 0.0171  max mem: 2428
# Epoch: [0]  [1730/2343]  eta: 0:05:05  lr: 0.003000  loss: 0.1794 (0.2793)  loss_classifier: 0.0764 (0.1321)  loss_box_reg: 0.0910 (0.1251)  loss_objectness: 0.0051 (0.0167)  loss_rpn_box_reg: 0.0025 (0.0053)  time: 0.4976  data: 0.0174  max mem: 2428
# Epoch: [0]  [1740/2343]  eta: 0:05:00  lr: 0.003000  loss: 0.1389 (0.2787)  loss_classifier: 0.0658 (0.1318)  loss_box_reg: 0.0671 (0.1249)  loss_objectness: 0.0051 (0.0166)  loss_rpn_box_reg: 0.0026 (0.0053)  time: 0.4957  data: 0.0170  max mem: 2428
# Epoch: [0]  [1750/2343]  eta: 0:04:55  lr: 0.003000  loss: 0.1361 (0.2782)  loss_classifier: 0.0739 (0.1315)  loss_box_reg: 0.0639 (0.1247)  loss_objectness: 0.0054 (0.0166)  loss_rpn_box_reg: 0.0022 (0.0053)  time: 0.4835  data: 0.0168  max mem: 2428
# Epoch: [0]  [1760/2343]  eta: 0:04:50  lr: 0.003000  loss: 0.1174 (0.2774)  loss_classifier: 0.0576 (0.1311)  loss_box_reg: 0.0639 (0.1244)  loss_objectness: 0.0036 (0.0165)  loss_rpn_box_reg: 0.0022 (0.0053)  time: 0.4921  data: 0.0174  max mem: 2428
# Epoch: [0]  [1770/2343]  eta: 0:04:45  lr: 0.003000  loss: 0.1127 (0.2766)  loss_classifier: 0.0440 (0.1308)  loss_box_reg: 0.0610 (0.1241)  loss_objectness: 0.0024 (0.0164)  loss_rpn_box_reg: 0.0020 (0.0053)  time: 0.5051  data: 0.0180  max mem: 2428
# Epoch: [0]  [1780/2343]  eta: 0:04:40  lr: 0.003000  loss: 0.1156 (0.2762)  loss_classifier: 0.0549 (0.1305)  loss_box_reg: 0.0649 (0.1241)  loss_objectness: 0.0035 (0.0164)  loss_rpn_box_reg: 0.0017 (0.0053)  time: 0.5019  data: 0.0180  max mem: 2428
# Epoch: [0]  [1790/2343]  eta: 0:04:35  lr: 0.003000  loss: 0.1252 (0.2754)  loss_classifier: 0.0518 (0.1300)  loss_box_reg: 0.0721 (0.1238)  loss_objectness: 0.0032 (0.0163)  loss_rpn_box_reg: 0.0024 (0.0053)  time: 0.4906  data: 0.0169  max mem: 2428
# Epoch: [0]  [1800/2343]  eta: 0:04:30  lr: 0.003000  loss: 0.1369 (0.2748)  loss_classifier: 0.0518 (0.1297)  loss_box_reg: 0.0715 (0.1236)  loss_objectness: 0.0035 (0.0163)  loss_rpn_box_reg: 0.0029 (0.0053)  time: 0.5055  data: 0.0162  max mem: 2428
# Epoch: [0]  [1810/2343]  eta: 0:04:25  lr: 0.003000  loss: 0.1369 (0.2741)  loss_classifier: 0.0546 (0.1293)  loss_box_reg: 0.0669 (0.1233)  loss_objectness: 0.0042 (0.0162)  loss_rpn_box_reg: 0.0023 (0.0052)  time: 0.5064  data: 0.0168  max mem: 2428
# Epoch: [0]  [1820/2343]  eta: 0:04:20  lr: 0.003000  loss: 0.1165 (0.2738)  loss_classifier: 0.0478 (0.1291)  loss_box_reg: 0.0630 (0.1232)  loss_objectness: 0.0057 (0.0163)  loss_rpn_box_reg: 0.0019 (0.0052)  time: 0.4982  data: 0.0176  max mem: 2428
# Epoch: [0]  [1830/2343]  eta: 0:04:15  lr: 0.003000  loss: 0.1165 (0.2733)  loss_classifier: 0.0434 (0.1289)  loss_box_reg: 0.0570 (0.1230)  loss_objectness: 0.0036 (0.0163)  loss_rpn_box_reg: 0.0021 (0.0052)  time: 0.5119  data: 0.0177  max mem: 2428
# Epoch: [0]  [1840/2343]  eta: 0:04:10  lr: 0.003000  loss: 0.1943 (0.2731)  loss_classifier: 0.0716 (0.1287)  loss_box_reg: 0.0822 (0.1229)  loss_objectness: 0.0072 (0.0163)  loss_rpn_box_reg: 0.0026 (0.0052)  time: 0.5028  data: 0.0180  max mem: 2428
# Epoch: [0]  [1850/2343]  eta: 0:04:05  lr: 0.003000  loss: 0.1878 (0.2727)  loss_classifier: 0.0716 (0.1285)  loss_box_reg: 0.0822 (0.1228)  loss_objectness: 0.0072 (0.0163)  loss_rpn_box_reg: 0.0029 (0.0053)  time: 0.4895  data: 0.0177  max mem: 2428
# Epoch: [0]  [1860/2343]  eta: 0:04:00  lr: 0.003000  loss: 0.1765 (0.2724)  loss_classifier: 0.0796 (0.1282)  loss_box_reg: 0.0731 (0.1227)  loss_objectness: 0.0068 (0.0162)  loss_rpn_box_reg: 0.0040 (0.0053)  time: 0.4931  data: 0.0174  max mem: 2428
# Epoch: [0]  [1870/2343]  eta: 0:03:55  lr: 0.003000  loss: 0.1497 (0.2719)  loss_classifier: 0.0630 (0.1279)  loss_box_reg: 0.0716 (0.1226)  loss_objectness: 0.0062 (0.0162)  loss_rpn_box_reg: 0.0030 (0.0053)  time: 0.4851  data: 0.0174  max mem: 2428
# ...
# Epoch: [3]  [1070/2343]  eta: 0:10:35  lr: 0.000300  loss: 0.0747 (0.1202)  loss_classifier: 0.0284 (0.0435)  loss_box_reg: 0.0412 (0.0683)  loss_objectness: 0.0020 (0.0050)  loss_rpn_box_reg: 0.0017 (0.0034)  time: 0.5080  data: 0.0187  max mem: 2443
# Epoch: [3]  [1080/2343]  eta: 0:10:30  lr: 0.000300  loss: 0.0747 (0.1203)  loss_classifier: 0.0343 (0.0435)  loss_box_reg: 0.0523 (0.0684)  loss_objectness: 0.0030 (0.0051)  loss_rpn_box_reg: 0.0021 (0.0034)  time: 0.5019  data: 0.0182  max mem: 2443
# Epoch: [3]  [1090/2343]  eta: 0:10:25  lr: 0.000300  loss: 0.0731 (0.1201)  loss_classifier: 0.0236 (0.0434)  loss_box_reg: 0.0464 (0.0682)  loss_objectness: 0.0039 (0.0051)  loss_rpn_box_reg: 0.0027 (0.0034)  time: 0.4971  data: 0.0175  max mem: 2443
# Epoch: [3]  [1100/2343]  eta: 0:10:20  lr: 0.000300  loss: 0.0739 (0.1201)  loss_classifier: 0.0374 (0.0434)  loss_box_reg: 0.0418 (0.0682)  loss_objectness: 0.0023 (0.0050)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 0.4957  data: 0.0182  max mem: 2443
# Epoch: [3]  [1110/2343]  eta: 0:10:15  lr: 0.000300  loss: 0.0887 (0.1202)  loss_classifier: 0.0418 (0.0434)  loss_box_reg: 0.0488 (0.0683)  loss_objectness: 0.0023 (0.0051)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 0.4960  data: 0.0180  max mem: 2443
# Epoch: [3]  [1120/2343]  eta: 0:10:10  lr: 0.000300  loss: 0.0864 (0.1201)  loss_classifier: 0.0313 (0.0434)  loss_box_reg: 0.0488 (0.0682)  loss_objectness: 0.0027 (0.0051)  loss_rpn_box_reg: 0.0017 (0.0034)  time: 0.5012  data: 0.0169  max mem: 2443
# Epoch: [3]  [1130/2343]  eta: 0:10:04  lr: 0.000300  loss: 0.0810 (0.1199)  loss_classifier: 0.0267 (0.0433)  loss_box_reg: 0.0393 (0.0681)  loss_objectness: 0.0021 (0.0050)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.4934  data: 0.0169  max mem: 2443
# Epoch: [3]  [1140/2343]  eta: 0:09:59  lr: 0.000300  loss: 0.0810 (0.1198)  loss_classifier: 0.0249 (0.0433)  loss_box_reg: 0.0523 (0.0681)  loss_objectness: 0.0017 (0.0050)  loss_rpn_box_reg: 0.0016 (0.0034)  time: 0.4927  data: 0.0178  max mem: 2443
# Epoch: [3]  [1150/2343]  eta: 0:09:55  lr: 0.000300  loss: 0.1062 (0.1199)  loss_classifier: 0.0313 (0.0433)  loss_box_reg: 0.0642 (0.0682)  loss_objectness: 0.0022 (0.0051)  loss_rpn_box_reg: 0.0021 (0.0034)  time: 0.4992  data: 0.0180  max mem: 2443
# Epoch: [3]  [1160/2343]  eta: 0:09:50  lr: 0.000300  loss: 0.0785 (0.1195)  loss_classifier: 0.0268 (0.0431)  loss_box_reg: 0.0509 (0.0680)  loss_objectness: 0.0016 (0.0050)  loss_rpn_box_reg: 0.0012 (0.0034)  time: 0.5023  data: 0.0179  max mem: 2443
# Epoch: [3]  [1170/2343]  eta: 0:09:45  lr: 0.000300  loss: 0.0901 (0.1197)  loss_classifier: 0.0331 (0.0432)  loss_box_reg: 0.0483 (0.0681)  loss_objectness: 0.0017 (0.0051)  loss_rpn_box_reg: 0.0012 (0.0034)  time: 0.5079  data: 0.0186  max mem: 2443
# Epoch: [3]  [1180/2343]  eta: 0:09:40  lr: 0.000300  loss: 0.0927 (0.1195)  loss_classifier: 0.0389 (0.0432)  loss_box_reg: 0.0529 (0.0679)  loss_objectness: 0.0017 (0.0050)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.5009  data: 0.0184  max mem: 2443
# Epoch: [3]  [1190/2343]  eta: 0:09:35  lr: 0.000300  loss: 0.0857 (0.1193)  loss_classifier: 0.0306 (0.0431)  loss_box_reg: 0.0482 (0.0678)  loss_objectness: 0.0013 (0.0050)  loss_rpn_box_reg: 0.0013 (0.0033)  time: 0.4968  data: 0.0175  max mem: 2443
# Epoch: [3]  [1200/2343]  eta: 0:09:30  lr: 0.000300  loss: 0.0695 (0.1192)  loss_classifier: 0.0275 (0.0431)  loss_box_reg: 0.0432 (0.0678)  loss_objectness: 0.0020 (0.0050)  loss_rpn_box_reg: 0.0012 (0.0033)  time: 0.4933  data: 0.0177  max mem: 2443
# Epoch: [3]  [1210/2343]  eta: 0:09:24  lr: 0.000300  loss: 0.0780 (0.1191)  loss_classifier: 0.0326 (0.0430)  loss_box_reg: 0.0430 (0.0677)  loss_objectness: 0.0018 (0.0050)  loss_rpn_box_reg: 0.0012 (0.0033)  time: 0.4869  data: 0.0182  max mem: 2443
# Epoch: [3]  [1220/2343]  eta: 0:09:19  lr: 0.000300  loss: 0.0777 (0.1188)  loss_classifier: 0.0325 (0.0430)  loss_box_reg: 0.0405 (0.0676)  loss_objectness: 0.0013 (0.0050)  loss_rpn_box_reg: 0.0014 (0.0033)  time: 0.4835  data: 0.0181  max mem: 2443
# Epoch: [3]  [1230/2343]  eta: 0:09:14  lr: 0.000300  loss: 0.0847 (0.1190)  loss_classifier: 0.0317 (0.0430)  loss_box_reg: 0.0468 (0.0677)  loss_objectness: 0.0021 (0.0050)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.4817  data: 0.0179  max mem: 2443
# Epoch: [3]  [1240/2343]  eta: 0:09:09  lr: 0.000300  loss: 0.0847 (0.1187)  loss_classifier: 0.0306 (0.0429)  loss_box_reg: 0.0529 (0.0676)  loss_objectness: 0.0028 (0.0049)  loss_rpn_box_reg: 0.0014 (0.0033)  time: 0.4857  data: 0.0176  max mem: 2443
# Epoch: [3]  [1250/2343]  eta: 0:09:04  lr: 0.000300  loss: 0.0790 (0.1187)  loss_classifier: 0.0269 (0.0428)  loss_box_reg: 0.0469 (0.0676)  loss_objectness: 0.0017 (0.0049)  loss_rpn_box_reg: 0.0014 (0.0033)  time: 0.4878  data: 0.0180  max mem: 2443
# Epoch: [3]  [1260/2343]  eta: 0:08:59  lr: 0.000300  loss: 0.0839 (0.1185)  loss_classifier: 0.0303 (0.0428)  loss_box_reg: 0.0429 (0.0675)  loss_objectness: 0.0019 (0.0049)  loss_rpn_box_reg: 0.0017 (0.0033)  time: 0.5050  data: 0.0182  max mem: 2443
# Epoch: [3]  [1270/2343]  eta: 0:08:54  lr: 0.000300  loss: 0.0659 (0.1186)  loss_classifier: 0.0280 (0.0429)  loss_box_reg: 0.0374 (0.0676)  loss_objectness: 0.0015 (0.0049)  loss_rpn_box_reg: 0.0012 (0.0033)  time: 0.5143  data: 0.0176  max mem: 2443
# Epoch: [3]  [1280/2343]  eta: 0:08:49  lr: 0.000300  loss: 0.0787 (0.1186)  loss_classifier: 0.0310 (0.0429)  loss_box_reg: 0.0483 (0.0675)  loss_objectness: 0.0022 (0.0049)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 0.5017  data: 0.0177  max mem: 2443
# Epoch: [3]  [1290/2343]  eta: 0:08:44  lr: 0.000300  loss: 0.0787 (0.1184)  loss_classifier: 0.0288 (0.0428)  loss_box_reg: 0.0414 (0.0674)  loss_objectness: 0.0025 (0.0049)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 0.4898  data: 0.0177  max mem: 2443
# Epoch: [3]  [1300/2343]  eta: 0:08:39  lr: 0.000300  loss: 0.0864 (0.1185)  loss_classifier: 0.0253 (0.0428)  loss_box_reg: 0.0492 (0.0675)  loss_objectness: 0.0022 (0.0049)  loss_rpn_box_reg: 0.0019 (0.0033)  time: 0.4904  data: 0.0181  max mem: 2443
# Epoch: [3]  [1310/2343]  eta: 0:08:34  lr: 0.000300  loss: 0.0939 (0.1185)  loss_classifier: 0.0314 (0.0428)  loss_box_reg: 0.0575 (0.0676)  loss_objectness: 0.0020 (0.0049)  loss_rpn_box_reg: 0.0019 (0.0033)  time: 0.4994  data: 0.0190  max mem: 2443
# Epoch: [3]  [1320/2343]  eta: 0:08:29  lr: 0.000300  loss: 0.0930 (0.1185)  loss_classifier: 0.0314 (0.0428)  loss_box_reg: 0.0559 (0.0675)  loss_objectness: 0.0017 (0.0049)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 0.5106  data: 0.0188  max mem: 2443
# Epoch: [3]  [1330/2343]  eta: 0:08:24  lr: 0.000300  loss: 0.0770 (0.1181)  loss_classifier: 0.0314 (0.0427)  loss_box_reg: 0.0388 (0.0673)  loss_objectness: 0.0017 (0.0049)  loss_rpn_box_reg: 0.0014 (0.0033)  time: 0.5047  data: 0.0181  max mem: 2443
# Epoch: [3]  [1340/2343]  eta: 0:08:19  lr: 0.000300  loss: 0.0679 (0.1178)  loss_classifier: 0.0230 (0.0425)  loss_box_reg: 0.0388 (0.0672)  loss_objectness: 0.0014 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.4938  data: 0.0178  max mem: 2443
# Epoch: [3]  [1350/2343]  eta: 0:08:14  lr: 0.000300  loss: 0.0794 (0.1178)  loss_classifier: 0.0295 (0.0425)  loss_box_reg: 0.0483 (0.0671)  loss_objectness: 0.0019 (0.0048)  loss_rpn_box_reg: 0.0021 (0.0033)  time: 0.4986  data: 0.0180  max mem: 2443
# Epoch: [3]  [1360/2343]  eta: 0:08:10  lr: 0.000300  loss: 0.1154 (0.1178)  loss_classifier: 0.0434 (0.0426)  loss_box_reg: 0.0620 (0.0671)  loss_objectness: 0.0025 (0.0048)  loss_rpn_box_reg: 0.0019 (0.0032)  time: 0.5032  data: 0.0185  max mem: 2443
# Epoch: [3]  [1370/2343]  eta: 0:08:04  lr: 0.000300  loss: 0.1183 (0.1178)  loss_classifier: 0.0409 (0.0426)  loss_box_reg: 0.0579 (0.0672)  loss_objectness: 0.0029 (0.0048)  loss_rpn_box_reg: 0.0017 (0.0032)  time: 0.4935  data: 0.0185  max mem: 2443
# Epoch: [3]  [1380/2343]  eta: 0:08:00  lr: 0.000300  loss: 0.0855 (0.1178)  loss_classifier: 0.0317 (0.0426)  loss_box_reg: 0.0538 (0.0672)  loss_objectness: 0.0021 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 0.4947  data: 0.0183  max mem: 2443
# Epoch: [3]  [1390/2343]  eta: 0:07:55  lr: 0.000300  loss: 0.0923 (0.1179)  loss_classifier: 0.0326 (0.0426)  loss_box_reg: 0.0523 (0.0673)  loss_objectness: 0.0027 (0.0048)  loss_rpn_box_reg: 0.0018 (0.0032)  time: 0.5100  data: 0.0184  max mem: 2443
# Epoch: [3]  [1400/2343]  eta: 0:07:50  lr: 0.000300  loss: 0.0923 (0.1177)  loss_classifier: 0.0315 (0.0425)  loss_box_reg: 0.0399 (0.0672)  loss_objectness: 0.0019 (0.0048)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 0.5143  data: 0.0186  max mem: 2443
# Epoch: [3]  [1410/2343]  eta: 0:07:45  lr: 0.000300  loss: 0.0772 (0.1176)  loss_classifier: 0.0267 (0.0424)  loss_box_reg: 0.0383 (0.0672)  loss_objectness: 0.0017 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0032)  time: 0.5159  data: 0.0190  max mem: 2448
# Epoch: [3]  [1420/2343]  eta: 0:07:40  lr: 0.000300  loss: 0.0878 (0.1175)  loss_classifier: 0.0268 (0.0424)  loss_box_reg: 0.0554 (0.0671)  loss_objectness: 0.0017 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0032)  time: 0.5133  data: 0.0186  max mem: 2448
# Epoch: [3]  [1430/2343]  eta: 0:07:35  lr: 0.000300  loss: 0.0981 (0.1176)  loss_classifier: 0.0351 (0.0424)  loss_box_reg: 0.0494 (0.0672)  loss_objectness: 0.0026 (0.0048)  loss_rpn_box_reg: 0.0020 (0.0032)  time: 0.4936  data: 0.0183  max mem: 2448
# Epoch: [3]  [1440/2343]  eta: 0:07:30  lr: 0.000300  loss: 0.1103 (0.1177)  loss_classifier: 0.0356 (0.0424)  loss_box_reg: 0.0636 (0.0672)  loss_objectness: 0.0035 (0.0048)  loss_rpn_box_reg: 0.0020 (0.0032)  time: 0.4915  data: 0.0182  max mem: 2448
# Epoch: [3]  [1450/2343]  eta: 0:07:25  lr: 0.000300  loss: 0.0890 (0.1175)  loss_classifier: 0.0253 (0.0424)  loss_box_reg: 0.0517 (0.0671)  loss_objectness: 0.0016 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 0.4970  data: 0.0178  max mem: 2448
# Epoch: [3]  [1460/2343]  eta: 0:07:20  lr: 0.000300  loss: 0.0779 (0.1173)  loss_classifier: 0.0262 (0.0423)  loss_box_reg: 0.0430 (0.0670)  loss_objectness: 0.0012 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 0.5007  data: 0.0178  max mem: 2448
# Epoch: [3]  [1470/2343]  eta: 0:07:15  lr: 0.000300  loss: 0.0791 (0.1173)  loss_classifier: 0.0319 (0.0423)  loss_box_reg: 0.0496 (0.0670)  loss_objectness: 0.0014 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 0.5142  data: 0.0180  max mem: 2448
# Epoch: [3]  [1480/2343]  eta: 0:07:10  lr: 0.000300  loss: 0.0916 (0.1172)  loss_classifier: 0.0310 (0.0423)  loss_box_reg: 0.0588 (0.0670)  loss_objectness: 0.0028 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0032)  time: 0.5047  data: 0.0181  max mem: 2448
# Epoch: [3]  [1490/2343]  eta: 0:07:05  lr: 0.000300  loss: 0.1006 (0.1172)  loss_classifier: 0.0305 (0.0423)  loss_box_reg: 0.0561 (0.0670)  loss_objectness: 0.0028 (0.0048)  loss_rpn_box_reg: 0.0020 (0.0032)  time: 0.4883  data: 0.0181  max mem: 2448
# Epoch: [3]  [1500/2343]  eta: 0:07:00  lr: 0.000300  loss: 0.0897 (0.1171)  loss_classifier: 0.0326 (0.0422)  loss_box_reg: 0.0503 (0.0669)  loss_objectness: 0.0030 (0.0048)  loss_rpn_box_reg: 0.0018 (0.0032)  time: 0.4822  data: 0.0176  max mem: 2448
# Epoch: [3]  [1510/2343]  eta: 0:06:55  lr: 0.000300  loss: 0.0897 (0.1173)  loss_classifier: 0.0326 (0.0422)  loss_box_reg: 0.0505 (0.0669)  loss_objectness: 0.0025 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.4972  data: 0.0183  max mem: 2448
# Epoch: [3]  [1520/2343]  eta: 0:06:50  lr: 0.000300  loss: 0.0818 (0.1170)  loss_classifier: 0.0275 (0.0421)  loss_box_reg: 0.0452 (0.0668)  loss_objectness: 0.0021 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.5039  data: 0.0196  max mem: 2448
# Epoch: [3]  [1530/2343]  eta: 0:06:45  lr: 0.000300  loss: 0.0606 (0.1169)  loss_classifier: 0.0212 (0.0421)  loss_box_reg: 0.0333 (0.0667)  loss_objectness: 0.0018 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0034)  time: 0.4950  data: 0.0195  max mem: 2448
# Epoch: [3]  [1540/2343]  eta: 0:06:40  lr: 0.000300  loss: 0.0734 (0.1169)  loss_classifier: 0.0297 (0.0421)  loss_box_reg: 0.0438 (0.0667)  loss_objectness: 0.0019 (0.0048)  loss_rpn_box_reg: 0.0017 (0.0033)  time: 0.4927  data: 0.0190  max mem: 2448
# Epoch: [3]  [1550/2343]  eta: 0:06:35  lr: 0.000300  loss: 0.0807 (0.1166)  loss_classifier: 0.0312 (0.0420)  loss_box_reg: 0.0438 (0.0665)  loss_objectness: 0.0021 (0.0048)  loss_rpn_box_reg: 0.0012 (0.0033)  time: 0.5059  data: 0.0187  max mem: 2448
# Epoch: [3]  [1560/2343]  eta: 0:06:30  lr: 0.000300  loss: 0.0650 (0.1166)  loss_classifier: 0.0266 (0.0420)  loss_box_reg: 0.0362 (0.0665)  loss_objectness: 0.0012 (0.0048)  loss_rpn_box_reg: 0.0012 (0.0033)  time: 0.5066  data: 0.0185  max mem: 2448
# Epoch: [3]  [1570/2343]  eta: 0:06:25  lr: 0.000300  loss: 0.0742 (0.1164)  loss_classifier: 0.0264 (0.0419)  loss_box_reg: 0.0431 (0.0664)  loss_objectness: 0.0013 (0.0047)  loss_rpn_box_reg: 0.0017 (0.0033)  time: 0.5025  data: 0.0171  max mem: 2448
# Epoch: [3]  [1580/2343]  eta: 0:06:20  lr: 0.000300  loss: 0.0776 (0.1166)  loss_classifier: 0.0318 (0.0420)  loss_box_reg: 0.0436 (0.0665)  loss_objectness: 0.0015 (0.0048)  loss_rpn_box_reg: 0.0017 (0.0033)  time: 0.4965  data: 0.0158  max mem: 2448
# Epoch: [3]  [1590/2343]  eta: 0:06:15  lr: 0.000300  loss: 0.1183 (0.1166)  loss_classifier: 0.0390 (0.0420)  loss_box_reg: 0.0602 (0.0665)  loss_objectness: 0.0035 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.4952  data: 0.0172  max mem: 2448
# Epoch: [3]  [1600/2343]  eta: 0:06:10  lr: 0.000300  loss: 0.1236 (0.1170)  loss_classifier: 0.0327 (0.0422)  loss_box_reg: 0.0602 (0.0666)  loss_objectness: 0.0043 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.5039  data: 0.0183  max mem: 2448
# Epoch: [3]  [1610/2343]  eta: 0:06:05  lr: 0.000300  loss: 0.1053 (0.1169)  loss_classifier: 0.0411 (0.0422)  loss_box_reg: 0.0646 (0.0666)  loss_objectness: 0.0028 (0.0048)  loss_rpn_box_reg: 0.0022 (0.0033)  time: 0.4906  data: 0.0181  max mem: 2448
# Epoch: [3]  [1620/2343]  eta: 0:06:00  lr: 0.000300  loss: 0.1053 (0.1170)  loss_classifier: 0.0328 (0.0422)  loss_box_reg: 0.0645 (0.0666)  loss_objectness: 0.0028 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.4850  data: 0.0180  max mem: 2448
# Epoch: [3]  [1630/2343]  eta: 0:05:55  lr: 0.000300  loss: 0.1146 (0.1170)  loss_classifier: 0.0328 (0.0422)  loss_box_reg: 0.0645 (0.0666)  loss_objectness: 0.0015 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 0.4952  data: 0.0181  max mem: 2448
# Epoch: [3]  [1640/2343]  eta: 0:05:50  lr: 0.000300  loss: 0.1126 (0.1171)  loss_classifier: 0.0357 (0.0423)  loss_box_reg: 0.0744 (0.0667)  loss_objectness: 0.0015 (0.0048)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 0.4970  data: 0.0187  max mem: 2448
# Epoch: [3]  [1650/2343]  eta: 0:05:45  lr: 0.000300  loss: 0.1056 (0.1172)  loss_classifier: 0.0371 (0.0423)  loss_box_reg: 0.0632 (0.0668)  loss_objectness: 0.0024 (0.0048)  loss_rpn_box_reg: 0.0016 (0.0033)  time: 0.5026  data: 0.0188  max mem: 2448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-273fe481890a> in <module>()
#       1 for epoch in range(params['MAXEPOCHS']):
#       2     # train for one epoch, printing every 10 iterations
# ----> 3     train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
#       4
#       5     # update the learning rate
#
# <ipython-input-31-9ecf2d244cfd> in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      32             lr_scheduler.step()
#      33
# ---> 34         metric_logger.update(loss=losses, **loss_dict)
#      35         metric_logger.update(lr=optimizer.param_groups[0]["lr"])
#
# /content/utils.py in update(self, **kwargs)
#     153         for k, v in kwargs.items():
#     154             if isinstance(v, torch.Tensor):
# --> 155                 v = v.item()
#     156             assert isinstance(v, (float, int))
#     157             self.meters[k].update(v)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualization of results
#
# Now that training has finished, let's have a look at what it actually predicts.

# %%
# pick one image from the validation set
img, _ = val_dataset[30]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

prediction

# %% [markdown]
# Printing the prediction shows that we have a list of dictionaries. Each element of the list corresponds to a different image. As we have a single image, there is a single dictionary in the list.
# The dictionary contains the predictions for the image we passed. In this case, we can see that it contains `boxes`, `labels`, and `scores` as fields.
#
# Let's inspect the image and the predicted boxes.
# For that, we need to convert the image, which has been rescaled to 0-1 and had the channels flipped so that we have it in `[C, H, W]` format.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

img_preds = prediction[0]
for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}: {score}'
    draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# ## Post-processing
#
# We might notice that there are duplicate detections in the image. Let's post-process the detections with non-maximum suppression.
#
# ** Update: FasterRCNN already has NMS built into it, so you actually do not need to do NMS again.

# %%
img_preds = prediction[0]
keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])

# %% [markdown]
# Check the predictions again after applying nms.
#
# ** Update: You should not see any difference unless you have specified a lower IoU threshold than the default of 0.5.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Now, let's further filter out the non-confident detections.

# %%
det_threshold = 0

# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        # filter out non-confident detections
        if score > det_threshold:
            draw.rectangle(((x1, y1), (x2, y2)), outline="red")
            text = f'{dataset.cat2name[label]}: {score}'
            draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Much better! Once you are satisfied with the results, save your model weights.

# %%
# save model weights
FILENAME = f"bs-{params['BATCH_SIZE']}_lr-{params['LR']}_ep-{params['MAXEPOCHS']}_back-{params['BACKBONE']}_FPN-{params['FPN']}_thr-{params['IOU_THRESHOLD']}"
save_path = os.path.join(base_folder, f"./{FILENAME}.pth")
#save_path = os.path.join(base_folder, "./weights/lr-5e-3_resnet152.pth")
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ## Evaluation on Validation Set
#
# As a sanity check, let's evaluate the model performance on the validation set

# %%
with open(val_annotation) as json_file:
    val_data = json.load(json_file)

model.eval()
detections = []
with torch.no_grad():
    for image in val_data["images"]:
        img_name = image["file_name"]
        img_id = image["id"]

        img = Image.open(os.path.join(til_root, 'images', img_name)).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
validation_json = os.path.join(base_folder, f"./val-{FILENAME}.json")
with open(validation_json, 'w') as f:
    json.dump(detections, f)

# %%
# Get evaluation score against validation set to make sure your prediction json file is in the correct format
coco_gt = COCO(val_annotation)
coco_dt = coco_gt.loadRes(validation_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# ## Generate Predictions on Test Images

# %%
# You should already have uploaded the testing images onto your google drive.

testing_images_path = os.path.join(base_folder, "challenge_5_test_dataset.zip") # change this path to the zip file for the test images
# !unzip $testing_images_path

# %%
til_test_root = "/content/challenge_5_test_dataset/" # extracted testing images path
test_img_root = os.path.join(til_test_root, "images")
img_dir = os.scandir(test_img_root)

# %%
# load model weights (if not using the current trained model)
model.load_state_dict(torch.load(save_path, map_location=device))
model.to(device)
model.eval()

# %% [markdown]
# Let's visualize some predictions on the test images. Run this a few times to visualize different images.

# %%
img = Image.open(next(img_dir).path).convert('RGB')
draw = ImageDraw.Draw(img)
det_threshold = 0.5

# do the prediction
with torch.no_grad():
    img_tensor = transforms.ToTensor()(img)
    img_preds = model([img_tensor.to(device)])[0]

for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    # filter out non-confident detections
    if score > det_threshold:
        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(img)

# %% [markdown]
# ## Submission of Results
#
# Submission json file should be in [COCO format](https://cocodataset.org/#format-results).
#
# ```
# [{
#     "image_id": int,
#     "category_id": int,
#     "bbox": [x,y,width,height],
#     "score": float,
# }]
# ```
#
# Refer to **sample_submission_cv.json** for an example.
#
# For this competition, the metric for evaluation will be mAP @ 0.50:0.95

# %%
# generate detections on the folder of test images (this will be used for submission)
detections = []
with torch.no_grad():
    for image in img_dir:
        img_id = int(image.name.split('.')[0])

        img = Image.open(image.path).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
test_pred_json = os.path.join(base_folder, f"./test-{FILENAME}.json")
with open(test_pred_json, 'w') as f:
    json.dump(detections, f)

# %% [markdown]
# ## Check Your Submission JSON Format (RUN THIS BEFORE SUBMISSION)
#
# Run this function first with the given sample json (change this path for the different challenges) to make sure everything works before you submit. Just need to ensure that there are no errors when you run this. **If you get any errors, check your generated json file.**

# %%
sample_json_path = os.path.join(til_test_root, "c1_test_sample.json")

coco_gt = COCO(sample_json_path)
coco_dt = coco_gt.loadRes(test_pred_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# If you get an `AssertionError: Results do not correspond to current coco set`, it most likely means that some of the "image_id" are out of range (either 0 or higher than number of test images).
