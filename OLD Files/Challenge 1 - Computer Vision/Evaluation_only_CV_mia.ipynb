# %% [markdown]
# ## Downloading Dependencies

# %%
# First, we need to install pycocotools. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.
# The version by default in Colab has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-v1g9w2oj
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-v1g9w2oj
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (57.0.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (0.29.23)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=263901 sha256=e2a9d5553bab458eb71155191eca6bf11620f3ffe7f96efaa452971d7f3b8239
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ycix0ih/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# Successfully installed pycocotools-2.0

# %%
import json
import math
import os
import random
import sys
import time

import numpy as np
import torch
import torch.utils.data
import torchvision

from PIL import Image, ImageDraw
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms
from torchvision.ops import batched_nms
from torchvision.transforms import functional as F

# %%
from typing import List, Tuple

import torchvision.models as models

from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

# %% [markdown]
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/utils.py` and `references/detection/coco_eval.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/coco_eval.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 29023, done.
# remote: Counting objects: 100% (1566/1566), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 29023 (delta 1154), reused 1502 (delta 1117), pack-reused 27457
# Receiving objects: 100% (29023/29023), 37.50 MiB | 35.29 MiB/s, done.
# Resolving deltas: 100% (21764/21764), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
import utils
from coco_eval import CocoEvaluator

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Object Detection Dataset
# We will be providing the base dataset that will be used for the first task of the Object Detection competition.

# %%
# You should have uploaded the training dataset onto your google drive.

base_folder = '/content/drive/MyDrive/TIL2021_CV' # Change this path to your folder for this competition
training_path = os.path.join(base_folder, "c1_release.zip") # zip file for training dataset

# %%
# unzip the training dataset
# !unzip $training_path
# Out:
# Archive:  /content/drive/MyDrive/TIL2021_CV/c1_release.zip
#    creating: c1_release/
#   inflating: c1_release/val.json
#   inflating: c1_release/train.json
#   inflating: c1_release/labels.json
#   inflating: c1_release/CREDITS.txt
#    creating: c1_release/images/
#   inflating: c1_release/images/0dab6f0b8525d425.jpg
#   inflating: c1_release/images/19cc71d55265e083.jpg
#   inflating: c1_release/images/2574278a3406efa9.jpg
#   inflating: c1_release/images/4b2243190b2ae75e.jpg
#   inflating: c1_release/images/984815695c3ca54b.jpg
#   inflating: c1_release/images/0038162a38adaaa8.jpg
#   inflating: c1_release/images/b3750a548fd77a04.jpg
#   inflating: c1_release/images/5117b754613a09a9.jpg
#   inflating: c1_release/images/88488e72c60fcbde.jpg
#   inflating: c1_release/images/89fc506a70c0d39d.jpg
#   inflating: c1_release/images/d06312a3067178c8.jpg
#   inflating: c1_release/images/bfd56ff4bf1c8789.jpg
#   inflating: c1_release/images/485fb30319e9acc2.jpg
#   inflating: c1_release/images/68f9116f03685bf5.jpg
#   inflating: c1_release/images/48072723582a53f5.jpg
#   inflating: c1_release/images/1297d4220dec7960.jpg
#   inflating: c1_release/images/36352f2bd651e795.jpg
#   inflating: c1_release/images/366cb7a9edb48015.jpg
#   inflating: c1_release/images/0b814415f1ecc0bd.jpg
#   inflating: c1_release/images/01837594a31df162.jpg
#   inflating: c1_release/images/c4e0e8463866cd30.jpg
#   inflating: c1_release/images/7866aab9dab6f121.jpg
#   inflating: c1_release/images/0537887742a45748.jpg
#   inflating: c1_release/images/eded460f9c8c725d.jpg
#   inflating: c1_release/images/d8121ba6234dac82.jpg
#   inflating: c1_release/images/87d7b8685bb5825d.jpg
#   inflating: c1_release/images/aebda1918c6c6710.jpg
#   inflating: c1_release/images/1b4289dd18fdcbd1.jpg
#   inflating: c1_release/images/9435accfb27d2316.jpg
#   inflating: c1_release/images/71b2ee3f883d1eed.jpg
#   inflating: c1_release/images/da7297556b8c7ac3.jpg
#   inflating: c1_release/images/d582bb2505d7d91d.jpg
#   inflating: c1_release/images/dc7ac9d19aa592b0.jpg
#   inflating: c1_release/images/61676f0508ce8882.jpg
#   inflating: c1_release/images/a565d6501f8563c6.jpg
#   inflating: c1_release/images/ad85b101398e1c31.jpg
#   inflating: c1_release/images/0faefeb7d8e8ea55.jpg
#   inflating: c1_release/images/c17edbf11712fa47.jpg
#   inflating: c1_release/images/736605cc2d3d17f8.jpg
#   inflating: c1_release/images/f23f81fcfb0c450a.jpg
#   inflating: c1_release/images/16dfcf2c195a45e5.jpg
#   inflating: c1_release/images/ded05c7ceca83a90.jpg
#   inflating: c1_release/images/508c237d24894d23.jpg
#   inflating: c1_release/images/b83a907b1fd10f1f.jpg
#   inflating: c1_release/images/d2090618b3c22335.jpg
#   inflating: c1_release/images/a314d39dcdffd95e.jpg
#   inflating: c1_release/images/a50a2cbee3cac6e6.jpg
#   inflating: c1_release/images/176bb055af27da62.jpg
#   inflating: c1_release/images/9ce37b161b175f50.jpg
#   inflating: c1_release/images/71bb46966dd9db04.jpg
#   inflating: c1_release/images/6b4f006b73cee63b.jpg
#   inflating: c1_release/images/b5e7874e113ca129.jpg
#   inflating: c1_release/images/79b15209eba377b0.jpg
#   inflating: c1_release/images/783d188844686eda.jpg
#   inflating: c1_release/images/4d960b4f9d71a00a.jpg
#   inflating: c1_release/images/d74017e61bfcc0fd.jpg
#   inflating: c1_release/images/c64efcc9ccd83b94.jpg
#   inflating: c1_release/images/fb00ff6731927326.jpg
#   inflating: c1_release/images/712967956e696780.jpg
#   inflating: c1_release/images/90a924862ca55bab.jpg
#   inflating: c1_release/images/00ae6efec51b9be3.jpg
#   inflating: c1_release/images/13a2c6bd4445d9b1.jpg
#   inflating: c1_release/images/71415e87351f10c1.jpg
#   inflating: c1_release/images/c521facf4aaec77b.jpg
#   inflating: c1_release/images/36d3d977ddbdc677.jpg
#   inflating: c1_release/images/849d1c22528072df.jpg
#   inflating: c1_release/images/75a116c1f619546f.jpg
#   inflating: c1_release/images/df22d4352a82912b.jpg
#   inflating: c1_release/images/178f377c72af95ba.jpg
#   inflating: c1_release/images/5825142442d8c323.jpg
#   inflating: c1_release/images/0bf1e041d90f51bf.jpg
#   inflating: c1_release/images/22c0d81139f5db79.jpg
#   inflating: c1_release/images/ce6dffccf604b9d0.jpg
#   inflating: c1_release/images/c2c0b51ec9024e38.jpg
#   inflating: c1_release/images/ab65119518adb6ff.jpg
#   inflating: c1_release/images/e4e7d265650e742f.jpg
#   inflating: c1_release/images/acbb2a3bdfb6200a.jpg
#   inflating: c1_release/images/dfaf930cee398614.jpg
#   inflating: c1_release/images/dfa6485b0ea0b86b.jpg
#   inflating: c1_release/images/d21f270fef984c84.jpg
#   inflating: c1_release/images/b9c1db7efb9c72b2.jpg
#   inflating: c1_release/images/beb8882ef72eafae.jpg
#   inflating: c1_release/images/00d9b6154afed374.jpg
#   inflating: c1_release/images/269fce50a948f788.jpg
#   inflating: c1_release/images/46ca274d65dd4c3d.jpg
#   inflating: c1_release/images/49c16d780f11e37c.jpg
#   inflating: c1_release/images/40143957f75f4c5b.jpg
#   inflating: c1_release/images/a5dd6f6d30dcba85.jpg
#   inflating: c1_release/images/73472d2d0b84b59f.jpg
#   inflating: c1_release/images/9f6dd881219ff3b1.jpg
#   inflating: c1_release/images/11762fef71d44be3.jpg
#   inflating: c1_release/images/e57c4079fa28f706.jpg
#   inflating: c1_release/images/2a0645f032aa5e34.jpg
#   inflating: c1_release/images/dd530668208400da.jpg
#   inflating: c1_release/images/57a5b6049d288489.jpg
#   inflating: c1_release/images/d411cffee4f995ac.jpg
#   inflating: c1_release/images/10cd436fec46a7be.jpg
#   inflating: c1_release/images/b8516a423cbf91f7.jpg
#   inflating: c1_release/images/e7c8fdd8c07d0840.jpg
#   inflating: c1_release/images/2ff659d2ff82340f.jpg
#   inflating: c1_release/images/7cf3b682d4811366.jpg
#   inflating: c1_release/images/c9fc3a5d6474f365.jpg
#   inflating: c1_release/images/1000c2ef277ddc1a.jpg
#   inflating: c1_release/images/9fe890b0f5318257.jpg
#   inflating: c1_release/images/f72a03511e83ab88.jpg
#   inflating: c1_release/images/2550393392ca12e6.jpg
#   inflating: c1_release/images/d8e18753fd149063.jpg
#   inflating: c1_release/images/e1d29844b9d4b86b.jpg
#   inflating: c1_release/images/01f9d9d8a9f60dcd.jpg
#   inflating: c1_release/images/0325a9d5795989ec.jpg
#   inflating: c1_release/images/441b8a3482f2b87b.jpg
#   inflating: c1_release/images/be2b0baf62540f2a.jpg
#   inflating: c1_release/images/0bf21e7a2c7870d2.jpg
#   inflating: c1_release/images/765ca12b02f46267.jpg
#   inflating: c1_release/images/fd1bab1ee40478d0.jpg
#   inflating: c1_release/images/939ac88cbda145cb.jpg
#   inflating: c1_release/images/047202d1f56b4b0a.jpg
#   inflating: c1_release/images/ebcaa7114aa24171.jpg
#   inflating: c1_release/images/a70deaf9f9b9ecbf.jpg
#   inflating: c1_release/images/74beff6e9a776319.jpg
#   inflating: c1_release/images/263149151b310b9f.jpg
#   inflating: c1_release/images/1e392f8cdb5974c0.jpg
#   inflating: c1_release/images/afe8aa84db511b29.jpg
#   inflating: c1_release/images/1d131ba9b79e532a.jpg
#   inflating: c1_release/images/454e14109c325e4b.jpg
#   inflating: c1_release/images/713b130e28581e21.jpg
#   inflating: c1_release/images/dd24e2e43d0dc17b.jpg
#   inflating: c1_release/images/409b4801fc0d1f7d.jpg
#   inflating: c1_release/images/1add12655dc10de9.jpg
#   inflating: c1_release/images/020efd3803ff4e94.jpg
#   inflating: c1_release/images/2adf377ee3579a3c.jpg
#   inflating: c1_release/images/b275d40197a9bee2.jpg
#   inflating: c1_release/images/06d4434886eafe25.jpg
#   inflating: c1_release/images/1e6a97846b8dfbc3.jpg
#   inflating: c1_release/images/14a8617113acb5b9.jpg
#   inflating: c1_release/images/egg.jpg
#   inflating: c1_release/images/a322f4d0d7406b0b.jpg
#   inflating: c1_release/images/199939529ff0d489.jpg
#   inflating: c1_release/images/c338a1733f3c7bba.jpg
#   inflating: c1_release/images/2ea2f32000c73278.jpg
#   inflating: c1_release/images/cbe8eaf80351fac8.jpg
#   inflating: c1_release/images/c7c8264347cdad7b.jpg
#   inflating: c1_release/images/5c9d40a4dbf4ce53.jpg
#   inflating: c1_release/images/91bd045a74edde64.jpg
#   inflating: c1_release/images/a3567cd68406728a.jpg
#   inflating: c1_release/images/b447bdeb5295d547.jpg
#   inflating: c1_release/images/718831f086175b46.jpg
#   inflating: c1_release/images/138a8bc5729be3a6.jpg
#   inflating: c1_release/images/045fbad43714951a.jpg
#   inflating: c1_release/images/9bc0a093a9fd5457.jpg
#   inflating: c1_release/images/6c646850f2b66d34.jpg
#   inflating: c1_release/images/ae91fc5b7fdb45c8.jpg
#   inflating: c1_release/images/833906d54244f0b6.jpg
#   inflating: c1_release/images/a972c35efed5ea15.jpg
#   inflating: c1_release/images/042bfb27cadbb718.jpg
#   inflating: c1_release/images/0de288406b98cd86.jpg
#   inflating: c1_release/images/0983828d8645f192.jpg
#   inflating: c1_release/images/b1a5bc5454039637.jpg
#   inflating: c1_release/images/3757ad4efb2c1379.jpg
#   inflating: c1_release/images/ec3d9fa9250fcdf8.jpg
#   inflating: c1_release/images/ba1c73c4940662f4.jpg
#   inflating: c1_release/images/d451673f2e0d79fe.jpg
#   inflating: c1_release/images/f9f56ed54b066e43.jpg
#   inflating: c1_release/images/4d8dbaa93038d37c.jpg
#   inflating: c1_release/images/058635d2f18298bb.jpg
#   inflating: c1_release/images/1478e241b43c2ea3.jpg
#   inflating: c1_release/images/c81653df12f1911a.jpg
#   inflating: c1_release/images/7a0f30b2451d06c8.jpg
#   inflating: c1_release/images/ec119ef34fd73ff0.jpg
#   inflating: c1_release/images/4dee0d9e7b41beb4.jpg
#   inflating: c1_release/images/ebf1e8eee102a65a.jpg
#   inflating: c1_release/images/a3b7db96f53be615.jpg
#   inflating: c1_release/images/aa1d3e23aa00fc68.jpg
#   inflating: c1_release/images/efd5d8870d899aab.jpg
#   inflating: c1_release/images/3069a58c04f8ea9d.jpg
#   inflating: c1_release/images/2634df456c4ea4ca.jpg
#   inflating: c1_release/images/0d21a6e72398a02a.jpg
#   inflating: c1_release/images/47ebfe89f3157cf2.jpg
#   inflating: c1_release/images/b158365db74b237d.jpg
#   inflating: c1_release/images/d216db7671f76244.jpg
#   inflating: c1_release/images/55762ad679ad8cf4.jpg
#   inflating: c1_release/images/63b9cd6513ad17b6.jpg
#   inflating: c1_release/images/e8ad5e31484ef889.jpg
#   inflating: c1_release/images/305399814fc5ddb0.jpg
#   inflating: c1_release/images/f548a994b8b81fcf.jpg
#   inflating: c1_release/images/2447bbc76e402b8e.jpg
#   inflating: c1_release/images/78b08488c9ac88af.jpg
#   inflating: c1_release/images/1268d8d14aa08269.jpg
#   inflating: c1_release/images/e1fda21a5dddc716.jpg
#   inflating: c1_release/images/69986b95816f7735.jpg
#   inflating: c1_release/images/50ecbbe3d3bb0a5c.jpg
#   inflating: c1_release/images/48c7b82e8ace4486.jpg
#   inflating: c1_release/images/04612218590af532.jpg
#   inflating: c1_release/images/55aaa9c3b1432961.jpg
#   inflating: c1_release/images/c07b221ce167b532.jpg
#   inflating: c1_release/images/692285d829fa241c.jpg
#   inflating: c1_release/images/80e444db26d6c94c.jpg
#   inflating: c1_release/images/c2af652d689a4ec5.jpg
#   inflating: c1_release/images/134bd2146501866e.jpg
#   inflating: c1_release/images/b2dab25f00958513.jpg
#   inflating: c1_release/images/526dd084db44e33c.jpg
#   inflating: c1_release/images/a5e1b98bab4ae3bd.jpg
#   inflating: c1_release/images/a85f5ba0a94bf1c2.jpg
#   inflating: c1_release/images/a015bcab031b8a97.jpg
#   inflating: c1_release/images/3780666da35374e7.jpg
#   inflating: c1_release/images/78ea90b811276b08.jpg
#   inflating: c1_release/images/383e9ccdf26d38a4.jpg
#   inflating: c1_release/images/7913366dfe67e873.jpg
#   inflating: c1_release/images/10de89a5a63c0255.jpg
#   inflating: c1_release/images/098f83f0703b28a5.jpg
#   inflating: c1_release/images/627f67980b0d7120.jpg
#   inflating: c1_release/images/4dac497a040330c8.jpg
#   inflating: c1_release/images/0444a46ed9808947.jpg
#   inflating: c1_release/images/985cb3639081508e.jpg
#   inflating: c1_release/images/4bdcd2dc64720eb8.jpg
#   inflating: c1_release/images/09cf802fb1a64ac2.jpg
#   inflating: c1_release/images/be7aae0d065c11a0.jpg
#   inflating: c1_release/images/d1b2a18aa8633e16.jpg
#   inflating: c1_release/images/176b7efd8d1ea7b6.jpg
#   inflating: c1_release/images/d48327bf728668f4.jpg
#   inflating: c1_release/images/1f62d1896518cd36.jpg
#   inflating: c1_release/images/9b2332c01df5c400.jpg
#   inflating: c1_release/images/1917d27f13ddd6d7.jpg
#   inflating: c1_release/images/953a574366a7fd79.jpg
#   inflating: c1_release/images/b4ca95be831e8fac.jpg
#   inflating: c1_release/images/79c0f06c2d436409.jpg
#   inflating: c1_release/images/1c539c79957fa155.jpg
#   inflating: c1_release/images/da5e72c02b511f09.jpg
#   inflating: c1_release/images/0255dfa1a434e412.jpg
#   inflating: c1_release/images/e2bc06993d3cf513.jpg
#   inflating: c1_release/images/93f75c24381bfde1.jpg
#   inflating: c1_release/images/2884a930ec6e1b17.jpg
#   inflating: c1_release/images/6680556acebceb3c.jpg
#   inflating: c1_release/images/916f68aaff0024a1.jpg
#   inflating: c1_release/images/67104693b206c803.jpg
#   inflating: c1_release/images/dd06e6ea57db6258.jpg
#   inflating: c1_release/images/79f4fdf91ab44345.jpg
#   inflating: c1_release/images/5e03d5c138b53e88.jpg
#   inflating: c1_release/images/912efa93f3611980.jpg
#   inflating: c1_release/images/63a301ca1a382515.jpg
#   inflating: c1_release/images/affe1f82dfdc17a6.jpg
#   inflating: c1_release/images/0450a0a7feff6a9e.jpg
#   inflating: c1_release/images/3912ce3faae20dfe.jpg
#   inflating: c1_release/images/bd1fd90f3faff373.jpg
#   inflating: c1_release/images/bb5475b3c113d197.jpg
#   inflating: c1_release/images/89a82d07a5b2f43a.jpg
#   inflating: c1_release/images/ce606aba67c6b869.jpg
#   inflating: c1_release/images/1a0b571ed895f850.jpg
#   inflating: c1_release/images/c11a7b1fe300477a.jpg
#   inflating: c1_release/images/b9ffc4296e70ce31.jpg
#   inflating: c1_release/images/38fbe6c8997acda4.jpg
#   inflating: c1_release/images/0a73fcb7ba206735.jpg
#   inflating: c1_release/images/5a7790ecd6daf1f5.jpg
#   inflating: c1_release/images/07301815c8038143.jpg
#   inflating: c1_release/images/3881e2c1e8c8efc6.jpg
#   inflating: c1_release/images/ae1648ca913aa15b.jpg
#   inflating: c1_release/images/ebf253c394c32b59.jpg
#   inflating: c1_release/images/f59a0dcfbba49ac6.jpg
#   inflating: c1_release/images/792d977674dfc957.jpg
#   inflating: c1_release/images/6744ab4101ed604c.jpg
#   inflating: c1_release/images/382ad144b32c8615.jpg
#   inflating: c1_release/images/15f821f3adc3c528.jpg
#   inflating: c1_release/images/4662dcd57d8afe2d.jpg
#   inflating: c1_release/images/242a147fddb74765.jpg
#   inflating: c1_release/images/4d81d8907911c077.jpg
#   inflating: c1_release/images/d06b5635c6b0b7ba.jpg
#   inflating: c1_release/images/3839cad1657a84e6.jpg
#   inflating: c1_release/images/21a26059fc1e8c33.jpg
#   inflating: c1_release/images/b868dcbfd82e4659.jpg
#   inflating: c1_release/images/6cac7afb673682f3.jpg
#   inflating: c1_release/images/acf8281ca2250b0c.jpg
#   inflating: c1_release/images/ed7163dd98f9df15.jpg
#   inflating: c1_release/images/f2258b1ad0baf1ca.jpg
#   inflating: c1_release/images/e6931e60dd8d3567.jpg
#   inflating: c1_release/images/15841379d3baa274.jpg
#   inflating: c1_release/images/0ed3c3844a7429a4.jpg
#   inflating: c1_release/images/a7036ffe17d9cb17.jpg
#   inflating: c1_release/images/f55622acfdc2b094.jpg
#   inflating: c1_release/images/794178cfe11fe946.jpg
#   inflating: c1_release/images/975616eff5a7755e.jpg
#   inflating: c1_release/images/f735f12f8d70cdde.jpg
#   inflating: c1_release/images/89fa26a371e95f4e.jpg
#   inflating: c1_release/images/d465f2393baa68bb.jpg
#   inflating: c1_release/images/7fce2c184b35c218.jpg
#   inflating: c1_release/images/2932a277daeb2e5b.jpg
#   inflating: c1_release/images/d0e699c6c994578e.jpg
#   inflating: c1_release/images/56d1131046a577b0.jpg
#   inflating: c1_release/images/1533bb2725126980.jpg
#   inflating: c1_release/images/72746bfe49fc9b99.jpg
#   inflating: c1_release/images/d75f88e8bba4a424.jpg
#   inflating: c1_release/images/bc688d39308b1adc.jpg
#   inflating: c1_release/images/82c27bf7a65619b5.jpg
#   inflating: c1_release/images/82329251c17f7fcf.jpg
#   inflating: c1_release/images/6ad8f6380f34c7af.jpg
#   inflating: c1_release/images/bda9c04327c04c3d.jpg
#   inflating: c1_release/images/e60db4a79a969007.jpg
#   inflating: c1_release/images/e39fd8a8f5ad36fd.jpg
#   inflating: c1_release/images/b3833bbf116406e1.jpg
#   inflating: c1_release/images/e3960e74324f46cb.jpg
#   inflating: c1_release/images/988f7f51019815d4.jpg
#   inflating: c1_release/images/85250eaf3565cbf7.jpg
#   inflating: c1_release/images/064eba3ab924894e.jpg
#   inflating: c1_release/images/1424bbd44f6bf487.jpg
#   inflating: c1_release/images/dcad0f2430084a8b.jpg
#   inflating: c1_release/images/82e2192949043236.jpg
#   inflating: c1_release/images/d00c3cc59c32e9b0.jpg
#   inflating: c1_release/images/ec146555b6ed3694.jpg
#   inflating: c1_release/images/31c291da11976123.jpg
#   inflating: c1_release/images/a51a500469ffef9c.jpg
#   inflating: c1_release/images/2cfd6c97a9e29cff.jpg
#   inflating: c1_release/images/c22c1cc673245afd.jpg
#   inflating: c1_release/images/2e9d5e8c28d177fe.jpg
#   inflating: c1_release/images/570a51a7c712b056.jpg
#   inflating: c1_release/images/e4f3c6e01c8e79df.jpg
#   inflating: c1_release/images/162f5cd16f96c478.jpg
#   inflating: c1_release/images/21bc68f567ac688a.jpg
#   inflating: c1_release/images/796ba91b6f953f3b.jpg
#   inflating: c1_release/images/813e1f9f07d62761.jpg
#   inflating: c1_release/images/32a1ef3639faf1d2.jpg
#   inflating: c1_release/images/a3cac0f53f6591de.jpg
#   inflating: c1_release/images/b25f2035f2bd907b.jpg
#   inflating: c1_release/images/36076652cb9048df.jpg
#   inflating: c1_release/images/b747c9728447678c.jpg
#   inflating: c1_release/images/da8aff17baddd427.jpg
#   inflating: c1_release/images/a5acf53430391812.jpg
#   inflating: c1_release/images/4fd55f4a6c5043aa.jpg
#   inflating: c1_release/images/46867075a34c8f53.jpg
#   inflating: c1_release/images/beb9280209159f63.jpg
#   inflating: c1_release/images/716f853d489e3c68.jpg
#   inflating: c1_release/images/5cad2dfd824df4cd.jpg
#   inflating: c1_release/images/31e321ac776f44f8.jpg
#   inflating: c1_release/images/efe073c2ca76a6b9.jpg
#   inflating: c1_release/images/ffafc750f95db0da.jpg
#   inflating: c1_release/images/198e141077978025.jpg
#   inflating: c1_release/images/ef782c4d386cda0d.jpg
#   inflating: c1_release/images/6f6a7690aea552e4.jpg
#   inflating: c1_release/images/1edc75caafd61271.jpg
#   inflating: c1_release/images/e728ad218e82146c.jpg
#   inflating: c1_release/images/c1a83d1f099b011f.jpg
#   inflating: c1_release/images/325f2eb732d4fef9.jpg
#   inflating: c1_release/images/660220daf42ae887.jpg
#   inflating: c1_release/images/0620fe4c9e29ab20.jpg
#   inflating: c1_release/images/045dbc91b32d8ced.jpg
#   inflating: c1_release/images/f0504acf6f5fb832.jpg
#   inflating: c1_release/images/5b3ba56aa623b1ce.jpg
#   inflating: c1_release/images/00067fe83e3e21c8.jpg
#   inflating: c1_release/images/b31f811b870d8ee7.jpg
#   inflating: c1_release/images/c2109f41fc884fb2.jpg
#   inflating: c1_release/images/1ad1784fd960c116.jpg
#   inflating: c1_release/images/9d3adf05f8d028c0.jpg
#   inflating: c1_release/images/01c9f9235365a654.jpg
#   inflating: c1_release/images/00dd76913fe509f1.jpg
#   inflating: c1_release/images/55a12d61937e380e.jpg
#   inflating: c1_release/images/c78e1e4d4a603cc6.jpg
#   inflating: c1_release/images/a2b358b25839e684.jpg
#   inflating: c1_release/images/10422817d7d9b0c1.jpg
#   inflating: c1_release/images/9a8b6d6fc0446498.jpg
#   inflating: c1_release/images/24ca90ab5ec55ab4.jpg
#   inflating: c1_release/images/c1763010efd27dec.jpg
#   inflating: c1_release/images/d100d9591181d298.jpg
#   inflating: c1_release/images/2e0553cc2173c450.jpg
#   inflating: c1_release/images/b9397fd37795e3c7.jpg
#   inflating: c1_release/images/dd49251d408ace4a.jpg
#   inflating: c1_release/images/79731ac754356a03.jpg
#   inflating: c1_release/images/93cc6e7e9a5722be.jpg
#   inflating: c1_release/images/180d1f2ac5ca5f0e.jpg
#   inflating: c1_release/images/2e8c305297c841aa.jpg
#   inflating: c1_release/images/364ee924606fc444.jpg
#   inflating: c1_release/images/143793332d1085a0.jpg
#   inflating: c1_release/images/468116035c8024e6.jpg
#   inflating: c1_release/images/32504afdc35969e3.jpg
#   inflating: c1_release/images/d8a16d251f14a6d7.jpg
#   inflating: c1_release/images/b56b7fc326fe6a27.jpg
#   inflating: c1_release/images/1706e964d55a4b95.jpg
#   inflating: c1_release/images/19688abc3573bcf7.jpg
#   inflating: c1_release/images/2e59ebfaa79bfefb.jpg
#   inflating: c1_release/images/c054547dfd391452.jpg
#   inflating: c1_release/images/0a4442253dde2c6b.jpg
#   inflating: c1_release/images/31126662b449a665.jpg
#   inflating: c1_release/images/3b827c62f4f1d40e.jpg
#   inflating: c1_release/images/1849dd41b5e1a45d.jpg
#   inflating: c1_release/images/f9b3422a75aaca6a.jpg
#   inflating: c1_release/images/4373f61d97535195.jpg
#   inflating: c1_release/images/672bc2783a0ddbeb.jpg
#   inflating: c1_release/images/df72f5f6e134fdc2.jpg
#   inflating: c1_release/images/911b1a45c364e189.jpg
#   inflating: c1_release/images/2f042b7c9c519c90.jpg
#   inflating: c1_release/images/70253f04e5ca71af.jpg
#   inflating: c1_release/images/41527b065897a6a9.jpg
#   inflating: c1_release/images/ab0aecdb460a8265.jpg
#   inflating: c1_release/images/c4e5cdfe10e77244.jpg
#   inflating: c1_release/images/f542d4c2b81269b3.jpg
#   inflating: c1_release/images/4637d71999fbbf96.jpg
#   inflating: c1_release/images/f72f1bc74db2855d.jpg
#   inflating: c1_release/images/c78ae33ba4d8c769.jpg
#   inflating: c1_release/images/43b5058beec85ee4.jpg
#   inflating: c1_release/images/b8b4c124d1a24d88.jpg
#   inflating: c1_release/images/01ff769691d1ea2f.jpg
#   inflating: c1_release/images/0f989b2ead0fb4e6.jpg
#   inflating: c1_release/images/25b2afd243c527ce.jpg
#   inflating: c1_release/images/68cced0dd5aab3de.jpg
#   inflating: c1_release/images/375c14e927fa4dd7.jpg
#   inflating: c1_release/images/e2751e978202b9e7.jpg
#   inflating: c1_release/images/0278e268b62c4e13.jpg
#   inflating: c1_release/images/3230bab9456631b8.jpg
#   inflating: c1_release/images/b5a0a74dd7e4dfd6.jpg
#   inflating: c1_release/images/991008da98930b16.jpg
#   inflating: c1_release/images/166b974e85386982.jpg
#   inflating: c1_release/images/9ee8a7f0f8ec56f7.jpg
#   inflating: c1_release/images/56bbad7b9d696446.jpg
#   inflating: c1_release/images/b299fdda54edaa80.jpg
#   inflating: c1_release/images/279b5f19b42e6972.jpg
#   inflating: c1_release/images/6855931abb52f57d.jpg
#   inflating: c1_release/images/b4056f3cb4a63052.jpg
#   inflating: c1_release/images/966f946732fb776e.jpg
#   inflating: c1_release/images/e66a4123f3bf9aad.jpg
#   inflating: c1_release/images/1834852a813bca05.jpg
#   inflating: c1_release/images/e4fe9dadb4d4af5c.jpg
#   inflating: c1_release/images/0991597ba9f18cf6.jpg
#   inflating: c1_release/images/993e494ef7080d28.jpg
#   inflating: c1_release/images/bbd26e5f0dfa8650.jpg
#   inflating: c1_release/images/54c6656acda20a4b.jpg
#   inflating: c1_release/images/0eabdfa367cc126c.jpg
#   inflating: c1_release/images/ad89f84333288d2f.jpg
#   inflating: c1_release/images/39b4f3785c72d2be.jpg
#   inflating: c1_release/images/9c785a44d4e42165.jpg
#   inflating: c1_release/images/5d7de24b8b746010.jpg
#   inflating: c1_release/images/7b9944faafa1f4d5.jpg
#   inflating: c1_release/images/db9a16adf9693d28.jpg
#   inflating: c1_release/images/4bf275dab52d40d0.jpg
#   inflating: c1_release/images/11e7bde8edb3e630.jpg
#   inflating: c1_release/images/3447e24953fcec24.jpg
#   inflating: c1_release/images/62350f7aa0ba7298.jpg
#   inflating: c1_release/images/073f5c4f40ada4e6.jpg
#   inflating: c1_release/images/64e9bb804b667bd5.jpg
#   inflating: c1_release/images/bbd6ee3ac7aa37d7.jpg
#   inflating: c1_release/images/56de9c0ee1cd3922.jpg
#   inflating: c1_release/images/17dba471109aef9c.jpg
#   inflating: c1_release/images/fa66cebee6103b5d.jpg
#   inflating: c1_release/images/201e6f49d0138ee4.jpg
#   inflating: c1_release/images/f47135ec80e0d3b6.jpg
#   inflating: c1_release/images/a75edc99062d2500.jpg
#   inflating: c1_release/images/6461b3fe617b6d65.jpg
#   inflating: c1_release/images/067610426972073f.jpg
#   inflating: c1_release/images/1c872b24f9b9c228.jpg
#   inflating: c1_release/images/032dba2913b03d02.jpg
#   inflating: c1_release/images/fd17f5dd33b92198.jpg
#   inflating: c1_release/images/be90eb4c91df0a23.jpg
#   inflating: c1_release/images/71196c5d91ea4355.jpg
#   inflating: c1_release/images/69deed5b47ce18e9.jpg
#   inflating: c1_release/images/c6bf415f26aa2a0c.jpg
#   inflating: c1_release/images/c4217c35040391e3.jpg
#   inflating: c1_release/images/000a816392d086c4.jpg
#   inflating: c1_release/images/59f19ee53fd237f3.jpg
#   inflating: c1_release/images/9f4ee0e11481d2d8.jpg
#   inflating: c1_release/images/0066f4d8f05df0a4.jpg
#   inflating: c1_release/images/cf9e14d4fa31e5f6.jpg
#   inflating: c1_release/images/350903737f8bb0c8.jpg
#   inflating: c1_release/images/a0a675d15b40086c.jpg
#   inflating: c1_release/images/96bba456ab6ae22c.jpg
#   inflating: c1_release/images/5942216ab31d043d.jpg
#   inflating: c1_release/images/dc8f6588d4f01eaa.jpg
#   inflating: c1_release/images/3555bdbd1fa85b2a.jpg
#   inflating: c1_release/images/8e5b7a932684f598.jpg
#   inflating: c1_release/images/a414e5fe6b8988a0.jpg
#   inflating: c1_release/images/90105616cec5d7bc.jpg
#   inflating: c1_release/images/c9ba2c094261d92a.jpg
#   inflating: c1_release/images/e142c2dd486a1090.jpg
#   inflating: c1_release/images/cfb2c565c7c2ca42.jpg
#   inflating: c1_release/images/ae916ec249796511.jpg
#   inflating: c1_release/images/e9f9942a3ba822f0.jpg
#   inflating: c1_release/images/c1ee5c7523f80b90.jpg
#   inflating: c1_release/images/a802f6dc3df32f38.jpg
#   inflating: c1_release/images/9cb0944e53cf1fe5.jpg
#   inflating: c1_release/images/cf704f7c4f5409c6.jpg
#   inflating: c1_release/images/ac4d4fb76395c456.jpg
#   inflating: c1_release/images/4f2cd3cc74e7fa3a.jpg
#   inflating: c1_release/images/ea3413c4a75ed342.jpg
#   inflating: c1_release/images/bfa6dce35600c79b.jpg
#   inflating: c1_release/images/d10885899405a9d2.jpg
#   inflating: c1_release/images/10af2df892bc940e.jpg
#   inflating: c1_release/images/080557c9029a9661.jpg
#   inflating: c1_release/images/a1b5ea5c725025bc.jpg
#   inflating: c1_release/images/dc905d3f4b9207fe.jpg
#   inflating: c1_release/images/6fce769d69c3054a.jpg
#   inflating: c1_release/images/3f2ca441dc3149c7.jpg
#   inflating: c1_release/images/7b2d0990b4fba4d0.jpg
#   inflating: c1_release/images/9c2ff8cdcca17720.jpg
#   inflating: c1_release/images/36a6002ac1e608b0.jpg
#   inflating: c1_release/images/00477f027254668d.jpg
#   inflating: c1_release/images/a21db612b349bca6.jpg
#   inflating: c1_release/images/fec5e9d1b7b2b26f.jpg
#   inflating: c1_release/images/02881bf75cbb6eb8.jpg
#   inflating: c1_release/images/07078f12ba7346fe.jpg
#   inflating: c1_release/images/79819dfc0367b4b5.jpg
#   inflating: c1_release/images/ede1727dbc32db46.jpg
#   inflating: c1_release/images/577638569201b670.jpg
#   inflating: c1_release/images/3ea41a8cc836f961.jpg
#   inflating: c1_release/images/01a5337adb2f6b8f.jpg
#   inflating: c1_release/images/b00cb3d5c05abd96.jpg
#   inflating: c1_release/images/1c4d055ffe71d1a7.jpg
#   inflating: c1_release/images/12adbe99e4c6afa3.jpg
#   inflating: c1_release/images/bb4a05417bd8b420.jpg
#   inflating: c1_release/images/4b2fbf63d11e877a.jpg
#   inflating: c1_release/images/5005b55be212c69f.jpg
#   inflating: c1_release/images/d6894b5026199f6c.jpg
#   inflating: c1_release/images/03448ba85249779d.jpg
#   inflating: c1_release/images/647b04ffdba43360.jpg
#   inflating: c1_release/images/c9d733569d1206b7.jpg
#   inflating: c1_release/images/c1404d03f70ec91d.jpg
#   inflating: c1_release/images/ae816c59ca921298.jpg
#   inflating: c1_release/images/03a0b6a4d91622ef.jpg
#   inflating: c1_release/images/a750e8b23303e324.jpg
#   inflating: c1_release/images/c69c28102ba4b56d.jpg
#   inflating: c1_release/images/073c7f3f4d3a2b02.jpg
#   inflating: c1_release/images/499ee7345d2841f7.jpg
#   inflating: c1_release/images/37849965c0121f83.jpg
#   inflating: c1_release/images/d483def10ff85285.jpg
#   inflating: c1_release/images/733062629cbad40c.jpg
#   inflating: c1_release/images/78e1d763746e5d6d.jpg
#   inflating: c1_release/images/c3464e796d93d371.jpg
#   inflating: c1_release/images/9e8a43573265df2e.jpg
#   inflating: c1_release/images/6543570776d4f7f5.jpg
#   inflating: c1_release/images/7d1609cbaf08afa0.jpg
#   inflating: c1_release/images/3a235e5e7212c569.jpg
#   inflating: c1_release/images/c0fc67c541693fd0.jpg
#   inflating: c1_release/images/1a18380d69182ce1.jpg
#   inflating: c1_release/images/3018817fb738da56.jpg
#   inflating: c1_release/images/3777383aa4c0448c.jpg
#   inflating: c1_release/images/43ade7d3afb6ca4c.jpg
#   inflating: c1_release/images/3d3cc3d279b6aca7.jpg
#   inflating: c1_release/images/ca746f4b4ba2082f.jpg
#   inflating: c1_release/images/66223abe6f20e61b.jpg
#   inflating: c1_release/images/6dd556c6ec5617a7.jpg
#   inflating: c1_release/images/e1f190b6baf241e8.jpg
#   inflating: c1_release/images/8798633e8c86ea26.jpg
#   inflating: c1_release/images/557ed5bb76024921.jpg
#   inflating: c1_release/images/9522993bd6b7bc2b.jpg
#   inflating: c1_release/images/1729354c589c3da5.jpg
#   inflating: c1_release/images/acdc1689738cc394.jpg
#   inflating: c1_release/images/3107d746d0df0af0.jpg
#   inflating: c1_release/images/008b726d2abe8a3c.jpg
#   inflating: c1_release/images/067b2b47862db52b.jpg
#   inflating: c1_release/images/bc9196272a845ff7.jpg
#   inflating: c1_release/images/1797f4e85e52bc5a.jpg
#   inflating: c1_release/images/b9dacbbed9698edb.jpg
#   inflating: c1_release/images/aa4706abffc45dba.jpg
#   inflating: c1_release/images/2e00666c4a47161e.jpg
#   inflating: c1_release/images/265737752aae7733.jpg
#   inflating: c1_release/images/667a9ed793ef6b22.jpg
#   inflating: c1_release/images/5288dd90c2c98dd4.jpg
#   inflating: c1_release/images/b9d62d2f34ff822c.jpg
#   inflating: c1_release/images/1f43386eab883567.jpg
#   inflating: c1_release/images/2bda01f24b444793.jpg
#   inflating: c1_release/images/3d8f72f7790d1acd.jpg
#   inflating: c1_release/images/6591136bd2c5bf6f.jpg
#   inflating: c1_release/images/dc49d80adc91b600.jpg
#   inflating: c1_release/images/c335c853165441cd.jpg
#   inflating: c1_release/images/05c2162593cbad93.jpg
#   inflating: c1_release/images/33aa037d6d45705d.jpg
#   inflating: c1_release/images/f450a2a6387fdce5.jpg
#   inflating: c1_release/images/d79ab0a0b37fb252.jpg
#   inflating: c1_release/images/2192d1ffb1857fc0.jpg
#   inflating: c1_release/images/03865f70b4ff8131.jpg
#   inflating: c1_release/images/b7099f05bfd42546.jpg
#   inflating: c1_release/images/810d0ac56ce4f1b5.jpg
#   inflating: c1_release/images/f982732a2d007f06.jpg
#   inflating: c1_release/images/5c45a60b58aa63b6.jpg
#   inflating: c1_release/images/0faa0a356b2b084a.jpg
#   inflating: c1_release/images/5279c768b9774947.jpg
#   inflating: c1_release/images/b28f93dead8a6f6b.jpg
#   inflating: c1_release/images/02d32e145bda69ba.jpg
#   inflating: c1_release/images/46df4ca3cbd75fca.jpg
#   inflating: c1_release/images/eca3a80e5c85e87e.jpg
#   inflating: c1_release/images/420b65a5bbe1ccc5.jpg
#   inflating: c1_release/images/20a2e1b511192fa1.jpg
#   inflating: c1_release/images/c9da0cdb522edae1.jpg
#   inflating: c1_release/images/d825c39588c3d7e0.jpg
#   inflating: c1_release/images/551494977032df7f.jpg
#   inflating: c1_release/images/c061a726efa20894.jpg
#   inflating: c1_release/images/63db28256dfe650d.jpg
#   inflating: c1_release/images/d6da7d5d1f023491.jpg
#   inflating: c1_release/images/d0d4988552d744cb.jpg
#   inflating: c1_release/images/1c612a217a32c6d5.jpg
#   inflating: c1_release/images/d291c4ef4426f7a6.jpg
#   inflating: c1_release/images/998f5cfc4345ced4.jpg
#   inflating: c1_release/images/993743635f966e13.jpg
#   inflating: c1_release/images/dfa29f30e2113c03.jpg
#   inflating: c1_release/images/f2e54595887013ce.jpg
#   inflating: c1_release/images/7192d60ddc256e6d.jpg
#   inflating: c1_release/images/63844e147b40d27b.jpg
#   inflating: c1_release/images/650f322092461837.jpg
#   inflating: c1_release/images/c142100989f608a8.jpg
#   inflating: c1_release/images/eca8fffbe8eef505.jpg
#   inflating: c1_release/images/1307e1ccdd1c0706.jpg
#   inflating: c1_release/images/20448cbfcdfe3faf.jpg
#   inflating: c1_release/images/bf6c57a56afa5b2d.jpg
#   inflating: c1_release/images/36f0775c399aaefb.jpg
#   inflating: c1_release/images/6f27e05dad2f7941.jpg
#   inflating: c1_release/images/619fc1745f4a2594.jpg
#   inflating: c1_release/images/c9922aadf7799998.jpg
#   inflating: c1_release/images/a91d41ef22ee14df.jpg
#   inflating: c1_release/images/58d5df080ccb1766.jpg
#   inflating: c1_release/images/d7f84a5e66311e3c.jpg
#   inflating: c1_release/images/e33ad3c49e762a20.jpg
#   inflating: c1_release/images/0a24363fd369f0b9.jpg
#   inflating: c1_release/images/bacdfe5548c778f6.jpg
#   inflating: c1_release/images/01c7ecddc932e281.jpg
#   inflating: c1_release/images/c40bbac31966e46f.jpg
#   inflating: c1_release/images/975dcb6565b861f5.jpg
#   inflating: c1_release/images/70fa6b059e922cfb.jpg
#   inflating: c1_release/images/1e775b2ac11d7160.jpg
#   inflating: c1_release/images/d4684b45f871f23c.jpg
#   inflating: c1_release/images/5ac213be01e7bf1d.jpg
#   inflating: c1_release/images/913edb34bf0e0e92.jpg
#   inflating: c1_release/images/1688723201a7b440.jpg
#   inflating: c1_release/images/bbc972b63f5a3d96.jpg
#   inflating: c1_release/images/9d42f8bd77a2011a.jpg
#   inflating: c1_release/images/69d7915107cf7cbe.jpg
#   inflating: c1_release/images/c633ff2caa4f6435.jpg
#   inflating: c1_release/images/c96fa4dcb4f1cf30.jpg
#   inflating: c1_release/images/a4d5c2891da824a1.jpg
#   inflating: c1_release/images/0111926f53db2f0c.jpg
#   inflating: c1_release/images/f50eb6944435cab3.jpg
#   inflating: c1_release/images/2061417a29ace2b2.jpg
#   inflating: c1_release/images/41aeee7a6d2dc338.jpg
#   inflating: c1_release/images/2679ebf33131bb8a.jpg
#   inflating: c1_release/images/680daeb4d6e9494c.jpg
#   inflating: c1_release/images/9043c5e29e5d49a7.jpg
#   inflating: c1_release/images/c52176a79e475237.jpg
#   inflating: c1_release/images/bf631e454f8286d6.jpg
#   inflating: c1_release/images/818c36d0b603e096.jpg
#   inflating: c1_release/images/13e44917ec1d8b11.jpg
#   inflating: c1_release/images/017f5c44f832d181.jpg
#   inflating: c1_release/images/1fd7a6827cf3fec3.jpg
#   inflating: c1_release/images/5427c3fd7d227dd1.jpg
#   inflating: c1_release/images/c7cabb0aceacfbf3.jpg
#   inflating: c1_release/images/d5351f9212ed82d9.jpg
#   inflating: c1_release/images/936552f2f3f027ed.jpg
#   inflating: c1_release/images/e1c49a6291d7662a.jpg
#   inflating: c1_release/images/763eb659f24f23cb.jpg
#   inflating: c1_release/images/14a8ac1d26af0a5b.jpg
#   inflating: c1_release/images/067469e582067fa8.jpg
#   inflating: c1_release/images/dee95bc9146cc61a.jpg
#   inflating: c1_release/images/0d56d5df19e6f132.jpg
#   inflating: c1_release/images/1654984f61b0de3b.jpg
#   inflating: c1_release/images/011f9a9e4f5507b0.jpg
#   inflating: c1_release/images/f293fe844c854266.jpg
#   inflating: c1_release/images/5131fffd972286b9.jpg
#   inflating: c1_release/images/82a086d82a06a105.jpg
#   inflating: c1_release/images/2b2be9046a734b6f.jpg
#   inflating: c1_release/images/986d83f3fb033092.jpg
#   inflating: c1_release/images/380756c0750ab15b.jpg
#   inflating: c1_release/images/f5fc5eb3275f3c74.jpg
#   inflating: c1_release/images/b90ade89c3bdb8d3.jpg
#   inflating: c1_release/images/8721f66dd58d6cfb.jpg
#   inflating: c1_release/images/183d59bd018fd4c7.jpg
#   inflating: c1_release/images/81b4dae7b9b41d60.jpg
#   inflating: c1_release/images/432441900bbb94ad.jpg
#   inflating: c1_release/images/ddf779353fba5886.jpg
#   inflating: c1_release/images/a2964485110a7ea1.jpg
#   inflating: c1_release/images/240d1f8d6983b9b9.jpg
#   inflating: c1_release/images/44a4eed65a52d6d6.jpg
#   inflating: c1_release/images/bada3367ce4f410b.jpg
#   inflating: c1_release/images/b50fca5e367b7951.jpg
#   inflating: c1_release/images/d8ae1df51fb58598.jpg
#   inflating: c1_release/images/ad06fbc665776899.jpg
#   inflating: c1_release/images/a743ed1fcddfa0e8.jpg
#   inflating: c1_release/images/b86fa94eda8a4614.jpg
#   inflating: c1_release/images/081949bdb9dac0c1.jpg
#   inflating: c1_release/images/8e1a2cb0278ac82d.jpg
#   inflating: c1_release/images/771a333bdab1bc70.jpg
#   inflating: c1_release/images/b71801006f840739.jpg
#   inflating: c1_release/images/04b7abbc5a6a39a8.jpg
#   inflating: c1_release/images/0991a6b74935b991.jpg
#   inflating: c1_release/images/97f69afb74e5ca74.jpg
#   inflating: c1_release/images/649c65b7148aff68.jpg
#   inflating: c1_release/images/2f7a73cee4e20888.jpg
#   inflating: c1_release/images/c94f0beeca18fdeb.jpg
#   inflating: c1_release/images/bbe1295eff7e8682.jpg
#   inflating: c1_release/images/47c7a0a7647d69d6.jpg
#   inflating: c1_release/images/d58305a34eabd361.jpg
#   inflating: c1_release/images/c75d6743771fd1d2.jpg
#   inflating: c1_release/images/96ec6586d124284f.jpg
#   inflating: c1_release/images/400bc9e0aed700ec.jpg
#   inflating: c1_release/images/d2f4c8970ce31313.jpg
#   inflating: c1_release/images/c112ed6de53ae44c.jpg
#   inflating: c1_release/images/3ca1729e4c65490f.jpg
#   inflating: c1_release/images/7e850fdba2f0f538.jpg
#   inflating: c1_release/images/b3c54d1f1b997999.jpg
#   inflating: c1_release/images/d346b84fa5703f5a.jpg
#   inflating: c1_release/images/949b92d97570b902.jpg
#   inflating: c1_release/images/a6334513d2f2ee59.jpg
#   inflating: c1_release/images/6110fdaa36e30eb0.jpg
#   inflating: c1_release/images/892607e1f50e46d8.jpg
#   inflating: c1_release/images/83b786826da0bd21.jpg
#   inflating: c1_release/images/e66db3539cd2df35.jpg
#   inflating: c1_release/images/842f77aac21d2240.jpg
#   inflating: c1_release/images/fa9119aea412d86e.jpg
#   inflating: c1_release/images/df4a81c2acd2d86f.jpg
#   inflating: c1_release/images/aa12329f61ef0178.jpg
#   inflating: c1_release/images/626019a1af94951e.jpg
#   inflating: c1_release/images/dc56d25146c9e70b.jpg
#   inflating: c1_release/images/c1b1ae2a2b153c67.jpg
#   inflating: c1_release/images/be64d2824a0c7812.jpg
#   inflating: c1_release/images/57ee1c1184f55344.jpg
#   inflating: c1_release/images/e46cff5b286a860c.jpg
#   inflating: c1_release/images/d448c253f51570ff.jpg
#   inflating: c1_release/images/91b8c149315b1d28.jpg
#   inflating: c1_release/images/84237cc9147d22b3.jpg
#   inflating: c1_release/images/c0497922a175b3a5.jpg
#   inflating: c1_release/images/deb6a8b3f8140271.jpg
#   inflating: c1_release/images/06e43e81ff4d9264.jpg
#   inflating: c1_release/images/b580551f72fc5f74.jpg
#   inflating: c1_release/images/84c3840d76658917.jpg
#   inflating: c1_release/images/f744000312937b1c.jpg
#   inflating: c1_release/images/6007b7c2347ebb6b.jpg
#   inflating: c1_release/images/a2ec3cc038c1f3f9.jpg
#   inflating: c1_release/images/027aa105d464ccbf.jpg
#   inflating: c1_release/images/e98886bb8554617e.jpg
#   inflating: c1_release/images/749baee3ff668ee5.jpg
#   inflating: c1_release/images/1d1261d3d045d57c.jpg
#   inflating: c1_release/images/83786101185f59eb.jpg
#   inflating: c1_release/images/8ddcb332c08b4d8a.jpg
#   inflating: c1_release/images/fd5860bda0401b83.jpg
#   inflating: c1_release/images/4526914f6954d678.jpg
#   inflating: c1_release/images/c9e808f0379c3f98.jpg
#   inflating: c1_release/images/45c0c6a246971a04.jpg
#   inflating: c1_release/images/d462e2dad14e4dba.jpg
#   inflating: c1_release/images/56dbf71b5bcb70a8.jpg
#   inflating: c1_release/images/425699d2431a75e4.jpg
#   inflating: c1_release/images/9ec6dd1900c89533.jpg
#   inflating: c1_release/images/0a2a47cfbb2bc25c.jpg
#   inflating: c1_release/images/4f375b2f557d8c32.jpg
#   inflating: c1_release/images/ad13116fc9aae6ba.jpg
#   inflating: c1_release/images/caec67fad9bfe0f8.jpg
#   inflating: c1_release/images/991870170c216176.jpg
#   inflating: c1_release/images/6676ded7f36dc589.jpg
#   inflating: c1_release/images/61ed4a80fec576de.jpg
#   inflating: c1_release/images/a1c581a56342be93.jpg
#   inflating: c1_release/images/00bb938225f875d4.jpg
#   inflating: c1_release/images/6d4404e00d879d25.jpg
#   inflating: c1_release/images/153ab7a437141388.jpg
#   inflating: c1_release/images/02d506cd4285ec21.jpg
#   inflating: c1_release/images/e5c9d20001890d69.jpg
#   inflating: c1_release/images/c975e85caf870c1f.jpg
#   inflating: c1_release/images/455bb8f48f22aa88.jpg
#   inflating: c1_release/images/dd3df75cfd133ae8.jpg
#   inflating: c1_release/images/de97ec026fe10214.jpg
#   inflating: c1_release/images/11be4823f755e652.jpg
#   inflating: c1_release/images/32407463dc179e34.jpg
#   inflating: c1_release/images/e6d7e23837d1c90a.jpg
#   inflating: c1_release/images/beee2329e14c354d.jpg
#   inflating: c1_release/images/564b21232b0ad5db.jpg
#   inflating: c1_release/images/ffa18124f949beee.jpg
#   inflating: c1_release/images/d092bb45cca7da5e.jpg
#   inflating: c1_release/images/967ee86ad1e703db.jpg
#   inflating: c1_release/images/4fcc8c4516d805f1.jpg
#   inflating: c1_release/images/90d149216addfabc.jpg
#   inflating: c1_release/images/69ab5ed9f1480aff.jpg
#   inflating: c1_release/images/bdb9f9df06f95529.jpg
#   inflating: c1_release/images/df6790f8fd32daac.jpg
#   inflating: c1_release/images/e1195ecd0b7ed69d.jpg
#   inflating: c1_release/images/05345cabb6a8c12f.jpg
#   inflating: c1_release/images/f548917dc25c5b31.jpg
#   inflating: c1_release/images/14c6eed0d1db6d2d.jpg
#   inflating: c1_release/images/0f38a2302b0984dd.jpg
#   inflating: c1_release/images/80b00b66a8aca986.jpg
#   inflating: c1_release/images/17a1e84bf33c50aa.jpg
#   inflating: c1_release/images/00b68ff0919c939a.jpg
#   inflating: c1_release/images/a1162a0ad3891170.jpg
#   inflating: c1_release/images/86f44fa67f4f0eb3.jpg
#   inflating: c1_release/images/e4df66f1e0b371f8.jpg
#   inflating: c1_release/images/d0db040e80278066.jpg
#   inflating: c1_release/images/b66a224c7e152317.jpg
#   inflating: c1_release/images/1483ab6a11c30a5a.jpg
#   inflating: c1_release/images/2220d5ec5d81fcaf.jpg
#   inflating: c1_release/images/8defa9caf4699c08.jpg
#   inflating: c1_release/images/bb5c5ed8194458cf.jpg
#   inflating: c1_release/images/6152b780f3c996b1.jpg
#   inflating: c1_release/images/dc3e1a616da54fe4.jpg
#   inflating: c1_release/images/01265fe7ce2ee6ff.jpg
#   inflating: c1_release/images/a0e7de6035c55b73.jpg
#   inflating: c1_release/images/02346291da2bec37.jpg
#   inflating: c1_release/images/2995241cf49c4e25.jpg
#   inflating: c1_release/images/56925a422b0dbd97.jpg
#   inflating: c1_release/images/11a62efbfb84a790.jpg
#   inflating: c1_release/images/201262624ca1aa01.jpg
#   inflating: c1_release/images/0e657218bf0375bf.jpg
#   inflating: c1_release/images/d932c98eac22815c.jpg
#   inflating: c1_release/images/4e05e6ad0f636d5a.jpg
#   inflating: c1_release/images/daf1511191bfbfd6.jpg
#   inflating: c1_release/images/218fb0e9888f061d.jpg
#   inflating: c1_release/images/8e0fdaf1bb4ecd52.jpg
#   inflating: c1_release/images/cfdbd23128ff6388.jpg
#   inflating: c1_release/images/3ea0cccd9f14a34a.jpg
#   inflating: c1_release/images/eef59da84ca47a36.jpg
#   inflating: c1_release/images/1396e51b6c8eea64.jpg
#   inflating: c1_release/images/502d881499fd8cf9.jpg
#   inflating: c1_release/images/ed7968c387a37664.jpg
#   inflating: c1_release/images/b028373a3ad234e8.jpg
#   inflating: c1_release/images/c23301ec754d6c74.jpg
#   inflating: c1_release/images/fefe38527ef461ea.jpg
#   inflating: c1_release/images/a23a55ad58603ff9.jpg
#   inflating: c1_release/images/39f4dfb46559f887.jpg
#   inflating: c1_release/images/f0f123d6cfe30726.jpg
#   inflating: c1_release/images/4f9e4ab37f1e7c9f.jpg
#   inflating: c1_release/images/c12f661e4a86c25a.jpg
#   inflating: c1_release/images/db950745aee2ead2.jpg
#   inflating: c1_release/images/a3082e90b7732df1.jpg
#   inflating: c1_release/images/5c5bd7f3ea77b5be.jpg
#   inflating: c1_release/images/2401c86768d83888.jpg
#   inflating: c1_release/images/7131fb0ce7595205.jpg
#   inflating: c1_release/images/e9c882effb3326e9.jpg
#   inflating: c1_release/images/4332899378a3c778.jpg
#   inflating: c1_release/images/1e28d92c0edc5dca.jpg
#   inflating: c1_release/images/ae1ab29eb10752ea.jpg
#   inflating: c1_release/images/e418d99d2152cc71.jpg
#   inflating: c1_release/images/f7e323226bb5efce.jpg
#   inflating: c1_release/images/682c2f6cd892e53b.jpg
#   inflating: c1_release/images/d399e2e9fe6c46ac.jpg
#   inflating: c1_release/images/2f72821d59f3c21a.jpg
#   inflating: c1_release/images/43c7ff42582bbb1c.jpg
#   inflating: c1_release/images/48a1be34abf456fb.jpg
#   inflating: c1_release/images/9a2e32b93cda0092.jpg
#   inflating: c1_release/images/9cb799af74ec55a7.jpg
#   inflating: c1_release/images/16f5ef7987f11cd4.jpg
#   inflating: c1_release/images/b290b40954071bd9.jpg
#   inflating: c1_release/images/c8a3448702b5c3b2.jpg
#   inflating: c1_release/images/c8dd8f02d3a37816.jpg
#   inflating: c1_release/images/60d69872c2ab494d.jpg
#   inflating: c1_release/images/c3cff23c1af5a2ad.jpg
#   inflating: c1_release/images/8942969b9e0990e0.jpg
#   inflating: c1_release/images/4793b68e74a43fc0.jpg
#   inflating: c1_release/images/b818a239d142d866.jpg
#   inflating: c1_release/images/11eeeb35eb045cb1.jpg
#   inflating: c1_release/images/abe81cc5ff0910ae.jpg
#   inflating: c1_release/images/c7a56fa014298c6c.jpg
#   inflating: c1_release/images/2556269f3926832e.jpg
#   inflating: c1_release/images/b991e80e4f52d6d6.jpg
#   inflating: c1_release/images/641d7197636ab4a4.jpg
#   inflating: c1_release/images/6f61d40e0902f0c0.jpg
#   inflating: c1_release/images/af17bdd916591bc9.jpg
#   inflating: c1_release/images/fb1c492ffad0006b.jpg
#   inflating: c1_release/images/e7a6312d44e0a77e.jpg
#   inflating: c1_release/images/ddee21d2ffff3e21.jpg
#   inflating: c1_release/images/16453a60a2d6ca7b.jpg
#   inflating: c1_release/images/f4a033d88e81fc5e.jpg
#   inflating: c1_release/images/c9ed923a87195d93.jpg
#   inflating: c1_release/images/fb92ddaca4ea6127.jpg
#   inflating: c1_release/images/544e743e195a518c.jpg
#   inflating: c1_release/images/d09b5eca26643045.jpg
#   inflating: c1_release/images/e7d42a0429313d20.jpg
#   inflating: c1_release/images/6795bb2c553f4981.jpg
#   inflating: c1_release/images/6a2464e92c4e6e93.jpg
#   inflating: c1_release/images/9365b5feea7a3918.jpg
#   inflating: c1_release/images/ceefee01c11d960e.jpg
#   inflating: c1_release/images/e1de3989d775edcd.jpg
#   inflating: c1_release/images/2e1037da0637e4d6.jpg
#   inflating: c1_release/images/faa5db1b4c6558be.jpg
#   inflating: c1_release/images/639004eedd625737.jpg
#   inflating: c1_release/images/eeccc005d01e5e70.jpg
#   inflating: c1_release/images/660a65e2285067e5.jpg
#   inflating: c1_release/images/29a1cc46b9fb02f4.jpg
#   inflating: c1_release/images/b4d49948eeef4523.jpg
#   inflating: c1_release/images/c0782d2d278b3226.jpg
#   inflating: c1_release/images/a04863ae73bf2a0e.jpg
#   inflating: c1_release/images/5654de4d6d767773.jpg
#   inflating: c1_release/images/17d24eddde4245f8.jpg
#   inflating: c1_release/images/91fa748ac28d6875.jpg
#   inflating: c1_release/images/e26fea90d5ea0d58.jpg
#   inflating: c1_release/images/e53808cb77b6350e.jpg
#   inflating: c1_release/images/79dfa0bc1cec7b5e.jpg
#   inflating: c1_release/images/0ac3fc65e09d143c.jpg
#   inflating: c1_release/images/db371ca17c532605.jpg
#   inflating: c1_release/images/a2f2050ebeb597a2.jpg
#   inflating: c1_release/images/a81851ba1a88cccb.jpg
#   inflating: c1_release/images/25cfe36c5346410a.jpg
#   inflating: c1_release/images/c4a1c033172f4395.jpg
#   inflating: c1_release/images/de5b2bbed01fd231.jpg
#   inflating: c1_release/images/66ac1bcbc8ffa63c.jpg
#   inflating: c1_release/images/c63fe18225fb9776.jpg
#   inflating: c1_release/images/19fb7a6513c5f8c3.jpg
#   inflating: c1_release/images/29ab07bcabb98c99.jpg
# ...
#   inflating: c1_release/images/a32f334d68931517.jpg
#   inflating: c1_release/images/2b4d16e4ea02e35d.jpg
#   inflating: c1_release/images/756394a48b7c70ea.jpg
#   inflating: c1_release/images/d58c8cbcaf792124.jpg
#   inflating: c1_release/images/6ef09bb629ee8f2d.jpg
#   inflating: c1_release/images/2cd124b93e08d137.jpg
#   inflating: c1_release/images/5d2399fe45483838.jpg
#   inflating: c1_release/images/a518ffce01eeb918.jpg
#   inflating: c1_release/images/70470f22b97eb2a0.jpg
#   inflating: c1_release/images/5874193c5fde6a82.jpg
#   inflating: c1_release/images/abfa9cf2d258e4a2.jpg
#   inflating: c1_release/images/738343fa498c9890.jpg
#   inflating: c1_release/images/e7ef55269bcc6bc2.jpg
#   inflating: c1_release/images/43cde7305147ab18.jpg
#   inflating: c1_release/images/e1cde41acdc76be7.jpg
#   inflating: c1_release/images/a475e4545b362d72.jpg
#   inflating: c1_release/images/f2b41ae952b652f9.jpg
#   inflating: c1_release/images/d9de69079725d8a5.jpg
#   inflating: c1_release/images/d1ca61d988b33e07.jpg
#   inflating: c1_release/images/27ae72ac09992207.jpg
#   inflating: c1_release/images/24fc40c0ce5b9719.jpg
#   inflating: c1_release/images/1c12c448ab689b61.jpg
#   inflating: c1_release/images/009b10ebcb3b20c8.jpg
#   inflating: c1_release/images/219d7cb2cb90d54b.jpg
#   inflating: c1_release/images/09ba78cf7df90160.jpg
#   inflating: c1_release/images/aa40160418044eb0.jpg
#   inflating: c1_release/images/10d7b747dd5bd41f.jpg
#   inflating: c1_release/images/eaa0a46feb588242.jpg
#   inflating: c1_release/images/0040d7f1676ab75c.jpg
#   inflating: c1_release/images/ba0afeb7df37dd3c.jpg
#   inflating: c1_release/images/370e5b88f0e3802e.jpg
#   inflating: c1_release/images/5ab58c90342535d6.jpg
#   inflating: c1_release/images/a087282117886e38.jpg
#   inflating: c1_release/images/052fd0dcf6743b11.jpg
#   inflating: c1_release/images/c2f5661dfc8e2be4.jpg
#   inflating: c1_release/images/80a243fcfe2563b7.jpg
#   inflating: c1_release/images/bc20446868787e3b.jpg
#   inflating: c1_release/images/cc766c4445b46fa4.jpg
#   inflating: c1_release/images/771f6424b2597346.jpg
#   inflating: c1_release/images/c24e59385000a1ac.jpg
#   inflating: c1_release/images/0eb4b3c6b866e473.jpg
#   inflating: c1_release/images/b014b503012b95ee.jpg
#   inflating: c1_release/images/1f78be9996406750.jpg
#   inflating: c1_release/images/04c9ac834bd9491d.jpg
#   inflating: c1_release/images/f1b7b6f19f6648e7.jpg
#   inflating: c1_release/images/c5abd4840a3cdcf4.jpg
#   inflating: c1_release/images/0f1f4941e20c34d9.jpg
#   inflating: c1_release/images/c68558fdf545a47e.jpg
#   inflating: c1_release/images/8101b1c8c908313e.jpg
#   inflating: c1_release/images/3147abc745a8e37e.jpg
#   inflating: c1_release/images/c7b049cb92457c60.jpg
#   inflating: c1_release/images/26968e53c0880926.jpg
#   inflating: c1_release/images/ce480e618aff9d8e.jpg
#   inflating: c1_release/images/e8551daa3ee58a04.jpg
#   inflating: c1_release/images/81b4981a29b092f6.jpg
#   inflating: c1_release/images/040e18db3113355b.jpg
#   inflating: c1_release/images/6e448f66e97b2298.jpg
#   inflating: c1_release/images/1ae560feac00939e.jpg
#   inflating: c1_release/images/8efb57d780fc1dee.jpg
#   inflating: c1_release/images/b23157738e1d1b2b.jpg
#   inflating: c1_release/images/98ee0fec42cbeca6.jpg
#   inflating: c1_release/images/c76a6767f20fa1a1.jpg
#   inflating: c1_release/images/92da6e5cb8134526.jpg
#   inflating: c1_release/images/3529bb22f2160c47.jpg
#   inflating: c1_release/images/057ec45bce2dc44d.jpg
#   inflating: c1_release/images/e3691b9ef64eedc6.jpg
#   inflating: c1_release/images/c286bad1e06f9c84.jpg
#   inflating: c1_release/images/a2d4e8b1dd6c7283.jpg
#   inflating: c1_release/images/1f2ce2daae21098c.jpg
#   inflating: c1_release/images/00fe71a3b0a6f666.jpg
#   inflating: c1_release/images/afa9916c52d5ebf4.jpg
#   inflating: c1_release/images/b1c09534e084cf40.jpg
#   inflating: c1_release/images/1b20709a3d75407e.jpg
#   inflating: c1_release/images/f4ffa9ba01e0d289.jpg
#   inflating: c1_release/images/2350246360828de3.jpg
#   inflating: c1_release/images/2c1bb5ccbd3f50c2.jpg
#   inflating: c1_release/images/0930345451d77e60.jpg
#   inflating: c1_release/images/6048209aafb73de7.jpg
#   inflating: c1_release/images/8f892665e2d4808b.jpg
#   inflating: c1_release/images/729cec59cd308181.jpg
#   inflating: c1_release/images/2e82339f844b5699.jpg
#   inflating: c1_release/images/1da8de7eda7d4f83.jpg
#   inflating: c1_release/images/f26853b922eccf67.jpg
#   inflating: c1_release/images/6c6af8363dd75841.jpg
#   inflating: c1_release/images/e047612d1317aecf.jpg
#   inflating: c1_release/images/68667678c5e1a233.jpg
#   inflating: c1_release/images/668ad6cb4384a5ba.jpg
#   inflating: c1_release/images/0ef80c96aed09a3f.jpg
#   inflating: c1_release/images/ac46abbe00c47e57.jpg
#   inflating: c1_release/images/017684986536c4eb.jpg
#   inflating: c1_release/images/f6719e4a2012dea5.jpg
#   inflating: c1_release/images/150e1b25471404d0.jpg
#   inflating: c1_release/images/f15c2aa25eef4af7.jpg
#   inflating: c1_release/images/bd0ced0ad2f1dc6e.jpg
#   inflating: c1_release/images/a4e6f80a0519343b.jpg
#   inflating: c1_release/images/eb6c11049d5a6fc4.jpg
#   inflating: c1_release/images/d9fa41e1c4ba8394.jpg
#   inflating: c1_release/images/dd234b7042e9d5c8.jpg
#   inflating: c1_release/images/31a0c3de94cfeb55.jpg
#   inflating: c1_release/images/1922f521c6735613.jpg
#   inflating: c1_release/images/00aff39f5b46a575.jpg
#   inflating: c1_release/images/d66eba14e52ceabe.jpg
#   inflating: c1_release/images/18094636c2d7542c.jpg
#   inflating: c1_release/images/b6b62e9ca68bd256.jpg
#   inflating: c1_release/images/b20b2b9ebaf3d356.jpg
#   inflating: c1_release/images/e9431d5f30392f47.jpg
#   inflating: c1_release/images/711db68a4be8d7bc.jpg
#   inflating: c1_release/images/16e358ea8b912f05.jpg
#   inflating: c1_release/images/a408bd4bf4510085.jpg
#   inflating: c1_release/images/039926922eb72dca.jpg
#   inflating: c1_release/images/833598fb3f255517.jpg
#   inflating: c1_release/images/2eb5af2a35755378.jpg
#   inflating: c1_release/images/10049327d9ae85b7.jpg
#   inflating: c1_release/images/bb647b3862ef7cc8.jpg
#   inflating: c1_release/images/29ace6ba90fc039d.jpg
#   inflating: c1_release/images/01463f5494340d3d.jpg
#   inflating: c1_release/images/2898d5619e15af45.jpg
#   inflating: c1_release/images/ba6d77da92642804.jpg
#   inflating: c1_release/images/5061171babf6ab78.jpg
#   inflating: c1_release/images/6632fbd1bfe1ec4e.jpg
#   inflating: c1_release/images/cee24d6da9c6dca2.jpg
#   inflating: c1_release/images/555b86db953090f7.jpg
#   inflating: c1_release/images/4202dad9d123a81a.jpg
#   inflating: c1_release/images/de9455e8b419bb0d.jpg
#   inflating: c1_release/images/36a6e85bfa5e6b1e.jpg
#   inflating: c1_release/images/83c9bcc6bda041d5.jpg
#   inflating: c1_release/images/fffd5bf113b34961.jpg
#   inflating: c1_release/images/e4239e0e7ed4b573.jpg
#   inflating: c1_release/images/2421c5be0e357520.jpg
#   inflating: c1_release/images/018c6cd27e4deb80.jpg
#   inflating: c1_release/images/0b2fe3628cf12870.jpg
#   inflating: c1_release/images/325732216751fab0.jpg
#   inflating: c1_release/images/607e2ff306709888.jpg
#   inflating: c1_release/images/dabce5e2b8518833.jpg
#   inflating: c1_release/images/efea186cfcab99d0.jpg
#   inflating: c1_release/images/3a315985a2706fa8.jpg
#   inflating: c1_release/images/08b64c502035fcfb.jpg
#   inflating: c1_release/images/8e92db9026fcbbef.jpg
#   inflating: c1_release/images/94162125aafcb66c.jpg
#   inflating: c1_release/images/ad53c1846c06b9e8.jpg
#   inflating: c1_release/images/93c7b67d1a3bfdf4.jpg
#   inflating: c1_release/images/7191e319f5cf3ff5.jpg
#   inflating: c1_release/images/a064c48d2b3d8783.jpg
#   inflating: c1_release/images/5e79687dc6906281.jpg
#   inflating: c1_release/images/0a08c8e24385d886.jpg
#   inflating: c1_release/images/09a40ed64c620298.jpg
#   inflating: c1_release/images/df7cf0687009b4f8.jpg
#   inflating: c1_release/images/9f93afb3c0a69cbb.jpg
#   inflating: c1_release/images/c71efd91b31cfb94.jpg
#   inflating: c1_release/images/e48cb0d571893b05.jpg
#   inflating: c1_release/images/2d0304d8663e3c54.jpg
#   inflating: c1_release/images/e37093b89a215a9f.jpg
#   inflating: c1_release/images/004f028530fc447f.jpg
#   inflating: c1_release/images/00729cbff3e95243.jpg
#   inflating: c1_release/images/1f16e3f9627c4538.jpg
#   inflating: c1_release/images/1144357227d92d7a.jpg
#   inflating: c1_release/images/9484f613d2ab167c.jpg
#   inflating: c1_release/images/386b66ffdcd400e0.jpg
#   inflating: c1_release/images/39402152b2877138.jpg
#   inflating: c1_release/images/02878c5f332550a4.jpg
#   inflating: c1_release/images/f1ede48cc063a149.jpg
#   inflating: c1_release/images/1ac450cd43cb4856.jpg
#   inflating: c1_release/images/cbe844af167248c9.jpg
#   inflating: c1_release/images/e0f978489877559b.jpg
#   inflating: c1_release/images/1e83b072e6afb80b.jpg
#   inflating: c1_release/images/dc758f589b3943ae.jpg
#   inflating: c1_release/images/c23141d1db7b977b.jpg
#   inflating: c1_release/images/859acdb553e6125b.jpg
#   inflating: c1_release/images/0167038ff2f74f37.jpg
#   inflating: c1_release/images/135a3772e8021a9b.jpg
#   inflating: c1_release/images/17b3459cd1b2d095.jpg
#   inflating: c1_release/images/20efc4e7bede834c.jpg
#   inflating: c1_release/images/175886d397006877.jpg
#   inflating: c1_release/images/245ff7c3ba90a2a6.jpg
#   inflating: c1_release/images/401ee6d3e9a17e42.jpg
#   inflating: c1_release/images/c0aab486add959b6.jpg
#   inflating: c1_release/images/d9802e7173f8b64a.jpg
#   inflating: c1_release/images/59d584614b5a1f6c.jpg
#   inflating: c1_release/images/4220e0f047742686.jpg
#   inflating: c1_release/images/7c368873d2cc7a51.jpg
#   inflating: c1_release/images/20ceeae447dda13d.jpg
#   inflating: c1_release/images/f2d3a56278e28c87.jpg
#   inflating: c1_release/images/fdac7149f1360ff4.jpg
#   inflating: c1_release/images/9998688851abfa34.jpg
#   inflating: c1_release/images/eccf23c18c0dfd8a.jpg
#   inflating: c1_release/images/ae4b2591b063482c.jpg
#   inflating: c1_release/images/3807a6fbe5159d36.jpg
#   inflating: c1_release/images/13aaf4003bdfa89d.jpg
#   inflating: c1_release/images/c0d5fe7165095dbf.jpg
#   inflating: c1_release/images/0351c91b732780b5.jpg
#   inflating: c1_release/images/3f10bd7b18992b42.jpg
#   inflating: c1_release/images/15b551835173b7ee.jpg
#   inflating: c1_release/images/737a48376a899666.jpg
#   inflating: c1_release/images/f0a3fdf0ae2b0fe8.jpg
#   inflating: c1_release/images/6b7db5139f6ef182.jpg
#   inflating: c1_release/images/9bb8be667aacda30.jpg
#   inflating: c1_release/images/cd5336608ca5173f.jpg
#   inflating: c1_release/images/00cfc4ac9b70768c.jpg
#   inflating: c1_release/images/f05496ba69dac325.jpg
#   inflating: c1_release/images/25880c4f38d01747.jpg
#   inflating: c1_release/images/ab1f0dea4d0cb969.jpg
#   inflating: c1_release/images/e8250a9a97db322c.jpg
#   inflating: c1_release/images/f82b7b49dd7e6250.jpg
#   inflating: c1_release/images/171e8b8685b5df2f.jpg
#   inflating: c1_release/images/b33877688eb41e0c.jpg
#   inflating: c1_release/images/a12bdf1b01069bc0.jpg
#   inflating: c1_release/images/d05ea3ef1b61f1b4.jpg
#   inflating: c1_release/images/00f0f51211309eb7.jpg
#   inflating: c1_release/images/e308782a1f3c044d.jpg
#   inflating: c1_release/images/84536dc3b9c7300c.jpg
#   inflating: c1_release/images/63432b505dbd1510.jpg
#   inflating: c1_release/images/db6120d73c6f0166.jpg
#   inflating: c1_release/images/5744c25ca5748e24.jpg
#   inflating: c1_release/images/cbec94f652cf1646.jpg
#   inflating: c1_release/images/b6cd99a575951641.jpg
#   inflating: c1_release/images/9ef1444657e823fe.jpg
#   inflating: c1_release/images/f3e8654f8128d83c.jpg
#   inflating: c1_release/images/e53be292088804c3.jpg
#   inflating: c1_release/images/29962ff9be724997.jpg
#   inflating: c1_release/images/f78451d5a8c5160f.jpg
#   inflating: c1_release/images/a5e8346410a3c756.jpg
#   inflating: c1_release/images/30dde9cdf5bd33c6.jpg
#   inflating: c1_release/images/bd79d206d5ba197d.jpg
#   inflating: c1_release/images/ce328594214a4741.jpg
#   inflating: c1_release/images/6cfb7e86dc474b5c.jpg
#   inflating: c1_release/images/8c9c4261022f2537.jpg
#   inflating: c1_release/images/1f673c442e5b851a.jpg
#   inflating: c1_release/images/743573ccb7fc3efa.jpg
#   inflating: c1_release/images/b2366a3764e558f2.jpg
#   inflating: c1_release/images/485ec86b50981f16.jpg
#   inflating: c1_release/images/f69cfba57ac0bdc5.jpg
#   inflating: c1_release/images/c0d54bda835cdbc2.jpg
#   inflating: c1_release/images/08083fa30c3f3e79.jpg
#   inflating: c1_release/images/5825ab5ed38e6074.jpg
#   inflating: c1_release/images/902f93620c1d0665.jpg
#   inflating: c1_release/images/722cadb34fad189a.jpg
#   inflating: c1_release/images/8d5b43c63a0fc761.jpg
#   inflating: c1_release/images/9de4f6270bd08744.jpg
#   inflating: c1_release/images/5c32c303fe3cc944.jpg
#   inflating: c1_release/images/e95cb303f757259c.jpg
#   inflating: c1_release/images/bb3d1127d05d8769.jpg
#   inflating: c1_release/images/90bbfc4756462154.jpg
#   inflating: c1_release/images/613f983cee0e77d5.jpg
#   inflating: c1_release/images/da89fc36c2034806.jpg
#   inflating: c1_release/images/370f82ca4634bcbe.jpg
#   inflating: c1_release/images/bc1383071283bcf2.jpg
#   inflating: c1_release/images/dc600dc97f3ffb54.jpg
#   inflating: c1_release/images/4a8facaf31131757.jpg
#   inflating: c1_release/images/b5420e240c302445.jpg
#   inflating: c1_release/images/785c80f415ab5911.jpg
#   inflating: c1_release/images/b45c55a58b20fb0e.jpg
#   inflating: c1_release/images/bc1c915b3d2a5c1b.jpg
#   inflating: c1_release/images/14f80ae705fa954f.jpg
#   inflating: c1_release/images/bffc03ea886a219c.jpg
#   inflating: c1_release/images/585a2a3394bbcc61.jpg
#   inflating: c1_release/images/9c491db9e8f054cd.jpg
#   inflating: c1_release/images/424660424ca6f115.jpg
#   inflating: c1_release/images/0f637ada542e4cbb.jpg
#   inflating: c1_release/images/e8b4e2652a8bad4b.jpg
#   inflating: c1_release/images/d25e0c58c74290ec.jpg
#   inflating: c1_release/images/50db4b93cf58e368.jpg
#   inflating: c1_release/images/009bec3e424b3d83.jpg
#   inflating: c1_release/images/337fc5fbff30138e.jpg
#   inflating: c1_release/images/7253dcb9a219fafe.jpg
#   inflating: c1_release/images/1abbbcc68d68a2ec.jpg
#   inflating: c1_release/images/93ff05253bc9b3ba.jpg
#   inflating: c1_release/images/929be975b5c75978.jpg
#   inflating: c1_release/images/07621394c8ad0b47.jpg
#   inflating: c1_release/images/bfe3049823d9bad5.jpg
#   inflating: c1_release/images/6773df4aeb54e2f5.jpg
#   inflating: c1_release/images/9a8bf2bec0d3c615.jpg
#   inflating: c1_release/images/856effd189801242.jpg
#   inflating: c1_release/images/b1447277b3d16ca7.jpg
#   inflating: c1_release/images/3906e05a09484bc4.jpg
#   inflating: c1_release/images/955f4f5d36cdf36f.jpg
#   inflating: c1_release/images/fe3ed890b6f035e3.jpg
#   inflating: c1_release/images/43c0a0da3b9e1e16.jpg
#   inflating: c1_release/images/85bbca10aab0705f.jpg
#   inflating: c1_release/images/5461e333c9a5925e.jpg
#   inflating: c1_release/images/d3ead6a057b7fc47.jpg
#   inflating: c1_release/images/e8e7147f80f80d75.jpg
#   inflating: c1_release/images/164ff5c07df15d67.jpg
#   inflating: c1_release/images/4660f7c7c2d96fa4.jpg
#   inflating: c1_release/images/867782412469c7de.jpg
#   inflating: c1_release/images/6ca860c09a110014.jpg
#   inflating: c1_release/images/0078bca7eca5120d.jpg
#   inflating: c1_release/images/120ef7bb99fc7ee5.jpg
#   inflating: c1_release/images/e61a4ed0334bc500.jpg
#   inflating: c1_release/images/ce163a0fb7de89c6.jpg
#   inflating: c1_release/images/bba8bae128437caf.jpg
#   inflating: c1_release/images/ac5abf8c7e71af93.jpg
#   inflating: c1_release/images/f42ca54419c0f024.jpg
#   inflating: c1_release/images/fafef762e226cbe7.jpg
#   inflating: c1_release/images/d1e1b8eec032333a.jpg
#   inflating: c1_release/images/a516152520bc04cf.jpg
#   inflating: c1_release/images/7e8d4b96b2461aa7.jpg

# %% [markdown]
# Let's have a look at the dataset and how it is layed down.
#
# The data is structured as follows
# ```
# c1_release/
#   images/
#     0001e6adc4fbab0c.jpg
#     00067fe83e3e21c8.jpg
#     0008ab3d8674f6ca.jpg
#     ...
#   labels.json
#   train.json
#   val.json
# ```
#
# `labels.json` contains the labels for the whole dataset (`train.json` + `val.json`) if you need it.

# %% [markdown]
# ### Defining the Dataset
#
# The [torchvision reference scripts for training object detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
# Additionally, if you want to use aspect ratio grouping during training (so that each batch only contains images with similar aspect ratio), then it is recommended to also implement a `get_height_and_width` method, which returns the height and the width of the image. If this method is not provided, we query all elements of the dataset via `__getitem__` , which loads the image in memory and is slower than if a custom method is provided.
#
# Let's write a `torch.utils.data.Dataset` class for this dataset.

# %%
class TILDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))
        cats = self.coco.loadCats(self.coco.getCatIds())
        self.cat2name = {cat['id']:cat['name'] for cat in cats} # maps category id to category name (useful for visualization)

    def __getitem__(self, index):
        coco = self.coco
        img_id = self.ids[index] # Image ID
        ann_ids = coco.getAnnIds(imgIds=img_id) # get annotation id from coco
        coco_annotation = coco.loadAnns(ann_ids) # target coco_annotation file for an image
        path = coco.loadImgs(img_id)[0]['file_name'] # path for input image
        img = Image.open(os.path.join(self.root, 'images', path)).convert('RGB') # open the input image

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        # Labels
        labels = []
        for i in range(num_objs):
            labels.append(coco_annotation[i]['category_id'])
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Tensorise img_id
        img_id = torch.tensor([img_id])

        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        target["area"] = areas
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.ids)

# %% [markdown]
# That's all for the dataset. Let's see how the outputs are structured for this dataset

# %%
til_root = "/content/c1_release/" # extracted training dataset path
train_annotation = os.path.join(til_root, "train.json")
val_annotation = os.path.join(til_root, "val.json")

dataset = TILDataset(til_root, train_annotation)
dataset[30]
# Out:
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# (<PIL.Image.Image image mode=RGB size=1024x683 at 0x7F71DDA44210>,
#  {'area': tensor([ 77211., 309760.]),
#   'boxes': tensor([[658., 309., 865., 682.],
#           [ 69., 170., 674., 682.]]),
#   'image_id': tensor([31]),
#   'iscrowd': tensor([0, 0]),
#   'labels': tensor([4, 4])})

# %% [markdown]
# So we can see that by default, the dataset returns a `PIL.Image` and a dictionary containing several fields, including `boxes` and `labels`.
#
# Let's next look at one example from the training set.

# %%
source_img, img_annots = dataset[13]
draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=850x1024 at 0x7F717DF346D0>

# %% [markdown]
# ## Visualization of results
#
# Now that training has finished, let's have a look at what it actually predicts.

# %%
# pick one image from the validation set
img, _ = val_dataset[13]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-166445ce46ae> in <module>()
#       1 # pick one image from the validation set
# ----> 2 img, _ = val_dataset[13]
#       3
#       4 model.eval()
#       5 with torch.no_grad():
#
# NameError: name 'val_dataset' is not defined

# %% [markdown]
# Printing the prediction shows that we have a list of dictionaries. Each element of the list corresponds to a different image. As we have a single image, there is a single dictionary in the list.
# The dictionary contains the predictions for the image we passed. In this case, we can see that it contains `boxes`, `labels`, and `scores` as fields.
#
# Let's inspect the image and the predicted boxes.
# For that, we need to convert the image, which has been rescaled to 0-1 and had the channels flipped so that we have it in `[C, H, W]` format.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

img_preds = prediction[0]
for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}: {score}'
    draw.text((x1+5, y1+5), text)

display(pred_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0a2ad73719f2> in <module>()
#       1 # convert the image, which has been rescaled to 0-1 and had the channels flipped
# ----> 2 pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
#       3 draw = ImageDraw.Draw(pred_img)
#       4
#       5 img_preds = prediction[0]
#
# NameError: name 'img' is not defined

# %%
img_preds = prediction[0]
keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f499b2b54ea9> in <module>()
# ----> 1 img_preds = prediction[0]
#       2 keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])
#
# NameError: name 'prediction' is not defined

# %% [markdown]
# Load Model Weights

# %%
# hyper-parameters
params = {'BATCH_SIZE': 20,
          'LR': 0.005,
          'CLASSES': 6,
          'MAXEPOCHS': 20,
          'BACKBONE': 'resnet101',
          'FPN': True,
          'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
          'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
          'MIN_SIZE': 512,
          'MAX_SIZE': 512,
          'IMG_MEAN': [0.485, 0.456, 0.406],
          'IMG_STD': [0.229, 0.224, 0.225],
          'IOU_THRESHOLD': 0.5
          }

# %%
def get_resnet_backbone(backbone_name: str):
    """
    Returns a resnet backbone pretrained on ImageNet.
    Removes the average-pooling layer and the linear layer at the end.
    """
    if backbone_name == 'resnet18':
        pretrained_model = models.resnet18(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet34':
        pretrained_model = models.resnet34(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet50':
        pretrained_model = models.resnet50(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet101':
        pretrained_model = models.resnet101(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet152':
        pretrained_model = models.resnet152(pretrained=True, progress=False)
        out_channels = 2048

    backbone = torch.nn.Sequential(*list(pretrained_model.children())[:-2])
    backbone.out_channels = out_channels

    return backbone

# %%
def get_resnet_fpn_backbone(backbone_name: str):
    """
    Returns a specified ResNet backbone with FPN pretrained on ImageNet.
    """
    return resnet_fpn_backbone(backbone_name, pretrained=True, trainable_layers=3)

# %%
def get_anchor_generator(anchor_size: Tuple[tuple] = None, aspect_ratios: Tuple[tuple] = None):
    """Returns the anchor generator."""
    if anchor_size is None:
        anchor_size = ((16,), (32,), (64,), (128,))
    if aspect_ratios is None:
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_size)

    anchor_generator = AnchorGenerator(sizes=anchor_size,
                                       aspect_ratios=aspect_ratios)
    return anchor_generator

# %%
def get_roi_pool(featmap_names: List[str] = None, output_size: int = 7, sampling_ratio: int = 2):
    """Returns the ROI Pooling"""
    if featmap_names is None:
        # default for resnet with FPN
        featmap_names = ['0', '1', '2', '3']

    roi_pooler = MultiScaleRoIAlign(featmap_names=featmap_names,
                                    output_size=output_size,
                                    sampling_ratio=sampling_ratio)

    return roi_pooler

# %%
def get_fasterRCNN(backbone: torch.nn.Module,
                   anchor_generator: AnchorGenerator,
                   roi_pooler: MultiScaleRoIAlign,
                   num_classes: int,
                   image_mean: List[float] = [0.485, 0.456, 0.406],
                   image_std: List[float] = [0.229, 0.224, 0.225],
                   min_size: int = 512,
                   max_size: int = 1024,
                   **kwargs
                   ):
    """Returns the Faster-RCNN model. Default normalization: ImageNet"""
    model = FasterRCNN(backbone=backbone,
                       rpn_anchor_generator=anchor_generator,
                       box_roi_pool=roi_pooler,
                       num_classes=num_classes,
                       image_mean=image_mean,  # ImageNet
                       image_std=image_std,  # ImageNet
                       min_size=min_size,
                       max_size=max_size,
                       **kwargs
                       )
    model.num_classes = num_classes
    model.image_mean = image_mean
    model.image_std = image_std
    model.min_size = min_size
    model.max_size = max_size

    return model

# %%
def get_fasterRCNN_resnet(num_classes: int,
                          backbone_name: str,
                          anchor_size: List[float],
                          aspect_ratios: List[float],
                          fpn: bool = True,
                          min_size: int = 512,
                          max_size: int = 1024,
                          **kwargs
                          ):
    """Returns the Faster-RCNN model with resnet backbone with and without fpn."""

    # Backbone
    if fpn:
        backbone = get_resnet_fpn_backbone(backbone_name=backbone_name)
    else:
        backbone = get_resnet_backbone(backbone_name=backbone_name)

    # Anchors
    anchor_size = anchor_size
    aspect_ratios = aspect_ratios * len(anchor_size)
    anchor_generator = get_anchor_generator(anchor_size=anchor_size, aspect_ratios=aspect_ratios)

    # ROI Pool
    with torch.no_grad():
        backbone.eval()
        random_input = torch.rand(size=(1, 3, 512, 512))
        features = backbone(random_input)

    if isinstance(features, torch.Tensor):
        from collections import OrderedDict

        features = OrderedDict([('0', features)])

    featmap_names = [key for key in features.keys() if key.isnumeric()]

    roi_pool = get_roi_pool(featmap_names=featmap_names)

    # Model
    return get_fasterRCNN(backbone=backbone,
                          anchor_generator=anchor_generator,
                          roi_pooler=roi_pool,
                          num_classes=num_classes,
                          min_size=min_size,
                          max_size=max_size,
                          **kwargs)

# %%
model = get_fasterRCNN_resnet(num_classes=params['CLASSES'],
                              backbone_name=params['BACKBONE'],
                              anchor_size=params['ANCHOR_SIZE'],
                              aspect_ratios=params['ASPECT_RATIOS'],
                              fpn=params['FPN'],
                              min_size=params['MIN_SIZE'],
                              max_size=params['MAX_SIZE'],
                              image_mean=params['IMG_MEAN'],
                              image_std=params['IMG_STD'])

# %%
# load model weights
loadfilename = "c1_weights_"+str(params['BACKBONE'])+"_epochs_"+str(params['MAXEPOCHS'])+"_batchsize_"+str(params['BATCH_SIZE'])+".pth"
load_path = os.path.join(base_folder, loadfilename)
model.load_state_dict(torch.load(load_path))
model.eval()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (7): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (8): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (9): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (10): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (11): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (12): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (13): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (14): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (15): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (16): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (17): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (18): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (19): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (20): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (21): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (22): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )

# %%
# move model to the right device
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (7): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (8): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (9): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (10): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (11): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (12): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (13): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (14): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (15): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (16): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (17): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (18): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (19): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (20): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (21): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (22): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )

# %%
# construct an optimizer
model_params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(model_params, 
                            lr=params['LR'],
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %% [markdown]
# ## Evaluation on Validation Set
#
# As a sanity check, let's evaluate the model performance on the validation set

# %%
with open(val_annotation) as json_file:
    val_data = json.load(json_file)

model.eval()
detections = []
with torch.no_grad():
    for image in val_data["images"]:
        img_name = image["file_name"]
        img_id = image["id"]

        img = Image.open(os.path.join(til_root, 'images', img_name)).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
filepath = "validation_preds_"+str(params['BACKBONE'])+"_epochs_"+str(params['MAXEPOCHS'])+"_batchsize_"+str(params['BATCH_SIZE'])+".json"
validation_json = os.path.join(base_folder, filepath)
with open(validation_json, 'w') as f:
    json.dump(detections, f)

# %%
# Get evaluation score against validation set to make sure your prediction json file is in the correct format
coco_gt = COCO(val_annotation)
coco_dt = coco_gt.loadRes(validation_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.634
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.729

# %% [markdown]
# ## Generate Predictions on Test Images

# %%
# You should already have uploaded the testing images onto your google drive.

testing_images_path = os.path.join(base_folder, "c1_test_release.zip") # change this path to the zip file for the test images
# !unzip $testing_images_path
# Out:
# Archive:  /content/drive/MyDrive/TIL2021_CV/c1_test_release.zip
# replace c1_test_release/c1_test_sample.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace c1_test_release/c1_test_sample.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: c1_test_release/c1_test_sample.json
#   inflating: c1_test_release/CREDITS.txt
#   inflating: c1_test_release/images/232.jpg
#   inflating: c1_test_release/images/181.jpg
#   inflating: c1_test_release/images/135.jpg
#   inflating: c1_test_release/images/236.jpg
#   inflating: c1_test_release/images/195.jpg
#   inflating: c1_test_release/images/101.jpg
#   inflating: c1_test_release/images/95.jpg
#   inflating: c1_test_release/images/93.jpg
#   inflating: c1_test_release/images/2.jpg
#   inflating: c1_test_release/images/59.jpg
#   inflating: c1_test_release/images/180.jpg
#   inflating: c1_test_release/images/65.jpg
#   inflating: c1_test_release/images/183.jpg
#   inflating: c1_test_release/images/62.jpg
#   inflating: c1_test_release/images/206.jpg
#   inflating: c1_test_release/images/175.jpg
#   inflating: c1_test_release/images/124.jpg
#   inflating: c1_test_release/images/121.jpg
#   inflating: c1_test_release/images/60.jpg
#   inflating: c1_test_release/images/50.jpg
#   inflating: c1_test_release/images/131.jpg
#   inflating: c1_test_release/images/190.jpg
#   inflating: c1_test_release/images/165.jpg
#   inflating: c1_test_release/images/141.jpg
#   inflating: c1_test_release/images/148.jpg
#   inflating: c1_test_release/images/32.jpg
#   inflating: c1_test_release/images/244.jpg
#   inflating: c1_test_release/images/29.jpg
#   inflating: c1_test_release/images/221.jpg
#   inflating: c1_test_release/images/88.jpg
#   inflating: c1_test_release/images/68.jpg
#   inflating: c1_test_release/images/139.jpg
#   inflating: c1_test_release/images/162.jpg
#   inflating: c1_test_release/images/123.jpg
#   inflating: c1_test_release/images/21.jpg
#   inflating: c1_test_release/images/143.jpg
#   inflating: c1_test_release/images/73.jpg
#   inflating: c1_test_release/images/7.jpg
#   inflating: c1_test_release/images/188.jpg
#   inflating: c1_test_release/images/120.jpg
#   inflating: c1_test_release/images/16.jpg
#   inflating: c1_test_release/images/77.jpg
#   inflating: c1_test_release/images/161.jpg
#   inflating: c1_test_release/images/160.jpg
#   inflating: c1_test_release/images/83.jpg
#   inflating: c1_test_release/images/108.jpg
#   inflating: c1_test_release/images/241.jpg
#   inflating: c1_test_release/images/106.jpg
#   inflating: c1_test_release/images/110.jpg
#   inflating: c1_test_release/images/18.jpg
#   inflating: c1_test_release/images/140.jpg
#   inflating: c1_test_release/images/138.jpg
#   inflating: c1_test_release/images/156.jpg
#   inflating: c1_test_release/images/173.jpg
#   inflating: c1_test_release/images/111.jpg
#   inflating: c1_test_release/images/14.jpg
#   inflating: c1_test_release/images/185.jpg
#   inflating: c1_test_release/images/220.jpg
#   inflating: c1_test_release/images/39.jpg
#   inflating: c1_test_release/images/197.jpg
#   inflating: c1_test_release/images/109.jpg
#   inflating: c1_test_release/images/56.jpg
#   inflating: c1_test_release/images/91.jpg
#   inflating: c1_test_release/images/105.jpg
#   inflating: c1_test_release/images/231.jpg
#   inflating: c1_test_release/images/219.jpg
#   inflating: c1_test_release/images/149.jpg
#   inflating: c1_test_release/images/52.jpg
#   inflating: c1_test_release/images/203.jpg
#   inflating: c1_test_release/images/126.jpg
#   inflating: c1_test_release/images/51.jpg
#   inflating: c1_test_release/images/154.jpg
#   inflating: c1_test_release/images/87.jpg
#   inflating: c1_test_release/images/174.jpg
#   inflating: c1_test_release/images/125.jpg
#   inflating: c1_test_release/images/147.jpg
#   inflating: c1_test_release/images/75.jpg
#   inflating: c1_test_release/images/191.jpg
#   inflating: c1_test_release/images/78.jpg
#   inflating: c1_test_release/images/212.jpg
#   inflating: c1_test_release/images/76.jpg
#   inflating: c1_test_release/images/159.jpg
#   inflating: c1_test_release/images/10.jpg
#   inflating: c1_test_release/images/58.jpg
#   inflating: c1_test_release/images/199.jpg
#   inflating: c1_test_release/images/119.jpg
#   inflating: c1_test_release/images/79.jpg
#   inflating: c1_test_release/images/134.jpg
#   inflating: c1_test_release/images/54.jpg
#   inflating: c1_test_release/images/187.jpg
#   inflating: c1_test_release/images/86.jpg
#   inflating: c1_test_release/images/226.jpg
#   inflating: c1_test_release/images/228.jpg
#   inflating: c1_test_release/images/22.jpg
#   inflating: c1_test_release/images/38.jpg
#   inflating: c1_test_release/images/146.jpg
#   inflating: c1_test_release/images/37.jpg
#   inflating: c1_test_release/images/193.jpg
#   inflating: c1_test_release/images/129.jpg
#   inflating: c1_test_release/images/20.jpg
#   inflating: c1_test_release/images/6.jpg
#   inflating: c1_test_release/images/213.jpg
#   inflating: c1_test_release/images/166.jpg
#   inflating: c1_test_release/images/117.jpg
#   inflating: c1_test_release/images/151.jpg
#   inflating: c1_test_release/images/248.jpg
#   inflating: c1_test_release/images/246.jpg
#   inflating: c1_test_release/images/215.jpg
#   inflating: c1_test_release/images/150.jpg
#   inflating: c1_test_release/images/8.jpg
#   inflating: c1_test_release/images/11.jpg
#   inflating: c1_test_release/images/211.jpg
#   inflating: c1_test_release/images/27.jpg
#   inflating: c1_test_release/images/205.jpg
#   inflating: c1_test_release/images/152.jpg
#   inflating: c1_test_release/images/207.jpg
#   inflating: c1_test_release/images/145.jpg
#   inflating: c1_test_release/images/92.jpg
#   inflating: c1_test_release/images/144.jpg
#   inflating: c1_test_release/images/167.jpg
#   inflating: c1_test_release/images/169.jpg
#   inflating: c1_test_release/images/66.jpg
#   inflating: c1_test_release/images/163.jpg
#   inflating: c1_test_release/images/9.jpg
#   inflating: c1_test_release/images/182.jpg
#   inflating: c1_test_release/images/170.jpg
#   inflating: c1_test_release/images/47.jpg
#   inflating: c1_test_release/images/157.jpg
#   inflating: c1_test_release/images/43.jpg
#   inflating: c1_test_release/images/41.jpg
#   inflating: c1_test_release/images/84.jpg
#   inflating: c1_test_release/images/179.jpg
#   inflating: c1_test_release/images/209.jpg
#   inflating: c1_test_release/images/128.jpg
#   inflating: c1_test_release/images/196.jpg
#   inflating: c1_test_release/images/74.jpg
#   inflating: c1_test_release/images/164.jpg
#   inflating: c1_test_release/images/192.jpg
#   inflating: c1_test_release/images/99.jpg
#   inflating: c1_test_release/images/72.jpg
#   inflating: c1_test_release/images/245.jpg
#   inflating: c1_test_release/images/130.jpg
#   inflating: c1_test_release/images/114.jpg
#   inflating: c1_test_release/images/210.jpg
#   inflating: c1_test_release/images/238.jpg
#   inflating: c1_test_release/images/82.jpg
#   inflating: c1_test_release/images/71.jpg
#   inflating: c1_test_release/images/189.jpg
#   inflating: c1_test_release/images/201.jpg
#   inflating: c1_test_release/images/155.jpg
#   inflating: c1_test_release/images/70.jpg
#   inflating: c1_test_release/images/25.jpg
#   inflating: c1_test_release/images/112.jpg
#   inflating: c1_test_release/images/127.jpg
#   inflating: c1_test_release/images/100.jpg
#   inflating: c1_test_release/images/63.jpg
#   inflating: c1_test_release/images/229.jpg
#   inflating: c1_test_release/images/247.jpg
#   inflating: c1_test_release/images/42.jpg
#   inflating: c1_test_release/images/218.jpg
#   inflating: c1_test_release/images/243.jpg
#   inflating: c1_test_release/images/96.jpg
#   inflating: c1_test_release/images/224.jpg
#   inflating: c1_test_release/images/249.jpg
#   inflating: c1_test_release/images/115.jpg
#   inflating: c1_test_release/images/26.jpg
#   inflating: c1_test_release/images/136.jpg
#   inflating: c1_test_release/images/61.jpg
#   inflating: c1_test_release/images/57.jpg
#   inflating: c1_test_release/images/153.jpg
#   inflating: c1_test_release/images/17.jpg
#   inflating: c1_test_release/images/31.jpg
#   inflating: c1_test_release/images/30.jpg
#   inflating: c1_test_release/images/178.jpg
#   inflating: c1_test_release/images/237.jpg
#   inflating: c1_test_release/images/69.jpg
#   inflating: c1_test_release/images/23.jpg
#   inflating: c1_test_release/images/116.jpg
#   inflating: c1_test_release/images/132.jpg
#   inflating: c1_test_release/images/216.jpg
#   inflating: c1_test_release/images/1.jpg
#   inflating: c1_test_release/images/40.jpg
#   inflating: c1_test_release/images/28.jpg
#   inflating: c1_test_release/images/227.jpg
#   inflating: c1_test_release/images/171.jpg
#   inflating: c1_test_release/images/34.jpg
#   inflating: c1_test_release/images/45.jpg
#   inflating: c1_test_release/images/176.jpg
#   inflating: c1_test_release/images/5.jpg
#   inflating: c1_test_release/images/3.jpg
#   inflating: c1_test_release/images/118.jpg
#   inflating: c1_test_release/images/53.jpg
#   inflating: c1_test_release/images/33.jpg
#   inflating: c1_test_release/images/103.jpg
#   inflating: c1_test_release/images/13.jpg
#   inflating: c1_test_release/images/64.jpg
#   inflating: c1_test_release/images/36.jpg
#   inflating: c1_test_release/images/240.jpg
#   inflating: c1_test_release/images/48.jpg
#   inflating: c1_test_release/images/81.jpg
#   inflating: c1_test_release/images/235.jpg
#   inflating: c1_test_release/images/133.jpg
#   inflating: c1_test_release/images/94.jpg
#   inflating: c1_test_release/images/177.jpg
#   inflating: c1_test_release/images/223.jpg
#   inflating: c1_test_release/images/102.jpg
#   inflating: c1_test_release/images/200.jpg
#   inflating: c1_test_release/images/98.jpg
#   inflating: c1_test_release/images/104.jpg
#   inflating: c1_test_release/images/250.jpg
#   inflating: c1_test_release/images/97.jpg
#   inflating: c1_test_release/images/35.jpg
#   inflating: c1_test_release/images/90.jpg
#   inflating: c1_test_release/images/122.jpg
#   inflating: c1_test_release/images/4.jpg
#   inflating: c1_test_release/images/217.jpg
#   inflating: c1_test_release/images/80.jpg
#   inflating: c1_test_release/images/214.jpg
#   inflating: c1_test_release/images/113.jpg
#   inflating: c1_test_release/images/208.jpg
#   inflating: c1_test_release/images/67.jpg
#   inflating: c1_test_release/images/184.jpg
#   inflating: c1_test_release/images/49.jpg
#   inflating: c1_test_release/images/234.jpg
#   inflating: c1_test_release/images/19.jpg
#   inflating: c1_test_release/images/239.jpg
#   inflating: c1_test_release/images/55.jpg
#   inflating: c1_test_release/images/12.jpg
#   inflating: c1_test_release/images/142.jpg
#   inflating: c1_test_release/images/198.jpg
#   inflating: c1_test_release/images/137.jpg
#   inflating: c1_test_release/images/85.jpg
#   inflating: c1_test_release/images/202.jpg
#   inflating: c1_test_release/images/194.jpg
#   inflating: c1_test_release/images/24.jpg
#   inflating: c1_test_release/images/46.jpg
#   inflating: c1_test_release/images/242.jpg
#   inflating: c1_test_release/images/233.jpg
#   inflating: c1_test_release/images/44.jpg
#   inflating: c1_test_release/images/107.jpg
#   inflating: c1_test_release/images/204.jpg
#   inflating: c1_test_release/images/168.jpg
#   inflating: c1_test_release/images/222.jpg
#   inflating: c1_test_release/images/172.jpg
#   inflating: c1_test_release/images/89.jpg
#   inflating: c1_test_release/images/225.jpg
#   inflating: c1_test_release/images/15.jpg
#   inflating: c1_test_release/images/158.jpg
#   inflating: c1_test_release/images/230.jpg
#   inflating: c1_test_release/images/186.jpg

# %%
til_test_root = "/content/c1_test_release/" # extracted testing images path
test_img_root = os.path.join(til_test_root, "images")
img_dir = os.scandir(test_img_root)

# %% [markdown]
# Let's visualize some predictions on the test images. Run this a few times to visualize different images.

# %%
img = Image.open(next(img_dir).path).convert('RGB')
draw = ImageDraw.Draw(img)
det_threshold = 0.5

# do the prediction
with torch.no_grad():
    img_tensor = transforms.ToTensor()(img)
    img_preds = model([img_tensor.to(device)])[0]

for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    # filter out non-confident detections
    if score > det_threshold:
        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=375x500 at 0x7F71739ADC50>

# %% [markdown]
# ## Submission of Results
#
# Submission json file should be in [COCO format](https://cocodataset.org/#format-results).
#
# ```
# [{
#     "image_id": int,
#     "category_id": int,
#     "bbox": [x,y,width,height],
#     "score": float,
# }]
# ```
#
# Refer to **sample_submission_cv.json** for an example.
#
# For this competition, the metric for evaluation will be mAP @ 0.50:0.95

# %%
# generate detections on the folder of test images (this will be used for submission)
detections = []
with torch.no_grad():
    for image in img_dir:
        img_id = int(image.name.split('.')[0])

        img = Image.open(image.path).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
savefilename = "test_preds_"+str(params['BACKBONE'])+"_epochs_"+str(params['MAXEPOCHS'])+"_batchsize_"+str(params['BATCH_SIZE'])+".json"

test_pred_json = os.path.join(base_folder, savefilename)
with open(test_pred_json, 'w') as f:
    json.dump(detections, f)

# %% [markdown]
# ## Check Your Submission JSON Format (RUN THIS BEFORE SUBMISSION)
#
# Run this function first with the given sample json (change this path for the different challenges) to make sure everything works before you submit. Just need to ensure that there are no errors when you run this. **If you get any errors, check your generated json file.**

# %%
sample_json_path = os.path.join(til_test_root, "c1_test_sample.json")

coco_gt = COCO(sample_json_path)
coco_dt = coco_gt.loadRes(test_pred_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000

# %% [markdown]
# If you get an `AssertionError: Results do not correspond to current coco set`, it most likely means that some of the "image_id" are out of range (either 0 or higher than number of test images).
