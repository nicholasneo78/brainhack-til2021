# %% [markdown]
# ## Link to Colab

# %%
# connect to google colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Downloading Dependencies

# %%
# install torchaudio
# !pip install torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torchaudio==0.7.0
#   Using cached https://files.pythonhosted.org/packages/5d/75/5ce994c76cf7b53ff8c577d7a8221fa0c9dfe9e34c0536c6eaf3e466788a/torchaudio-0.7.0-cp37-cp37m-manylinux1_x86_64.whl
# Collecting torch==1.7.0
#   Downloading https://download.pytorch.org/whl/cu92/torch-1.7.0%2Bcu92-cp37-cp37m-linux_x86_64.whl (577.3MB)
#      |████████████████████████████████| 577.3MB 29kB/s
# Collecting dataclasses
#   Downloading https://files.pythonhosted.org/packages/26/2f/1095cdc2868052dd1e64520f7c0d5c8c550ad297e944e641dbf1ffbb9a5d/dataclasses-0.6-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->torchaudio==0.7.0) (3.7.4.3)
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.7.0+cu92 which is incompatible.
# ERROR: torchtext 0.10.0 has requirement torch==1.9.0, but you'll have torch 1.7.0+cu92 which is incompatible.
# Installing collected packages: dataclasses, torch, torchaudio
#   Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
# Successfully installed dataclasses-0.6 torch-1.7.0+cu92 torchaudio-0.7.0

# %%
import os
import numpy as np
import pandas as pd

# for F1-score & confusion matrix later
from sklearn.metrics import classification_report
import seaborn as sns

# current torch version is 1.7.0+cu101
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import warnings
warnings.filterwarnings("ignore")
import torchaudio
from torchaudio.transforms import MelSpectrogram
from torchaudio.transforms import TimeMasking, FrequencyMasking

import matplotlib.pyplot as plt
import IPython.display as ipd

import time
import random
from tqdm import tqdm

# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"

# COLAB CONFIG
# change colab flag to false if train using jupyter notebook
COLAB_FLAG = True
COLAB_FILEPATH = './drive/My Drive/TIL2021/competition/SC/' if COLAB_FLAG == True else './'
pd.options.mode.chained_assignment = None  # default='warn'
# %matplotlib inline
# Out:
# cuda

# %% [markdown]
# ## Speech Classification Dataset
# We will be providing the base dataset that will be used for the first task of the Speech Classification competition.

# %%
# old dataset
#!gdown --id 1im5shxcavdoTRNT66mhVdtA_E0ZR8QLl
#!unzip s1_train_release.zip

# the extra+base dataset
# 1st acc
base_folder = '/content/drive/MyDrive/TIL2021/competition/SC'
training_path = os.path.join(base_folder, "s2_full_with_egg.zip") # zip file for training dataset
# !unzip $training_path
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: s2_full_with_egg/five/train_five_5514.wav
#   inflating: s2_full_with_egg/five/train_five_5515.wav
#   inflating: s2_full_with_egg/five/train_five_5516.wav
#   inflating: s2_full_with_egg/five/train_five_5517.wav
#   inflating: s2_full_with_egg/five/train_five_5518.wav
#   inflating: s2_full_with_egg/five/train_five_5519.wav
#   inflating: s2_full_with_egg/five/train_five_5520.wav
#   inflating: s2_full_with_egg/five/train_five_5521.wav
#   inflating: s2_full_with_egg/five/train_five_5522.wav
#   inflating: s2_full_with_egg/five/train_five_5523.wav
#   inflating: s2_full_with_egg/five/train_five_5524.wav
#   inflating: s2_full_with_egg/five/train_five_5525.wav
#   inflating: s2_full_with_egg/five/train_five_5526.wav
#   inflating: s2_full_with_egg/five/train_five_5527.wav
#   inflating: s2_full_with_egg/five/train_five_5528.wav
#   inflating: s2_full_with_egg/five/train_five_5529.wav
#   inflating: s2_full_with_egg/five/train_five_5530.wav
#   inflating: s2_full_with_egg/five/train_five_5531.wav
#   inflating: s2_full_with_egg/five/train_five_5532.wav
#   inflating: s2_full_with_egg/five/train_five_5533.wav
#   inflating: s2_full_with_egg/five/train_five_5534.wav
#   inflating: s2_full_with_egg/five/train_five_5535.wav
#   inflating: s2_full_with_egg/five/train_five_5536.wav
#   inflating: s2_full_with_egg/five/train_five_5537.wav
#   inflating: s2_full_with_egg/five/train_five_5538.wav
#   inflating: s2_full_with_egg/five/train_five_5539.wav
#   inflating: s2_full_with_egg/five/train_five_5540.wav
#   inflating: s2_full_with_egg/five/train_five_5541.wav
#   inflating: s2_full_with_egg/five/train_five_5542.wav
#   inflating: s2_full_with_egg/five/train_five_5543.wav
#   inflating: s2_full_with_egg/five/train_five_5544.wav
#   inflating: s2_full_with_egg/five/train_five_5545.wav
#   inflating: s2_full_with_egg/five/train_five_5546.wav
#   inflating: s2_full_with_egg/five/train_five_5547.wav
#   inflating: s2_full_with_egg/five/train_five_5548.wav
#   inflating: s2_full_with_egg/five/train_five_5549.wav
#   inflating: s2_full_with_egg/five/train_five_5550.wav
#   inflating: s2_full_with_egg/five/train_five_5551.wav
#   inflating: s2_full_with_egg/five/train_five_5552.wav
#   inflating: s2_full_with_egg/five/train_five_5553.wav
#   inflating: s2_full_with_egg/five/train_five_5554.wav
#   inflating: s2_full_with_egg/five/train_five_5555.wav
#   inflating: s2_full_with_egg/five/train_five_5556.wav
#   inflating: s2_full_with_egg/five/train_five_5557.wav
#   inflating: s2_full_with_egg/five/train_five_5558.wav
#   inflating: s2_full_with_egg/five/train_five_5559.wav
#   inflating: s2_full_with_egg/five/train_five_5560.wav
#   inflating: s2_full_with_egg/five/train_five_5561.wav
#   inflating: s2_full_with_egg/five/train_five_5562.wav
#   inflating: s2_full_with_egg/five/train_five_5563.wav
#   inflating: s2_full_with_egg/five/train_five_5564.wav
#   inflating: s2_full_with_egg/five/train_five_5565.wav
#   inflating: s2_full_with_egg/five/train_five_5566.wav
#   inflating: s2_full_with_egg/five/train_five_5567.wav
#   inflating: s2_full_with_egg/five/train_five_5568.wav
#   inflating: s2_full_with_egg/five/train_five_5569.wav
#   inflating: s2_full_with_egg/five/train_five_5570.wav
#   inflating: s2_full_with_egg/five/train_five_5571.wav
#   inflating: s2_full_with_egg/five/train_five_5572.wav
#   inflating: s2_full_with_egg/five/train_five_5573.wav
#   inflating: s2_full_with_egg/five/train_five_5574.wav
#   inflating: s2_full_with_egg/five/train_five_5575.wav
#   inflating: s2_full_with_egg/five/train_five_5576.wav
#   inflating: s2_full_with_egg/five/train_five_5577.wav
#   inflating: s2_full_with_egg/five/train_five_5578.wav
#   inflating: s2_full_with_egg/five/train_five_5579.wav
#   inflating: s2_full_with_egg/five/train_five_5580.wav
#   inflating: s2_full_with_egg/five/train_five_5581.wav
#   inflating: s2_full_with_egg/five/train_five_5582.wav
#   inflating: s2_full_with_egg/five/train_five_5583.wav
#   inflating: s2_full_with_egg/five/train_five_5584.wav
#   inflating: s2_full_with_egg/five/train_five_5585.wav
#   inflating: s2_full_with_egg/five/train_five_5586.wav
#   inflating: s2_full_with_egg/five/train_five_5587.wav
#   inflating: s2_full_with_egg/five/train_five_5588.wav
#   inflating: s2_full_with_egg/five/train_five_5589.wav
#   inflating: s2_full_with_egg/five/train_five_5590.wav
#   inflating: s2_full_with_egg/five/train_five_5591.wav
#   inflating: s2_full_with_egg/five/train_five_5592.wav
#   inflating: s2_full_with_egg/five/train_five_5593.wav
#   inflating: s2_full_with_egg/five/train_five_5594.wav
#   inflating: s2_full_with_egg/five/train_five_5595.wav
#   inflating: s2_full_with_egg/five/train_five_5596.wav
#   inflating: s2_full_with_egg/five/train_five_5597.wav
#   inflating: s2_full_with_egg/five/train_five_5598.wav
#   inflating: s2_full_with_egg/five/train_five_5599.wav
#    creating: s2_full_with_egg/four/
#   inflating: s2_full_with_egg/four/train_four_2800.wav
#   inflating: s2_full_with_egg/four/train_four_2801.wav
#   inflating: s2_full_with_egg/four/train_four_2802.wav
#   inflating: s2_full_with_egg/four/train_four_2803.wav
#   inflating: s2_full_with_egg/four/train_four_2804.wav
#   inflating: s2_full_with_egg/four/train_four_2805.wav
#   inflating: s2_full_with_egg/four/train_four_2806.wav
#   inflating: s2_full_with_egg/four/train_four_2807.wav
#   inflating: s2_full_with_egg/four/train_four_2808.wav
#   inflating: s2_full_with_egg/four/train_four_2809.wav
#   inflating: s2_full_with_egg/four/train_four_2810.wav
#   inflating: s2_full_with_egg/four/train_four_2811.wav
#   inflating: s2_full_with_egg/four/train_four_2812.wav
#   inflating: s2_full_with_egg/four/train_four_2813.wav
#   inflating: s2_full_with_egg/four/train_four_2814.wav
#   inflating: s2_full_with_egg/four/train_four_2815.wav
#   inflating: s2_full_with_egg/four/train_four_2816.wav
#   inflating: s2_full_with_egg/four/train_four_2817.wav
#   inflating: s2_full_with_egg/four/train_four_2818.wav
#   inflating: s2_full_with_egg/four/train_four_2819.wav
#   inflating: s2_full_with_egg/four/train_four_2820.wav
#   inflating: s2_full_with_egg/four/train_four_2821.wav
#   inflating: s2_full_with_egg/four/train_four_2822.wav
#   inflating: s2_full_with_egg/four/train_four_2823.wav
#   inflating: s2_full_with_egg/four/train_four_2824.wav
#   inflating: s2_full_with_egg/four/train_four_2825.wav
#   inflating: s2_full_with_egg/four/train_four_2826.wav
#   inflating: s2_full_with_egg/four/train_four_2827.wav
#   inflating: s2_full_with_egg/four/train_four_2828.wav
#   inflating: s2_full_with_egg/four/train_four_2829.wav
#   inflating: s2_full_with_egg/four/train_four_2830.wav
#   inflating: s2_full_with_egg/four/train_four_2831.wav
#   inflating: s2_full_with_egg/four/train_four_2832.wav
#   inflating: s2_full_with_egg/four/train_four_2833.wav
#   inflating: s2_full_with_egg/four/train_four_2834.wav
#   inflating: s2_full_with_egg/four/train_four_2835.wav
#   inflating: s2_full_with_egg/four/train_four_2836.wav
#   inflating: s2_full_with_egg/four/train_four_2837.wav
#   inflating: s2_full_with_egg/four/train_four_2838.wav
#   inflating: s2_full_with_egg/four/train_four_2839.wav
#   inflating: s2_full_with_egg/four/train_four_2840.wav
#   inflating: s2_full_with_egg/four/train_four_2841.wav
#   inflating: s2_full_with_egg/four/train_four_2842.wav
#   inflating: s2_full_with_egg/four/train_four_2843.wav
#   inflating: s2_full_with_egg/four/train_four_2844.wav
#   inflating: s2_full_with_egg/four/train_four_2845.wav
#   inflating: s2_full_with_egg/four/train_four_2846.wav
#   inflating: s2_full_with_egg/four/train_four_2847.wav
#   inflating: s2_full_with_egg/four/train_four_2848.wav
#   inflating: s2_full_with_egg/four/train_four_2849.wav
#   inflating: s2_full_with_egg/four/train_four_2850.wav
#   inflating: s2_full_with_egg/four/train_four_2851.wav
#   inflating: s2_full_with_egg/four/train_four_2852.wav
#   inflating: s2_full_with_egg/four/train_four_2853.wav
#   inflating: s2_full_with_egg/four/train_four_2854.wav
#   inflating: s2_full_with_egg/four/train_four_2855.wav
#   inflating: s2_full_with_egg/four/train_four_2856.wav
#   inflating: s2_full_with_egg/four/train_four_2857.wav
#   inflating: s2_full_with_egg/four/train_four_2858.wav
#   inflating: s2_full_with_egg/four/train_four_2859.wav
#   inflating: s2_full_with_egg/four/train_four_2860.wav
#   inflating: s2_full_with_egg/four/train_four_2861.wav
#   inflating: s2_full_with_egg/four/train_four_2862.wav
#   inflating: s2_full_with_egg/four/train_four_2863.wav
#   inflating: s2_full_with_egg/four/train_four_2864.wav
#   inflating: s2_full_with_egg/four/train_four_2865.wav
#   inflating: s2_full_with_egg/four/train_four_2866.wav
#   inflating: s2_full_with_egg/four/train_four_2867.wav
#   inflating: s2_full_with_egg/four/train_four_2868.wav
#   inflating: s2_full_with_egg/four/train_four_2869.wav
#   inflating: s2_full_with_egg/four/train_four_2870.wav
#   inflating: s2_full_with_egg/four/train_four_2871.wav
#   inflating: s2_full_with_egg/four/train_four_2872.wav
#   inflating: s2_full_with_egg/four/train_four_2873.wav
#   inflating: s2_full_with_egg/four/train_four_2874.wav
#   inflating: s2_full_with_egg/four/train_four_2875.wav
#   inflating: s2_full_with_egg/four/train_four_2876.wav
#   inflating: s2_full_with_egg/four/train_four_2877.wav
#   inflating: s2_full_with_egg/four/train_four_2878.wav
#   inflating: s2_full_with_egg/four/train_four_2879.wav
#   inflating: s2_full_with_egg/four/train_four_2880.wav
#   inflating: s2_full_with_egg/four/train_four_2881.wav
#   inflating: s2_full_with_egg/four/train_four_2882.wav
#   inflating: s2_full_with_egg/four/train_four_2883.wav
#   inflating: s2_full_with_egg/four/train_four_2884.wav
#   inflating: s2_full_with_egg/four/train_four_2885.wav
#   inflating: s2_full_with_egg/four/train_four_2886.wav
#   inflating: s2_full_with_egg/four/train_four_2887.wav
#   inflating: s2_full_with_egg/four/train_four_2888.wav
#   inflating: s2_full_with_egg/four/train_four_2889.wav
#   inflating: s2_full_with_egg/four/train_four_2890.wav
#   inflating: s2_full_with_egg/four/train_four_2891.wav
#   inflating: s2_full_with_egg/four/train_four_2892.wav
#   inflating: s2_full_with_egg/four/train_four_2893.wav
#   inflating: s2_full_with_egg/four/train_four_2894.wav
#   inflating: s2_full_with_egg/four/train_four_2895.wav
#   inflating: s2_full_with_egg/four/train_four_2896.wav
#   inflating: s2_full_with_egg/four/train_four_2897.wav
#   inflating: s2_full_with_egg/four/train_four_2898.wav
#   inflating: s2_full_with_egg/four/train_four_2899.wav
#   inflating: s2_full_with_egg/four/train_four_2900.wav
#   inflating: s2_full_with_egg/four/train_four_2901.wav
#   inflating: s2_full_with_egg/four/train_four_2902.wav
#   inflating: s2_full_with_egg/four/train_four_2903.wav
#   inflating: s2_full_with_egg/four/train_four_2904.wav
#   inflating: s2_full_with_egg/four/train_four_2905.wav
#   inflating: s2_full_with_egg/four/train_four_2906.wav
#   inflating: s2_full_with_egg/four/train_four_2907.wav
#   inflating: s2_full_with_egg/four/train_four_2908.wav
#   inflating: s2_full_with_egg/four/train_four_2909.wav
#   inflating: s2_full_with_egg/four/train_four_2910.wav
#   inflating: s2_full_with_egg/four/train_four_2911.wav
#   inflating: s2_full_with_egg/four/train_four_2912.wav
#   inflating: s2_full_with_egg/four/train_four_2913.wav
#   inflating: s2_full_with_egg/four/train_four_2914.wav
#   inflating: s2_full_with_egg/four/train_four_2915.wav
#   inflating: s2_full_with_egg/four/train_four_2916.wav
#   inflating: s2_full_with_egg/four/train_four_2917.wav
#   inflating: s2_full_with_egg/four/train_four_2918.wav
#   inflating: s2_full_with_egg/four/train_four_2919.wav
#   inflating: s2_full_with_egg/four/train_four_2920.wav
#   inflating: s2_full_with_egg/four/train_four_2921.wav
#   inflating: s2_full_with_egg/four/train_four_2922.wav
#   inflating: s2_full_with_egg/four/train_four_2923.wav
#   inflating: s2_full_with_egg/four/train_four_2924.wav
#   inflating: s2_full_with_egg/four/train_four_2925.wav
#   inflating: s2_full_with_egg/four/train_four_2926.wav
#   inflating: s2_full_with_egg/four/train_four_2927.wav
#   inflating: s2_full_with_egg/four/train_four_2928.wav
#   inflating: s2_full_with_egg/four/train_four_2929.wav
#   inflating: s2_full_with_egg/four/train_four_2930.wav
#   inflating: s2_full_with_egg/four/train_four_2931.wav
#   inflating: s2_full_with_egg/four/train_four_2932.wav
#   inflating: s2_full_with_egg/four/train_four_2933.wav
#   inflating: s2_full_with_egg/four/train_four_2934.wav
#   inflating: s2_full_with_egg/four/train_four_2935.wav
#   inflating: s2_full_with_egg/four/train_four_2936.wav
#   inflating: s2_full_with_egg/four/train_four_2937.wav
#   inflating: s2_full_with_egg/four/train_four_2938.wav
#   inflating: s2_full_with_egg/four/train_four_2939.wav
#   inflating: s2_full_with_egg/four/train_four_2940.wav
#   inflating: s2_full_with_egg/four/train_four_2941.wav
#   inflating: s2_full_with_egg/four/train_four_2942.wav
#   inflating: s2_full_with_egg/four/train_four_2943.wav
#   inflating: s2_full_with_egg/four/train_four_2944.wav
#   inflating: s2_full_with_egg/four/train_four_2945.wav
#   inflating: s2_full_with_egg/four/train_four_2946.wav
#   inflating: s2_full_with_egg/four/train_four_2947.wav
#   inflating: s2_full_with_egg/four/train_four_2948.wav
#   inflating: s2_full_with_egg/four/train_four_2949.wav
#   inflating: s2_full_with_egg/four/train_four_2950.wav
#   inflating: s2_full_with_egg/four/train_four_2951.wav
#   inflating: s2_full_with_egg/four/train_four_2952.wav
#   inflating: s2_full_with_egg/four/train_four_2953.wav
#   inflating: s2_full_with_egg/four/train_four_2954.wav
#   inflating: s2_full_with_egg/four/train_four_2955.wav
#   inflating: s2_full_with_egg/four/train_four_2956.wav
#   inflating: s2_full_with_egg/four/train_four_2957.wav
#   inflating: s2_full_with_egg/four/train_four_2958.wav
#   inflating: s2_full_with_egg/four/train_four_2959.wav
#   inflating: s2_full_with_egg/four/train_four_2960.wav
#   inflating: s2_full_with_egg/four/train_four_2961.wav
#   inflating: s2_full_with_egg/four/train_four_2962.wav
#   inflating: s2_full_with_egg/four/train_four_2963.wav
#   inflating: s2_full_with_egg/four/train_four_2964.wav
#   inflating: s2_full_with_egg/four/train_four_2965.wav
#   inflating: s2_full_with_egg/four/train_four_2966.wav
#   inflating: s2_full_with_egg/four/train_four_2967.wav
#   inflating: s2_full_with_egg/four/train_four_2968.wav
#   inflating: s2_full_with_egg/four/train_four_2969.wav
#   inflating: s2_full_with_egg/four/train_four_2970.wav
#   inflating: s2_full_with_egg/four/train_four_2971.wav
#   inflating: s2_full_with_egg/four/train_four_2972.wav
#   inflating: s2_full_with_egg/four/train_four_2973.wav
#   inflating: s2_full_with_egg/four/train_four_2974.wav
#   inflating: s2_full_with_egg/four/train_four_2975.wav
#   inflating: s2_full_with_egg/four/train_four_2976.wav
#   inflating: s2_full_with_egg/four/train_four_2977.wav
#   inflating: s2_full_with_egg/four/train_four_2978.wav
#   inflating: s2_full_with_egg/four/train_four_2979.wav
#   inflating: s2_full_with_egg/four/train_four_2980.wav
#   inflating: s2_full_with_egg/four/train_four_2981.wav
#   inflating: s2_full_with_egg/four/train_four_2982.wav
#   inflating: s2_full_with_egg/four/train_four_2983.wav
#   inflating: s2_full_with_egg/four/train_four_2984.wav
#   inflating: s2_full_with_egg/four/train_four_2985.wav
#   inflating: s2_full_with_egg/four/train_four_2986.wav
#   inflating: s2_full_with_egg/four/train_four_2987.wav
#   inflating: s2_full_with_egg/four/train_four_2988.wav
#   inflating: s2_full_with_egg/four/train_four_2989.wav
#   inflating: s2_full_with_egg/four/train_four_2990.wav
#   inflating: s2_full_with_egg/four/train_four_2991.wav
#   inflating: s2_full_with_egg/four/train_four_2992.wav
#   inflating: s2_full_with_egg/four/train_four_2993.wav
#   inflating: s2_full_with_egg/four/train_four_2994.wav
#   inflating: s2_full_with_egg/four/train_four_2995.wav
#   inflating: s2_full_with_egg/four/train_four_2996.wav
#   inflating: s2_full_with_egg/four/train_four_2997.wav
#   inflating: s2_full_with_egg/four/train_four_2998.wav
#   inflating: s2_full_with_egg/four/train_four_2999.wav
#   inflating: s2_full_with_egg/four/train_four_3000.wav
#   inflating: s2_full_with_egg/four/train_four_3001.wav
#   inflating: s2_full_with_egg/four/train_four_3002.wav
#   inflating: s2_full_with_egg/four/train_four_3003.wav
#   inflating: s2_full_with_egg/four/train_four_3004.wav
#   inflating: s2_full_with_egg/four/train_four_3005.wav
#   inflating: s2_full_with_egg/four/train_four_3006.wav
#   inflating: s2_full_with_egg/four/train_four_3007.wav
#   inflating: s2_full_with_egg/four/train_four_3008.wav
#   inflating: s2_full_with_egg/four/train_four_3009.wav
#   inflating: s2_full_with_egg/four/train_four_3010.wav
#   inflating: s2_full_with_egg/four/train_four_3011.wav
#   inflating: s2_full_with_egg/four/train_four_3012.wav
#   inflating: s2_full_with_egg/four/train_four_3013.wav
#   inflating: s2_full_with_egg/four/train_four_3014.wav
#   inflating: s2_full_with_egg/four/train_four_3015.wav
#   inflating: s2_full_with_egg/four/train_four_3016.wav
#   inflating: s2_full_with_egg/four/train_four_3017.wav
#   inflating: s2_full_with_egg/four/train_four_3018.wav
#   inflating: s2_full_with_egg/four/train_four_3019.wav
#   inflating: s2_full_with_egg/four/train_four_3020.wav
#   inflating: s2_full_with_egg/four/train_four_3021.wav
#   inflating: s2_full_with_egg/four/train_four_3022.wav
#   inflating: s2_full_with_egg/four/train_four_3023.wav
#   inflating: s2_full_with_egg/four/train_four_3024.wav
#   inflating: s2_full_with_egg/four/train_four_3025.wav
#   inflating: s2_full_with_egg/four/train_four_3026.wav
#   inflating: s2_full_with_egg/four/train_four_3027.wav
#   inflating: s2_full_with_egg/four/train_four_3028.wav
#   inflating: s2_full_with_egg/four/train_four_3029.wav
#   inflating: s2_full_with_egg/four/train_four_3030.wav
#   inflating: s2_full_with_egg/four/train_four_3031.wav
#   inflating: s2_full_with_egg/four/train_four_3032.wav
#   inflating: s2_full_with_egg/four/train_four_3033.wav
#   inflating: s2_full_with_egg/four/train_four_3034.wav
#   inflating: s2_full_with_egg/four/train_four_3035.wav
#   inflating: s2_full_with_egg/four/train_four_3036.wav
#   inflating: s2_full_with_egg/four/train_four_3037.wav
#   inflating: s2_full_with_egg/four/train_four_3038.wav
#   inflating: s2_full_with_egg/four/train_four_3039.wav
#   inflating: s2_full_with_egg/four/train_four_3040.wav
#   inflating: s2_full_with_egg/four/train_four_3041.wav
#   inflating: s2_full_with_egg/four/train_four_3042.wav
#   inflating: s2_full_with_egg/four/train_four_3043.wav
#   inflating: s2_full_with_egg/four/train_four_3044.wav
#   inflating: s2_full_with_egg/four/train_four_3045.wav
#   inflating: s2_full_with_egg/four/train_four_3046.wav
#   inflating: s2_full_with_egg/four/train_four_3047.wav
#   inflating: s2_full_with_egg/four/train_four_3048.wav
#   inflating: s2_full_with_egg/four/train_four_3049.wav
#   inflating: s2_full_with_egg/four/train_four_3050.wav
#   inflating: s2_full_with_egg/four/train_four_3051.wav
#   inflating: s2_full_with_egg/four/train_four_3052.wav
#   inflating: s2_full_with_egg/four/train_four_3053.wav
#   inflating: s2_full_with_egg/four/train_four_3054.wav
#   inflating: s2_full_with_egg/four/train_four_3055.wav
#   inflating: s2_full_with_egg/four/train_four_3056.wav
#   inflating: s2_full_with_egg/four/train_four_3057.wav
#   inflating: s2_full_with_egg/four/train_four_3058.wav
#   inflating: s2_full_with_egg/four/train_four_3059.wav
#   inflating: s2_full_with_egg/four/train_four_3060.wav
#   inflating: s2_full_with_egg/four/train_four_3061.wav
#   inflating: s2_full_with_egg/four/train_four_3062.wav
#   inflating: s2_full_with_egg/four/train_four_3063.wav
#   inflating: s2_full_with_egg/four/train_four_3064.wav
#   inflating: s2_full_with_egg/four/train_four_3065.wav
#   inflating: s2_full_with_egg/four/train_four_3066.wav
#   inflating: s2_full_with_egg/four/train_four_3067.wav
#   inflating: s2_full_with_egg/four/train_four_3068.wav
#   inflating: s2_full_with_egg/four/train_four_3069.wav
#   inflating: s2_full_with_egg/four/train_four_3070.wav
#   inflating: s2_full_with_egg/four/train_four_3071.wav
#   inflating: s2_full_with_egg/four/train_four_3072.wav
#   inflating: s2_full_with_egg/four/train_four_3073.wav
#   inflating: s2_full_with_egg/four/train_four_3074.wav
#   inflating: s2_full_with_egg/four/train_four_3075.wav
#   inflating: s2_full_with_egg/four/train_four_3076.wav
#   inflating: s2_full_with_egg/four/train_four_3077.wav
#   inflating: s2_full_with_egg/four/train_four_3078.wav
#   inflating: s2_full_with_egg/four/train_four_3079.wav
#   inflating: s2_full_with_egg/four/train_four_3080.wav
#   inflating: s2_full_with_egg/four/train_four_3081.wav
#   inflating: s2_full_with_egg/four/train_four_3082.wav
#   inflating: s2_full_with_egg/four/train_four_3083.wav
#   inflating: s2_full_with_egg/four/train_four_3084.wav
#   inflating: s2_full_with_egg/four/train_four_3085.wav
#   inflating: s2_full_with_egg/four/train_four_3086.wav
#   inflating: s2_full_with_egg/four/train_four_3087.wav
#   inflating: s2_full_with_egg/four/train_four_3088.wav
#   inflating: s2_full_with_egg/four/train_four_3089.wav
#   inflating: s2_full_with_egg/four/train_four_3090.wav
#   inflating: s2_full_with_egg/four/train_four_3091.wav
#   inflating: s2_full_with_egg/four/train_four_3092.wav
#   inflating: s2_full_with_egg/four/train_four_3093.wav
#   inflating: s2_full_with_egg/four/train_four_3094.wav
#   inflating: s2_full_with_egg/four/train_four_3095.wav
#   inflating: s2_full_with_egg/four/train_four_3096.wav
#   inflating: s2_full_with_egg/four/train_four_3097.wav
#   inflating: s2_full_with_egg/four/train_four_3098.wav
#   inflating: s2_full_with_egg/four/train_four_3099.wav
#   inflating: s2_full_with_egg/four/train_four_3100.wav
#   inflating: s2_full_with_egg/four/train_four_3101.wav
#   inflating: s2_full_with_egg/four/train_four_3102.wav
#   inflating: s2_full_with_egg/four/train_four_3103.wav
#   inflating: s2_full_with_egg/four/train_four_3104.wav
#   inflating: s2_full_with_egg/four/train_four_3105.wav
#   inflating: s2_full_with_egg/four/train_four_3106.wav
#   inflating: s2_full_with_egg/four/train_four_3107.wav
#   inflating: s2_full_with_egg/four/train_four_3108.wav
#   inflating: s2_full_with_egg/four/train_four_3109.wav
#   inflating: s2_full_with_egg/four/train_four_3110.wav
#   inflating: s2_full_with_egg/four/train_four_3111.wav
#   inflating: s2_full_with_egg/four/train_four_3112.wav
#   inflating: s2_full_with_egg/four/train_four_3113.wav
#   inflating: s2_full_with_egg/four/train_four_3114.wav
#   inflating: s2_full_with_egg/four/train_four_3115.wav
#   inflating: s2_full_with_egg/four/train_four_3116.wav
#   inflating: s2_full_with_egg/four/train_four_3117.wav
#   inflating: s2_full_with_egg/four/train_four_3118.wav
#   inflating: s2_full_with_egg/four/train_four_3119.wav
#   inflating: s2_full_with_egg/four/train_four_3120.wav
#   inflating: s2_full_with_egg/four/train_four_3121.wav
#   inflating: s2_full_with_egg/four/train_four_3122.wav
#   inflating: s2_full_with_egg/four/train_four_3123.wav
#   inflating: s2_full_with_egg/four/train_four_3124.wav
#   inflating: s2_full_with_egg/four/train_four_3125.wav
#   inflating: s2_full_with_egg/four/train_four_3126.wav
#   inflating: s2_full_with_egg/four/train_four_3127.wav
#   inflating: s2_full_with_egg/four/train_four_3128.wav
#   inflating: s2_full_with_egg/four/train_four_3129.wav
#   inflating: s2_full_with_egg/four/train_four_3130.wav
#   inflating: s2_full_with_egg/four/train_four_3131.wav
#   inflating: s2_full_with_egg/four/train_four_3132.wav
#   inflating: s2_full_with_egg/four/train_four_3133.wav
#   inflating: s2_full_with_egg/four/train_four_3134.wav
#   inflating: s2_full_with_egg/four/train_four_3135.wav
#   inflating: s2_full_with_egg/four/train_four_3136.wav
#   inflating: s2_full_with_egg/four/train_four_3137.wav
#   inflating: s2_full_with_egg/four/train_four_3138.wav
#   inflating: s2_full_with_egg/four/train_four_3139.wav
#   inflating: s2_full_with_egg/four/train_four_3140.wav
#   inflating: s2_full_with_egg/four/train_four_3141.wav
#   inflating: s2_full_with_egg/four/train_four_3142.wav
#   inflating: s2_full_with_egg/four/train_four_3143.wav
#   inflating: s2_full_with_egg/four/train_four_3144.wav
#   inflating: s2_full_with_egg/four/train_four_3145.wav
#   inflating: s2_full_with_egg/four/train_four_3146.wav
#   inflating: s2_full_with_egg/four/train_four_3147.wav
#   inflating: s2_full_with_egg/four/train_four_3148.wav
#   inflating: s2_full_with_egg/four/train_four_3149.wav
#    creating: s2_full_with_egg/go/
#   inflating: s2_full_with_egg/go/train_go_5600.wav
#   inflating: s2_full_with_egg/go/train_go_5601.wav
#   inflating: s2_full_with_egg/go/train_go_5602.wav
#   inflating: s2_full_with_egg/go/train_go_5603.wav
#   inflating: s2_full_with_egg/go/train_go_5604.wav
#   inflating: s2_full_with_egg/go/train_go_5605.wav
#   inflating: s2_full_with_egg/go/train_go_5606.wav
#   inflating: s2_full_with_egg/go/train_go_5607.wav
#   inflating: s2_full_with_egg/go/train_go_5608.wav
#   inflating: s2_full_with_egg/go/train_go_5609.wav
#   inflating: s2_full_with_egg/go/train_go_5610.wav
#   inflating: s2_full_with_egg/go/train_go_5611.wav
#   inflating: s2_full_with_egg/go/train_go_5612.wav
#   inflating: s2_full_with_egg/go/train_go_5613.wav
#   inflating: s2_full_with_egg/go/train_go_5614.wav
#   inflating: s2_full_with_egg/go/train_go_5615.wav
#   inflating: s2_full_with_egg/go/train_go_5616.wav
#   inflating: s2_full_with_egg/go/train_go_5617.wav
#   inflating: s2_full_with_egg/go/train_go_5618.wav
#   inflating: s2_full_with_egg/go/train_go_5619.wav
#   inflating: s2_full_with_egg/go/train_go_5620.wav
#   inflating: s2_full_with_egg/go/train_go_5621.wav
#   inflating: s2_full_with_egg/go/train_go_5622.wav
#   inflating: s2_full_with_egg/go/train_go_5623.wav
#   inflating: s2_full_with_egg/go/train_go_5624.wav
#   inflating: s2_full_with_egg/go/train_go_5625.wav
#   inflating: s2_full_with_egg/go/train_go_5626.wav
#   inflating: s2_full_with_egg/go/train_go_5627.wav
#   inflating: s2_full_with_egg/go/train_go_5628.wav
#   inflating: s2_full_with_egg/go/train_go_5629.wav
#   inflating: s2_full_with_egg/go/train_go_5630.wav
#   inflating: s2_full_with_egg/go/train_go_5631.wav
#   inflating: s2_full_with_egg/go/train_go_5632.wav
#   inflating: s2_full_with_egg/go/train_go_5633.wav
#   inflating: s2_full_with_egg/go/train_go_5634.wav
#   inflating: s2_full_with_egg/go/train_go_5635.wav
#   inflating: s2_full_with_egg/go/train_go_5636.wav
#   inflating: s2_full_with_egg/go/train_go_5637.wav
#   inflating: s2_full_with_egg/go/train_go_5638.wav
#   inflating: s2_full_with_egg/go/train_go_5639.wav
#   inflating: s2_full_with_egg/go/train_go_5640.wav
#   inflating: s2_full_with_egg/go/train_go_5641.wav
#   inflating: s2_full_with_egg/go/train_go_5642.wav
#   inflating: s2_full_with_egg/go/train_go_5643.wav
#   inflating: s2_full_with_egg/go/train_go_5644.wav
#   inflating: s2_full_with_egg/go/train_go_5645.wav
#   inflating: s2_full_with_egg/go/train_go_5646.wav
#   inflating: s2_full_with_egg/go/train_go_5647.wav
#   inflating: s2_full_with_egg/go/train_go_5648.wav
#   inflating: s2_full_with_egg/go/train_go_5649.wav
#   inflating: s2_full_with_egg/go/train_go_5650.wav
#   inflating: s2_full_with_egg/go/train_go_5651.wav
#   inflating: s2_full_with_egg/go/train_go_5652.wav
#   inflating: s2_full_with_egg/go/train_go_5653.wav
#   inflating: s2_full_with_egg/go/train_go_5654.wav
#   inflating: s2_full_with_egg/go/train_go_5655.wav
#   inflating: s2_full_with_egg/go/train_go_5656.wav
#   inflating: s2_full_with_egg/go/train_go_5657.wav
#   inflating: s2_full_with_egg/go/train_go_5658.wav
#   inflating: s2_full_with_egg/go/train_go_5659.wav
#   inflating: s2_full_with_egg/go/train_go_5660.wav
#   inflating: s2_full_with_egg/go/train_go_5661.wav
#   inflating: s2_full_with_egg/go/train_go_5662.wav
#   inflating: s2_full_with_egg/go/train_go_5663.wav
#   inflating: s2_full_with_egg/go/train_go_5664.wav
#   inflating: s2_full_with_egg/go/train_go_5665.wav
#   inflating: s2_full_with_egg/go/train_go_5666.wav
#   inflating: s2_full_with_egg/go/train_go_5667.wav
#   inflating: s2_full_with_egg/go/train_go_5668.wav
#   inflating: s2_full_with_egg/go/train_go_5669.wav
#   inflating: s2_full_with_egg/go/train_go_5670.wav
#   inflating: s2_full_with_egg/go/train_go_5671.wav
#   inflating: s2_full_with_egg/go/train_go_5672.wav
#   inflating: s2_full_with_egg/go/train_go_5673.wav
#   inflating: s2_full_with_egg/go/train_go_5674.wav
#   inflating: s2_full_with_egg/go/train_go_5675.wav
#   inflating: s2_full_with_egg/go/train_go_5676.wav
#   inflating: s2_full_with_egg/go/train_go_5677.wav
#   inflating: s2_full_with_egg/go/train_go_5678.wav
#   inflating: s2_full_with_egg/go/train_go_5679.wav
#   inflating: s2_full_with_egg/go/train_go_5680.wav
#   inflating: s2_full_with_egg/go/train_go_5681.wav
#   inflating: s2_full_with_egg/go/train_go_5682.wav
#   inflating: s2_full_with_egg/go/train_go_5683.wav
#   inflating: s2_full_with_egg/go/train_go_5684.wav
#   inflating: s2_full_with_egg/go/train_go_5685.wav
#   inflating: s2_full_with_egg/go/train_go_5686.wav
#   inflating: s2_full_with_egg/go/train_go_5687.wav
#   inflating: s2_full_with_egg/go/train_go_5688.wav
#   inflating: s2_full_with_egg/go/train_go_5689.wav
#   inflating: s2_full_with_egg/go/train_go_5690.wav
#   inflating: s2_full_with_egg/go/train_go_5691.wav
#   inflating: s2_full_with_egg/go/train_go_5692.wav
#   inflating: s2_full_with_egg/go/train_go_5693.wav
#   inflating: s2_full_with_egg/go/train_go_5694.wav
#   inflating: s2_full_with_egg/go/train_go_5695.wav
#   inflating: s2_full_with_egg/go/train_go_5696.wav
#   inflating: s2_full_with_egg/go/train_go_5697.wav
#   inflating: s2_full_with_egg/go/train_go_5698.wav
#   inflating: s2_full_with_egg/go/train_go_5699.wav
#   inflating: s2_full_with_egg/go/train_go_5700.wav
#   inflating: s2_full_with_egg/go/train_go_5701.wav
#   inflating: s2_full_with_egg/go/train_go_5702.wav
#   inflating: s2_full_with_egg/go/train_go_5703.wav
#   inflating: s2_full_with_egg/go/train_go_5704.wav
#   inflating: s2_full_with_egg/go/train_go_5705.wav
#   inflating: s2_full_with_egg/go/train_go_5706.wav
#   inflating: s2_full_with_egg/go/train_go_5707.wav
#   inflating: s2_full_with_egg/go/train_go_5708.wav
#   inflating: s2_full_with_egg/go/train_go_5709.wav
#   inflating: s2_full_with_egg/go/train_go_5710.wav
#   inflating: s2_full_with_egg/go/train_go_5711.wav
#   inflating: s2_full_with_egg/go/train_go_5712.wav
#   inflating: s2_full_with_egg/go/train_go_5713.wav
#   inflating: s2_full_with_egg/go/train_go_5714.wav
#   inflating: s2_full_with_egg/go/train_go_5715.wav
#   inflating: s2_full_with_egg/go/train_go_5716.wav
#   inflating: s2_full_with_egg/go/train_go_5717.wav
#   inflating: s2_full_with_egg/go/train_go_5718.wav
#   inflating: s2_full_with_egg/go/train_go_5719.wav
#   inflating: s2_full_with_egg/go/train_go_5720.wav
#   inflating: s2_full_with_egg/go/train_go_5721.wav
#   inflating: s2_full_with_egg/go/train_go_5722.wav
#   inflating: s2_full_with_egg/go/train_go_5723.wav
#   inflating: s2_full_with_egg/go/train_go_5724.wav
#   inflating: s2_full_with_egg/go/train_go_5725.wav
#   inflating: s2_full_with_egg/go/train_go_5726.wav
#   inflating: s2_full_with_egg/go/train_go_5727.wav
#   inflating: s2_full_with_egg/go/train_go_5728.wav
#   inflating: s2_full_with_egg/go/train_go_5729.wav
#   inflating: s2_full_with_egg/go/train_go_5730.wav
#   inflating: s2_full_with_egg/go/train_go_5731.wav
#   inflating: s2_full_with_egg/go/train_go_5732.wav
#   inflating: s2_full_with_egg/go/train_go_5733.wav
#   inflating: s2_full_with_egg/go/train_go_5734.wav
#   inflating: s2_full_with_egg/go/train_go_5735.wav
#   inflating: s2_full_with_egg/go/train_go_5736.wav
#   inflating: s2_full_with_egg/go/train_go_5737.wav
#   inflating: s2_full_with_egg/go/train_go_5738.wav
#   inflating: s2_full_with_egg/go/train_go_5739.wav
#   inflating: s2_full_with_egg/go/train_go_5740.wav
#   inflating: s2_full_with_egg/go/train_go_5741.wav
#   inflating: s2_full_with_egg/go/train_go_5742.wav
#   inflating: s2_full_with_egg/go/train_go_5743.wav
#   inflating: s2_full_with_egg/go/train_go_5744.wav
#   inflating: s2_full_with_egg/go/train_go_5745.wav
#   inflating: s2_full_with_egg/go/train_go_5746.wav
#   inflating: s2_full_with_egg/go/train_go_5747.wav
#   inflating: s2_full_with_egg/go/train_go_5748.wav
#   inflating: s2_full_with_egg/go/train_go_5749.wav
#   inflating: s2_full_with_egg/go/train_go_5750.wav
#   inflating: s2_full_with_egg/go/train_go_5751.wav
#   inflating: s2_full_with_egg/go/train_go_5752.wav
#   inflating: s2_full_with_egg/go/train_go_5753.wav
#   inflating: s2_full_with_egg/go/train_go_5754.wav
#   inflating: s2_full_with_egg/go/train_go_5755.wav
#   inflating: s2_full_with_egg/go/train_go_5756.wav
#   inflating: s2_full_with_egg/go/train_go_5757.wav
#   inflating: s2_full_with_egg/go/train_go_5758.wav
#   inflating: s2_full_with_egg/go/train_go_5759.wav
#   inflating: s2_full_with_egg/go/train_go_5760.wav
#   inflating: s2_full_with_egg/go/train_go_5761.wav
#   inflating: s2_full_with_egg/go/train_go_5762.wav
#   inflating: s2_full_with_egg/go/train_go_5763.wav
#   inflating: s2_full_with_egg/go/train_go_5764.wav
#   inflating: s2_full_with_egg/go/train_go_5765.wav
#   inflating: s2_full_with_egg/go/train_go_5766.wav
#   inflating: s2_full_with_egg/go/train_go_5767.wav
#   inflating: s2_full_with_egg/go/train_go_5768.wav
#   inflating: s2_full_with_egg/go/train_go_5769.wav
#   inflating: s2_full_with_egg/go/train_go_5770.wav
#   inflating: s2_full_with_egg/go/train_go_5771.wav
#   inflating: s2_full_with_egg/go/train_go_5772.wav
#   inflating: s2_full_with_egg/go/train_go_5773.wav
#   inflating: s2_full_with_egg/go/train_go_5774.wav
#   inflating: s2_full_with_egg/go/train_go_5775.wav
#   inflating: s2_full_with_egg/go/train_go_5776.wav
#   inflating: s2_full_with_egg/go/train_go_5777.wav
#   inflating: s2_full_with_egg/go/train_go_5778.wav
#   inflating: s2_full_with_egg/go/train_go_5779.wav
#   inflating: s2_full_with_egg/go/train_go_5780.wav
#   inflating: s2_full_with_egg/go/train_go_5781.wav
#   inflating: s2_full_with_egg/go/train_go_5782.wav
#   inflating: s2_full_with_egg/go/train_go_5783.wav
#   inflating: s2_full_with_egg/go/train_go_5784.wav
#   inflating: s2_full_with_egg/go/train_go_5785.wav
#   inflating: s2_full_with_egg/go/train_go_5786.wav
#   inflating: s2_full_with_egg/go/train_go_5787.wav
#   inflating: s2_full_with_egg/go/train_go_5788.wav
#   inflating: s2_full_with_egg/go/train_go_5789.wav
#   inflating: s2_full_with_egg/go/train_go_5790.wav
#   inflating: s2_full_with_egg/go/train_go_5791.wav
#   inflating: s2_full_with_egg/go/train_go_5792.wav
#   inflating: s2_full_with_egg/go/train_go_5793.wav
#   inflating: s2_full_with_egg/go/train_go_5794.wav
#   inflating: s2_full_with_egg/go/train_go_5795.wav
#   inflating: s2_full_with_egg/go/train_go_5796.wav
#   inflating: s2_full_with_egg/go/train_go_5797.wav
#   inflating: s2_full_with_egg/go/train_go_5798.wav
#   inflating: s2_full_with_egg/go/train_go_5799.wav
#   inflating: s2_full_with_egg/go/train_go_5800.wav
#   inflating: s2_full_with_egg/go/train_go_5801.wav
#   inflating: s2_full_with_egg/go/train_go_5802.wav
#   inflating: s2_full_with_egg/go/train_go_5803.wav
#   inflating: s2_full_with_egg/go/train_go_5804.wav
#   inflating: s2_full_with_egg/go/train_go_5805.wav
#   inflating: s2_full_with_egg/go/train_go_5806.wav
#   inflating: s2_full_with_egg/go/train_go_5807.wav
#   inflating: s2_full_with_egg/go/train_go_5808.wav
#   inflating: s2_full_with_egg/go/train_go_5809.wav
#   inflating: s2_full_with_egg/go/train_go_5810.wav
#   inflating: s2_full_with_egg/go/train_go_5811.wav
#   inflating: s2_full_with_egg/go/train_go_5812.wav
#   inflating: s2_full_with_egg/go/train_go_5813.wav
#   inflating: s2_full_with_egg/go/train_go_5814.wav
#   inflating: s2_full_with_egg/go/train_go_5815.wav
#   inflating: s2_full_with_egg/go/train_go_5816.wav
#   inflating: s2_full_with_egg/go/train_go_5817.wav
#   inflating: s2_full_with_egg/go/train_go_5818.wav
#   inflating: s2_full_with_egg/go/train_go_5819.wav
#   inflating: s2_full_with_egg/go/train_go_5820.wav
#   inflating: s2_full_with_egg/go/train_go_5821.wav
#   inflating: s2_full_with_egg/go/train_go_5822.wav
#   inflating: s2_full_with_egg/go/train_go_5823.wav
#   inflating: s2_full_with_egg/go/train_go_5824.wav
#   inflating: s2_full_with_egg/go/train_go_5825.wav
#   inflating: s2_full_with_egg/go/train_go_5826.wav
#   inflating: s2_full_with_egg/go/train_go_5827.wav
#   inflating: s2_full_with_egg/go/train_go_5828.wav
#   inflating: s2_full_with_egg/go/train_go_5829.wav
#   inflating: s2_full_with_egg/go/train_go_5830.wav
#   inflating: s2_full_with_egg/go/train_go_5831.wav
#   inflating: s2_full_with_egg/go/train_go_5832.wav
#   inflating: s2_full_with_egg/go/train_go_5833.wav
#   inflating: s2_full_with_egg/go/train_go_5834.wav
#   inflating: s2_full_with_egg/go/train_go_5835.wav
#   inflating: s2_full_with_egg/go/train_go_5836.wav
#   inflating: s2_full_with_egg/go/train_go_5837.wav
#   inflating: s2_full_with_egg/go/train_go_5838.wav
#   inflating: s2_full_with_egg/go/train_go_5839.wav
#   inflating: s2_full_with_egg/go/train_go_5840.wav
#   inflating: s2_full_with_egg/go/train_go_5841.wav
#   inflating: s2_full_with_egg/go/train_go_5842.wav
#   inflating: s2_full_with_egg/go/train_go_5843.wav
#   inflating: s2_full_with_egg/go/train_go_5844.wav
#   inflating: s2_full_with_egg/go/train_go_5845.wav
#   inflating: s2_full_with_egg/go/train_go_5846.wav
#   inflating: s2_full_with_egg/go/train_go_5847.wav
#   inflating: s2_full_with_egg/go/train_go_5848.wav
#   inflating: s2_full_with_egg/go/train_go_5849.wav
#   inflating: s2_full_with_egg/go/train_go_5850.wav
#   inflating: s2_full_with_egg/go/train_go_5851.wav
#   inflating: s2_full_with_egg/go/train_go_5852.wav
#   inflating: s2_full_with_egg/go/train_go_5853.wav
#   inflating: s2_full_with_egg/go/train_go_5854.wav
#   inflating: s2_full_with_egg/go/train_go_5855.wav
#   inflating: s2_full_with_egg/go/train_go_5856.wav
#   inflating: s2_full_with_egg/go/train_go_5857.wav
#   inflating: s2_full_with_egg/go/train_go_5858.wav
#   inflating: s2_full_with_egg/go/train_go_5859.wav
#   inflating: s2_full_with_egg/go/train_go_5860.wav
#   inflating: s2_full_with_egg/go/train_go_5861.wav
#   inflating: s2_full_with_egg/go/train_go_5862.wav
#   inflating: s2_full_with_egg/go/train_go_5863.wav
#   inflating: s2_full_with_egg/go/train_go_5864.wav
#   inflating: s2_full_with_egg/go/train_go_5865.wav
#   inflating: s2_full_with_egg/go/train_go_5866.wav
#   inflating: s2_full_with_egg/go/train_go_5867.wav
#   inflating: s2_full_with_egg/go/train_go_5868.wav
#   inflating: s2_full_with_egg/go/train_go_5869.wav
#   inflating: s2_full_with_egg/go/train_go_5870.wav
#   inflating: s2_full_with_egg/go/train_go_5871.wav
#   inflating: s2_full_with_egg/go/train_go_5872.wav
#   inflating: s2_full_with_egg/go/train_go_5873.wav
#   inflating: s2_full_with_egg/go/train_go_5874.wav
#   inflating: s2_full_with_egg/go/train_go_5875.wav
#   inflating: s2_full_with_egg/go/train_go_5876.wav
#   inflating: s2_full_with_egg/go/train_go_5877.wav
#   inflating: s2_full_with_egg/go/train_go_5878.wav
#   inflating: s2_full_with_egg/go/train_go_5879.wav
#   inflating: s2_full_with_egg/go/train_go_5880.wav
#   inflating: s2_full_with_egg/go/train_go_5881.wav
#   inflating: s2_full_with_egg/go/train_go_5882.wav
#   inflating: s2_full_with_egg/go/train_go_5883.wav
#   inflating: s2_full_with_egg/go/train_go_5884.wav
#   inflating: s2_full_with_egg/go/train_go_5885.wav
#   inflating: s2_full_with_egg/go/train_go_5886.wav
#   inflating: s2_full_with_egg/go/train_go_5887.wav
#   inflating: s2_full_with_egg/go/train_go_5888.wav
#   inflating: s2_full_with_egg/go/train_go_5889.wav
#   inflating: s2_full_with_egg/go/train_go_5890.wav
#   inflating: s2_full_with_egg/go/train_go_5891.wav
#   inflating: s2_full_with_egg/go/train_go_5892.wav
#   inflating: s2_full_with_egg/go/train_go_5893.wav
#   inflating: s2_full_with_egg/go/train_go_5894.wav
#   inflating: s2_full_with_egg/go/train_go_5895.wav
#   inflating: s2_full_with_egg/go/train_go_5896.wav
#   inflating: s2_full_with_egg/go/train_go_5897.wav
#   inflating: s2_full_with_egg/go/train_go_5898.wav
#   inflating: s2_full_with_egg/go/train_go_5899.wav
#   inflating: s2_full_with_egg/go/train_go_5900.wav
#   inflating: s2_full_with_egg/go/train_go_5901.wav
#   inflating: s2_full_with_egg/go/train_go_5902.wav
#   inflating: s2_full_with_egg/go/train_go_5903.wav
#   inflating: s2_full_with_egg/go/train_go_5904.wav
#   inflating: s2_full_with_egg/go/train_go_5905.wav
#   inflating: s2_full_with_egg/go/train_go_5906.wav
#   inflating: s2_full_with_egg/go/train_go_5907.wav
#   inflating: s2_full_with_egg/go/train_go_5908.wav
#   inflating: s2_full_with_egg/go/train_go_5909.wav
#   inflating: s2_full_with_egg/go/train_go_5910.wav
#   inflating: s2_full_with_egg/go/train_go_5911.wav
#   inflating: s2_full_with_egg/go/train_go_5912.wav
#   inflating: s2_full_with_egg/go/train_go_5913.wav
#   inflating: s2_full_with_egg/go/train_go_5914.wav
#   inflating: s2_full_with_egg/go/train_go_5915.wav
#   inflating: s2_full_with_egg/go/train_go_5916.wav
#   inflating: s2_full_with_egg/go/train_go_5917.wav
#   inflating: s2_full_with_egg/go/train_go_5918.wav
#   inflating: s2_full_with_egg/go/train_go_5919.wav
#   inflating: s2_full_with_egg/go/train_go_5920.wav
#   inflating: s2_full_with_egg/go/train_go_5921.wav
#   inflating: s2_full_with_egg/go/train_go_5922.wav
#   inflating: s2_full_with_egg/go/train_go_5923.wav
#   inflating: s2_full_with_egg/go/train_go_5924.wav
#   inflating: s2_full_with_egg/go/train_go_5925.wav
#   inflating: s2_full_with_egg/go/train_go_5926.wav
#   inflating: s2_full_with_egg/go/train_go_5927.wav
#   inflating: s2_full_with_egg/go/train_go_5928.wav
#   inflating: s2_full_with_egg/go/train_go_5929.wav
#   inflating: s2_full_with_egg/go/train_go_5930.wav
#   inflating: s2_full_with_egg/go/train_go_5931.wav
#   inflating: s2_full_with_egg/go/train_go_5932.wav
#   inflating: s2_full_with_egg/go/train_go_5933.wav
#   inflating: s2_full_with_egg/go/train_go_5934.wav
#   inflating: s2_full_with_egg/go/train_go_5935.wav
#   inflating: s2_full_with_egg/go/train_go_5936.wav
#   inflating: s2_full_with_egg/go/train_go_5937.wav
#   inflating: s2_full_with_egg/go/train_go_5938.wav
#   inflating: s2_full_with_egg/go/train_go_5939.wav
#   inflating: s2_full_with_egg/go/train_go_5940.wav
#   inflating: s2_full_with_egg/go/train_go_5941.wav
#   inflating: s2_full_with_egg/go/train_go_5942.wav
#   inflating: s2_full_with_egg/go/train_go_5943.wav
#   inflating: s2_full_with_egg/go/train_go_5944.wav
#   inflating: s2_full_with_egg/go/train_go_5945.wav
#   inflating: s2_full_with_egg/go/train_go_5946.wav
#   inflating: s2_full_with_egg/go/train_go_5947.wav
#   inflating: s2_full_with_egg/go/train_go_5948.wav
#   inflating: s2_full_with_egg/go/train_go_5949.wav
#    creating: s2_full_with_egg/left/
#   inflating: s2_full_with_egg/left/train_left_4900.wav
#   inflating: s2_full_with_egg/left/train_left_4901.wav
#   inflating: s2_full_with_egg/left/train_left_4902.wav
#   inflating: s2_full_with_egg/left/train_left_4903.wav
#   inflating: s2_full_with_egg/left/train_left_4904.wav
#   inflating: s2_full_with_egg/left/train_left_4905.wav
#   inflating: s2_full_with_egg/left/train_left_4906.wav
#   inflating: s2_full_with_egg/left/train_left_4907.wav
#   inflating: s2_full_with_egg/left/train_left_4908.wav
#   inflating: s2_full_with_egg/left/train_left_4909.wav
#   inflating: s2_full_with_egg/left/train_left_4910.wav
#   inflating: s2_full_with_egg/left/train_left_4911.wav
#   inflating: s2_full_with_egg/left/train_left_4912.wav
#   inflating: s2_full_with_egg/left/train_left_4913.wav
#   inflating: s2_full_with_egg/left/train_left_4914.wav
#   inflating: s2_full_with_egg/left/train_left_4915.wav
#   inflating: s2_full_with_egg/left/train_left_4916.wav
#   inflating: s2_full_with_egg/left/train_left_4917.wav
#   inflating: s2_full_with_egg/left/train_left_4918.wav
#   inflating: s2_full_with_egg/left/train_left_4919.wav
#   inflating: s2_full_with_egg/left/train_left_4920.wav
#   inflating: s2_full_with_egg/left/train_left_4921.wav
#   inflating: s2_full_with_egg/left/train_left_4922.wav
#   inflating: s2_full_with_egg/left/train_left_4923.wav
#   inflating: s2_full_with_egg/left/train_left_4924.wav
#   inflating: s2_full_with_egg/left/train_left_4925.wav
#   inflating: s2_full_with_egg/left/train_left_4926.wav
#   inflating: s2_full_with_egg/left/train_left_4927.wav
#   inflating: s2_full_with_egg/left/train_left_4928.wav
#   inflating: s2_full_with_egg/left/train_left_4929.wav
#   inflating: s2_full_with_egg/left/train_left_4930.wav
#   inflating: s2_full_with_egg/left/train_left_4931.wav
#   inflating: s2_full_with_egg/left/train_left_4932.wav
#   inflating: s2_full_with_egg/left/train_left_4933.wav
#   inflating: s2_full_with_egg/left/train_left_4934.wav
#   inflating: s2_full_with_egg/left/train_left_4935.wav
#   inflating: s2_full_with_egg/left/train_left_4936.wav
#   inflating: s2_full_with_egg/left/train_left_4937.wav
#   inflating: s2_full_with_egg/left/train_left_4938.wav
#   inflating: s2_full_with_egg/left/train_left_4939.wav
#   inflating: s2_full_with_egg/left/train_left_4940.wav
#   inflating: s2_full_with_egg/left/train_left_4941.wav
#   inflating: s2_full_with_egg/left/train_left_4942.wav
#   inflating: s2_full_with_egg/left/train_left_4943.wav
#   inflating: s2_full_with_egg/left/train_left_4944.wav
#   inflating: s2_full_with_egg/left/train_left_4945.wav
#   inflating: s2_full_with_egg/left/train_left_4946.wav
#   inflating: s2_full_with_egg/left/train_left_4947.wav
#   inflating: s2_full_with_egg/left/train_left_4948.wav
#   inflating: s2_full_with_egg/left/train_left_4949.wav
#   inflating: s2_full_with_egg/left/train_left_4950.wav
#   inflating: s2_full_with_egg/left/train_left_4951.wav
#   inflating: s2_full_with_egg/left/train_left_4952.wav
#   inflating: s2_full_with_egg/left/train_left_4953.wav
#   inflating: s2_full_with_egg/left/train_left_4954.wav
#   inflating: s2_full_with_egg/left/train_left_4955.wav
#   inflating: s2_full_with_egg/left/train_left_4956.wav
#   inflating: s2_full_with_egg/left/train_left_4957.wav
#   inflating: s2_full_with_egg/left/train_left_4958.wav
#   inflating: s2_full_with_egg/left/train_left_4959.wav
#   inflating: s2_full_with_egg/left/train_left_4960.wav
#   inflating: s2_full_with_egg/left/train_left_4961.wav
#   inflating: s2_full_with_egg/left/train_left_4962.wav
#   inflating: s2_full_with_egg/left/train_left_4963.wav
#   inflating: s2_full_with_egg/left/train_left_4964.wav
#   inflating: s2_full_with_egg/left/train_left_4965.wav
#   inflating: s2_full_with_egg/left/train_left_4966.wav
#   inflating: s2_full_with_egg/left/train_left_4967.wav
#   inflating: s2_full_with_egg/left/train_left_4968.wav
#   inflating: s2_full_with_egg/left/train_left_4969.wav
#   inflating: s2_full_with_egg/left/train_left_4970.wav
#   inflating: s2_full_with_egg/left/train_left_4971.wav
#   inflating: s2_full_with_egg/left/train_left_4972.wav
#   inflating: s2_full_with_egg/left/train_left_4973.wav
#   inflating: s2_full_with_egg/left/train_left_4974.wav
#   inflating: s2_full_with_egg/left/train_left_4975.wav
#   inflating: s2_full_with_egg/left/train_left_4976.wav
# ...
#   inflating: s2_full_with_egg/zero/train_zero_4270.wav
#   inflating: s2_full_with_egg/zero/train_zero_4271.wav
#   inflating: s2_full_with_egg/zero/train_zero_4272.wav
#   inflating: s2_full_with_egg/zero/train_zero_4273.wav
#   inflating: s2_full_with_egg/zero/train_zero_4274.wav
#   inflating: s2_full_with_egg/zero/train_zero_4275.wav
#   inflating: s2_full_with_egg/zero/train_zero_4276.wav
#   inflating: s2_full_with_egg/zero/train_zero_4277.wav
#   inflating: s2_full_with_egg/zero/train_zero_4278.wav
#   inflating: s2_full_with_egg/zero/train_zero_4279.wav
#   inflating: s2_full_with_egg/zero/train_zero_4280.wav
#   inflating: s2_full_with_egg/zero/train_zero_4281.wav
#   inflating: s2_full_with_egg/zero/train_zero_4282.wav
#   inflating: s2_full_with_egg/zero/train_zero_4283.wav
#   inflating: s2_full_with_egg/zero/train_zero_4284.wav
#   inflating: s2_full_with_egg/zero/train_zero_4285.wav
#   inflating: s2_full_with_egg/zero/train_zero_4286.wav
#   inflating: s2_full_with_egg/zero/train_zero_4287.wav
#   inflating: s2_full_with_egg/zero/train_zero_4288.wav
#   inflating: s2_full_with_egg/zero/train_zero_4289.wav
#   inflating: s2_full_with_egg/zero/train_zero_4290.wav
#   inflating: s2_full_with_egg/zero/train_zero_4291.wav
#   inflating: s2_full_with_egg/zero/train_zero_4292.wav
#   inflating: s2_full_with_egg/zero/train_zero_4293.wav
#   inflating: s2_full_with_egg/zero/train_zero_4294.wav
#   inflating: s2_full_with_egg/zero/train_zero_4295.wav
#   inflating: s2_full_with_egg/zero/train_zero_4296.wav
#   inflating: s2_full_with_egg/zero/train_zero_4297.wav
#   inflating: s2_full_with_egg/zero/train_zero_4298.wav
#   inflating: s2_full_with_egg/zero/train_zero_4299.wav
#   inflating: s2_full_with_egg/zero/train_zero_4300.wav
#   inflating: s2_full_with_egg/zero/train_zero_4301.wav
#   inflating: s2_full_with_egg/zero/train_zero_4302.wav
#   inflating: s2_full_with_egg/zero/train_zero_4303.wav
#   inflating: s2_full_with_egg/zero/train_zero_4304.wav
#   inflating: s2_full_with_egg/zero/train_zero_4305.wav
#   inflating: s2_full_with_egg/zero/train_zero_4306.wav
#   inflating: s2_full_with_egg/zero/train_zero_4307.wav
#   inflating: s2_full_with_egg/zero/train_zero_4308.wav
#   inflating: s2_full_with_egg/zero/train_zero_4309.wav
#   inflating: s2_full_with_egg/zero/train_zero_4310.wav
#   inflating: s2_full_with_egg/zero/train_zero_4311.wav
#   inflating: s2_full_with_egg/zero/train_zero_4312.wav
#   inflating: s2_full_with_egg/zero/train_zero_4313.wav
#   inflating: s2_full_with_egg/zero/train_zero_4314.wav
#   inflating: s2_full_with_egg/zero/train_zero_4315.wav
#   inflating: s2_full_with_egg/zero/train_zero_4316.wav
#   inflating: s2_full_with_egg/zero/train_zero_4317.wav
#   inflating: s2_full_with_egg/zero/train_zero_4318.wav
#   inflating: s2_full_with_egg/zero/train_zero_4319.wav
#   inflating: s2_full_with_egg/zero/train_zero_4320.wav
#   inflating: s2_full_with_egg/zero/train_zero_4321.wav
#   inflating: s2_full_with_egg/zero/train_zero_4322.wav
#   inflating: s2_full_with_egg/zero/train_zero_4323.wav
#   inflating: s2_full_with_egg/zero/train_zero_4324.wav
#   inflating: s2_full_with_egg/zero/train_zero_4325.wav
#   inflating: s2_full_with_egg/zero/train_zero_4326.wav
#   inflating: s2_full_with_egg/zero/train_zero_4327.wav
#   inflating: s2_full_with_egg/zero/train_zero_4328.wav
#   inflating: s2_full_with_egg/zero/train_zero_4329.wav
#   inflating: s2_full_with_egg/zero/train_zero_4330.wav
#   inflating: s2_full_with_egg/zero/train_zero_4331.wav
#   inflating: s2_full_with_egg/zero/train_zero_4332.wav
#   inflating: s2_full_with_egg/zero/train_zero_4333.wav
#   inflating: s2_full_with_egg/zero/train_zero_4334.wav
#   inflating: s2_full_with_egg/zero/train_zero_4335.wav
#   inflating: s2_full_with_egg/zero/train_zero_4336.wav
#   inflating: s2_full_with_egg/zero/train_zero_4337.wav
#   inflating: s2_full_with_egg/zero/train_zero_4338.wav
#   inflating: s2_full_with_egg/zero/train_zero_4339.wav
#   inflating: s2_full_with_egg/zero/train_zero_4340.wav
#   inflating: s2_full_with_egg/zero/train_zero_4341.wav
#   inflating: s2_full_with_egg/zero/train_zero_4342.wav
#   inflating: s2_full_with_egg/zero/train_zero_4343.wav
#   inflating: s2_full_with_egg/zero/train_zero_4344.wav
#   inflating: s2_full_with_egg/zero/train_zero_4345.wav
#   inflating: s2_full_with_egg/zero/train_zero_4346.wav
#   inflating: s2_full_with_egg/zero/train_zero_4347.wav
#   inflating: s2_full_with_egg/zero/train_zero_4348.wav
#   inflating: s2_full_with_egg/zero/train_zero_4349.wav
#   inflating: s2_full_with_egg/zero/train_zero_4350.wav
#   inflating: s2_full_with_egg/zero/train_zero_4351.wav
#   inflating: s2_full_with_egg/zero/train_zero_4352.wav
#   inflating: s2_full_with_egg/zero/train_zero_4353.wav
#   inflating: s2_full_with_egg/zero/train_zero_4354.wav
#   inflating: s2_full_with_egg/zero/train_zero_4355.wav
#   inflating: s2_full_with_egg/zero/train_zero_4356.wav
#   inflating: s2_full_with_egg/zero/train_zero_4357.wav
#   inflating: s2_full_with_egg/zero/train_zero_4358.wav
#   inflating: s2_full_with_egg/zero/train_zero_4359.wav
#   inflating: s2_full_with_egg/zero/train_zero_4360.wav
#   inflating: s2_full_with_egg/zero/train_zero_4361.wav
#   inflating: s2_full_with_egg/zero/train_zero_4362.wav
#   inflating: s2_full_with_egg/zero/train_zero_4363.wav
#   inflating: s2_full_with_egg/zero/train_zero_4364.wav
#   inflating: s2_full_with_egg/zero/train_zero_4365.wav
#   inflating: s2_full_with_egg/zero/train_zero_4366.wav
#   inflating: s2_full_with_egg/zero/train_zero_4367.wav
#   inflating: s2_full_with_egg/zero/train_zero_4368.wav
#   inflating: s2_full_with_egg/zero/train_zero_4369.wav
#   inflating: s2_full_with_egg/zero/train_zero_4370.wav
#   inflating: s2_full_with_egg/zero/train_zero_4371.wav
#   inflating: s2_full_with_egg/zero/train_zero_4372.wav
#   inflating: s2_full_with_egg/zero/train_zero_4373.wav
#   inflating: s2_full_with_egg/zero/train_zero_4374.wav
#   inflating: s2_full_with_egg/zero/train_zero_4375.wav
#   inflating: s2_full_with_egg/zero/train_zero_4376.wav
#   inflating: s2_full_with_egg/zero/train_zero_4377.wav
#   inflating: s2_full_with_egg/zero/train_zero_4378.wav
#   inflating: s2_full_with_egg/zero/train_zero_4379.wav
#   inflating: s2_full_with_egg/zero/train_zero_4380.wav
#   inflating: s2_full_with_egg/zero/train_zero_4381.wav
#   inflating: s2_full_with_egg/zero/train_zero_4382.wav
#   inflating: s2_full_with_egg/zero/train_zero_4383.wav
#   inflating: s2_full_with_egg/zero/train_zero_4384.wav
#   inflating: s2_full_with_egg/zero/train_zero_4385.wav
#   inflating: s2_full_with_egg/zero/train_zero_4386.wav
#   inflating: s2_full_with_egg/zero/train_zero_4387.wav
#   inflating: s2_full_with_egg/zero/train_zero_4388.wav
#   inflating: s2_full_with_egg/zero/train_zero_4389.wav
#   inflating: s2_full_with_egg/zero/train_zero_4390.wav
#   inflating: s2_full_with_egg/zero/train_zero_4391.wav
#   inflating: s2_full_with_egg/zero/train_zero_4392.wav
#   inflating: s2_full_with_egg/zero/train_zero_4393.wav
#   inflating: s2_full_with_egg/zero/train_zero_4394.wav
#   inflating: s2_full_with_egg/zero/train_zero_4395.wav
#   inflating: s2_full_with_egg/zero/train_zero_4396.wav
#   inflating: s2_full_with_egg/zero/train_zero_4397.wav
#   inflating: s2_full_with_egg/zero/train_zero_4398.wav
#   inflating: s2_full_with_egg/zero/train_zero_4399.wav
#   inflating: s2_full_with_egg/zero/train_zero_4400.wav
#   inflating: s2_full_with_egg/zero/train_zero_4401.wav
#   inflating: s2_full_with_egg/zero/train_zero_4402.wav
#   inflating: s2_full_with_egg/zero/train_zero_4403.wav
#   inflating: s2_full_with_egg/zero/train_zero_4404.wav
#   inflating: s2_full_with_egg/zero/train_zero_4405.wav
#   inflating: s2_full_with_egg/zero/train_zero_4406.wav
#   inflating: s2_full_with_egg/zero/train_zero_4407.wav
#   inflating: s2_full_with_egg/zero/train_zero_4408.wav
#   inflating: s2_full_with_egg/zero/train_zero_4409.wav
#   inflating: s2_full_with_egg/zero/train_zero_4410.wav
#   inflating: s2_full_with_egg/zero/train_zero_4411.wav
#   inflating: s2_full_with_egg/zero/train_zero_4412.wav
#   inflating: s2_full_with_egg/zero/train_zero_4413.wav
#   inflating: s2_full_with_egg/zero/train_zero_4414.wav
#   inflating: s2_full_with_egg/zero/train_zero_4415.wav
#   inflating: s2_full_with_egg/zero/train_zero_4416.wav
#   inflating: s2_full_with_egg/zero/train_zero_4417.wav
#   inflating: s2_full_with_egg/zero/train_zero_4418.wav
#   inflating: s2_full_with_egg/zero/train_zero_4419.wav
#   inflating: s2_full_with_egg/zero/train_zero_4420.wav
#   inflating: s2_full_with_egg/zero/train_zero_4421.wav
#   inflating: s2_full_with_egg/zero/train_zero_4422.wav
#   inflating: s2_full_with_egg/zero/train_zero_4423.wav
#   inflating: s2_full_with_egg/zero/train_zero_4424.wav
#   inflating: s2_full_with_egg/zero/train_zero_4425.wav
#   inflating: s2_full_with_egg/zero/train_zero_4426.wav
#   inflating: s2_full_with_egg/zero/train_zero_4427.wav
#   inflating: s2_full_with_egg/zero/train_zero_4428.wav
#   inflating: s2_full_with_egg/zero/train_zero_4429.wav
#   inflating: s2_full_with_egg/zero/train_zero_4430.wav
#   inflating: s2_full_with_egg/zero/train_zero_4431.wav
#   inflating: s2_full_with_egg/zero/train_zero_4432.wav
#   inflating: s2_full_with_egg/zero/train_zero_4433.wav
#   inflating: s2_full_with_egg/zero/train_zero_4434.wav
#   inflating: s2_full_with_egg/zero/train_zero_4435.wav
#   inflating: s2_full_with_egg/zero/train_zero_4436.wav
#   inflating: s2_full_with_egg/zero/train_zero_4437.wav
#   inflating: s2_full_with_egg/zero/train_zero_4438.wav
#   inflating: s2_full_with_egg/zero/train_zero_4439.wav
#   inflating: s2_full_with_egg/zero/train_zero_4440.wav
#   inflating: s2_full_with_egg/zero/train_zero_4441.wav
#   inflating: s2_full_with_egg/zero/train_zero_4442.wav
#   inflating: s2_full_with_egg/zero/train_zero_4443.wav
#   inflating: s2_full_with_egg/zero/train_zero_4444.wav
#   inflating: s2_full_with_egg/zero/train_zero_4445.wav
#   inflating: s2_full_with_egg/zero/train_zero_4446.wav
#   inflating: s2_full_with_egg/zero/train_zero_4447.wav
#   inflating: s2_full_with_egg/zero/train_zero_4448.wav
#   inflating: s2_full_with_egg/zero/train_zero_4449.wav
#   inflating: s2_full_with_egg/zero/train_zero_4450.wav
#   inflating: s2_full_with_egg/zero/train_zero_4451.wav
#   inflating: s2_full_with_egg/zero/train_zero_4452.wav
#   inflating: s2_full_with_egg/zero/train_zero_4453.wav
#   inflating: s2_full_with_egg/zero/train_zero_4454.wav
#   inflating: s2_full_with_egg/zero/train_zero_4455.wav
#   inflating: s2_full_with_egg/zero/train_zero_4456.wav
#   inflating: s2_full_with_egg/zero/train_zero_4457.wav
#   inflating: s2_full_with_egg/zero/train_zero_4458.wav
#   inflating: s2_full_with_egg/zero/train_zero_4459.wav
#   inflating: s2_full_with_egg/zero/train_zero_4460.wav
#   inflating: s2_full_with_egg/zero/train_zero_4461.wav
#   inflating: s2_full_with_egg/zero/train_zero_4462.wav
#   inflating: s2_full_with_egg/zero/train_zero_4463.wav
#   inflating: s2_full_with_egg/zero/train_zero_4464.wav
#   inflating: s2_full_with_egg/zero/train_zero_4465.wav
#   inflating: s2_full_with_egg/zero/train_zero_4466.wav
#   inflating: s2_full_with_egg/zero/train_zero_4467.wav
#   inflating: s2_full_with_egg/zero/train_zero_4468.wav
#   inflating: s2_full_with_egg/zero/train_zero_4469.wav
#   inflating: s2_full_with_egg/zero/train_zero_4470.wav
#   inflating: s2_full_with_egg/zero/train_zero_4471.wav
#   inflating: s2_full_with_egg/zero/train_zero_4472.wav
#   inflating: s2_full_with_egg/zero/train_zero_4473.wav
#   inflating: s2_full_with_egg/zero/train_zero_4474.wav
#   inflating: s2_full_with_egg/zero/train_zero_4475.wav
#   inflating: s2_full_with_egg/zero/train_zero_4476.wav
#   inflating: s2_full_with_egg/zero/train_zero_4477.wav
#   inflating: s2_full_with_egg/zero/train_zero_4478.wav
#   inflating: s2_full_with_egg/zero/train_zero_4479.wav
#   inflating: s2_full_with_egg/zero/train_zero_4480.wav
#   inflating: s2_full_with_egg/zero/train_zero_4481.wav
#   inflating: s2_full_with_egg/zero/train_zero_4482.wav
#   inflating: s2_full_with_egg/zero/train_zero_4483.wav
#   inflating: s2_full_with_egg/zero/train_zero_4484.wav
#   inflating: s2_full_with_egg/zero/train_zero_4485.wav
#   inflating: s2_full_with_egg/zero/train_zero_4486.wav
#   inflating: s2_full_with_egg/zero/train_zero_4487.wav
#   inflating: s2_full_with_egg/zero/train_zero_4488.wav
#   inflating: s2_full_with_egg/zero/train_zero_4489.wav
#   inflating: s2_full_with_egg/zero/train_zero_4490.wav
#   inflating: s2_full_with_egg/zero/train_zero_4491.wav
#   inflating: s2_full_with_egg/zero/train_zero_4492.wav
#   inflating: s2_full_with_egg/zero/train_zero_4493.wav
#   inflating: s2_full_with_egg/zero/train_zero_4494.wav
#   inflating: s2_full_with_egg/zero/train_zero_4495.wav
#   inflating: s2_full_with_egg/zero/train_zero_4496.wav
#   inflating: s2_full_with_egg/zero/train_zero_4497.wav
#   inflating: s2_full_with_egg/zero/train_zero_4498.wav
#   inflating: s2_full_with_egg/zero/train_zero_4499.wav
#   inflating: s2_full_with_egg/zero/train_zero_4500.wav
#   inflating: s2_full_with_egg/zero/train_zero_4501.wav
#   inflating: s2_full_with_egg/zero/train_zero_4502.wav
#   inflating: s2_full_with_egg/zero/train_zero_4503.wav
#   inflating: s2_full_with_egg/zero/train_zero_4504.wav
#   inflating: s2_full_with_egg/zero/train_zero_4505.wav
#   inflating: s2_full_with_egg/zero/train_zero_4506.wav
#   inflating: s2_full_with_egg/zero/train_zero_4507.wav
#   inflating: s2_full_with_egg/zero/train_zero_4508.wav
#   inflating: s2_full_with_egg/zero/train_zero_4509.wav
#   inflating: s2_full_with_egg/zero/train_zero_4510.wav
#   inflating: s2_full_with_egg/zero/train_zero_4511.wav
#   inflating: s2_full_with_egg/zero/train_zero_4512.wav
#   inflating: s2_full_with_egg/zero/train_zero_4513.wav
#   inflating: s2_full_with_egg/zero/train_zero_4514.wav
#   inflating: s2_full_with_egg/zero/train_zero_4515.wav
#   inflating: s2_full_with_egg/zero/train_zero_4516.wav
#   inflating: s2_full_with_egg/zero/train_zero_4517.wav
#   inflating: s2_full_with_egg/zero/train_zero_4518.wav
#   inflating: s2_full_with_egg/zero/train_zero_4519.wav
#   inflating: s2_full_with_egg/zero/train_zero_4520.wav
#   inflating: s2_full_with_egg/zero/train_zero_4521.wav
#   inflating: s2_full_with_egg/zero/train_zero_4522.wav
#   inflating: s2_full_with_egg/zero/train_zero_4523.wav
#   inflating: s2_full_with_egg/zero/train_zero_4524.wav
#   inflating: s2_full_with_egg/zero/train_zero_4525.wav
#   inflating: s2_full_with_egg/zero/train_zero_4526.wav
#   inflating: s2_full_with_egg/zero/train_zero_4527.wav
#   inflating: s2_full_with_egg/zero/train_zero_4528.wav
#   inflating: s2_full_with_egg/zero/train_zero_4529.wav
#   inflating: s2_full_with_egg/zero/train_zero_4530.wav
#   inflating: s2_full_with_egg/zero/train_zero_4531.wav
#   inflating: s2_full_with_egg/zero/train_zero_4532.wav
#   inflating: s2_full_with_egg/zero/train_zero_4533.wav
#   inflating: s2_full_with_egg/zero/train_zero_4534.wav
#   inflating: s2_full_with_egg/zero/train_zero_4535.wav
#   inflating: s2_full_with_egg/zero/train_zero_4536.wav
#   inflating: s2_full_with_egg/zero/train_zero_4537.wav
#   inflating: s2_full_with_egg/zero/train_zero_4538.wav
#   inflating: s2_full_with_egg/zero/train_zero_4539.wav
#   inflating: s2_full_with_egg/zero/train_zero_4540.wav
#   inflating: s2_full_with_egg/zero/train_zero_4541.wav
#   inflating: s2_full_with_egg/zero/train_zero_4542.wav
#   inflating: s2_full_with_egg/zero/train_zero_4543.wav
#   inflating: s2_full_with_egg/zero/train_zero_4544.wav
#   inflating: s2_full_with_egg/zero/train_zero_4545.wav
#   inflating: s2_full_with_egg/zero/train_zero_4546.wav
#   inflating: s2_full_with_egg/zero/train_zero_4547.wav
#   inflating: s2_full_with_egg/zero/train_zero_4548.wav
#   inflating: s2_full_with_egg/zero/train_zero_4549.wav

# %%
class CustomSpeechDataset(torch.utils.data.Dataset):
  def __init__(self, path, typ='train', transforms=None):

    assert typ == 'train' or typ == 'test', 'typ must be either "train" or "test"'

    self.typ = typ
    self.transforms = transforms
    self.targets = []

    if self.typ == 'train':
      self.class_names = sorted(os.listdir(path))
      num_classes = len(self.class_names)

      for class_idx, class_name in enumerate(self.class_names):
        class_dirx = os.path.join(path, class_name)
        wav_list = os.listdir(class_dirx)

        for wav_file in wav_list:
          self.targets.append({
              'filename': wav_file,
              'path': os.path.join(class_dirx, wav_file),
              'class': class_name
          })

    if self.typ == 'test':
      wav_list = os.listdir(path)
      for wav_file in wav_list:
        self.targets.append({
            'filename': wav_file,
            'path': os.path.join(path, wav_file)
        })
  
  def __len__(self):
    return len(self.targets)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx.tolist()

    # sr is the sampling rate
    signal, sr = torchaudio.load(self.targets[idx]['path'], normalization=True)
    filename = self.targets[idx]['filename']

    if self.transforms:
      for transform in self.transforms:
        signal = transform(signal)

    if self.typ == 'train':
      clx_name = self.targets[idx]['class']
      return filename, signal, sr, clx_name
    
    elif self.typ == 'test':
      return filename, signal, sr

# helper function to check the time taken to train an epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
fd = CustomSpeechDataset(path='s2_full_with_egg', typ='train')
train_size = int(len(fd)*0.8)
valid_size = len(fd) - train_size
print(train_size, valid_size)
# train test split
#train_set, valid_set = torch.utils.data.random_split(fd, [train_size, valid_size])
# Out:
# 6160 1540

# %%
# turn the custom dataset into a list of data
full_dataset = list(fd)
full_dataset[:2]
# Out:
# [('train_bird_8685.wav',
#   tensor([[ 3.0518e-05,  3.0518e-05,  3.0518e-05,  ..., -1.4648e-03,
#            -1.1292e-03, -1.0376e-03]]),
#   16000,
#   'bird'),
#  ('train_bird_8538.wav',
#   tensor([[0.0117, 0.0117, 0.0117,  ..., 0.0172, 0.0180, 0.0143]]),
#   16000,
#   'bird')]

# %%
full_dataset[499:501]
# Out:
# [('train_cat_7747.wav',
#   tensor([[9.1553e-05, 6.1035e-05, 0.0000e+00,  ..., 3.0518e-05, 6.1035e-05,
#            0.0000e+00]]),
#   16000,
#   'cat'),
#  ('train_cat_7882.wav',
#   tensor([[-0.0134, -0.0141, -0.0155,  ..., -0.0180, -0.0192, -0.0180]]),
#   16000,
#   'cat')]

# %%
full_dataset[1]
# Out:
# ('train_bird_8538.wav',
#  tensor([[0.0117, 0.0117, 0.0117,  ..., 0.0172, 0.0180, 0.0143]]),
#  16000,
#  'bird')

# %%
len(full_dataset)
# Out:
# 7700

# %%
labels = fd.class_names
print(labels)
# Out:
# ['bird', 'cat', 'chicken', 'dog', 'down', 'eight', 'falcon', 'five', 'four', 'go', 'left', 'nine', 'one', 'right', 'seven', 'six', 'snake', 'stop', 'three', 'two', 'up', 'zero']

# %%
labels_to_indices = {}
for idx, l in enumerate(labels):
  labels_to_indices[l] = idx

# %%
print(labels_to_indices)
# Out:
# {'bird': 0, 'cat': 1, 'chicken': 2, 'dog': 3, 'down': 4, 'eight': 5, 'falcon': 6, 'five': 7, 'four': 8, 'go': 9, 'left': 10, 'nine': 11, 'one': 12, 'right': 13, 'seven': 14, 'six': 15, 'snake': 16, 'stop': 17, 'three': 18, 'two': 19, 'up': 20, 'zero': 21}

# %% [markdown]
# ## Manual split of data to the different classes
# Since the data is in order, we can do this way

# %%
multiplier = 350

bird_list = full_dataset[:1*multiplier]
cat_list = full_dataset[1*multiplier:2*multiplier]
chicken_list = full_dataset[2*multiplier:3*multiplier]
dog_list = full_dataset[3*multiplier:4*multiplier]
down_list = full_dataset[4*multiplier:5*multiplier]
eight_list = full_dataset[5*multiplier:6*multiplier]
falcon_list = full_dataset[6*multiplier:7*multiplier]
five_list = full_dataset[7*multiplier:8*multiplier]
four_list = full_dataset[8*multiplier:9*multiplier]
go_list = full_dataset[9*multiplier:10*multiplier]
left_list = full_dataset[10*multiplier:11*multiplier]
nine_list = full_dataset[11*multiplier:12*multiplier]
one_list = full_dataset[12*multiplier:13*multiplier]
right_list = full_dataset[13*multiplier:14*multiplier]
seven_list = full_dataset[14*multiplier:15*multiplier]
six_list = full_dataset[15*multiplier:16*multiplier]
snake_list = full_dataset[16*multiplier:17*multiplier]
stop_list = full_dataset[17*multiplier:18*multiplier]
three_list = full_dataset[18*multiplier:19*multiplier]
two_list = full_dataset[19*multiplier:20*multiplier]
up_list = full_dataset[20*multiplier:21*multiplier]
zero_list = full_dataset[21*multiplier:]

# %%
# sanity check
assert bird_list[0][3] == bird_list[-1][3]
assert eight_list[0][3] == eight_list[-1][3]
assert falcon_list[0][3] == falcon_list[-1][3]
assert five_list[0][3] == five_list[-1][3]
assert four_list[0][3] == four_list[-1][3]
assert nine_list[0][3] == nine_list[-1][3]
assert one_list[0][3] == one_list[-1][3]
assert seven_list[0][3] == seven_list[-1][3]
assert six_list[0][3] == six_list[-1][3]
assert snake_list[0][3] == snake_list[-1][3]
assert three_list[0][3] == three_list[-1][3]
assert two_list[0][3] == two_list[-1][3]
assert zero_list[0][3] == zero_list[-1][3]

# %%
len(eight_list) == len(bird_list)
# Out:
# True

# %% [markdown]
# ## Manual kFold implementation
# Create kFold data for later part of this notebook

# %%
# define a class that gets the complement of the list
class ComplementList(list):
    def __getitem__(self, val):
        if type(val) is slice and val.step == 'c':
            copy = self[:]
            copy[val.start:val.stop] = []
            return copy

        return super(ComplementList, self).__getitem__(val)

# testing the class implementation
l = ComplementList([1,2,3,4,5])
print(l[2:4:'c']) # [1, 5]
# Out:
# [1, 2, 5]

# %%
# define the k-fold constant
K = 5

# k is the k-fold constant, fd is the full dataset in list
def manual_k_fold(k, fd, fd_length):
    val_list = []
    train_list = []

    # randomise the dataset first
    random.shuffle(fd)

    # get the combinations of splits for the validation set
    for i in tqdm(range(k)):
        val_list.append(fd[int((i/k)*fd_length):int(((i+1)/k)*fd_length)])
        clist = ComplementList(fd)
        train_list.append(clist[int((i/k)*fd_length):int(((i+1)/k)*fd_length):'c'])

    return val_list, train_list

# %%
# extend the code by doing a separate split first
val_list_0, train_list_0 = manual_k_fold(K, bird_list, multiplier)
val_list_1, train_list_1 = manual_k_fold(K, eight_list, multiplier)
val_list_2, train_list_2 = manual_k_fold(K, falcon_list, multiplier)
val_list_3, train_list_3 = manual_k_fold(K, five_list, multiplier)
val_list_4, train_list_4 = manual_k_fold(K, four_list, multiplier)
val_list_5, train_list_5 = manual_k_fold(K, nine_list, multiplier)
val_list_6, train_list_6 = manual_k_fold(K, one_list, multiplier)
val_list_7, train_list_7 = manual_k_fold(K, seven_list, multiplier)
val_list_8, train_list_8 = manual_k_fold(K, six_list, multiplier)
val_list_9, train_list_9 = manual_k_fold(K, snake_list, multiplier)
val_list_10, train_list_10 = manual_k_fold(K, three_list, multiplier)
val_list_11, train_list_11 = manual_k_fold(K, two_list, multiplier)
val_list_12, train_list_12 = manual_k_fold(K, zero_list, multiplier)

val_list_13, train_list_13 = manual_k_fold(K, cat_list, multiplier)
val_list_14, train_list_14 = manual_k_fold(K, chicken_list, multiplier)
val_list_15, train_list_15 = manual_k_fold(K, dog_list, multiplier)
val_list_16, train_list_16 = manual_k_fold(K, down_list, multiplier)
val_list_17, train_list_17 = manual_k_fold(K, go_list, multiplier)
val_list_18, train_list_18 = manual_k_fold(K, left_list, multiplier)
val_list_19, train_list_19 = manual_k_fold(K, right_list, multiplier)
val_list_20, train_list_20 = manual_k_fold(K, stop_list, multiplier)
val_list_21, train_list_21 = manual_k_fold(K, up_list, multiplier)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 19472.16it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19897.08it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1918.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4090.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 3379.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 3277.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 3923.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14583.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2186.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 7460.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2116.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5667.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5546.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 841.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1522.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 6909.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5117.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4392.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 20887.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2043.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5066.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10798.93it/s]

# %%
val_list_list = [val_list_0,val_list_1,val_list_2,val_list_3,val_list_4,val_list_5,val_list_6,
                 val_list_7,val_list_8,val_list_9,val_list_10,val_list_11,val_list_12,val_list_13,
                 val_list_14,val_list_15,val_list_16,val_list_17,val_list_18,val_list_19,val_list_20,
                 val_list_21]

train_list_list = [train_list_0, train_list_1, train_list_2,train_list_3,train_list_4,train_list_5, train_list_6,
                 train_list_7, train_list_8, train_list_9, train_list_10, train_list_11, train_list_12, train_list_13,
                 train_list_14, train_list_15, train_list_16, train_list_17, train_list_18, train_list_19, train_list_20,
                 train_list_21]

# %%
# merge the files 
train_list = []
val_list = []
# merge the files into a list
for i in tqdm(range(K)):
    train_temp = []
    val_temp = []
    for j in range(len(val_list_list)):
        train_temp += train_list_list[j][i]
        val_temp += val_list_list[j][i]
    train_list.append(train_temp)
    val_list.append(val_temp)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 3389.06it/s]

# %%
len(val_temp), len(train_temp), len(train_list), len(val_list)
# Out:
# (1540, 6160, 5, 5)

# %%
#val_list, train_list = manual_k_fold(K, full_dataset, len(full_dataset))
#len(train_list[0]) , len(val_list[0])

# %%
# an example
# [fold][item set][particular file]
#print(val_list[0][0][0]) 
#print(val_list[1][0][0]) 
#print(val_list[2][0][0]) 
#print(val_list[3][0][0]) 
#print(val_list[4][0][0])

# %%
# shuffle the data to let the model generalise better
for i in range(K):
    random.shuffle(train_list[i])
    random.shuffle(val_list[i])

# %%
# random check
train_list[0][1]
# Out:
# ('train_nine_6471.wav',
#  tensor([[6.1035e-05, 3.0518e-05, 9.1553e-05,  ..., 7.5073e-03, 8.0261e-03,
#           8.2092e-03]]),
#  16000,
#  'nine')

# %% [markdown]
# ## Get the data distribution of each class

# %%
def train_data_distribution(data):
    train_filename_list = []
    train_label_list = []
    for i in range(len(data)):
        train_filename_list.append(data[i][0])
        train_label_list.append(data[i][3])

    # make to dataframe
    train_tuple = list(zip(train_filename_list, train_label_list))
    train_df = pd.DataFrame(train_tuple, columns=['train_filename', 'train_label'])

    return train_df

# %%
for i in range(K):
    print(f"Train Set {i+1}")
    train_dist = train_data_distribution(train_list[i])
    #print(train_dist.head(3))
    # find the count of each label to check distribution of the labels
    print(train_dist["train_label"].value_counts())
    print()
# Out:
# Train Set 1
# nine       280
# right      280
# six        280
# stop       280
# two        280
# cat        280
# four       280
# seven      280
# zero       280
# dog        280
# falcon     280
# five       280
# down       280
# three      280
# chicken    280
# one        280
# left       280
# go         280
# eight      280
# up         280
# snake      280
# bird       280
# Name: train_label, dtype: int64
#
# Train Set 2
# nine       280
# right      280
# six        280
# stop       280
# two        280
# cat        280
# four       280
# seven      280
# zero       280
# dog        280
# falcon     280
# five       280
# down       280
# three      280
# chicken    280
# one        280
# left       280
# go         280
# eight      280
# up         280
# snake      280
# bird       280
# Name: train_label, dtype: int64
#
# Train Set 3
# nine       280
# right      280
# six        280
# stop       280
# two        280
# cat        280
# four       280
# seven      280
# zero       280
# dog        280
# falcon     280
# five       280
# down       280
# three      280
# chicken    280
# one        280
# left       280
# go         280
# eight      280
# up         280
# snake      280
# bird       280
# Name: train_label, dtype: int64
#
# Train Set 4
# nine       280
# right      280
# six        280
# stop       280
# two        280
# cat        280
# four       280
# seven      280
# zero       280
# dog        280
# falcon     280
# five       280
# down       280
# three      280
# chicken    280
# one        280
# left       280
# go         280
# eight      280
# up         280
# snake      280
# bird       280
# Name: train_label, dtype: int64
#
# Train Set 5
# nine       280
# right      280
# six        280
# stop       280
# two        280
# cat        280
# four       280
# seven      280
# zero       280
# dog        280
# falcon     280
# five       280
# down       280
# three      280
# chicken    280
# one        280
# left       280
# go         280
# eight      280
# up         280
# snake      280
# bird       280
# Name: train_label, dtype: int64

# %% [markdown]
# ## Look at one example from the training set

# %%
train_list[0][1]
# Out:
# ('train_nine_6471.wav',
#  tensor([[6.1035e-05, 3.0518e-05, 9.1553e-05,  ..., 7.5073e-03, 8.0261e-03,
#           8.2092e-03]]),
#  16000,
#  'nine')

# %%
filename, waveform, sample_rate, label_id = train_list[0][1]

# %%
print("Shape of waveform: {}".format(waveform.size()))
print("Sample rate of waveform: {}".format(sample_rate))

# Let's plot the waveform using matplotlib
# We observe that the main audio activity happens at the later end of the clip
plt.plot(waveform.t().numpy());
# Out:
# Shape of waveform: torch.Size([1, 16000])
# Sample rate of waveform: 16000

# %%
# let's play the audio clip and hear it for ourselves!
ipd.Audio(waveform.numpy(), rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Constant Sample Lengths
# In order to insert our features into a model, we have to ensure that the features are of the same size. Below, we see that the sample length varies across the audio clips.
#
# Let's pad the audio clips to a maximum sample length of 16000. (16000 sample length is equal to 1 second at 16,000 Hz sampling rate)
# We will pad audio clips which are less than 1 second in length, with parts of itself.

# %%
# checking the first fold
audio_lens = []
for i in range(len(train_list[0])):
  audio_lens.append(train_list[0][i][1].size(1))

print('Max Sample Length:', max(audio_lens))
print('Min Sample Length:', min(audio_lens))
# Out:
# Max Sample Length: 16000
# Min Sample Length: 16000

# %% [markdown]
# ## Fixed Hyperparameters

# %%
# data augmentation -> have to fix this two, as it is a global implementation
# create multiple notebooks for different values of these two hyperparameters
#TIME_MASK_PARAM = 5
#FREQ_MASK_PARAM = 5

# %% [markdown]
# ## Data Augmentation
#
# Since the min and the max length is the same and hence no need to pad the audio, else can run PadAudio and the shorter ones will be repeated with its own audio
#
# We will do a simple data augmentation process in order to increase the variations in our dataset.
#
# In the audio domain, the augmentation technique known as [SpecAugment](https://arxiv.org/abs/1904.08779) is often used. It makes use of 3 steps:
# - Time Warp (warps the spectrogram to the left or right) 2nd row
# - Frequency Masking (randomly masks a range of frequencies) 3rd row
# - Time Masking (randomly masks a range of time) 4th row
#
# ![specaugment pic](https://drive.google.com/uc?export=view&id=1C085-PlXVhjzh4kzCy869VHRGwC3aDHJ)
#
# As Time Warp is computationally intensive and does not contribute significant improvement in results, we shall simply use Frequency and Time Masking in this example.

# %%
# pad the audio to the same length
class PadAudio(torch.nn.Module):
    def __init__(self, req_length = 16000):
        super().__init__()
        self.req_length = req_length

    def forward(self, waveform):
        while waveform.size(1) < self.req_length:
        # example if audio length is 15800 and max is 16000, the remaining 200 samples will be concatenated
        # with the FIRST 200 samples of the waveform itself again (repetition)
            waveform = torch.cat((waveform, waveform[:, :self.req_length - waveform.size(1)]), axis=1)
        return waveform

# Log-Mel Transform here to get ready to train with our RNN model later on
class LogMelTransform(torch.nn.Module):

    def __init__(self, log_offset = 1e-6):
        super().__init__()
        self.log_offset = log_offset

    def forward(self, melspectrogram):
        return torch.log(melspectrogram + self.log_offset)

class GaussianNoise(nn.Module):
    """Gaussian noise regularizer.

    Args:
        sigma (float, optional): relative standard deviation used to generate the
            noise. Relative means that it will be multiplied by the magnitude of
            the value your are adding the noise to. This means that sigma can be
            the same regardless of the scale of the vector.
        is_relative_detach (bool, optional): whether to detach the variable before
            computing the scale of the noise. If `False` then the scale of the noise
            won't be seen as a constant but something to optimize: this will bias the
            network to generate vectors with smaller values.
    """
    def __init__(self, sigma=0.1, is_relative_detach=True):
        super().__init__()
        self.sigma = sigma
        self.is_relative_detach = is_relative_detach
        self.register_buffer('noise', torch.tensor(0))

    def forward(self, x):
        if self.training and self.sigma != 0:
            scale = self.sigma * x.detach() if self.is_relative_detach else self.sigma * x
            sampled_noise = self.noise.expand(*x.size()).float().normal_() * scale
            x = x + sampled_noise
        return x 

# define a transformation sequence
def transform_sequence(time_mask, freq_mask, sigma=0.1):
    transformations = []
    transformations.append(PadAudio())
    transformations.append(MelSpectrogram(sample_rate = 16000, n_mels = 128))
    transformations.append(LogMelTransform())
    #eval_transformations = transformations.copy()
    # Noise Injection
    transformations.append(GaussianNoise(sigma=sigma, is_relative_detach=True))
    # for challenge 4
    eval_transformations = transformations.copy()
    # a maximum of 5 time steps will be masked
    transformations.append(TimeMasking(time_mask_param = time_mask)) 
    # maximum of 3 freq channels will be masked
    transformations.append(FrequencyMasking(freq_mask_param = freq_mask))
    return transformations, eval_transformations

# %%
TM1, FM1, SIGMA1 = 5, 9, 0.7
TM2, FM2, SIGMA2 = 5, 5, 1.2

# %%
transformations, eval_transformations = transform_sequence(time_mask=5, freq_mask=9, sigma=0.7)
print(transformations)
# Out:
# [PadAudio(), MelSpectrogram(
#   (spectrogram): Spectrogram()
#   (mel_scale): MelScale()
# ), LogMelTransform(), GaussianNoise(), TimeMasking(), FrequencyMasking()]

# %%
transformations2, _ = transform_sequence(time_mask=5, freq_mask=5, sigma=1.2)
print(transformations)
# Out:
# [PadAudio(), MelSpectrogram(
#   (spectrogram): Spectrogram()
#   (mel_scale): MelScale()
# ), LogMelTransform(), GaussianNoise(), TimeMasking(), FrequencyMasking()]

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.

# %%
# Fixed parameters
NUM_WORKERS = 4
PIN_MEMORY = True if device == 'cuda' else False

def train_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate, label

    tensors, targets, filenames = [], [], []

    # Gather in lists, and encode labels as indices
    for filename, waveform, sample_rate, label in batch:

        # duplicate one copy of plain data
        waveform_org = waveform.clone()

        # apply transformations
        for transform in transformations:
            waveform = transform(waveform)
        
        waveform = waveform.squeeze().T
        tensors += [waveform]
        targets += [labels_to_indices[label]]
        filenames += [filename]

        # append the original waveform
        for transform2 in transformations2:
            waveform_org = transform2(waveform_org)

        waveform_org = waveform_org.squeeze().T
        tensors += [waveform_org]
        targets += [labels_to_indices[label]]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)
    targets = torch.LongTensor(targets)

    return (tensors, targets, filenames)

def eval_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate, label

    tensors, targets, filenames = [], [], []

    # Gather in lists, and encode labels as indices
    for filename, waveform, sample_rate, label in batch:
        # apply transformations
        for transform in eval_transformations:
            waveform = transform(waveform)
        waveform = waveform.squeeze().T
        tensors += [waveform]
        targets += [labels_to_indices[label]]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)
    targets = torch.LongTensor(targets)
    filenames += [filename]

    return (tensors, targets, filenames)

def loader(train_set, valid_set, batch_size=64, num_workers=NUM_WORKERS, pin_mem=PIN_MEMORY):
    # implementing the loader function
    train_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=batch_size,
        shuffle=True,
        drop_last=False,
        collate_fn=train_collate_fn,
        num_workers=num_workers,
        pin_memory=pin_mem,
    )

    valid_loader = torch.utils.data.DataLoader(
        valid_set,
        batch_size=batch_size,
        shuffle=False,
        drop_last=False,
        collate_fn=eval_collate_fn,
        num_workers=num_workers,
        pin_memory=pin_mem,
    )

    return train_loader, valid_loader

# %% [markdown]
# ## Setting up and defining the Model and training loop
#
# In this speech classification example, we will make use of a Long-Short-Term Memory Recurrent Neural Network (LSTM-RNN).

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, device, classes=None, drop_flag=False, drop=0.5):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        
        self.drop_flag = drop_flag
        self.dropout = torch.nn.Dropout(drop)

        # hidden_size * 2 cuz bidirectional
        self.fc = nn.Linear(hidden_size*2, num_classes)
        self.device = device
        self.classes = classes

    def forward(self, x):
        # Set initial hidden and cell states
        batch_size = x.size(0)
        # bidirectional so need to multiply the layers by 2 for initial state
        h0 = torch.zeros(self.num_layers*2, batch_size, self.hidden_size).to(self.device) 

        # only applicable to LSTM because LSTM got 2 gates but GRU only has one!!!
        #c0 = torch.zeros(self.num_layers*2, batch_size, self.hidden_size).to(self.device) 
        
        # Forward propagate GRU
        out, _ = self.gru(x, h0.detach())  # shape = (batch_size, seq_length, hidden_size)
        # lstm implementation
        #out, _ = self.gru(x, (h0, c0))  # shape = (batch_size, seq_length, hidden_size)
        
        if self.drop_flag:
            out = self.dropout(out)

        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

    def predict(self, x):
        '''Predict one label from one sample's features'''
        # x: feature from a sample, LxN
        #   L is length of sequency
        #   N is feature dimension
        x = torch.tensor(x[np.newaxis, :], dtype=torch.float32)
        x = x.to(self.device)
        outputs = self.forward(x)
        _, predicted = torch.max(outputs.data, 1)
        predicted_index = predicted.item()
        return predicted_index


'''# initialize the model class
model = RNN(input_size=128, 
            hidden_size=HIDDEN_SIZE, 
            num_layers=NUM_LAYERS, 
            num_classes=len(labels), 
            device=device, 
            classes=labels).to(device)
print(model)'''

# define a function to train the model
def fit(model, train_loader, valid_loader, num_epochs, fold_num, optim_flag='adam'):
    # fixed configuration
    criterion = nn.CrossEntropyLoss()
    
    # choice of optimizers
    if optim_flag == 'adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    elif optim_flag == 'sgd99':
        optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.99)
    elif optim_flag == 'sgd90':
        optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
    elif optim_flag == 'adamw':
        optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3) # included a weight decay of 1e-02 for adam
    elif optim_flag == 'adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=1e-2)
    elif optim_flag == 'adadelta':
        optimizer = torch.optim.Adadelta(model.parameters(), lr=1)
    elif optim_flag == 'adamax':
        optimizer = torch.optim.Adamax(model.parameters(), lr=2e-3)
    else:
        return "No such optimizer, try again"

    # set the LR scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 
                                                           mode='min', 
                                                           factor=0.05, 
                                                           patience=3, 
                                                           min_lr=1e-5,
                                                           verbose=True)
    
    # fixed parameters to perform early stopping
    n_epochs_stop = 5
    epochs_no_improve = 0
    early_stop = False
    min_val_loss = np.inf
    threshold = 0.0001
    optimizer.zero_grad()

    # declare the fold number
    print(f'---------- Fold Number: {fold_num} ----------')

    # start the training loop
    for epoch in range(1,num_epochs+1):

        start_time = time.time()
        # training steps
        model.train()
        count_correct, count_total = 0, 0
        for idx, (features, targets, filenames) in enumerate(train_loader):

            features = features.to(device)
            targets = targets.to(device)

            # forward pass
            outputs = model(features)
            loss = criterion(outputs, targets)

            # backward pass
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            # training results
            _, argmax = torch.max(outputs, 1)
            count_correct += (targets == argmax.squeeze()).sum().item()
            count_total += targets.size(0)

        train_acc = count_correct / count_total
    
        # evaluation steps
        model.eval()
        count_correct, count_total = 0, 0
        val_pred_list, val_filename_list = [], []
        
        with torch.no_grad():
            for idx, (features, targets, filenames) in enumerate(valid_loader):

                features = features.to(device)
                targets = targets.to(device)

                # forward pass
                val_outputs = model(features)
                val_loss = criterion(val_outputs, targets)

                # validation results
                _, argmax = torch.max(val_outputs, 1)
                count_correct += (targets == argmax.squeeze()).sum().item()
                count_total += targets.size(0)
                val_pred_list += argmax.cpu().tolist()
                val_filename_list += filenames
        end_time = time.time()

        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        # print results
        valid_acc = count_correct / count_total
        if epoch<=3 or epoch%5==0:
            print('Epoch [{}/{}]: Train loss = {:.4f}, Train accuracy = {:.2f}, Valid loss = {:.4f}, Valid accuracy = {:.2f}' 
                    .format(epoch, num_epochs, loss.item(), 100*train_acc, val_loss.item(), 100*valid_acc))
            print(f'Time taken for Epoch {epoch}: {epoch_mins}m {epoch_secs}s')
        
        # add the scheduler code
        scheduler.step(val_loss)

        # --- EARLY STOPPING CONDITION ---
        if val_loss.item() < min_val_loss+threshold: # give some threshold to make the learning less strict
            # resets the no improve counter
            epochs_no_improve = 0
            min_val_loss = val_loss.item()
        else: # val_loss no improvement
            epochs_no_improve +=1
            print(f"Validation Loss did not improve count: {epochs_no_improve}")
            # set this line as min now
            min_val_loss = val_loss.item()
        if epoch > 5 and epochs_no_improve == n_epochs_stop:
            print("Training stopped due to early stopping!")
            break
        else:
            continue

    return val_loss.item(), 100*valid_acc, val_pred_list, val_filename_list, loss.item(), 100*train_acc

# %% [markdown]
# ## Configuration for a trained model
# - Declare hyperparameters
# - Training the model
# - Check and save the best fold
# - F1-score analysis
# - Confusion Matrix
# - Load model back to try it on the test set

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# # Can add the additional data in this function and pass as parameters

# %%
# ----- TRAINING THE MODEL -----
def train_helper(num_folds, train_list, val_list, batch_size, hidden_size, num_layers, epochs, optim_flag='adam',drop_flag=False, drop=0.5):

    # data loader for all the k-fold datasets
    train_loader_list = []
    valid_loader_list = []

    for i in range(num_folds):
        train_loader, valid_loader = loader(train_list[i], val_list[i], batch_size)
        train_loader_list.append(train_loader)
        valid_loader_list.append(valid_loader)

    # initialise list to store the kth folds results
    loss_list = [] # validation
    acc_list = [] # validation
    val_pred_array = []
    val_filename_array = []
    model_state_list = []
    train_loss_list = [] # train
    train_acc_list = [] # train

    # 5-fold loop
    for i in range(num_folds):
        # intialise the model class
        model = RNN(input_size=128, 
                    hidden_size=hidden_size, 
                    num_layers=num_layers, 
                    num_classes=len(labels), 
                    device=device, 
                    classes=labels,
                    drop_flag=drop_flag, drop=drop).to(device)
        print(model)
        print()

        # fit the model for training
        val_loss, val_acc, val_pred_list, val_filename_list, train_loss, train_acc = fit(model=model, 
                                                                                         train_loader=train_loader_list[i], 
                                                                                         valid_loader=valid_loader_list[i], 
                                                                                         num_epochs=epochs, 
                                                                                         fold_num=i+1, 
                                                                                         optim_flag=optim_flag)
        loss_list.append(val_loss)
        acc_list.append(val_acc)
        val_pred_array.append(val_pred_list)
        val_filename_array.append(val_filename_list)
        model_state_list.append(model)
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)

    return loss_list, acc_list, val_pred_array, val_filename_array, model_state_list, train_loss_list, train_acc_list

# ----- CHECK BEST FOLD BASED ON VALIDATION ACCURACY AND SAVE BEST FOLD MODEL -----
def save_best_fold(loss_list, acc_list, model_state_list, train_loss_list, train_acc_list, filename):
    # ----- CHECK THE BEST FOLD MODEL BASED ON MODEL VALIDATION ACCURACY -----
    print(f'Train Losses: {train_loss_list}')
    print(f'Train Accuracies: {train_acc_list}')
    print(f'Validation Losses: {loss_list}')
    print(f'Validation Accuracies: {acc_list}')
    best_fold_index = acc_list.index(max(acc_list))
    print(f'Best fold: {best_fold_index+1}')

    # ----- SAVE THE BEST FOLD MODEL -----
    torch.save(model_state_list[best_fold_index].state_dict(), f'{COLAB_FILEPATH}model/model-{filename}.pt')  
    print(f'Model Saved for Fold {best_fold_index+1}')
    return best_fold_index

# ----- F1 & CONFUSION MATRIX -----
def metrics_helper(val_list, val_filename_array, val_pred_array, best_fold_index, filename):
    # ----- F1-Score Analysis -----
    # get the pred and filename
    val_tuple = list(zip(val_filename_array[best_fold_index], val_pred_array[best_fold_index]))
    val_df = pd.DataFrame(val_tuple, columns=['val_filename', 'val_label_pred_num'])
    val_df['val_label_pred'] = val_df['val_label_pred_num'].apply(lambda x: labels[x])
    #val_df.head()

    # make a combined data frame by iteratively appending the values to a list
    val_filename_list_final = []
    val_true_list = []
    for i in range(len(val_list[best_fold_index])):
        val_filename_list_final.append(val_list[best_fold_index][i][0])
        val_true_list.append(val_list[best_fold_index][i][3])

    # make to dataframe
    val_tuple_final = list(zip(val_filename_list_final, val_true_list))
    #print(result_tuple)
    val_df_final = pd.DataFrame(val_tuple_final, columns=['val_filename', 'val_label_true'])
    #val_df_final.head()
    # append the predicted column into the final dataframe
    val_df_final['val_label_pred'] = val_df['val_label_pred']
    #val_df_final.head(3)

    # save the table to csv
    val_df_final.to_csv(f"{COLAB_FILEPATH}f1-table/f1-{filename}.csv", index=False)

    # import the csv back again
    #val_df_final = pd.read_csv(f"{COLAB_FILEPATH}f1-table/f1-{filename}.csv")
    #val_df_final.head()

    # simple check if length of data are equal
    assert len(val_df_final["val_label_true"]) == len(val_df_final["val_label_pred"])

    # get the multi-class F1-score to see the distribution of the predictions
    print(classification_report(list(val_df_final['val_label_true']), list(val_df_final['val_label_pred']), target_names=labels, digits=4))
    print()

    # confusion matrix
    cm_sns = pd.crosstab(val_df_final['val_label_true'], val_df_final['val_label_pred'], rownames=['Actual'], colnames=['Predicted'])
    plt.subplots(figsize=(12,10))
    sns.heatmap(cm_sns, annot=True, fmt="d", cmap='YlGnBu_r')
    plt.show()

# %% [markdown]
# ## CONFIGURATION 1
# - Hidden Size: 256
# - Number of layers: 4
# - Batch Size: 32
# - Optimizer: Adagrad
# - Epoch: 30
# - Dropout: 0.3

# %%
# ----- DECLARE HYPERPARAMETERS -----
HIDDEN_SIZE, NUM_LAYERS, BATCH_SIZE, OPTIM_NAME, EPOCHS, DROP_FLAG, DROPOUT = 256, 4, 32, 'adagrad', 30, True, 0.3
DR = f'_drop-{DROPOUT}' if DROP_FLAG == True else ''

# ----- EXPORTED FILENAME -----
FILENAME = f'double_extra_SC2_noise_HS-{HIDDEN_SIZE}_NL-{NUM_LAYERS}_BS-{BATCH_SIZE}_OP-{OPTIM_NAME}_EP-{EPOCHS}{DR}_TFS1-{TM1}-{FM1}-{SIGMA1}_TFS2-{TM2}-{FM2}-{SIGMA2}'
print(f'Filename: {FILENAME}\n')

# ----- TRAINING THE K-FOLD MODEL -----
loss_list, acc_list, val_pred_array, val_filename_array, model_state_list, train_loss_list, train_acc_list = train_helper(num_folds=K, 
                                                                                                                          train_list=train_list, 
                                                                                                                          val_list=val_list, 
                                                                                                                          batch_size=BATCH_SIZE, 
                                                                                                                          hidden_size=HIDDEN_SIZE, 
                                                                                                                          num_layers=NUM_LAYERS, 
                                                                                                                          epochs=EPOCHS, 
                                                                                                                          optim_flag=OPTIM_NAME,
                                                                                                                          drop_flag=DROP_FLAG, 
                                                                                                                          drop=DROPOUT)
# Out:
# Filename: double_extra_SC2_noise_HS-256_NL-4_BS-32_OP-adagrad_EP-30_drop-0.3_TFS1-5-9-0.7_TFS2-5-5-1.2
#
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 1 ----------
# Epoch [1/30]: Train loss = 3.3006, Train accuracy = 4.50, Valid loss = 3.1460, Valid accuracy = 4.55
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 2.9828, Train accuracy = 6.92, Valid loss = 3.3756, Valid accuracy = 8.77
# Time taken for Epoch 2: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [3/30]: Train loss = 1.7839, Train accuracy = 21.24, Valid loss = 2.4953, Valid accuracy = 35.52
# Time taken for Epoch 3: 0m 21s
# Epoch [5/30]: Train loss = 0.7988, Train accuracy = 65.49, Valid loss = 0.5497, Valid accuracy = 73.57
# Time taken for Epoch 5: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [10/30]: Train loss = 0.6343, Train accuracy = 86.18, Valid loss = 0.1906, Valid accuracy = 83.51
# Time taken for Epoch 10: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.6724, Train accuracy = 91.30, Valid loss = 0.0121, Valid accuracy = 87.14
# Time taken for Epoch 15: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [20/30]: Train loss = 0.0849, Train accuracy = 94.26, Valid loss = 0.0183, Valid accuracy = 88.70
# Time taken for Epoch 20: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.1756, Train accuracy = 95.47, Valid loss = 0.0042, Valid accuracy = 88.38
# Time taken for Epoch 25: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.1048, Train accuracy = 96.61, Valid loss = 0.0180, Valid accuracy = 89.09
# Time taken for Epoch 30: 0m 20s
# Validation Loss did not improve count: 2
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 2 ----------
# Epoch [1/30]: Train loss = 2.8158, Train accuracy = 4.85, Valid loss = 2.8730, Valid accuracy = 7.86
# Time taken for Epoch 1: 0m 21s
# Epoch [2/30]: Train loss = 2.8741, Train accuracy = 13.12, Valid loss = 2.1185, Valid accuracy = 8.25
# Time taken for Epoch 2: 0m 21s
# Epoch [3/30]: Train loss = 1.4405, Train accuracy = 33.94, Valid loss = 1.8088, Valid accuracy = 48.12
# Time taken for Epoch 3: 0m 20s
# Epoch [5/30]: Train loss = 1.2779, Train accuracy = 71.40, Valid loss = 1.1417, Valid accuracy = 70.52
# Time taken for Epoch 5: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [10/30]: Train loss = 0.2654, Train accuracy = 87.48, Valid loss = 0.0175, Valid accuracy = 85.13
# Time taken for Epoch 10: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [15/30]: Train loss = 0.0926, Train accuracy = 92.14, Valid loss = 0.0019, Valid accuracy = 87.79
# Time taken for Epoch 15: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [20/30]: Train loss = 0.2335, Train accuracy = 94.84, Valid loss = 0.0011, Valid accuracy = 89.16
# Time taken for Epoch 20: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.1241, Train accuracy = 96.08, Valid loss = 0.0039, Valid accuracy = 88.51
# Time taken for Epoch 25: 0m 20s
# Epoch    25: reducing learning rate of group 0 to 5.0000e-04.
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.0888, Train accuracy = 97.24, Valid loss = 0.0007, Valid accuracy = 89.74
# Time taken for Epoch 30: 0m 20s
# Validation Loss did not improve count: 1
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 3 ----------
# Epoch [1/30]: Train loss = 3.1195, Train accuracy = 4.73, Valid loss = 3.0982, Valid accuracy = 4.55
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 3.1667, Train accuracy = 4.70, Valid loss = 3.1385, Valid accuracy = 4.87
# Time taken for Epoch 2: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [3/30]: Train loss = 2.8647, Train accuracy = 7.98, Valid loss = 2.5647, Valid accuracy = 13.25
# Time taken for Epoch 3: 0m 21s
# Epoch [5/30]: Train loss = 1.3362, Train accuracy = 38.48, Valid loss = 1.0640, Valid accuracy = 56.82
# Time taken for Epoch 5: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [10/30]: Train loss = 0.4396, Train accuracy = 83.61, Valid loss = 1.3215, Valid accuracy = 80.45
# Time taken for Epoch 10: 0m 21s
# Validation Loss did not improve count: 1
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [15/30]: Train loss = 0.0809, Train accuracy = 91.32, Valid loss = 0.8024, Valid accuracy = 87.27
# Time taken for Epoch 15: 0m 20s
# Epoch    17: reducing learning rate of group 0 to 2.5000e-05.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [20/30]: Train loss = 0.4117, Train accuracy = 91.64, Valid loss = 0.6111, Valid accuracy = 86.75
# Time taken for Epoch 20: 0m 21s
# Epoch    21: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.1041, Train accuracy = 91.97, Valid loss = 1.0392, Valid accuracy = 87.01
# Time taken for Epoch 25: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.2595, Train accuracy = 91.66, Valid loss = 1.0565, Valid accuracy = 87.01
# Time taken for Epoch 30: 0m 21s
# Validation Loss did not improve count: 2
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 4 ----------
# Epoch [1/30]: Train loss = 2.9389, Train accuracy = 5.61, Valid loss = 2.5122, Valid accuracy = 12.14
# Time taken for Epoch 1: 0m 21s
# Epoch [2/30]: Train loss = 1.8235, Train accuracy = 20.30, Valid loss = 0.8719, Valid accuracy = 36.95
# Time taken for Epoch 2: 0m 21s
# Epoch [3/30]: Train loss = 0.9634, Train accuracy = 50.80, Valid loss = 0.7529, Valid accuracy = 58.64
# Time taken for Epoch 3: 0m 21s
# Epoch [5/30]: Train loss = 0.8866, Train accuracy = 77.45, Valid loss = 0.0401, Valid accuracy = 79.16
# Time taken for Epoch 5: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [10/30]: Train loss = 0.4525, Train accuracy = 89.57, Valid loss = 0.0054, Valid accuracy = 87.08
# Time taken for Epoch 10: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.2316, Train accuracy = 93.47, Valid loss = 0.0029, Valid accuracy = 87.73
# Time taken for Epoch 15: 0m 21s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.2871, Train accuracy = 96.33, Valid loss = 0.0020, Valid accuracy = 89.42
# Time taken for Epoch 20: 0m 19s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.0283, Train accuracy = 96.31, Valid loss = 0.0030, Valid accuracy = 89.29
# Time taken for Epoch 25: 0m 22s
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.1198, Train accuracy = 96.83, Valid loss = 0.0016, Valid accuracy = 89.29
# Time taken for Epoch 30: 0m 21s
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 5 ----------
# Epoch [1/30]: Train loss = 3.2668, Train accuracy = 4.94, Valid loss = 3.2038, Valid accuracy = 4.55
# Time taken for Epoch 1: 0m 21s
# Epoch [2/30]: Train loss = 3.0733, Train accuracy = 4.26, Valid loss = 3.0403, Valid accuracy = 4.55
# Time taken for Epoch 2: 0m 21s
# Epoch [3/30]: Train loss = 3.1719, Train accuracy = 4.02, Valid loss = 3.1791, Valid accuracy = 4.55
# Time taken for Epoch 3: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [5/30]: Train loss = 3.1481, Train accuracy = 4.47, Valid loss = 3.1156, Valid accuracy = 4.55
# Time taken for Epoch 5: 0m 19s
# Validation Loss did not improve count: 1
# Epoch [10/30]: Train loss = 0.3696, Train accuracy = 72.44, Valid loss = 1.4903, Valid accuracy = 79.74
# Time taken for Epoch 10: 0m 19s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.2709, Train accuracy = 86.58, Valid loss = 0.4912, Valid accuracy = 85.58
# Time taken for Epoch 15: 0m 19s
# Validation Loss did not improve count: 1
# Epoch    19: reducing learning rate of group 0 to 5.0000e-04.
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.1641, Train accuracy = 92.29, Valid loss = 0.8123, Valid accuracy = 87.66
# Time taken for Epoch 20: 0m 19s
# Validation Loss did not improve count: 1
# Epoch    23: reducing learning rate of group 0 to 2.5000e-05.
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.4077, Train accuracy = 93.91, Valid loss = 1.1080, Valid accuracy = 88.38
# Time taken for Epoch 25: 0m 19s
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 3
# Epoch    27: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.1846, Train accuracy = 93.39, Valid loss = 0.9343, Valid accuracy = 88.44
# Time taken for Epoch 30: 0m 19s

# %%
# ----- SAVE THE BEST FOLD MODEL -----
best_fold_index = save_best_fold(loss_list, acc_list, model_state_list, train_loss_list, train_acc_list, FILENAME)

# ----- GET THE F1 SCORE AND CONFUSION MATRIX -----
metrics_helper(val_list, val_filename_array, val_pred_array, best_fold_index, FILENAME)
# Out:
# Train Losses: [0.10480063408613205, 0.08876767009496689, 0.2594907581806183, 0.11981599032878876, 0.1845794916152954]
# Train Accuracies: [96.60714285714286, 97.24025974025975, 91.66396103896103, 96.8344155844156, 93.39285714285714]
# Validation Losses: [0.01803707331418991, 0.0006580117624253035, 1.05647873878479, 0.0015715818153694272, 0.9342740178108215]
# Validation Accuracies: [89.0909090909091, 89.74025974025975, 87.01298701298701, 89.28571428571429, 88.44155844155844]
# Best fold: 2
# Model Saved for Fold 2
#               precision    recall  f1-score   support
#
#         bird     0.8750    0.8000    0.8358        70
#          cat     0.8000    0.8571    0.8276        70
#      chicken     0.9855    0.9714    0.9784        70
#          dog     0.8261    0.8143    0.8201        70
#         down     0.9000    0.9000    0.9000        70
#        eight     0.9296    0.9429    0.9362        70
#       falcon     0.9420    0.9286    0.9353        70
#         five     0.9545    0.9000    0.9265        70
#         four     0.9000    0.9000    0.9000        70
#           go     0.7662    0.8429    0.8027        70
#         left     0.9375    0.8571    0.8955        70
#         nine     0.9552    0.9143    0.9343        70
#          one     0.9104    0.8714    0.8905        70
#        right     0.8784    0.9286    0.9028        70
#        seven     0.9531    0.8714    0.9104        70
#          six     0.9420    0.9286    0.9353        70
#        snake     0.9079    0.9857    0.9452        70
#         stop     0.8767    0.9143    0.8951        70
#        three     0.9118    0.8857    0.8986        70
#          two     0.8750    0.9000    0.8873        70
#           up     0.8267    0.8857    0.8552        70
#         zero     0.9296    0.9429    0.9362        70
#
#     accuracy                         0.8974      1540
#    macro avg     0.8992    0.8974    0.8977      1540
# weighted avg     0.8992    0.8974    0.8977      1540

# %% [markdown]
# ## CONFIGURATION 2
# - Hidden Size: 256
# - Number of layers: 4
# - Batch Size: 32
# - Optimizer: Adam
# - Epoch: 30
# - Dropout: 0.3

# %%
# ----- DECLARE HYPERPARAMETERS -----
HIDDEN_SIZE, NUM_LAYERS, BATCH_SIZE, OPTIM_NAME, EPOCHS, DROP_FLAG, DROPOUT = 256, 4, 32, 'adam', 30, True, 0.3
DR = f'_drop-{DROPOUT}' if DROP_FLAG == True else ''

# ----- EXPORTED FILENAME -----
FILENAME = f'double_extra_SC2_noise_HS-{HIDDEN_SIZE}_NL-{NUM_LAYERS}_BS-{BATCH_SIZE}_OP-{OPTIM_NAME}_EP-{EPOCHS}{DR}_TFS1-{TM1}-{FM1}-{SIGMA1}_TFS2-{TM2}-{FM2}-{SIGMA2}'
print(f'Filename: {FILENAME}\n')

# ----- TRAINING THE K-FOLD MODEL -----
loss_list, acc_list, val_pred_array, val_filename_array, model_state_list, train_loss_list, train_acc_list = train_helper(num_folds=K, 
                                                                                                                          train_list=train_list, 
                                                                                                                          val_list=val_list, 
                                                                                                                          batch_size=BATCH_SIZE, 
                                                                                                                          hidden_size=HIDDEN_SIZE, 
                                                                                                                          num_layers=NUM_LAYERS, 
                                                                                                                          epochs=EPOCHS, 
                                                                                                                          optim_flag=OPTIM_NAME,
                                                                                                                          drop_flag=DROP_FLAG, 
                                                                                                                          drop=DROPOUT)
# Out:
# Filename: double_extra_SC2_noise_HS-256_NL-4_BS-32_OP-adam_EP-30_drop-0.3_TFS1-5-9-0.7_TFS2-5-5-1.2
#
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 1 ----------
# Epoch [1/30]: Train loss = 2.3755, Train accuracy = 14.24, Valid loss = 2.3540, Valid accuracy = 37.79
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 1.0264, Train accuracy = 48.63, Valid loss = 0.4494, Valid accuracy = 68.96
# Time taken for Epoch 2: 0m 20s
# Epoch [3/30]: Train loss = 0.6455, Train accuracy = 67.93, Valid loss = 0.7611, Valid accuracy = 76.10
# Time taken for Epoch 3: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [5/30]: Train loss = 0.7944, Train accuracy = 79.15, Valid loss = 0.5509, Valid accuracy = 80.52
# Time taken for Epoch 5: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [10/30]: Train loss = 0.4021, Train accuracy = 87.62, Valid loss = 0.0171, Valid accuracy = 86.95
# Time taken for Epoch 10: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.6445, Train accuracy = 90.74, Valid loss = 0.0543, Valid accuracy = 85.65
# Time taken for Epoch 15: 0m 21s
# Validation Loss did not improve count: 1
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.2760, Train accuracy = 96.10, Valid loss = 0.0029, Valid accuracy = 89.55
# Time taken for Epoch 20: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.0182, Train accuracy = 97.08, Valid loss = 0.0083, Valid accuracy = 90.00
# Time taken for Epoch 25: 0m 21s
# Validation Loss did not improve count: 1
# Epoch    27: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.1160, Train accuracy = 97.63, Valid loss = 0.0058, Valid accuracy = 89.42
# Time taken for Epoch 30: 0m 21s
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 2 ----------
# Epoch [1/30]: Train loss = 1.6322, Train accuracy = 13.64, Valid loss = 1.7827, Valid accuracy = 30.13
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 2.1008, Train accuracy = 48.45, Valid loss = 1.7213, Valid accuracy = 67.92
# Time taken for Epoch 2: 0m 21s
# Epoch [3/30]: Train loss = 1.5691, Train accuracy = 69.03, Valid loss = 0.2294, Valid accuracy = 74.94
# Time taken for Epoch 3: 0m 21s
# Epoch [5/30]: Train loss = 0.5506, Train accuracy = 80.55, Valid loss = 0.0248, Valid accuracy = 80.00
# Time taken for Epoch 5: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 3
# Epoch     8: reducing learning rate of group 0 to 5.0000e-05.
# Validation Loss did not improve count: 4
# Epoch [10/30]: Train loss = 0.1394, Train accuracy = 91.59, Valid loss = 0.0026, Valid accuracy = 88.44
# Time taken for Epoch 10: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [15/30]: Train loss = 0.0865, Train accuracy = 93.65, Valid loss = 0.0015, Valid accuracy = 88.96
# Time taken for Epoch 15: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch    18: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.1879, Train accuracy = 94.68, Valid loss = 0.0020, Valid accuracy = 89.29
# Time taken for Epoch 20: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.1019, Train accuracy = 94.86, Valid loss = 0.0044, Valid accuracy = 87.79
# Time taken for Epoch 25: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [30/30]: Train loss = 0.0833, Train accuracy = 95.26, Valid loss = 0.0027, Valid accuracy = 89.48
# Time taken for Epoch 30: 0m 20s
# Validation Loss did not improve count: 3
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 3 ----------
# Epoch [1/30]: Train loss = 2.4655, Train accuracy = 12.36, Valid loss = 2.3168, Valid accuracy = 28.18
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 1.0789, Train accuracy = 44.45, Valid loss = 1.4051, Valid accuracy = 62.79
# Time taken for Epoch 2: 0m 20s
# Epoch [3/30]: Train loss = 0.8967, Train accuracy = 66.75, Valid loss = 0.8030, Valid accuracy = 69.55
# Time taken for Epoch 3: 0m 20s
# Epoch [5/30]: Train loss = 0.7849, Train accuracy = 79.15, Valid loss = 0.7511, Valid accuracy = 79.74
# Time taken for Epoch 5: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch     8: reducing learning rate of group 0 to 5.0000e-05.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch [10/30]: Train loss = 0.2968, Train accuracy = 91.84, Valid loss = 0.6798, Valid accuracy = 88.90
# Time taken for Epoch 10: 0m 20s
# Validation Loss did not improve count: 1
# Epoch    12: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 2
# Epoch [15/30]: Train loss = 0.2208, Train accuracy = 93.16, Valid loss = 0.5192, Valid accuracy = 89.09
# Time taken for Epoch 15: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.3518, Train accuracy = 93.34, Valid loss = 0.7297, Valid accuracy = 89.22
# Time taken for Epoch 20: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.3151, Train accuracy = 93.53, Valid loss = 0.2528, Valid accuracy = 88.90
# Time taken for Epoch 25: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.6598, Train accuracy = 93.79, Valid loss = 1.0363, Valid accuracy = 88.57
# Time taken for Epoch 30: 0m 20s
# Validation Loss did not improve count: 2
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 4 ----------
# Epoch [1/30]: Train loss = 2.3041, Train accuracy = 13.19, Valid loss = 2.0779, Valid accuracy = 33.38
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 1.1264, Train accuracy = 47.13, Valid loss = 0.4767, Valid accuracy = 63.77
# Time taken for Epoch 2: 0m 20s
# Epoch [3/30]: Train loss = 0.7916, Train accuracy = 68.89, Valid loss = 0.1937, Valid accuracy = 76.23
# Time taken for Epoch 3: 0m 20s
# Epoch [5/30]: Train loss = 0.4789, Train accuracy = 80.15, Valid loss = 0.0299, Valid accuracy = 80.58
# Time taken for Epoch 5: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [10/30]: Train loss = 0.0250, Train accuracy = 87.65, Valid loss = 0.0063, Valid accuracy = 86.10
# Time taken for Epoch 10: 0m 20s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-05.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.3273, Train accuracy = 94.79, Valid loss = 0.0025, Valid accuracy = 89.55
# Time taken for Epoch 15: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Epoch    19: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [20/30]: Train loss = 0.2146, Train accuracy = 96.00, Valid loss = 0.0034, Valid accuracy = 90.45
# Time taken for Epoch 20: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.0584, Train accuracy = 96.03, Valid loss = 0.0014, Valid accuracy = 89.94
# Time taken for Epoch 25: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.0056, Train accuracy = 96.35, Valid loss = 0.0022, Valid accuracy = 89.74
# Time taken for Epoch 30: 0m 20s
# RNN(
#   (gru): GRU(128, 256, num_layers=4, batch_first=True, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=22, bias=True)
# )
#
# ---------- Fold Number: 5 ----------
# Epoch [1/30]: Train loss = 2.1601, Train accuracy = 14.20, Valid loss = 2.8557, Valid accuracy = 27.47
# Time taken for Epoch 1: 0m 20s
# Epoch [2/30]: Train loss = 0.9462, Train accuracy = 48.47, Valid loss = 0.8457, Valid accuracy = 67.08
# Time taken for Epoch 2: 0m 20s
# Epoch [3/30]: Train loss = 0.6201, Train accuracy = 69.15, Valid loss = 3.0449, Valid accuracy = 73.96
# Time taken for Epoch 3: 0m 20s
# Validation Loss did not improve count: 1
# Epoch [5/30]: Train loss = 0.8762, Train accuracy = 79.21, Valid loss = 1.7036, Valid accuracy = 84.48
# Time taken for Epoch 5: 0m 21s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [10/30]: Train loss = 0.5820, Train accuracy = 87.84, Valid loss = 0.5611, Valid accuracy = 87.60
# Time taken for Epoch 10: 0m 22s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-05.
# Validation Loss did not improve count: 1
# Epoch [15/30]: Train loss = 0.1431, Train accuracy = 94.19, Valid loss = 0.3101, Valid accuracy = 90.58
# Time taken for Epoch 15: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [20/30]: Train loss = 0.3319, Train accuracy = 95.36, Valid loss = 0.2045, Valid accuracy = 89.68
# Time taken for Epoch 20: 0m 20s
# Epoch    20: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 1
# Epoch [25/30]: Train loss = 0.0999, Train accuracy = 95.83, Valid loss = 0.1417, Valid accuracy = 90.06
# Time taken for Epoch 25: 0m 20s
# Validation Loss did not improve count: 1
# Validation Loss did not improve count: 2
# Validation Loss did not improve count: 1
# Epoch [30/30]: Train loss = 0.1453, Train accuracy = 95.90, Valid loss = 0.1335, Valid accuracy = 91.10
# Time taken for Epoch 30: 0m 20s

# %%
# ----- SAVE THE BEST FOLD MODEL -----
best_fold_index = save_best_fold(loss_list, acc_list, model_state_list, train_loss_list, train_acc_list, FILENAME)

# ----- GET THE F1 SCORE AND CONFUSION MATRIX -----
metrics_helper(val_list, val_filename_array, val_pred_array, best_fold_index, FILENAME)
# Out:
# Train Losses: [0.11595775932073593, 0.08325725793838501, 0.6597891449928284, 0.005640516523271799, 0.14533743262290955]
# Train Accuracies: [97.62987012987013, 95.25974025974025, 93.7905844155844, 96.34740259740259, 95.90097402597402]
# Validation Losses: [0.005815674085170031, 0.0027095319237560034, 1.0363404750823975, 0.0022024093195796013, 0.13347385823726654]
# Validation Accuracies: [89.41558441558442, 89.48051948051948, 88.57142857142857, 89.74025974025975, 91.1038961038961]
# Best fold: 5
# Model Saved for Fold 5
#               precision    recall  f1-score   support
#
#         bird     0.8816    0.9571    0.9178        70
#          cat     0.9265    0.9000    0.9130        70
#      chicken     0.9714    0.9714    0.9714        70
#          dog     0.8971    0.8714    0.8841        70
#         down     0.9000    0.9000    0.9000        70
#        eight     0.9143    0.9143    0.9143        70
#       falcon     0.9429    0.9429    0.9429        70
#         five     0.9254    0.8857    0.9051        70
#         four     0.9565    0.9429    0.9496        70
#           go     0.7349    0.8714    0.7974        70
#         left     0.9683    0.8714    0.9173        70
#         nine     0.8971    0.8714    0.8841        70
#          one     0.8714    0.8714    0.8714        70
#        right     0.9538    0.8857    0.9185        70
#        seven     0.9706    0.9429    0.9565        70
#          six     0.9571    0.9571    0.9571        70
#        snake     0.9067    0.9714    0.9379        70
#         stop     0.9559    0.9286    0.9420        70
#        three     0.8873    0.9000    0.8936        70
#          two     0.8615    0.8000    0.8296        70
#           up     0.8961    0.9857    0.9388        70
#         zero     0.9130    0.9000    0.9065        70
#
#     accuracy                         0.9110      1540
#    macro avg     0.9132    0.9110    0.9113      1540
# weighted avg     0.9132    0.9110    0.9113      1540

# %% [markdown]
# ## Test Set

# %%
# THIS TEST SET MIGHT BE WRONG
#!gdown --id 1AvP49xengGjnFTG209AgvAGj-by8WGSi
#!unzip -q -o s1_test.zip

# %%
# THIS TEST SET IS CORRECT
# !unzip -q -o './drive/My Drive/TIL2021/competition/SC/challenge_4_test_dataset.zip' -d "./content/"

# %%
# Initialise dataset object for test set
#test_set = CustomSpeechDataset(path='s1_test', typ='test')
test_set = CustomSpeechDataset(path='./content/challenge_4_test_dataset', typ='test')

# %% [markdown]
# ## Load back any model that was saved earlier

# %%
# ----- MODEL CONFIGURATION -----

HIDDEN_SIZE = 256 #256
NUM_LAYERS = 4 #2
BATCH_SIZE = 32 #64
OPTIM_NAME = 'adam' #'adam'
EPOCHS = 30 #30
DROP_FLAG = True #False
DROPOUT = 0.3 #0.5

DR = f'_drop-{DROPOUT}' if DROP_FLAG == True else ''

# ----- EXPORTED FILENAME -----
FILENAME = f'double_extra_SC2_noise_HS-{HIDDEN_SIZE}_NL-{NUM_LAYERS}_BS-{BATCH_SIZE}_OP-{OPTIM_NAME}_EP-{EPOCHS}{DR}_TFS1-{TM1}-{FM1}-{SIGMA1}_TFS2-{TM2}-{FM2}-{SIGMA2}'


# ----- LOAD BACK THE MODEL -----
model = RNN(input_size=128, 
            hidden_size=HIDDEN_SIZE, 
            num_layers=NUM_LAYERS, 
            num_classes=len(labels), 
            device=device, 
            classes=labels, 
            drop_flag=DROP_FLAG, 
            drop=DROPOUT).to(device)

print(model.load_state_dict(torch.load(f'{COLAB_FILEPATH}model/model-{FILENAME}.pt')))
print(f'Loaded filepath: {COLAB_FILEPATH}model/model-{FILENAME}.pt')
# Out:
# <All keys matched successfully>
# Loaded filepath: ./drive/My Drive/TIL2021/competition/SC/model/model-double_extra_SC2_noise_HS-256_NL-4_BS-32_OP-adam_EP-30_drop-0.3_TFS1-5-9-0.7_TFS2-5-5-1.2.pt

# %% [markdown]
# ## Test the model with the test set

# %%
# define test collate function and set up test loader

def test_collate_fn(batch):

    # A data tuple has the form:
    # filename, waveform, sample_rate

    tensors, filenames = [], []

    # Gather in lists
    for filename, waveform, sample_rate in batch:
        # apply transformations
        for transform in eval_transformations:
            waveform = transform(waveform)
        waveform = waveform.squeeze().T
        tensors += [waveform]
        filenames += [filename]

    # Group the list of tensors into a batched tensor
    tensors = torch.stack(tensors)

    return (tensors, filenames)

test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=64,
    shuffle=False,
    drop_last=False,
    collate_fn=test_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
)

# %%
# pass test set through the RNN model
model.eval()
pred_list, filename_list = [], []
with torch.no_grad():
  for idx, (features, filenames) in enumerate(test_loader):

    features = features.to(device)

    # forward pass
    outputs = model(features)

    # test results
    _, argmax = torch.max(outputs, 1)
    pred_list += argmax.cpu().tolist()
    filename_list += filenames

# %%
print(pred_list[:5]) 
print(filename_list[:5])
# Out:
# [20, 3, 19, 3, 20]
# ['challenge_4_test_0441.wav', 'challenge_4_test_0121.wav', 'challenge_4_test_1074.wav', 'challenge_4_test_1408.wav', 'challenge_4_test_0654.wav']

# %% [markdown]
# ## Submission of Results
# Submission csv file should contain only 2 columns for filename and label, in that order. The file should be sorted by filename, and exclude headers.
#
# Refer to **sample_submission.csv** for an example.

# %%
result_tuple = list(zip(filename_list, pred_list))
#print(result_tuple)
submission = pd.DataFrame(result_tuple, columns=['filename', 'pred'])
submission = submission.sort_values('filename').reset_index(drop=True)
submission['label'] = submission['pred'].apply(lambda x: labels[x])

# %%
submission[['filename', 'label']].head()
# Out:
#                     filename  label
# 0  challenge_4_test_0000.wav   bird
# 1  challenge_4_test_0001.wav   five
# 2  challenge_4_test_0002.wav   bird
# 3  challenge_4_test_0004.wav  right
# 4  challenge_4_test_0005.wav     go

# %%
submission["label"].value_counts()
# Out:
# bird       179
# go         158
# right      102
# five        97
# up          83
# cat         83
# two         72
# eight       67
# four        67
# falcon      67
# dog         63
# chicken     47
# snake       47
# zero        46
# six         45
# seven       41
# stop        39
# three       38
# left        27
# nine        22
# down        19
# one         15
# Name: label, dtype: int64

# %%
submission[['filename', 'label']].to_csv(f'{COLAB_FILEPATH}submission/submission-{FILENAME}-1.csv', header=None, index=None)
